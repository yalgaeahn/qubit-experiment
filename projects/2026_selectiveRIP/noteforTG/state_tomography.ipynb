# %% [markdown]
# # Init

# %%
# %run ../scripts/bootstrap_notebook.py

import importlib
import sys
from copy import deepcopy
from datetime import datetime
from pathlib import Path
from pprint import pprint

import laboneq.dsl.quantum.qpu as qpu_mod
import numpy as np
from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
from laboneq.dsl.calibration import Oscillator, SignalCalibration
from laboneq.dsl.device import DeviceSetup
from laboneq.dsl.enums import ModulationType
from laboneq.serializers import load
from laboneq.simple import *

repo_root = PROJECT_ROOT

# descriptor = generate_descriptor(
#     #pqsc=[""], # 장비 여러개 사용시
#     shfqc_6=["DEV12256"],
#     number_data_qubits=3,
#     multiplex=True,
#     number_multiplex=6,
#     include_cr_lines=False,
#     include_ef_lines=True,
#     get_zsync=False,  # Only set to True when using real device
#     save=True,
#     filename="1port",
#     ip_address="192.168.0.83",
# )

# descriptor
# setup = DeviceSetup.from_descriptor(yaml_text=descriptor, server_host="192.168.0.83")
descriptor_candidates = [
    repo_root / "configs" / "descriptors" / "1port.yaml",
    Path("../configs/descriptors/1port.yaml"),
    Path("configs/descriptors/1port.yaml"),
]
descriptor_path = next((p for p in descriptor_candidates if p.exists()), descriptor_candidates[0])
setup = DeviceSetup.from_yaml(filepath=str(descriptor_path.resolve()), server_host="192.168.0.83")
setup.instruments[0].device_options = "SHFQC/PLUS/QC6CH"

bus_ids = [f"b{i}" for i in range(3)]
bus_port = [3, 4, 5]  # used 1,2,3 for qubit drive

for i, bus in zip(bus_port, bus_ids):
    setup.add_connections(
        setup.instruments[0].uid,
        # each bus uses its own drive:
        create_connection(
            to_signal=f"{bus}/drive",
            ports=f"SGCHANNELS/{i}/OUTPUT",
        ),
    )

# Calibrate qubit drive/measure lines for oscillator phase increments
qubit_ids = [uid for uid in setup.logical_signal_groups if uid.startswith("q")]
for qubit in qubit_ids:
    for line, frequency, mod_type in [
        ("drive", 5e9, ModulationType.HARDWARE),
        ("drive_ef", 6e9, ModulationType.HARDWARE),
        ("measure", 4e9, ModulationType.SOFTWARE),
    ]:
        logical_signal = setup.logical_signal_by_uid(f"{qubit}/{line}")
        oscillator = Oscillator(modulation_type=mod_type)
        logical_signal.calibration = SignalCalibration(
            local_oscillator=Oscillator(frequency=frequency),
            oscillator=oscillator,
        )
        if line == "measure":
            acquire_signal = setup.logical_signal_by_uid(f"{qubit}/acquire")
            acquire_signal.calibration = SignalCalibration(
                local_oscillator=Oscillator(frequency=frequency),
                oscillator=oscillator,
            )

from qubit_experiment.qpu_types.fixed_transmon import (
    FixedTransmonQubit,
    FixedTransmonQubitParameters,
)
from qubit_experiment.qpu_types.bus_cavity import BusCavity, BusCavityParameters
from qubit_experiment.qpu_types.fixed_transmon.operations import FixedTransmonOperations
from qubit_experiment.qpu_types.bus_cavity.operations import BusCavityOperations
from laboneq.dsl.quantum.qpu import QPU, QuantumPlatform
from qubit_experiment.helper import load_qubit_parameters, save_qubit_parameters

qubit_uids = [uid for uid in setup.logical_signal_groups if uid.startswith("q")]
bus_uids = [uid for uid in setup.logical_signal_groups if uid.startswith("b")]

qubits = FixedTransmonQubit.from_device_setup(setup, qubit_uids=qubit_uids)
buses = BusCavity.from_device_setup(setup, qubit_uids=bus_uids)

qpu = QPU(
    quantum_elements={"qubits": qubits, "bus": buses},
    quantum_operations=[FixedTransmonOperations, BusCavityOperations],
)


def find_latest_json(folder_path: Path) -> Path | None:
    timestamps = []
    for candidate in folder_path.iterdir():
        try:
            timestamp_str = candidate.name.split("_", 1)[0]
            timestamp = datetime.strptime(timestamp_str, "%Y%m%d-%H%M%S")
            timestamps.append((timestamp, candidate))
        except ValueError:
            continue

    if timestamps:
        return max(timestamps, key=lambda item: item[0])[1]
    return None


qb_pars_file = find_latest_json(repo_root / "qpu_parameters")
if qb_pars_file is None:
    raise FileNotFoundError(f"No qpu_parameters snapshot found under {repo_root / 'qpu_parameters'}")
print(f"LOADED: {qb_pars_file}")


class CombinedOperations(FixedTransmonOperations, BusCavityOperations):
    pass


qpu_mod.CombinedOperations = CombinedOperations

# Backward-compatibility aliases for legacy serialized qpu_parameters snapshots.
for legacy_name, canonical_name in {
    "qpu_types": "qubit_experiment.qpu_types",
    "qpu_types.fixed_transmon": "qubit_experiment.qpu_types.fixed_transmon",
    "qpu_types.fixed_transmon.qubit_types": "qubit_experiment.qpu_types.fixed_transmon.qubit_types",
    "qpu_types.fixed_transmon.operations": "qubit_experiment.qpu_types.fixed_transmon.operations",
    "qpu_types.bus_cavity": "qubit_experiment.qpu_types.bus_cavity",
    "qpu_types.bus_cavity.bus_types": "qubit_experiment.qpu_types.bus_cavity.bus_types",
    "qpu_types.bus_cavity.operations": "qubit_experiment.qpu_types.bus_cavity.operations",
}.items():
    sys.modules.setdefault(legacy_name, importlib.import_module(canonical_name))

qpu = load(qb_pars_file)

buses = qpu.groups.bus
qubits = qpu.groups.qubits

from laboneq.simple import workflow

folder_store = workflow.logbook.FolderStore(
    "/Users/yalgaeahn/Library/CloudStorage/SynologyDrive-KAIST/RIP_APS_2026/experiment_store"
)
folder_store.activate()
# Out:
# Project root: /Users/yalgaeahn/Research/20_Projects/qubit-experiment/projects/2026_selectiveRIP
# Added to sys.path:
#   - /Users/yalgaeahn/Research/20_Projects/qubit-experiment/projects/2026_selectiveRIP
#   - /Users/yalgaeahn/Research/20_Projects/qubit-experiment
# LOADED: /Users/yalgaeahn/Research/20_Projects/qubit-experiment/projects/2026_selectiveRIP/qpu_parameters/20260303-0948_3Q_tomo

# %%
session = Session(setup)
session.connect(ignore_version_mismatch=False, do_emulation=False)
# Out:
# [2026.03.11 05:03:07.689] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /Users/yalgaeahn/Research/20_Projects/qubit-experiment/projects/2026_selectiveRIP/noteforTG/laboneq_output/log
# [2026.03.11 05:03:07.690] INFO    VERSION: laboneq 25.10.3
# [2026.03.11 05:03:07.691] INFO    Connecting to data server at 192.168.0.83:8004
# [2026.03.11 05:03:07.812] INFO    Connected to Zurich Instruments LabOne Data Server version 25.10.1.4 at 192.168.0.83:8004
# [2026.03.11 05:03:07.857] INFO    Configuring the device setup
# [2026.03.11 05:03:07.894] INFO    The device setup is configured

# %% [markdown]
# # 2Q Quantum State Tomography

# %% [markdown]
# ## Multiplexed IQ cloud

# %%
from qubit_experiment.experiments import iq_cloud_common, iq_cloud
q = qubits[0]
qq = qubits[2]

temporary_parameters = {}
q_temp_pars = deepcopy(q.parameters)
qq_temp_pars = deepcopy(qq.parameters)

# q_temp_pars.readout_integration_delay = 180e-9
# qq_temp_pars.readout_integration_delay= 180e-9
# q_temp_pars.readout_length = 1.6e-6
# qq_temp_pars.readout_length = 1.6e-6
temporary_parameters[q.uid] = q_temp_pars
temporary_parameters[qq.uid] = qq_temp_pars
#######################################################################

options = iq_cloud.experiment_workflow.options()
options.do_analysis(True)
options.update(False)
#options.count(1024)

iq_result = iq_cloud.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=[q,qq],
    temporary_parameters=temporary_parameters,
    options=options,
).run()

# %% [markdown]
# ## 2Q QST

# %%
from qubit_experiment.analysis import twoq_qst as twoq_qst_analysis
from qubit_experiment.experiments import twoq_qst
q = qubits[0]
qq = qubits[2]

temporary_parameters = {}
q_temp_pars = deepcopy(q.parameters)
qq_temp_pars = deepcopy(qq.parameters)
temporary_parameters[q.uid] = q_temp_pars
temporary_parameters[qq.uid] = qq_temp_pars


ctrl = q
targ = qq

bus = [buses[0], buses[1], buses[2]]

RUN_CONVERGENCE_VALIDATION = False
RUN_SHOT_SWEEP_CONVERGENCE = True
CONVERGENCE_REPEATS = 1
CONVERGENCE_STATES = ("00", "01", "10", "11", "++", "+-", "-+", "--")
SHOT_SWEEP_LOG2_VALUES = tuple(range(3, 9))
SHOT_SWEEP_STATES = CONVERGENCE_STATES
SHOT_SWEEP_REPEATS_PER_POINT = 3

qst_options = twoq_qst.experiment_workflow.options()
qst_options.do_analysis(True)
qst_options.do_readout_calibration(True)
qst_options.initial_state("++")
qst_options.custom_prep(False)
qst_options.do_convergence_validation(RUN_CONVERGENCE_VALIDATION)
qst_options.convergence_repeats_per_state(CONVERGENCE_REPEATS)
qst_options.convergence_suite_states(CONVERGENCE_STATES)
qst_options.convergence_do_plotting(True)
qst_options.do_shot_sweep_convergence(RUN_SHOT_SWEEP_CONVERGENCE)
qst_options.shot_sweep_log2_values(SHOT_SWEEP_LOG2_VALUES)
qst_options.shot_sweep_suite_states(SHOT_SWEEP_STATES)
qst_options.shot_sweep_repeats_per_point(SHOT_SWEEP_REPEATS_PER_POINT)
qst_options.shot_sweep_do_plotting(True)

analysis_options = twoq_qst_analysis.analysis_workflow.options()
analysis_options.do_plotting(True)
# analysis_options.max_mle_iterations(4000)

twoq_qst_output = twoq_qst.run_bundle(
    session=session,
    qpu=qpu,
    qubits=[ctrl, targ],
    bus=bus,
    temporary_parameters=temporary_parameters,
    options=qst_options,
    analysis_options=analysis_options,
)

print("Workflow output keys:", list(twoq_qst_output.keys()))
if twoq_qst_output.get("analysis_result") is not None:
    print("Main analysis metric keys:", list(twoq_qst_output["analysis_result"]["metrics"].keys()))
if twoq_qst_output.get("convergence_report") is not None:
    print("Convergence report keys:", list(twoq_qst_output["convergence_report"].keys()))
if twoq_qst_output.get("shot_sweep_report") is not None:
    print("Shot sweep report keys:", list(twoq_qst_output["shot_sweep_report"].keys()))
# Out:
# [2026.03.11 05:03:10.377] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:10.377] INFO      Workflow 'twoq_qst': execution started at 2026-03-10 20:03:10.376801Z
# [2026.03.11 05:03:10.377] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:10.389] INFO    Task 'resolve_target_configuration': started at 2026-03-10 20:03:10.389112Z
# [2026.03.11 05:03:10.389] INFO    Task 'resolve_target_configuration': ended at 2026-03-10 20:03:10.389831Z
# [2026.03.11 05:03:10.390] INFO    Task 'temporary_qpu': started at 2026-03-10 20:03:10.390366Z
# [2026.03.11 05:03:10.391] INFO    Task 'temporary_qpu': ended at 2026-03-10 20:03:10.391213Z
# [2026.03.11 05:03:10.394] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-03-10
# [2026.03.11 05:03:10.394] INFO    20:03:10.394188Z
# [2026.03.11 05:03:10.395] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-03-10 20:03:10.395408Z
# [2026.03.11 05:03:10.397] INFO    Task 'should_run_readout_calibration': started at 2026-03-10 20:03:10.396979Z
# [2026.03.11 05:03:10.397] INFO    Task 'should_run_readout_calibration': ended at 2026-03-10 20:03:10.397496Z
# [2026.03.11 05:03:10.398] INFO    Task '_bundle_readout_calibration_result': started at 2026-03-10
# [2026.03.11 05:03:10.398] INFO    20:03:10.397938Z
# [2026.03.11 05:03:10.398] INFO    Task '_bundle_readout_calibration_result': ended at 2026-03-10 20:03:10.398541Z
# [2026.03.11 05:03:10.399] INFO    Task 'create_experiment': started at 2026-03-10 20:03:10.398932Z
# [2026.03.11 05:03:10.404] INFO    Task 'create_experiment': ended at 2026-03-10 20:03:10.404745Z
# [2026.03.11 05:03:10.407] INFO    Task 'compile_experiment': started at 2026-03-10 20:03:10.407209Z
# [2026.03.11 05:03:10.409] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:03:10.409] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:03:10.410] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:03:10.410] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:03:10.410] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:03:10.410] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:03:10.410] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:03:10.414] INFO    Schedule completed. [0.003 s]
# [2026.03.11 05:03:10.417] INFO    Code generation completed for all AWGs. [0.002 s]
# [2026.03.11 05:03:10.417] INFO    Completed compilation step 1 of 1. [0.006 s]
# [2026.03.11 05:03:10.420] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:10.420] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:03:10.420] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:10.421] INFO      SHFQC_DEV12256        0         28            0           2     14400
# [2026.03.11 05:03:10.421] INFO      SHFQC_DEV12256_sg     0         32            3           2      1024
# [2026.03.11 05:03:10.421] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:10.421] INFO      TOTAL                           60            3                 15424
# [2026.03.11 05:03:10.422] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:10.425] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:03:10.425] INFO    Task 'compile_experiment': ended at 2026-03-10 20:03:10.425791Z
# [2026.03.11 05:03:10.433] INFO    Task 'run_experiment': started at 2026-03-10 20:03:10.433348Z
# [2026.03.11 05:03:10.518] INFO    Starting near-time execution...
# [2026.03.11 05:03:13.367] INFO    Finished near-time execution.
# [2026.03.11 05:03:13.444] INFO    Task 'run_experiment': ended at 2026-03-10 20:03:13.444292Z
# [2026.03.11 05:03:13.450] INFO    Task '_bundle_readout_calibration_result': started at 2026-03-10
# [2026.03.11 05:03:13.451] INFO    20:03:13.450468Z
# [2026.03.11 05:03:13.451] INFO    Task '_bundle_readout_calibration_result': ended at 2026-03-10 20:03:13.451719Z
# [2026.03.11 05:03:13.452] INFO    Task '_materialize_readout_calibration_bundle': started at 2026-03-10
# [2026.03.11 05:03:13.452] INFO    20:03:13.452449Z
# [2026.03.11 05:03:13.453] INFO    Task '_materialize_readout_calibration_bundle': ended at 2026-03-10
# [2026.03.11 05:03:13.453] INFO    20:03:13.453413Z
# [2026.03.11 05:03:13.454] INFO    Task '_extract_readout_calibration_result': started at 2026-03-10
# [2026.03.11 05:03:13.454] INFO    20:03:13.454310Z
# [2026.03.11 05:03:13.455] INFO    Task '_extract_readout_calibration_result': ended at 2026-03-10 20:03:13.455104Z
# [2026.03.11 05:03:13.455] INFO    Task 'create_experiment': started at 2026-03-10 20:03:13.455645Z
# [2026.03.11 05:03:13.459] INFO    Task 'create_experiment': ended at 2026-03-10 20:03:13.459380Z
# [2026.03.11 05:03:13.462] INFO    Task 'compile_experiment': started at 2026-03-10 20:03:13.462472Z
# [2026.03.11 05:03:13.517] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:03:13.518] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:03:13.518] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:03:13.518] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:03:13.518] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:03:13.519] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:03:13.519] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:03:13.519] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:03:13.519] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:03:13.520] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:03:13.525] INFO    Schedule completed. [0.003 s]
# [2026.03.11 05:03:13.529] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.03.11 05:03:13.529] INFO    Completed compilation step 1 of 1. [0.008 s]
# [2026.03.11 05:03:13.531] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:13.531] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:03:13.532] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:13.532] INFO      SHFQC_DEV12256        0         61            0           2     14400
# [2026.03.11 05:03:13.532] INFO      SHFQC_DEV12256_sg     0         99            7           6      2560
# [2026.03.11 05:03:13.532] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:03:13.533] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:03:13.533] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:03:13.533] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:13.533] INFO      TOTAL                          172           10                 16960
# [2026.03.11 05:03:13.533] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:13.537] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:03:13.538] INFO    Task 'compile_experiment': ended at 2026-03-10 20:03:13.538257Z
# [2026.03.11 05:03:13.550] INFO    Task 'run_experiment': started at 2026-03-10 20:03:13.550186Z
# [2026.03.11 05:03:13.661] INFO    Starting near-time execution...
# [2026.03.11 05:03:13.852] INFO    Estimated RT execution time: 5.24 s.
# [2026.03.11 05:03:20.229] INFO    Finished near-time execution.
# [2026.03.11 05:03:20.305] INFO    Task 'run_experiment': ended at 2026-03-10 20:03:20.305741Z
# [2026.03.11 05:03:20.315] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.315] INFO      Workflow 'twoq_qst': execution ended at 2026-03-10 20:03:20.315100Z
# [2026.03.11 05:03:20.315] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.317] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.318] INFO      Workflow 'analysis_twoq_qst': execution started at 2026-03-10
# [2026.03.11 05:03:20.318] INFO      20:03:20.317799Z
# [2026.03.11 05:03:20.318] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.331] INFO    Task 'analyze_tomography_run': started at 2026-03-10 20:03:20.331512Z
# [2026.03.11 05:03:20.443] INFO    Task 'analyze_tomography_run': ended at 2026-03-10 20:03:20.443283Z
# [2026.03.11 05:03:20.444] INFO    Task 'plot_density_matrix': started at 2026-03-10 20:03:20.444641Z
# [2026.03.11 05:03:20.494] INFO    Artifact: 'twoq_qst_density_matrix' of type 'Figure' logged at 2026-03-10
# [2026.03.11 05:03:20.495] INFO    20:03:20.494526Z
# [2026.03.11 05:03:20.549] INFO    Task 'plot_density_matrix': ended at 2026-03-10 20:03:20.549730Z
# [2026.03.11 05:03:20.550] INFO    Task 'plot_counts': started at 2026-03-10 20:03:20.550479Z
# [2026.03.11 05:03:20.582] INFO    Artifact: 'twoq_qst_counts' of type 'Figure' logged at 2026-03-10
# [2026.03.11 05:03:20.582] INFO    20:03:20.582194Z
# [2026.03.11 05:03:20.635] INFO    Task 'plot_counts': ended at 2026-03-10 20:03:20.635089Z
# [2026.03.11 05:03:20.636] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.636] INFO      Workflow 'analysis_twoq_qst': execution ended at 2026-03-10 20:03:20.635857Z
# [2026.03.11 05:03:20.636] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.638] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.639] INFO      Workflow 'twoq_qst_shot_sweep': execution started at 2026-03-10
# [2026.03.11 05:03:20.639] INFO      20:03:20.638605Z
# [2026.03.11 05:03:20.639] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.652] INFO    Task 'temporary_qpu': started at 2026-03-10 20:03:20.652047Z
# [2026.03.11 05:03:20.653] INFO    Task 'temporary_qpu': ended at 2026-03-10 20:03:20.653049Z
# [2026.03.11 05:03:20.655] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-03-10
# [2026.03.11 05:03:20.655] INFO    20:03:20.654955Z
# [2026.03.11 05:03:20.655] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-03-10 20:03:20.655605Z
# [2026.03.11 05:03:20.657] INFO    Task 'should_run_readout_calibration': started at 2026-03-10 20:03:20.656911Z
# [2026.03.11 05:03:20.657] INFO    Task 'should_run_readout_calibration': ended at 2026-03-10 20:03:20.657331Z
# [2026.03.11 05:03:20.657] INFO    Task '_bundle_readout_calibration_result': started at 2026-03-10
# [2026.03.11 05:03:20.657] INFO    20:03:20.657711Z
# [2026.03.11 05:03:20.658] INFO    Task '_bundle_readout_calibration_result': ended at 2026-03-10 20:03:20.658203Z
# [2026.03.11 05:03:20.658] INFO    Task '_materialize_readout_calibration_bundle': started at 2026-03-10
# [2026.03.11 05:03:20.658] INFO    20:03:20.658519Z
# [2026.03.11 05:03:20.659] INFO    Task '_materialize_readout_calibration_bundle': ended at 2026-03-10
# [2026.03.11 05:03:20.659] INFO    20:03:20.659031Z
# [2026.03.11 05:03:20.659] INFO    Task '_extract_readout_calibration_result': started at 2026-03-10
# [2026.03.11 05:03:20.659] INFO    20:03:20.659610Z
# [2026.03.11 05:03:20.660] INFO    Task '_extract_readout_calibration_result': ended at 2026-03-10 20:03:20.660218Z
# [2026.03.11 05:03:20.660] INFO    Task '_select_qubit_for_analysis': started at 2026-03-10 20:03:20.660558Z
# [2026.03.11 05:03:20.661] INFO    Task '_select_qubit_for_analysis': ended at 2026-03-10 20:03:20.660928Z
# [2026.03.11 05:03:20.661] INFO    Task '_select_qubit_for_analysis': started at 2026-03-10 20:03:20.661366Z
# [2026.03.11 05:03:20.661] INFO    Task '_select_qubit_for_analysis': ended at 2026-03-10 20:03:20.661889Z
# [2026.03.11 05:03:20.662] INFO    Task 'resolve_shot_sweep_suite_states': started at 2026-03-10 20:03:20.662241Z
# [2026.03.11 05:03:20.662] INFO    Task 'resolve_shot_sweep_suite_states': ended at 2026-03-10 20:03:20.662577Z
# [2026.03.11 05:03:20.663] INFO    Task 'resolve_shot_sweep_log2_values': started at 2026-03-10 20:03:20.662943Z
# [2026.03.11 05:03:20.663] INFO    Task 'resolve_shot_sweep_log2_values': ended at 2026-03-10 20:03:20.663467Z
# [2026.03.11 05:03:20.664] INFO    Task 'resolve_shot_sweep_counts': started at 2026-03-10 20:03:20.663879Z
# [2026.03.11 05:03:20.664] INFO    Task 'resolve_shot_sweep_counts': ended at 2026-03-10 20:03:20.664409Z
# [2026.03.11 05:03:20.664] INFO    Task 'resolve_shot_sweep_repeats_per_point': started at 2026-03-10
# [2026.03.11 05:03:20.665] INFO    20:03:20.664805Z
# [2026.03.11 05:03:20.665] INFO    Task 'resolve_shot_sweep_repeats_per_point': ended at 2026-03-10
# [2026.03.11 05:03:20.665] INFO    20:03:20.665451Z
# [2026.03.11 05:03:20.666] INFO    Task 'resolve_shot_sweep_repeat_indices': started at 2026-03-10 20:03:20.666059Z
# [2026.03.11 05:03:20.666] INFO    Task 'resolve_shot_sweep_repeat_indices': ended at 2026-03-10 20:03:20.666425Z
# [2026.03.11 05:03:20.666] INFO    Task '_resolve_analysis_max_mle_iterations': started at 2026-03-10
# [2026.03.11 05:03:20.666] INFO    20:03:20.666757Z
# [2026.03.11 05:03:20.667] INFO    Task '_resolve_analysis_max_mle_iterations': ended at 2026-03-10
# [2026.03.11 05:03:20.667] INFO    20:03:20.667274Z
# [2026.03.11 05:03:20.667] INFO    Task 'shot_count_from_log2': started at 2026-03-10 20:03:20.667900Z
# [2026.03.11 05:03:20.668] INFO    Task 'shot_count_from_log2': ended at 2026-03-10 20:03:20.668314Z
# [2026.03.11 05:03:20.668] INFO    Task 'create_experiment': started at 2026-03-10 20:03:20.668785Z
# [2026.03.11 05:03:20.675] INFO    Task 'create_experiment': ended at 2026-03-10 20:03:20.675785Z
# [2026.03.11 05:03:20.678] INFO    Task 'compile_experiment': started at 2026-03-10 20:03:20.678021Z
# [2026.03.11 05:03:20.681] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:03:20.682] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:03:20.682] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:03:20.682] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:03:20.682] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:03:20.683] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:03:20.683] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:03:20.683] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:03:20.683] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:03:20.684] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:03:20.688] INFO    Schedule completed. [0.003 s]
# [2026.03.11 05:03:20.693] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.03.11 05:03:20.693] INFO    Completed compilation step 1 of 1. [0.008 s]
# [2026.03.11 05:03:20.695] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.695] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:03:20.695] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.696] INFO      SHFQC_DEV12256        0         52            0           2     14400
# [2026.03.11 05:03:20.696] INFO      SHFQC_DEV12256_sg     0         71            5           4      2048
# [2026.03.11 05:03:20.696] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:03:20.696] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:03:20.696] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:03:20.697] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.697] INFO      TOTAL                          135            8                 16448
# [2026.03.11 05:03:20.697] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:20.701] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:03:20.701] INFO    Task 'compile_experiment': ended at 2026-03-10 20:03:20.701668Z
# [2026.03.11 05:03:20.709] INFO    Task 'run_experiment': started at 2026-03-10 20:03:20.709553Z
# [2026.03.11 05:03:20.924] INFO    Starting near-time execution...
# [2026.03.11 05:03:21.257] INFO    Finished near-time execution.
# [2026.03.11 05:03:21.346] INFO    Task 'run_experiment': ended at 2026-03-10 20:03:21.346213Z
# [2026.03.11 05:03:21.348] INFO    Task 'collect_shot_sweep_run_record': started at 2026-03-10 20:03:21.348060Z
# [2026.03.11 05:03:21.462] INFO    Task 'collect_shot_sweep_run_record': ended at 2026-03-10 20:03:21.462076Z
# [2026.03.11 05:03:21.463] INFO    Task '_append_item': started at 2026-03-10 20:03:21.462939Z
# [2026.03.11 05:03:21.463] INFO    Task '_append_item': ended at 2026-03-10 20:03:21.463518Z
# [2026.03.11 05:03:21.464] INFO    Task '_append_item_if_present': started at 2026-03-10 20:03:21.464073Z
# [2026.03.11 05:03:21.464] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:03:21.464584Z
# [2026.03.11 05:03:21.465] INFO    Task 'create_experiment': started at 2026-03-10 20:03:21.465089Z
# [2026.03.11 05:03:21.468] INFO    Task 'create_experiment': ended at 2026-03-10 20:03:21.468169Z
# [2026.03.11 05:03:21.470] INFO    Task 'compile_experiment': started at 2026-03-10 20:03:21.470031Z
# [2026.03.11 05:03:21.472] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:03:21.472] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:03:21.472] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:03:21.473] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:03:21.473] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:03:21.473] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:03:21.473] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:03:21.473] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:03:21.474] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:03:21.474] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:03:21.478] INFO    Schedule completed. [0.003 s]
# [2026.03.11 05:03:21.482] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.03.11 05:03:21.482] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.03.11 05:03:21.485] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:21.485] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:03:21.485] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:21.486] INFO      SHFQC_DEV12256        0         52            0           2     14400
# [2026.03.11 05:03:21.486] INFO      SHFQC_DEV12256_sg     0         71            5           4      2048
# [2026.03.11 05:03:21.486] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:03:21.486] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:03:21.487] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:03:21.487] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:21.487] INFO      TOTAL                          135            8                 16448
# [2026.03.11 05:03:21.487] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:21.491] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:03:21.492] INFO    Task 'compile_experiment': ended at 2026-03-10 20:03:21.492149Z
# [2026.03.11 05:03:21.499] INFO    Task 'run_experiment': started at 2026-03-10 20:03:21.499251Z
# [2026.03.11 05:03:21.639] INFO    Starting near-time execution...
# [2026.03.11 05:03:22.130] INFO    Finished near-time execution.
# [2026.03.11 05:03:22.214] INFO    Task 'run_experiment': ended at 2026-03-10 20:03:22.213853Z
# [2026.03.11 05:03:22.215] INFO    Task 'collect_shot_sweep_run_record': started at 2026-03-10 20:03:22.215769Z
# [2026.03.11 05:03:22.389] INFO    Task 'collect_shot_sweep_run_record': ended at 2026-03-10 20:03:22.389707Z
# [2026.03.11 05:03:22.390] INFO    Task '_append_item': started at 2026-03-10 20:03:22.390576Z
# [2026.03.11 05:03:22.391] INFO    Task '_append_item': ended at 2026-03-10 20:03:22.391069Z
# [2026.03.11 05:03:22.391] INFO    Task '_append_item_if_present': started at 2026-03-10 20:03:22.391548Z
# [2026.03.11 05:03:22.392] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:03:22.392067Z
# [2026.03.11 05:03:22.392] INFO    Task 'create_experiment': started at 2026-03-10 20:03:22.392628Z
# [2026.03.11 05:03:22.395] INFO    Task 'create_experiment': ended at 2026-03-10 20:03:22.395044Z
# [2026.03.11 05:03:22.397] INFO    Task 'compile_experiment': started at 2026-03-10 20:03:22.397015Z
# [2026.03.11 05:03:22.399] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:03:22.399] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:03:22.400] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:03:22.400] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:03:22.400] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:03:22.400] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:03:22.401] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:03:22.401] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:03:22.401] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:03:22.401] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:03:22.406] INFO    Schedule completed. [0.003 s]
# [2026.03.11 05:03:22.410] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.03.11 05:03:22.410] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.03.11 05:03:22.412] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:22.412] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:03:22.413] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:22.413] INFO      SHFQC_DEV12256        0         52            0           2     14400
# [2026.03.11 05:03:22.413] INFO      SHFQC_DEV12256_sg     0         71            5           4      2048
# [2026.03.11 05:03:22.414] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:03:22.414] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:03:22.414] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:03:22.414] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:22.414] INFO      TOTAL                          135            8                 16448
# [2026.03.11 05:03:22.415] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:22.419] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:03:22.419] INFO    Task 'compile_experiment': ended at 2026-03-10 20:03:22.419580Z
# [2026.03.11 05:03:22.427] INFO    Task 'run_experiment': started at 2026-03-10 20:03:22.427629Z
# [2026.03.11 05:03:22.591] INFO    Starting near-time execution...
# [2026.03.11 05:03:22.851] INFO    Finished near-time execution.
# [2026.03.11 05:03:22.909] INFO    Task 'run_experiment': ended at 2026-03-10 20:03:22.909333Z
# [2026.03.11 05:03:22.911] INFO    Task 'collect_shot_sweep_run_record': started at 2026-03-10 20:03:22.911293Z
# [2026.03.11 05:03:23.090] INFO    Task 'collect_shot_sweep_run_record': ended at 2026-03-10 20:03:23.090670Z
# [2026.03.11 05:03:23.091] INFO    Task '_append_item': started at 2026-03-10 20:03:23.091616Z
# [2026.03.11 05:03:23.092] INFO    Task '_append_item': ended at 2026-03-10 20:03:23.092192Z
# [2026.03.11 05:03:23.092] INFO    Task '_append_item_if_present': started at 2026-03-10 20:03:23.092634Z
# [2026.03.11 05:03:23.093] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:03:23.093151Z
# [2026.03.11 05:03:23.093] INFO    Task 'shot_count_from_log2': started at 2026-03-10 20:03:23.093686Z
# [2026.03.11 05:03:23.094] INFO    Task 'shot_count_from_log2': ended at 2026-03-10 20:03:23.094147Z
# [2026.03.11 05:03:23.094] INFO    Task 'create_experiment': started at 2026-03-10 20:03:23.094627Z
# [2026.03.11 05:03:23.097] INFO    Task 'create_experiment': ended at 2026-03-10 20:03:23.097186Z
# [2026.03.11 05:03:23.099] INFO    Task 'compile_experiment': started at 2026-03-10 20:03:23.099465Z
# [2026.03.11 05:03:23.101] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:03:23.102] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:03:23.102] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:03:23.102] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:03:23.102] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:03:23.102] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:03:23.103] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:03:23.103] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:03:23.103] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:03:23.104] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:03:23.108] INFO    Schedule completed. [0.003 s]
# [2026.03.11 05:03:23.112] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.03.11 05:03:23.112] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.03.11 05:03:23.114] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:23.115] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:03:23.115] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:23.117] INFO      SHFQC_DEV12256        0         52            0           2     14400
# [2026.03.11 05:03:23.118] INFO      SHFQC_DEV12256_sg     0         71            5           4      2048
# [2026.03.11 05:03:23.118] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:03:23.119] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:03:23.119] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:03:23.119] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:23.120] INFO      TOTAL                          135            8                 16448
# [2026.03.11 05:03:23.120] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:23.124] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:03:23.124] INFO    Task 'compile_experiment': ended at 2026-03-10 20:03:23.124833Z
# [2026.03.11 05:03:23.133] INFO    Task 'run_experiment': started at 2026-03-10 20:03:23.133169Z
# [2026.03.11 05:03:23.243] INFO    Starting near-time execution...
# [2026.03.11 05:03:23.588] INFO    Finished near-time execution.
# [2026.03.11 05:03:23.676] INFO    Task 'run_experiment': ended at 2026-03-10 20:03:23.676411Z
# [2026.03.11 05:03:23.679] INFO    Task 'collect_shot_sweep_run_record': started at 2026-03-10 20:03:23.678882Z
# [2026.03.11 05:03:23.890] INFO    Task 'collect_shot_sweep_run_record': ended at 2026-03-10 20:03:23.889841Z
# [2026.03.11 05:03:23.891] INFO    Task '_append_item': started at 2026-03-10 20:03:23.890868Z
# [2026.03.11 05:03:23.891] INFO    Task '_append_item': ended at 2026-03-10 20:03:23.891511Z
# [2026.03.11 05:03:23.892] INFO    Task '_append_item_if_present': started at 2026-03-10 20:03:23.892003Z
# [2026.03.11 05:03:23.892] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:03:23.892504Z
# [2026.03.11 05:03:23.893] INFO    Task 'create_experiment': started at 2026-03-10 20:03:23.893009Z
# [2026.03.11 05:03:23.895] INFO    Task 'create_experiment': ended at 2026-03-10 20:03:23.895502Z
# [2026.03.11 05:03:23.897] INFO    Task 'compile_experiment': started at 2026-03-10 20:03:23.897471Z
# [2026.03.11 05:03:23.900] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:03:23.900] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:03:23.900] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:03:23.900] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:03:23.900] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:03:23.901] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:03:23.901] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:03:23.901] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:03:23.901] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:03:23.901] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:03:23.907] INFO    Schedule completed. [0.004 s]
# [2026.03.11 05:03:23.910] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.03.11 05:03:23.911] INFO    Completed compilation step 1 of 1. [0.008 s]
# [2026.03.11 05:03:23.913] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:23.913] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:03:23.913] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:23.914] INFO      SHFQC_DEV12256        0         52            0           2     14400
# [2026.03.11 05:03:23.914] INFO      SHFQC_DEV12256_sg     0         71            5           4      2048
# [2026.03.11 05:03:23.914] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:03:23.914] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:03:23.915] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:03:23.915] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:23.915] INFO      TOTAL                          135            8                 16448
# [2026.03.11 05:03:23.915] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:23.919] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:03:23.920] INFO    Task 'compile_experiment': ended at 2026-03-10 20:03:23.920023Z
# [2026.03.11 05:03:23.927] INFO    Task 'run_experiment': started at 2026-03-10 20:03:23.927490Z
# [2026.03.11 05:03:24.115] INFO    Starting near-time execution...
# [2026.03.11 05:03:24.371] INFO    Finished near-time execution.
# [2026.03.11 05:03:24.442] INFO    Task 'run_experiment': ended at 2026-03-10 20:03:24.442225Z
# [2026.03.11 05:03:24.444] INFO    Task 'collect_shot_sweep_run_record': started at 2026-03-10 20:03:24.444082Z
# [2026.03.11 05:03:24.587] INFO    Task 'collect_shot_sweep_run_record': ended at 2026-03-10 20:03:24.587445Z
# [2026.03.11 05:03:24.588] INFO    Task '_append_item': started at 2026-03-10 20:03:24.588400Z
# [2026.03.11 05:03:24.589] INFO    Task '_append_item': ended at 2026-03-10 20:03:24.589003Z
# [2026.03.11 05:03:24.589] INFO    Task '_append_item_if_present': started at 2026-03-10 20:03:24.589565Z
# [2026.03.11 05:03:24.590] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:03:24.590065Z
# [2026.03.11 05:03:24.590] INFO    Task 'create_experiment': started at 2026-03-10 20:03:24.590584Z
# [2026.03.11 05:03:24.593] INFO    Task 'create_experiment': ended at 2026-03-10 20:03:24.593102Z
# [2026.03.11 05:03:24.595] INFO    Task 'compile_experiment': started at 2026-03-10 20:03:24.595004Z
# [2026.03.11 05:03:24.597] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:03:24.597] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:03:24.598] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:03:24.598] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:03:24.598] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:03:24.598] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:03:24.599] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:03:24.599] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:03:24.599] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:03:24.599] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:03:24.604] INFO    Schedule completed. [0.003 s]
# [2026.03.11 05:03:24.608] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.03.11 05:03:24.608] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.03.11 05:03:24.610] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:24.610] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:03:24.610] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:24.611] INFO      SHFQC_DEV12256        0         52            0           2     14400
# [2026.03.11 05:03:24.611] INFO      SHFQC_DEV12256_sg     0         71            5           4      2048
# [2026.03.11 05:03:24.611] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:03:24.612] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:03:24.612] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:03:24.612] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:24.612] INFO      TOTAL                          135            8                 16448
# [2026.03.11 05:03:24.613] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:24.616] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:03:24.617] INFO    Task 'compile_experiment': ended at 2026-03-10 20:03:24.617127Z
# [2026.03.11 05:03:24.624] INFO    Task 'run_experiment': started at 2026-03-10 20:03:24.624363Z
# [2026.03.11 05:03:24.729] INFO    Starting near-time execution...
# [2026.03.11 05:03:25.119] INFO    Finished near-time execution.
# [2026.03.11 05:03:25.210] INFO    Task 'run_experiment': ended at 2026-03-10 20:03:25.209965Z
# [2026.03.11 05:03:25.212] INFO    Task 'collect_shot_sweep_run_record': started at 2026-03-10 20:03:25.212181Z
# [2026.03.11 05:03:25.353] INFO    Task 'collect_shot_sweep_run_record': ended at 2026-03-10 20:03:25.352982Z
# [2026.03.11 05:03:25.354] INFO    Task '_append_item': started at 2026-03-10 20:03:25.353901Z
# [2026.03.11 05:03:25.354] INFO    Task '_append_item': ended at 2026-03-10 20:03:25.354485Z
# [2026.03.11 05:03:25.355] INFO    Task '_append_item_if_present': started at 2026-03-10 20:03:25.355043Z
# [2026.03.11 05:03:25.355] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:03:25.355502Z
# [2026.03.11 05:03:25.356] INFO    Task 'shot_count_from_log2': started at 2026-03-10 20:03:25.356003Z
# [2026.03.11 05:03:25.356] INFO    Task 'shot_count_from_log2': ended at 2026-03-10 20:03:25.356483Z
# [2026.03.11 05:03:25.357] INFO    Task 'create_experiment': started at 2026-03-10 20:03:25.357025Z
# [2026.03.11 05:03:25.359] INFO    Task 'create_experiment': ended at 2026-03-10 20:03:25.359569Z
# [2026.03.11 05:03:25.361] INFO    Task 'compile_experiment': started at 2026-03-10 20:03:25.361392Z
# [2026.03.11 05:03:25.363] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:03:25.363] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:03:25.364] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:03:25.364] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:03:25.364] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:03:25.364] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:03:25.364] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:03:25.365] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:03:25.365] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:03:25.365] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:03:25.370] INFO    Schedule completed. [0.003 s]
# [2026.03.11 05:03:25.374] INFO    Code generation completed for all AWGs. [0.004 s]
# [2026.03.11 05:03:25.374] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.03.11 05:03:25.376] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:25.376] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:03:25.376] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:25.377] INFO      SHFQC_DEV12256        0         52            0           2     14400
# [2026.03.11 05:03:25.377] INFO      SHFQC_DEV12256_sg     0         71            5           4      2048
# [2026.03.11 05:03:25.377] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:03:25.377] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:03:25.378] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:03:25.378] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:25.378] INFO      TOTAL                          135            8                 16448
# [2026.03.11 05:03:25.378] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:25.382] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:03:25.382] INFO    Task 'compile_experiment': ended at 2026-03-10 20:03:25.382818Z
# [2026.03.11 05:03:25.391] INFO    Task 'run_experiment': started at 2026-03-10 20:03:25.390899Z
# [2026.03.11 05:03:25.498] INFO    Starting near-time execution...
# [2026.03.11 05:03:25.900] INFO    Finished near-time execution.
# [2026.03.11 05:03:25.986] INFO    Task 'run_experiment': ended at 2026-03-10 20:03:25.986279Z
# [2026.03.11 05:03:25.988] INFO    Task 'collect_shot_sweep_run_record': started at 2026-03-10 20:03:25.988259Z
# [2026.03.11 05:03:26.197] INFO    Task 'collect_shot_sweep_run_record': ended at 2026-03-10 20:03:26.197468Z
# [2026.03.11 05:03:26.198] INFO    Task '_append_item': started at 2026-03-10 20:03:26.198394Z
# [2026.03.11 05:03:26.199] INFO    Task '_append_item': ended at 2026-03-10 20:03:26.199004Z
# [2026.03.11 05:03:26.199] INFO    Task '_append_item_if_present': started at 2026-03-10 20:03:26.199496Z
# [2026.03.11 05:03:26.200] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:03:26.200011Z
# [2026.03.11 05:03:26.200] INFO    Task 'create_experiment': started at 2026-03-10 20:03:26.200563Z
# [2026.03.11 05:03:26.203] INFO    Task 'create_experiment': ended at 2026-03-10 20:03:26.203032Z
# [2026.03.11 05:03:26.204] INFO    Task 'compile_experiment': started at 2026-03-10 20:03:26.204900Z
# [2026.03.11 05:03:26.207] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:03:26.207] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:03:26.207] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:03:26.207] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:03:26.208] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:03:26.208] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:03:26.208] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:03:26.208] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:03:26.208] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:03:26.209] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:03:26.214] INFO    Schedule completed. [0.003 s]
# [2026.03.11 05:03:26.217] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.03.11 05:03:26.218] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.03.11 05:03:26.219] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:26.220] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:03:26.220] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:26.220] INFO      SHFQC_DEV12256        0         52            0           2     14400
# [2026.03.11 05:03:26.220] INFO      SHFQC_DEV12256_sg     0         71            5           4      2048
# [2026.03.11 05:03:26.221] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:03:26.221] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:03:26.221] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:03:26.221] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:26.221] INFO      TOTAL                          135            8                 16448
# [2026.03.11 05:03:26.222] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:03:26.225] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:03:26.226] INFO    Task 'compile_experiment': ended at 2026-03-10 20:03:26.226287Z
# [2026.03.11 05:03:26.234] INFO    Task 'run_experiment': started at 2026-03-10 20:03:26.234177Z
# [2026.03.11 05:03:26.339] INFO    Starting near-time execution...
# [2026.03.11 05:03:26.729] INFO    Finished near-time execution.
# [2026.03.11 05:03:26.814] INFO    Task 'run_experiment': ended at 2026-03-10 20:03:26.814701Z
# [2026.03.11 05:03:26.816] INFO    Task 'collect_shot_sweep_run_record': started at 2026-03-10 20:03:26.816739Z
# [2026.03.11 05:03:26.929] INFO    Task 'collect_shot_sweep_run_record': ended at 2026-03-10 20:03:26.929184Z
# [2026.03.11 05:03:26.930] INFO    Task '_append_item': started at 2026-03-10 20:03:26.930158Z
# [2026.03.11 05:03:26.930] INFO    Task '_append_item': ended at 2026-03-10 20:03:26.930740Z
# [2026.03.11 05:03:26.931] INFO    Task '_append_item_if_present': started at 2026-03-10 20:03:26.931211Z
# [2026.03.11 05:03:26.931] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:03:26.931745Z
# [2026.03.11 05:03:26.932] INFO    Task 'create_experiment': started at 2026-03-10 20:03:26.932216Z
# [2026.03.11 05:03:26.935] INFO    Task 'create_experiment': ended at 2026-03-10 20:03:26.935364Z
# [2026.03.11 05:03:26.937] INFO    Task 'compile_experiment': started at 2026-03-10 20:03:26.937247Z
# [2026.03.11 05:03:26.939] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:03:26.939] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:03:26.940] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:03:26.940] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# ...
# [2026.03.11 05:05:20.661] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:05:20.661597Z
# [2026.03.11 05:05:20.662] INFO    Task 'shot_count_from_log2': started at 2026-03-10 20:05:20.662203Z
# [2026.03.11 05:05:20.663] INFO    Task 'shot_count_from_log2': ended at 2026-03-10 20:05:20.662917Z
# [2026.03.11 05:05:20.663] INFO    Task 'create_experiment': started at 2026-03-10 20:05:20.663778Z
# [2026.03.11 05:05:20.667] INFO    Task 'create_experiment': ended at 2026-03-10 20:05:20.667029Z
# [2026.03.11 05:05:20.670] INFO    Task 'compile_experiment': started at 2026-03-10 20:05:20.670068Z
# [2026.03.11 05:05:20.674] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:05:20.675] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:05:20.675] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:05:20.675] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:05:20.676] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:05:20.676] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:05:20.677] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:05:20.677] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:05:20.678] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:05:20.679] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:05:20.685] INFO    Schedule completed. [0.003 s]
# [2026.03.11 05:05:20.697] INFO    Code generation completed for all AWGs. [0.012 s]
# [2026.03.11 05:05:20.698] INFO    Completed compilation step 1 of 1. [0.016 s]
# [2026.03.11 05:05:20.711] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:20.712] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:05:20.712] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:20.713] INFO      SHFQC_DEV12256        0         61            0           2     14400
# [2026.03.11 05:05:20.714] INFO      SHFQC_DEV12256_sg     0         93            5           4      2048
# [2026.03.11 05:05:20.714] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:05:20.715] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:05:20.715] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:05:20.716] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:20.717] INFO      TOTAL                          166            8                 16448
# [2026.03.11 05:05:20.717] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:20.722] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:05:20.723] INFO    Task 'compile_experiment': ended at 2026-03-10 20:05:20.722647Z
# [2026.03.11 05:05:20.735] INFO    Task 'run_experiment': started at 2026-03-10 20:05:20.735295Z
# [2026.03.11 05:05:20.855] INFO    Starting near-time execution...
# [2026.03.11 05:05:21.630] INFO    Finished near-time execution.
# [2026.03.11 05:05:21.718] INFO    Task 'run_experiment': ended at 2026-03-10 20:05:21.718588Z
# [2026.03.11 05:05:21.721] INFO    Task 'collect_shot_sweep_run_record': started at 2026-03-10 20:05:21.720910Z
# [2026.03.11 05:05:21.835] INFO    Task 'collect_shot_sweep_run_record': ended at 2026-03-10 20:05:21.834837Z
# [2026.03.11 05:05:21.835] INFO    Task '_append_item': started at 2026-03-10 20:05:21.835661Z
# [2026.03.11 05:05:21.836] INFO    Task '_append_item': ended at 2026-03-10 20:05:21.836319Z
# [2026.03.11 05:05:21.837] INFO    Task '_append_item_if_present': started at 2026-03-10 20:05:21.836923Z
# [2026.03.11 05:05:21.837] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:05:21.837628Z
# [2026.03.11 05:05:21.838] INFO    Task 'create_experiment': started at 2026-03-10 20:05:21.838222Z
# [2026.03.11 05:05:21.841] INFO    Task 'create_experiment': ended at 2026-03-10 20:05:21.841369Z
# [2026.03.11 05:05:21.844] INFO    Task 'compile_experiment': started at 2026-03-10 20:05:21.843898Z
# [2026.03.11 05:05:21.846] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:05:21.847] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:05:21.847] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:05:21.848] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:05:21.848] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:05:21.849] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:05:21.849] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:05:21.850] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:05:21.850] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:05:21.851] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:05:21.858] INFO    Schedule completed. [0.004 s]
# [2026.03.11 05:05:21.866] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.03.11 05:05:21.866] INFO    Completed compilation step 1 of 1. [0.012 s]
# [2026.03.11 05:05:21.868] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:21.869] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:05:21.869] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:21.869] INFO      SHFQC_DEV12256        0         61            0           2     14400
# [2026.03.11 05:05:21.869] INFO      SHFQC_DEV12256_sg     0         93            5           4      2048
# [2026.03.11 05:05:21.870] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:05:21.870] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:05:21.870] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:05:21.870] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:21.871] INFO      TOTAL                          166            8                 16448
# [2026.03.11 05:05:21.871] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:21.874] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:05:21.875] INFO    Task 'compile_experiment': ended at 2026-03-10 20:05:21.875261Z
# [2026.03.11 05:05:21.882] INFO    Task 'run_experiment': started at 2026-03-10 20:05:21.882657Z
# [2026.03.11 05:05:22.085] INFO    Starting near-time execution...
# [2026.03.11 05:05:22.730] INFO    Finished near-time execution.
# [2026.03.11 05:05:22.814] INFO    Task 'run_experiment': ended at 2026-03-10 20:05:22.814722Z
# [2026.03.11 05:05:22.817] INFO    Task 'collect_shot_sweep_run_record': started at 2026-03-10 20:05:22.817209Z
# [2026.03.11 05:05:22.941] INFO    Task 'collect_shot_sweep_run_record': ended at 2026-03-10 20:05:22.941720Z
# [2026.03.11 05:05:22.942] INFO    Task '_append_item': started at 2026-03-10 20:05:22.942596Z
# [2026.03.11 05:05:22.943] INFO    Task '_append_item': ended at 2026-03-10 20:05:22.943128Z
# [2026.03.11 05:05:22.943] INFO    Task '_append_item_if_present': started at 2026-03-10 20:05:22.943640Z
# [2026.03.11 05:05:22.944] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:05:22.944302Z
# [2026.03.11 05:05:22.945] INFO    Task 'create_experiment': started at 2026-03-10 20:05:22.945045Z
# [2026.03.11 05:05:22.948] INFO    Task 'create_experiment': ended at 2026-03-10 20:05:22.948089Z
# [2026.03.11 05:05:22.951] INFO    Task 'compile_experiment': started at 2026-03-10 20:05:22.951797Z
# [2026.03.11 05:05:22.955] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.03.11 05:05:22.956] INFO    Resolved modulation type of oscillator 'b1_drive_osc' on signal 'b1/drive' to HARDWARE
# [2026.03.11 05:05:22.957] INFO    Resolved modulation type of oscillator 'b2_drive_osc' on signal 'b2/drive' to HARDWARE
# [2026.03.11 05:05:22.957] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.11 05:05:22.957] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.11 05:05:22.958] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.11 05:05:22.958] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.11 05:05:22.959] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.11 05:05:22.959] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.11 05:05:22.960] INFO    Starting LabOne Q Compiler run...
# [2026.03.11 05:05:22.967] INFO    Schedule completed. [0.005 s]
# [2026.03.11 05:05:22.979] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.03.11 05:05:22.982] INFO    Completed compilation step 1 of 1. [0.019 s]
# [2026.03.11 05:05:22.997] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:22.998] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.11 05:05:22.999] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:22.999] INFO      SHFQC_DEV12256        0         61            0           2     14400
# [2026.03.11 05:05:22.999] INFO      SHFQC_DEV12256_sg     0         93            5           4      2048
# [2026.03.11 05:05:23.000] INFO      SHFQC_DEV12256_sg     3          4            1           0         0
# [2026.03.11 05:05:23.000] INFO      SHFQC_DEV12256_sg     4          4            1           0         0
# [2026.03.11 05:05:23.000] INFO      SHFQC_DEV12256_sg     5          4            1           0         0
# [2026.03.11 05:05:23.001] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:23.001] INFO      TOTAL                          166            8                 16448
# [2026.03.11 05:05:23.001] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:23.009] INFO    Finished LabOne Q Compiler run.
# [2026.03.11 05:05:23.010] INFO    Task 'compile_experiment': ended at 2026-03-10 20:05:23.010119Z
# [2026.03.11 05:05:23.019] INFO    Task 'run_experiment': started at 2026-03-10 20:05:23.019572Z
# [2026.03.11 05:05:23.145] INFO    Starting near-time execution...
# [2026.03.11 05:05:23.780] INFO    Finished near-time execution.
# [2026.03.11 05:05:23.861] INFO    Task 'run_experiment': ended at 2026-03-10 20:05:23.861095Z
# [2026.03.11 05:05:23.863] INFO    Task 'collect_shot_sweep_run_record': started at 2026-03-10 20:05:23.863399Z
# [2026.03.11 05:05:24.041] INFO    Task 'collect_shot_sweep_run_record': ended at 2026-03-10 20:05:24.040950Z
# [2026.03.11 05:05:24.042] INFO    Task '_append_item': started at 2026-03-10 20:05:24.041949Z
# [2026.03.11 05:05:24.042] INFO    Task '_append_item': ended at 2026-03-10 20:05:24.042536Z
# [2026.03.11 05:05:24.043] INFO    Task '_append_item_if_present': started at 2026-03-10 20:05:24.043106Z
# [2026.03.11 05:05:24.043] INFO    Task '_append_item_if_present': ended at 2026-03-10 20:05:24.043540Z
# [2026.03.11 05:05:24.044] INFO    Task '_materialize_list': started at 2026-03-10 20:05:24.044003Z
# [2026.03.11 05:05:24.044] INFO    Task '_materialize_list': ended at 2026-03-10 20:05:24.044541Z
# [2026.03.11 05:05:24.045] INFO    Task '_materialize_list': started at 2026-03-10 20:05:24.045041Z
# [2026.03.11 05:05:24.045] INFO    Task '_materialize_list': ended at 2026-03-10 20:05:24.045589Z
# [2026.03.11 05:05:24.046] INFO    Task 'validate_shot_sweep_run_records': started at 2026-03-10 20:05:24.046034Z
# [2026.03.11 05:05:24.046] WARNING Lists that convert to NumPy arrays with dtype dtype('O') are not supported by the serializer [name: validate_shot_sweep_run_records.input.run_records].
# [2026.03.11 05:05:24.046] INFO    Task 'validate_shot_sweep_run_records': ended at 2026-03-10 20:05:24.046823Z
# [2026.03.11 05:05:24.047] INFO    Task 'aggregate_shot_sweep_statistics': started at 2026-03-10 20:05:24.047190Z
# [2026.03.11 05:05:24.047] WARNING Lists that convert to NumPy arrays with dtype dtype('O') are not supported by the serializer [name: aggregate_shot_sweep_statistics.input.run_records].
# [2026.03.11 05:05:24.049] INFO    Task 'aggregate_shot_sweep_statistics': ended at 2026-03-10 20:05:24.049035Z
# [2026.03.11 05:05:24.049] WARNING Lists that convert to NumPy arrays with dtype dtype('O') are not supported by the serializer [name: aggregate_shot_sweep_statistics.output].
# [2026.03.11 05:05:24.049] INFO    Task 'summarize_final_shot_sweep': started at 2026-03-10 20:05:24.049681Z
# [2026.03.11 05:05:24.050] WARNING Lists that convert to NumPy arrays with dtype dtype('O') are not supported by the serializer [name: summarize_final_shot_sweep.input.aggregated_stats].
# [2026.03.11 05:05:24.051] INFO    Task 'summarize_final_shot_sweep': ended at 2026-03-10 20:05:24.050317Z
# [2026.03.11 05:05:24.051] INFO    Task 'plot_shot_sweep_summary': started at 2026-03-10 20:05:24.051736Z
# [2026.03.11 05:05:24.051] WARNING Lists that convert to NumPy arrays with dtype dtype('O') are not supported by the serializer [name: plot_shot_sweep_summary.input.aggregated_stats].
# [2026.03.11 05:05:24.102] INFO    Artifact: 'twoq_qst_shot_sweep_summary' of type 'Figure' logged at 2026-03-10
# [2026.03.11 05:05:24.102] INFO    20:05:24.101865Z
# [2026.03.11 05:05:24.200] INFO    Task 'plot_shot_sweep_summary': ended at 2026-03-10 20:05:24.200764Z
# [2026.03.11 05:05:24.201] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:24.202] INFO      Workflow 'twoq_qst_shot_sweep': execution ended at 2026-03-10
# [2026.03.11 05:05:24.202] INFO      20:05:24.201712Z
# [2026.03.11 05:05:24.202] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.11 05:05:24.203] WARNING Lists that convert to NumPy arrays with dtype dtype('O') are not supported by the serializer [name: twoq_qst_shot_sweep.output.raw_run_records].
# [2026.03.11 05:05:24.203] WARNING Lists that convert to NumPy arrays with dtype dtype('O') are not supported by the serializer [name: twoq_qst_shot_sweep.output.aggregated_stats].
# Workflow output keys: ['tomography_result', 'readout_calibration_result', 'analysis_result', 'convergence_report', 'shot_sweep_report', 'initial_state', 'target_state_effective', 'custom_prep']
# Main analysis metric keys: ['trace', 'purity', 'min_eigenvalue', 'fidelity_to_target', 'pauli_correlators']
# Shot sweep report keys: ['suite_states', 'shot_log2_values', 'shot_counts', 'repeats_per_point', 'raw_run_records', 'failed_runs', 'validation_checks', 'aggregated_stats', 'final_summary']

# %% [markdown]
# ## 3Q QST

# %%
from qubit_experiment.analysis import threeq_qst as threeq_qst_analysis
from qubit_experiment.experiments import threeq_qst

spec = qubits[1]
ctrl = qubits[0]
targ = qubits[2]

threeq_temporary_parameters = {}
for qubit in (spec, ctrl, targ):
    threeq_temporary_parameters[qubit.uid] = deepcopy(qubit.parameters)

threeq_bus = [buses[0], buses[1], buses[2]]

RUN_3Q_CONVERGENCE_VALIDATION = False
RUN_3Q_SHOT_SWEEP_CONVERGENCE = True
THREEQ_CONVERGENCE_REPEATS = 1
THREEQ_CONVERGENCE_STATES = ("000", "111", "+++", "---")
THREEQ_SHOT_SWEEP_LOG2_VALUES = tuple(range(3, 9))
THREEQ_SHOT_SWEEP_STATES = THREEQ_CONVERGENCE_STATES
THREEQ_SHOT_SWEEP_REPEATS_PER_POINT = 3

threeq_qst_options = threeq_qst.experiment_workflow.options()
threeq_qst_options.do_analysis(True)
threeq_qst_options.do_readout_calibration(True)
threeq_qst_options.initial_state("+++")
threeq_qst_options.custom_prep(False)
threeq_qst_options.do_convergence_validation(RUN_3Q_CONVERGENCE_VALIDATION)
threeq_qst_options.convergence_repeats_per_state(THREEQ_CONVERGENCE_REPEATS)
threeq_qst_options.convergence_suite_states(THREEQ_CONVERGENCE_STATES)
threeq_qst_options.convergence_do_plotting(True)
threeq_qst_options.do_shot_sweep_convergence(RUN_3Q_SHOT_SWEEP_CONVERGENCE)
threeq_qst_options.shot_sweep_log2_values(THREEQ_SHOT_SWEEP_LOG2_VALUES)
threeq_qst_options.shot_sweep_suite_states(THREEQ_SHOT_SWEEP_STATES)
threeq_qst_options.shot_sweep_repeats_per_point(THREEQ_SHOT_SWEEP_REPEATS_PER_POINT)
threeq_qst_options.shot_sweep_do_plotting(True)

threeq_analysis_options = threeq_qst_analysis.analysis_workflow.options()
threeq_analysis_options.do_plotting(True)
# threeq_analysis_options.max_mle_iterations(4000)

threeq_qst_output = threeq_qst.run_bundle(
    session=session,
    qpu=qpu,
    qubits=[spec, ctrl, targ],
    bus=threeq_bus,
    temporary_parameters=threeq_temporary_parameters,
    options=threeq_qst_options,
    analysis_options=threeq_analysis_options,
)

print("Workflow output keys:", list(threeq_qst_output.keys()))
if threeq_qst_output.get("analysis_result") is not None:
    print(
        "3Q analysis metric keys:",
        list(threeq_qst_output["analysis_result"]["metrics"].keys()),
    )
if threeq_qst_output.get("convergence_report") is not None:
    print(
        "3Q convergence report keys:",
        list(threeq_qst_output["convergence_report"].keys()),
    )
if threeq_qst_output.get("shot_sweep_report") is not None:
    print(
        "3Q shot sweep report keys:",
        list(threeq_qst_output["shot_sweep_report"].keys()),
    )
