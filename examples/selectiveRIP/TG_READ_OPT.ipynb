# %% [markdown]
# # Digital Demodulation of RAW signal
#
# All the notation & argument naming follows Blais review paper
#
# $$
# \begin{align}
# \hat{V}_{I}(t) & = V_{\text{IF}}\Big[ \hat{X}_{f}(t)\cos(\omega_{\text{IF}}t)-\hat{P_{f}}(t)\sin(\omega_{\text{IF}}t)\Big] + \hat{V}_{\text{noise},t}(t) \\ \\
# \hat{V}_{Q}(t) & = -V_{\text{IF}}\Big[ \hat{P}_{f}(t)\cos(\omega_{\text{IF}}t)+\hat{X_{f}}(t)\sin(\omega_{\text{IF}}t)\Big] + \hat{V}_{\text{noise},t}(t)
#
# \end{align}
# $$
#
# $$
# \begin{equation}
# \hat{X}_f = \frac{\hat{a}^\dagger_f + \hat{a}_f}{2},
# \quad
# \hat{P}_f = \frac{i(\hat{a}^\dagger_f - \hat{a}_f)}{2},
# \end{equation}
# $$
#
# $$
# \begin{bmatrix}
# X_{f}(t) \\
# P_{f}(t)
# \end{bmatrix}
# = R^{-1}(t)
# \begin{bmatrix}
# V_{I}(t) \\
# V_{Q}(t)
# \end{bmatrix}
#
# $$

# %%
import numpy as np 
from pprint import pprint
from copy import deepcopy


from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
#from laboneq.contrib.example_helpers.generate_device_setup import generate_device_setup
from laboneq.dsl.device import DeviceSetup




descriptor = generate_descriptor(
    #pqsc=[""], # 장비 여러개 사용시
    shfqc_6=["DEV12256"],
    number_data_qubits=6,
    multiplex=True,
    number_multiplex=6,
    include_cr_lines=True,
    include_ef_lines=True,
    get_zsync=False,  # Only set to True when using real device
    save = True,
    filename="TG_RIP",
    ip_address="192.168.0.83"
)


#descriptor
setup = DeviceSetup.from_descriptor(yaml_text=descriptor, server_host="192.168.0.83")
#setup
setup.instruments[0].device_options = 'SHFQC/PLUS/QC6CH'
#setup.instruments

# %%
from laboneq.simple import Session
session = Session(setup)
session.connect(ignore_version_mismatch=False, do_emulation=False)
#session.disconnect()
# Out:
# [2026.01.04 22:45:01.820] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /home/yalgaeahn/JSAHN/qubit-experiment/examples/selectiveRIP/laboneq_output/log
# [2026.01.04 22:45:01.821] INFO    VERSION: laboneq 25.10.2
# [2026.01.04 22:45:01.823] INFO    Connecting to data server at 192.168.0.83:8004
# [2026.01.04 22:45:01.857] INFO    Connected to Zurich Instruments LabOne Data Server version 25.10.1.4 at 192.168.0.83:8004
# [2026.01.04 22:45:01.887] INFO    Configuring the device setup
# [2026.01.04 22:45:01.908] INFO    The device setup is configured

# %%
from qpu_types import TransmonQubit, TransmonQubitParameters
from helper import load_qubit_parameters, save_qubit_parameters
from operations import TransmonOperations
from laboneq.dsl.quantum.qpu import QPU, QuantumPlatform



_loaded_qubits = load_qubit_parameters(filename="latest") 
#qubits = TransmonQubit.from_device_setup(setup) # Also can be done with load_qubit_parameters 
qubits = list(_loaded_qubits.values())





qpu = QPU(quantum_elements=qubits, quantum_operations=TransmonOperations())
#quantum_platform = QuantumPlatform(setup=setup, qpu=qpu)

# qpu.topology.add_edge("bus", "q16", "q17")
# qpu.topology.add_edge("bus", "q17", "q18")
# qpu.topology.add_edge("bus", "q18", "q19")
# qpu.topology.plot()




from laboneq.simple import workflow
folder_store = workflow.logbook.FolderStore("./experiment_store") 
folder_store.activate()
#folder_store.deactivate()
#workflow.logbook.LoggingStore().activate()
#workflow.logbook.LogbookStore().deactivate()
# Out:
# LOADED:./qubit_parameters/20260104-2228_sample2.json

# %%
res_freq = qubits[1].parameters.readout_resonator_frequency
res_lo_freq = qubits[1].parameters.readout_lo_frequency
res_amp_range = qubits[1].parameters.readout_range_out
res_amp = qubits[1].parameters.readout_amplitude

q_freq = qubits[1].parameters.resonance_frequency_ge 
q_lo_freq = qubits[1].parameters.drive_lo_frequency 
q_amp_range = qubits[1].parameters.drive_range
q_amp = qubits[1].parameters.spectroscopy_amplitude #0.003


print(res_freq)
print(res_lo_freq)
print(res_amp_range)
print(res_amp)
print("==================")
print(q_freq)
print(q_lo_freq)
print(q_amp_range)
print(q_amp)
q.parameters
# Out:
# 7237131085.767722
# 7200000000.0
# 0
# 0.4
# ==================
# 3954845560.928186
# 4000000000.0
# 10
# 0.002
# TransmonQubitParameters(
# │   custom={},
# │   ge_T1=1.1272547581702817e-05,
# │   ge_T2=0,
# │   ge_T2_star=7.50613533972988e-06,
# │   ef_T1=0,
# │   ef_T2=0,
# │   ef_T2_star=0,
# │   drive_lo_frequency=4000000000.0,
# │   readout_lo_frequency=7200000000.0,
# │   resonance_frequency_ge=3954845560.928186,
# │   resonance_frequency_ef=None,
# │   readout_resonator_frequency=7237131085.767722,
# │   resonance_targ_frequency=None,
# │   ge_drive_amplitude_pi=0.5520653764076691,
# │   ge_drive_amplitude_pi2=0.2788283689914472,
# │   ge_drive_length=6.4e-08,
# │   ge_drive_pulse={
# │   │   'function': 'drag',
# │   │   'beta': 0,
# │   │   'sigma': 0.25
# │   },
# │   ef_drive_amplitude_pi=0.2,
# │   ef_drive_amplitude_pi2=0.1,
# │   ef_drive_length=5e-08,
# │   ef_drive_pulse={
# │   │   'function': 'drag',
# │   │   'beta': 0,
# │   │   'sigma': 0.25
# │   },
# │   cr_drive_amplitude=None,
# │   cr_drive_length=None,
# │   cr_drive_phase=None,
# │   cr_drive_pulse={
# │   │   'function': 'GaussianSquareDRAG',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0,
# │   │   'beta0': 0.0,
# │   │   'beta1': 0.0
# │   },
# │   cr_drive_cancel_amplitude=None,
# │   cr_drive_cancel_length=None,
# │   cr_drive_cancel_phase=None,
# │   cr_drive_cancel_pulse={
# │   │   'function': 'GaussianSquareDRAG',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0,
# │   │   'beta0': 0.0,
# │   │   'beta1': 0.0
# │   },
# │   qubit_resonator_coupling_strength_g=0,
# │   ge_chi_shift=0,
# │   readout_amplitude=0.4,
# │   readout_length=1e-06,
# │   readout_pulse={
# │   │   'function': 'GaussianSquare',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0
# │   },
# │   readout_integration_length=8e-07,
# │   readout_integration_delay=3.2e-07,
# │   readout_integration_kernels_type='default',
# │   readout_integration_kernels=None,
# │   readout_integration_discrimination_thresholds=None,
# │   reset_delay_length=0.0001,
# │   drive_range=10,
# │   readout_range_out=0,
# │   readout_range_in=0,
# │   spectroscopy_length=1e-05,
# │   spectroscopy_amplitude=0.002,
# │   spectroscopy_pulse={
# │   │   'function': 'GaussianSquare',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0
# │   },
# │   user_defined={}
# )

# %% [markdown]
# # Resonator Spectroscopy

# %%
from experiments import resonator_spectroscopy

####################################################################################
q=qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
#temp_pars.readout_resonator_frequency = 7.6283e9 #6.04036e9 #mode1
# temp_pars.readout_range_out = - 10

# temp_pars.reset_delay_length =200e-6
#temp_pars.readout_lo_frequency = 5.6e9
temporary_parameters[q.uid] = temp_pars
print(q.readout_parameters())
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#frequencies = q.parameters.readout_resonator_frequency + np.linspace(-10e6,10e6,501)
frequencies = temp_pars.readout_resonator_frequency + np.linspace(-2.0e6,2.0e6,1001)
#####################################################################################
options = resonator_spectroscopy.experiment_workflow.options()
#workflow.show_fields(options)
options.count(1024)
options.update(False)
options.use_cw(False) #qop.measure 
#options.fit_complex_resonator(False)
options.fit_lorentzian(True)
######################################################################################
# Build and run resonator_spectroscopy_amplitude wormflow
res_spec = resonator_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=q,
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)
res_spec_result = res_spec.run()
res_spec_analysis_result = res_spec_result.tasks["analysis_workflow"]
pprint(res_spec_analysis_result.output)
# Out:
# ('measure', {'amplitude': 0.4, 'length': 1e-06, 'pulse': {'function': 'GaussianSquare', 'sigma': 0.2, 'risefall_sigma_ratio': 3.0}})
# DRIVE range (dBm) : 10, READOUT range (dBm) : 0
# [2026.01.04 22:04:48.486] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:04:48.486] INFO      Workflow 'resonator_spectroscopy': execution started at 2026-01-04
# [2026.01.04 22:04:48.486] INFO      13:04:48.485980Z
# [2026.01.04 22:04:48.487] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:04:48.497] INFO    Task 'temporary_qpu': started at 2026-01-04 13:04:48.497272Z
# [2026.01.04 22:04:48.498] INFO    Task 'temporary_qpu': ended at 2026-01-04 13:04:48.498432Z
# [2026.01.04 22:04:48.500] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-04
# [2026.01.04 22:04:48.501] INFO    13:04:48.500634Z
# [2026.01.04 22:04:48.501] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-04 13:04:48.501400Z
# [2026.01.04 22:04:48.502] INFO    Task 'create_experiment': started at 2026-01-04 13:04:48.502200Z
# [2026.01.04 22:04:48.508] INFO    Task 'create_experiment': ended at 2026-01-04 13:04:48.507801Z
# [2026.01.04 22:04:48.509] INFO    Task 'compile_experiment': started at 2026-01-04 13:04:48.509587Z
# [2026.01.04 22:04:48.512] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.04 22:04:48.512] INFO    Starting LabOne Q Compiler run...
# [2026.01.04 22:04:48.755] INFO    Schedule completed. [0.239 s]
# [2026.01.04 22:04:48.809] INFO    Code generation completed for all AWGs. [0.053 s]
# [2026.01.04 22:04:48.809] INFO    Completed compilation step 1 of 1. [0.294 s]
# [2026.01.04 22:04:48.811] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:04:48.811] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.04 22:04:48.811] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:04:48.812] INFO      SHFQC_DEV12256        0         21            0           1      4000
# [2026.01.04 22:04:48.812] INFO      SHFQC_DEV12256_sg     1          9            1           0         0
# [2026.01.04 22:04:48.812] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:04:48.812] INFO      TOTAL                           30            1                  4000
# [2026.01.04 22:04:48.812] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:04:48.815] INFO    Finished LabOne Q Compiler run.
# [2026.01.04 22:04:48.816] INFO    Task 'compile_experiment': ended at 2026-01-04 13:04:48.816091Z
# [2026.01.04 22:04:48.821] INFO    Task 'run_experiment': started at 2026-01-04 13:04:48.820869Z
# [2026.01.04 22:04:49.264] INFO    Starting near-time execution...
# [2026.01.04 22:04:51.685] INFO    Finished near-time execution.
# [2026.01.04 22:04:51.800] INFO    Task 'run_experiment': ended at 2026-01-04 13:04:51.800393Z
# [2026.01.04 22:04:51.802] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:04:51.802] INFO      Workflow 'analysis_workflow': execution started at 2026-01-04
# [2026.01.04 22:04:51.802] INFO      13:04:51.802042Z
# [2026.01.04 22:04:51.803] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:04:51.805] INFO    Task 'calculate_signal_magnitude_and_phase': started at 2026-01-04
# [2026.01.04 22:04:51.805] INFO    13:04:51.805310Z
# [2026.01.04 22:04:51.806] INFO    Task 'calculate_signal_magnitude_and_phase': ended at 2026-01-04
# [2026.01.04 22:04:51.807] INFO    13:04:51.806589Z
# [2026.01.04 22:04:51.808] INFO    Task 'fit_data': started at 2026-01-04 13:04:51.808113Z
# [2026.01.04 22:04:51.815] INFO    Task 'fit_data': ended at 2026-01-04 13:04:51.815097Z
# [2026.01.04 22:04:51.816] INFO    Task 'extract_qubit_parameters': started at 2026-01-04 13:04:51.816054Z
# [2026.01.04 22:04:51.817] INFO    Task 'extract_qubit_parameters': ended at 2026-01-04 13:04:51.816993Z
# [2026.01.04 22:04:51.817] INFO    Task 'plot_raw_complex_data_1d': started at 2026-01-04 13:04:51.817529Z
# [2026.01.04 22:04:51.826] INFO    Artifact: 'Raw_data_q1' of type 'Figure' logged at 2026-01-04 13:04:51.826282Z
# [2026.01.04 22:04:51.903] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-01-04 13:04:51.902819Z
# [2026.01.04 22:04:51.903] INFO    Task 'plot_magnitude_phase': started at 2026-01-04 13:04:51.903647Z
# [2026.01.04 22:04:51.912] INFO    Artifact: 'Magnitude_Phase_q1' of type 'Figure' logged at 2026-01-04
# [2026.01.04 22:04:51.913] INFO    13:04:51.912763Z
# [2026.01.04 22:04:51.991] INFO    Task 'plot_magnitude_phase': ended at 2026-01-04 13:04:51.990918Z
# [2026.01.04 22:04:51.991] INFO    Task 'plot_real_imaginary': started at 2026-01-04 13:04:51.991677Z
# [2026.01.04 22:04:51.996] INFO    Artifact: 'Real_Imaginary_q1' of type 'Figure' logged at 2026-01-04
# [2026.01.04 22:04:51.997] INFO    13:04:51.996426Z
# [2026.01.04 22:04:52.042] INFO    Task 'plot_real_imaginary': ended at 2026-01-04 13:04:52.042164Z
# [2026.01.04 22:04:52.043] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:04:52.043] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-04 13:04:52.042921Z
# [2026.01.04 22:04:52.043] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:04:52.043] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:04:52.044] INFO      Workflow 'resonator_spectroscopy': execution ended at 2026-01-04
# [2026.01.04 22:04:52.044] INFO      13:04:52.043756Z
# [2026.01.04 22:04:52.044] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'new_parameter_values': {'q1': {'readout_resonator_frequency': 7237050529.844025+/-2252.8995714957973}},
#  'old_parameter_values': {'q1': {'readout_resonator_frequency': 7237131085.767722}}}

# %%
from experiments import qubit_spectroscopy

###############################################################
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temp_pars.spectroscopy_amplitude = 0.002 #0.003
temporary_parameters[q.uid] = temp_pars

#q.parameters.readout_amplitude = 1.0
frequencies = q.parameters.resonance_frequency_ge+ np.linspace(-1e6, 1e6, 201)
#print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
pprint(q.readout_parameters())
pprint(q.spectroscopy_parameters())
################################################################
options = qubit_spectroscopy.experiment_workflow.options()
options.update(False)
options.count(1024)
# workflow.show_fields(options)
###################################################################
qubit_spec = qubit_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)

qubit_spec_result = qubit_spec.run()
qubit_spec_result
# Out:
# ('measure',
#  {'amplitude': 0.4,
#   'length': 1e-06,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# ('drive',
#  {'amplitude': 0.002,
#   'length': 1e-05,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# [2026.01.04 22:11:38.486] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:11:38.486] INFO      Workflow 'qubit_spectroscopy': execution started at 2026-01-04
# [2026.01.04 22:11:38.486] INFO      13:11:38.485832Z
# [2026.01.04 22:11:38.487] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:11:38.495] INFO    Task 'temporary_qpu': started at 2026-01-04 13:11:38.495489Z
# [2026.01.04 22:11:38.496] INFO    Task 'temporary_qpu': ended at 2026-01-04 13:11:38.496435Z
# [2026.01.04 22:11:38.498] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-04
# [2026.01.04 22:11:38.498] INFO    13:11:38.498326Z
# [2026.01.04 22:11:38.499] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-04 13:11:38.498926Z
# [2026.01.04 22:11:38.499] INFO    Task 'create_experiment': started at 2026-01-04 13:11:38.499554Z
# [2026.01.04 22:11:38.504] INFO    Task 'create_experiment': ended at 2026-01-04 13:11:38.503869Z
# [2026.01.04 22:11:38.505] INFO    Task 'compile_experiment': started at 2026-01-04 13:11:38.505054Z
# [2026.01.04 22:11:38.506] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal '/logical_signal_groups/q1/acquire' to SOFTWARE
# [2026.01.04 22:11:38.507] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.04 22:11:38.507] INFO    Starting LabOne Q Compiler run...
# [2026.01.04 22:11:38.535] INFO    Schedule completed. [0.027 s]
# [2026.01.04 22:11:38.650] INFO    Code generation completed for all AWGs. [0.115 s]
# [2026.01.04 22:11:38.651] INFO    Completed compilation step 1 of 1. [0.143 s]
# [2026.01.04 22:11:38.653] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:11:38.653] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.04 22:11:38.653] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:11:38.654] INFO      SHFQC_DEV12256        0         10            0           1      4000
# [2026.01.04 22:11:38.654] INFO      SHFQC_DEV12256_sg     1         23            2           1     40000
# [2026.01.04 22:11:38.654] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:11:38.654] INFO      TOTAL                           33            2                 44000
# [2026.01.04 22:11:38.654] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:11:38.657] INFO    Finished LabOne Q Compiler run.
# [2026.01.04 22:11:38.657] INFO    Task 'compile_experiment': ended at 2026-01-04 13:11:38.657840Z
# [2026.01.04 22:11:38.663] INFO    Task 'run_experiment': started at 2026-01-04 13:11:38.663371Z
# [2026.01.04 22:11:38.802] INFO    Starting near-time execution...
# [2026.01.04 22:11:39.016] INFO    Estimated RT execution time: 43.45 s.
# [2026.01.04 22:12:22.661] INFO    Finished near-time execution.
# [2026.01.04 22:12:22.777] INFO    Task 'run_experiment': ended at 2026-01-04 13:12:22.776766Z
# [2026.01.04 22:12:22.780] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:12:22.780] INFO      Workflow 'analysis_workflow': execution started at 2026-01-04
# [2026.01.04 22:12:22.781] INFO      13:12:22.779733Z
# [2026.01.04 22:12:22.782] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:12:22.785] INFO    Task 'calculate_signal_magnitude_and_phase': started at 2026-01-04
# [2026.01.04 22:12:22.785] INFO    13:12:22.784810Z
# [2026.01.04 22:12:22.786] INFO    Task 'calculate_signal_magnitude_and_phase': ended at 2026-01-04
# [2026.01.04 22:12:22.786] INFO    13:12:22.785940Z
# [2026.01.04 22:12:22.786] INFO    Task 'fit_data': started at 2026-01-04 13:12:22.786712Z
# [2026.01.04 22:12:22.791] INFO    Task 'fit_data': ended at 2026-01-04 13:12:22.791565Z
# [2026.01.04 22:12:22.792] INFO    Task 'extract_qubit_parameters': started at 2026-01-04 13:12:22.792355Z
# [2026.01.04 22:12:22.793] INFO    Task 'extract_qubit_parameters': ended at 2026-01-04 13:12:22.793423Z
# [2026.01.04 22:12:22.794] INFO    Task 'plot_raw_complex_data_1d': started at 2026-01-04 13:12:22.793974Z
# [2026.01.04 22:12:22.802] INFO    Artifact: 'Raw_data_q1' of type 'Figure' logged at 2026-01-04 13:12:22.802726Z
# [2026.01.04 22:12:22.879] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-01-04 13:12:22.878891Z
# [2026.01.04 22:12:22.879] INFO    Task 'plot_qubit_spectroscopy': started at 2026-01-04 13:12:22.879755Z
# [2026.01.04 22:12:22.885] INFO    Artifact: 'Qubit_Spectroscopy_q1' of type 'Figure' logged at 2026-01-04
# [2026.01.04 22:12:22.885] INFO    13:12:22.885263Z
# [2026.01.04 22:12:22.938] INFO    Task 'plot_qubit_spectroscopy': ended at 2026-01-04 13:12:22.938108Z
# [2026.01.04 22:12:22.939] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:12:22.939] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-04 13:12:22.939051Z
# [2026.01.04 22:12:22.939] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:12:22.940] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:12:22.940] INFO      Workflow 'qubit_spectroscopy': execution ended at 2026-01-04
# [2026.01.04 22:12:22.940] INFO      13:12:22.940283Z
# [2026.01.04 22:12:22.941] INFO     ──────────────────────────────────────────────────────────────────────────────
# WorkflowResult(name=qubit_spectroscopy, index=())

# %% [markdown]
# # Dispersive Shift

# %%
qubits[1].parameters
# Out:
# TransmonQubitParameters(
# │   custom={},
# │   ge_T1=1.1272547581702817e-05,
# │   ge_T2=0,
# │   ge_T2_star=7.269352382266447e-06,
# │   ef_T1=0,
# │   ef_T2=0,
# │   ef_T2_star=0,
# │   drive_lo_frequency=4000000000.0,
# │   readout_lo_frequency=7200000000.0,
# │   resonance_frequency_ge=3954859644.737195,
# │   resonance_frequency_ef=None,
# │   readout_resonator_frequency=7237131085.767722,
# │   resonance_targ_frequency=None,
# │   ge_drive_amplitude_pi=0.5580004053673602,
# │   ge_drive_amplitude_pi2=0.27733901485856194,
# │   ge_drive_length=6.4e-08,
# │   ge_drive_pulse={
# │   │   'function': 'drag',
# │   │   'beta': 0,
# │   │   'sigma': 0.25
# │   },
# │   ef_drive_amplitude_pi=0.2,
# │   ef_drive_amplitude_pi2=0.1,
# │   ef_drive_length=5e-08,
# │   ef_drive_pulse={
# │   │   'function': 'drag',
# │   │   'beta': 0,
# │   │   'sigma': 0.25
# │   },
# │   cr_drive_amplitude=None,
# │   cr_drive_length=None,
# │   cr_drive_phase=None,
# │   cr_drive_pulse={
# │   │   'function': 'GaussianSquareDRAG',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0,
# │   │   'beta0': 0.0,
# │   │   'beta1': 0.0
# │   },
# │   cr_drive_cancel_amplitude=None,
# │   cr_drive_cancel_length=None,
# │   cr_drive_cancel_phase=None,
# │   cr_drive_cancel_pulse={
# │   │   'function': 'GaussianSquareDRAG',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0,
# │   │   'beta0': 0.0,
# │   │   'beta1': 0.0
# │   },
# │   qubit_resonator_coupling_strength_g=0,
# │   ge_chi_shift=0,
# │   readout_amplitude=0.4,
# │   readout_length=1.2e-06,
# │   readout_pulse={
# │   │   'function': 'GaussianSquare',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0
# │   },
# │   readout_integration_length=8e-07,
# │   readout_integration_delay=4e-07,
# │   readout_integration_kernels_type='default',
# │   readout_integration_kernels=None,
# │   readout_integration_discrimination_thresholds=None,
# │   reset_delay_length=0.0001,
# │   drive_range=10,
# │   readout_range_out=0,
# │   readout_range_in=0,
# │   spectroscopy_length=1e-05,
# │   spectroscopy_amplitude=0.002,
# │   spectroscopy_pulse={
# │   │   'function': 'GaussianSquare',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0
# │   },
# │   user_defined={}
# )

# %%
from experiments import dispersive_shift

#######################################################################
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)

#temp_pars.readout_resonator_frequency = 7.5582e9
temporary_parameters[q.uid] = temp_pars

print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = dispersive_shift.experiment_workflow.options()
options.count(1024)
options.update(False)
#print(workflow.show_fields(options))

###################################################################
dispersive = dispersive_shift.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=q,
    frequencies=q.parameters.readout_resonator_frequency + np.linspace(-5e6,5e6,201),
    options=options,
    states='ge',
    temporary_parameters=temporary_parameters
)

dispersive_result = dispersive.run() 
print(dispersive_result.tasks['analysis_workflow'].output)
# Out:
# DRIVE range (dBm) : 10, READOUT range (dBm) : 0
# [2026.01.04 22:45:50.357] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:45:50.358] INFO      Workflow 'dispersive_shift': execution started at 2026-01-04
# [2026.01.04 22:45:50.358] INFO      13:45:50.357454Z
# [2026.01.04 22:45:50.358] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:45:50.368] INFO    Task 'temporary_qpu': started at 2026-01-04 13:45:50.368134Z
# [2026.01.04 22:45:50.369] INFO    Task 'temporary_qpu': ended at 2026-01-04 13:45:50.369197Z
# [2026.01.04 22:45:50.371] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-04
# [2026.01.04 22:45:50.371] INFO    13:45:50.371228Z
# [2026.01.04 22:45:50.372] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-04 13:45:50.371901Z
# [2026.01.04 22:45:50.372] INFO    Task 'create_experiment': started at 2026-01-04 13:45:50.372783Z
# [2026.01.04 22:45:50.378] INFO    Task 'create_experiment': ended at 2026-01-04 13:45:50.378606Z
# [2026.01.04 22:45:50.382] INFO    Task 'compile_experiment': started at 2026-01-04 13:45:50.381880Z
# [2026.01.04 22:45:50.385] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.04 22:45:50.385] INFO    Starting LabOne Q Compiler run...
# [2026.01.04 22:45:50.510] INFO    Schedule completed. [0.124 s]
# [2026.01.04 22:45:50.535] INFO    Code generation completed for all AWGs. [0.023 s]
# [2026.01.04 22:45:50.535] INFO    Completed compilation step 1 of 1. [0.149 s]
# [2026.01.04 22:45:50.537] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:45:50.537] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.04 22:45:50.538] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:45:50.538] INFO      SHFQC_DEV12256        0         27            0           1      4800
# [2026.01.04 22:45:50.538] INFO      SHFQC_DEV12256_sg     1         14            2           1       256
# [2026.01.04 22:45:50.538] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:45:50.538] INFO      TOTAL                           41            2                  5056
# [2026.01.04 22:45:50.538] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:45:50.542] INFO    Finished LabOne Q Compiler run.
# [2026.01.04 22:45:50.543] INFO    Task 'compile_experiment': ended at 2026-01-04 13:45:50.543058Z
# [2026.01.04 22:45:50.549] INFO    Task 'run_experiment': started at 2026-01-04 13:45:50.549228Z
# [2026.01.04 22:45:50.692] INFO    Starting near-time execution...
# [2026.01.04 22:45:50.855] INFO    Estimated RT execution time: 41.69 s.
# [2026.01.04 22:46:32.740] INFO    Finished near-time execution.
# [2026.01.04 22:46:32.885] INFO    Task 'run_experiment': ended at 2026-01-04 13:46:32.884951Z
# [2026.01.04 22:46:32.886] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:46:32.887] INFO      Workflow 'analysis_workflow': execution started at 2026-01-04
# [2026.01.04 22:46:32.887] INFO      13:46:32.886612Z
# [2026.01.04 22:46:32.888] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:46:32.889] INFO    Task 'calculate_signal_differences': started at 2026-01-04 13:46:32.889504Z
# [2026.01.04 22:46:32.890] INFO    Task 'calculate_signal_differences': ended at 2026-01-04 13:46:32.890084Z
# [2026.01.04 22:46:32.890] INFO    Task 'extract_qubit_parameters': started at 2026-01-04 13:46:32.890665Z
# [2026.01.04 22:46:32.891] INFO    Task 'extract_qubit_parameters': ended at 2026-01-04 13:46:32.891219Z
# [2026.01.04 22:46:32.891] INFO    Task 'plot_dispersive_shift': started at 2026-01-04 13:46:32.891694Z
# [2026.01.04 22:46:32.903] INFO    Artifact: 'Dispersive_shift_q1' of type 'Figure' logged at 2026-01-04
# [2026.01.04 22:46:32.904] INFO    13:46:32.903330Z
# [2026.01.04 22:46:33.017] INFO    Task 'plot_dispersive_shift': ended at 2026-01-04 13:46:33.017527Z
# [2026.01.04 22:46:33.018] INFO    Task 'plot_signal_distances': started at 2026-01-04 13:46:33.018822Z
# [2026.01.04 22:46:33.025] INFO    Artifact: 'Signal_distances_q1' of type 'Figure' logged at 2026-01-04
# [2026.01.04 22:46:33.026] INFO    13:46:33.025177Z
# [2026.01.04 22:46:33.074] INFO    Task 'plot_signal_distances': ended at 2026-01-04 13:46:33.074156Z
# [2026.01.04 22:46:33.075] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:46:33.076] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-04 13:46:33.075474Z
# [2026.01.04 22:46:33.077] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:46:33.078] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:46:33.078] INFO      Workflow 'dispersive_shift': execution ended at 2026-01-04 13:46:33.078033Z
# [2026.01.04 22:46:33.078] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'old_parameter_values': {'q1': {'readout_resonator_frequency': 7237131085.767722}}, 'new_parameter_values': {'q1': {'readout_resonator_frequency': np.float64(7236481085.767722)}}}

# %% [markdown]
# # Params

# %% [markdown]
# # IQ Blobs
#
# AcquisitionType : INTEGRATION
# AveragingMode : SINGLESHOT

# %%
from experiments import iq_blobs

#######################################################################
q = qubits[1]

temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temp_pars.readout_length = 1.2e-6
temp_pars.readout_integration_length = 0.6e-6
temp_pars.readout_integration_delay = 0.4e-6
temp_pars.readout_resonator_frequency = 7.236e9
temp_pars.readout_amplitude = 0.7

temporary_parameters[q.uid] = temp_pars
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = iq_blobs.experiment_workflow.options()
options.count(2**14)
#print(workflow.show_fields(options))

###################################################################
iq = iq_blobs.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    options=options,
    states='ge',
    temporary_parameters=temporary_parameters
)
iq_blob_result = iq.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
iq_blob_result.tasks['analysis_workflow'].tasks['plot_iq_blobs'].output[q.uid]
print(iq_blob_result.tasks['analysis_workflow'].output)
# Out:
# DRIVE range (dBm) : 10, READOUT range (dBm) : 0
# [2026.01.04 22:57:28.335] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:57:28.336] INFO      Workflow 'iq_blobs': execution started at 2026-01-04 13:57:28.335511Z
# [2026.01.04 22:57:28.336] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:57:28.344] INFO    Task 'temporary_qpu': started at 2026-01-04 13:57:28.343936Z
# [2026.01.04 22:57:28.345] INFO    Task 'temporary_qpu': ended at 2026-01-04 13:57:28.345062Z
# [2026.01.04 22:57:28.347] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-04
# [2026.01.04 22:57:28.347] INFO    13:57:28.347270Z
# [2026.01.04 22:57:28.348] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-04 13:57:28.348263Z
# [2026.01.04 22:57:28.349] INFO    Task 'create_experiment': started at 2026-01-04 13:57:28.349132Z
# [2026.01.04 22:57:28.355] INFO    Task 'create_experiment': ended at 2026-01-04 13:57:28.354931Z
# [2026.01.04 22:57:28.356] INFO    Task 'compile_experiment': started at 2026-01-04 13:57:28.356500Z
# [2026.01.04 22:57:28.359] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal '/logical_signal_groups/q1/acquire' to SOFTWARE
# [2026.01.04 22:57:28.359] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.04 22:57:28.360] INFO    Starting LabOne Q Compiler run...
# [2026.01.04 22:57:28.361] INFO    Schedule completed. [0.001 s]
# [2026.01.04 22:57:28.363] INFO    Code generation completed for all AWGs. [0.001 s]
# [2026.01.04 22:57:28.363] INFO    Completed compilation step 1 of 1. [0.003 s]
# [2026.01.04 22:57:28.366] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:57:28.366] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.04 22:57:28.366] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:57:28.366] INFO      SHFQC_DEV12256        0          9            0           1      4800
# [2026.01.04 22:57:28.367] INFO      SHFQC_DEV12256_sg     1         12            2           1       256
# [2026.01.04 22:57:28.367] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:57:28.367] INFO      TOTAL                           21            2                  5056
# [2026.01.04 22:57:28.367] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:57:28.370] INFO    Finished LabOne Q Compiler run.
# [2026.01.04 22:57:28.371] INFO    Task 'compile_experiment': ended at 2026-01-04 13:57:28.371436Z
# [2026.01.04 22:57:28.377] INFO    Task 'run_experiment': started at 2026-01-04 13:57:28.377463Z
# [2026.01.04 22:57:28.481] INFO    Starting near-time execution...
# [2026.01.04 22:57:38.267] INFO    Finished near-time execution.
# [2026.01.04 22:57:38.384] INFO    Task 'run_experiment': ended at 2026-01-04 13:57:38.384016Z
# [2026.01.04 22:57:38.389] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:57:38.389] INFO      Workflow 'analysis_workflow': execution started at 2026-01-04
# [2026.01.04 22:57:38.390] INFO      13:57:38.389260Z
# [2026.01.04 22:57:38.390] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:57:38.391] INFO    Task 'collect_shots': started at 2026-01-04 13:57:38.391465Z
# [2026.01.04 22:57:38.392] INFO    Task 'collect_shots': ended at 2026-01-04 13:57:38.392106Z
# [2026.01.04 22:57:38.400] INFO    Task 'fit_data': started at 2026-01-04 13:57:38.399779Z
# [2026.01.04 22:57:38.525] INFO    Task 'fit_data': ended at 2026-01-04 13:57:38.525670Z
# [2026.01.04 22:57:38.526] WARNING Type <class 'dict'> has the following unsupported values: {'mapping': value={0: 1, 1: 0} type=dict}. Only dictionaries with values of the following types are supported: [NoneType, int, float, complex, bool, str, dict, list, tuple, integer, ndarray, ModelResult, Variable, AffineScalarFunc, BaseEstimator]. [name: fit_data.output.q1].
# [2026.01.04 22:57:38.527] INFO    Task 'calculate_assignment_matrices': started at 2026-01-04 13:57:38.527052Z
# [2026.01.04 22:57:38.527] WARNING Type <class 'dict'> has the following unsupported values: {'q1': value={'model': GaussianMixture(max_iter=500, n_components=2, random_state=0), 'method': 'gmm', 'mapping': {0: 1, 1: 0}} type=dict}. Only dictionaries with values of the following types are supported: [NoneType, int, float, complex, bool, str, dict, list, tuple, integer, ndarray, ModelResult, Variable, AffineScalarFunc, BaseEstimator]. [name: calculate_assignment_matrices.input.fit_results].
# [2026.01.04 22:57:38.536] INFO    Task 'calculate_assignment_matrices': ended at 2026-01-04 13:57:38.536762Z
# [2026.01.04 22:57:38.537] INFO    Task 'calculate_assignment_fidelities': started at 2026-01-04 13:57:38.537682Z
# [2026.01.04 22:57:38.538] INFO    Task 'calculate_assignment_fidelities': ended at 2026-01-04 13:57:38.538305Z
# [2026.01.04 22:57:38.538] INFO    Task 'plot_iq_blobs': started at 2026-01-04 13:57:38.538673Z
# [2026.01.04 22:57:38.539] WARNING Type <class 'dict'> has the following unsupported values: {'q1': value={'model': GaussianMixture(max_iter=500, n_components=2, random_state=0), 'method': 'gmm', 'mapping': {0: 1, 1: 0}} type=dict}. Only dictionaries with values of the following types are supported: [NoneType, int, float, complex, bool, str, dict, list, tuple, integer, ndarray, ModelResult, Variable, AffineScalarFunc, BaseEstimator]. [name: plot_iq_blobs.input.fit_results].
# [2026.01.04 22:57:38.620] INFO    Artifact: 'IQ_blobs_q1' of type 'Figure' logged at 2026-01-04 13:57:38.620126Z
# [2026.01.04 22:57:38.760] INFO    Task 'plot_iq_blobs': ended at 2026-01-04 13:57:38.760462Z
# [2026.01.04 22:57:38.762] INFO    Task 'plot_assignment_matrices': started at 2026-01-04 13:57:38.761888Z
# [2026.01.04 22:57:38.773] INFO    Artifact: 'Assignment_matrix_q1' of type 'Figure' logged at 2026-01-04
# [2026.01.04 22:57:38.774] INFO    13:57:38.773336Z
# [2026.01.04 22:57:38.845] INFO    Task 'plot_assignment_matrices': ended at 2026-01-04 13:57:38.845520Z
# [2026.01.04 22:57:38.847] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:57:38.848] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-04 13:57:38.846963Z
# [2026.01.04 22:57:38.848] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:57:38.849] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:57:38.850] INFO      Workflow 'iq_blobs': execution ended at 2026-01-04 13:57:38.849237Z
# [2026.01.04 22:57:38.851] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'q1': np.float64(0.829010009765625)}

# %%
iq_blob_result

# %%
# from laboneq.simple import show_pulse_sheet
# from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

# show_pulse_sheet(compiled_experiment=iq_blob_result.tasks["compile_experiment"].output,name='test', interactive=True, max_events_to_publish=10000)

# %% [markdown]
# # IQ Traj
#
#
#
# To plot trajectory
# AcquisitionType : RAW
# AveragingMode : cyclic
#
#
#
# #### Readout Pulse Shaping
#
# rise and fall time $\tau_r$
# - $\tau_r \gg 1/\kappa$  $\implies$ adiabatic
# - $\tau_r \le 1/\kappa$  $\implies$ non-adiabatic
#
# 일반적인 steady state discrimination 이 목표라면 $\tau_r \approx 3 \sim 5 /\kappa$
#
#
# 의도적으로 non-adiabatic regime 에서 fast readout도 가능

# %%
# qubits[0].parameters.readout_integration_length = 0.8e-6
# qubits[0].parameters.readout_length = 1.0e-6

# %%
qubits[1].parameters
# Out:
# TransmonQubitParameters(
# │   custom={},
# │   ge_T1=1.1272547581702817e-05,
# │   ge_T2=0,
# │   ge_T2_star=7.119888078443992e-06,
# │   ef_T1=0,
# │   ef_T2=0,
# │   ef_T2_star=0,
# │   drive_lo_frequency=4000000000.0,
# │   readout_lo_frequency=7200000000.0,
# │   resonance_frequency_ge=3954567473.780986,
# │   resonance_frequency_ef=None,
# │   readout_resonator_frequency=7236100000.0,
# │   resonance_targ_frequency=None,
# │   ge_drive_amplitude_pi=0.554548769634859,
# │   ge_drive_amplitude_pi2=0.273672983227164,
# │   ge_drive_length=6.4e-08,
# │   ge_drive_pulse={
# │   │   'function': 'drag',
# │   │   'beta': 0,
# │   │   'sigma': 0.25
# │   },
# │   ef_drive_amplitude_pi=0.2,
# │   ef_drive_amplitude_pi2=0.1,
# │   ef_drive_length=5e-08,
# │   ef_drive_pulse={
# │   │   'function': 'drag',
# │   │   'beta': 0,
# │   │   'sigma': 0.25
# │   },
# │   cr_drive_amplitude=None,
# │   cr_drive_length=None,
# │   cr_drive_phase=None,
# │   cr_drive_pulse={
# │   │   'function': 'GaussianSquareDRAG',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0,
# │   │   'beta0': 0.0,
# │   │   'beta1': 0.0
# │   },
# │   cr_drive_cancel_amplitude=None,
# │   cr_drive_cancel_length=None,
# │   cr_drive_cancel_phase=None,
# │   cr_drive_cancel_pulse={
# │   │   'function': 'GaussianSquareDRAG',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0,
# │   │   'beta0': 0.0,
# │   │   'beta1': 0.0
# │   },
# │   qubit_resonator_coupling_strength_g=0,
# │   ge_chi_shift=0,
# │   readout_amplitude=0.7,
# │   readout_length=1e-06,
# │   readout_pulse={
# │   │   'function': 'GaussianSquare',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0
# │   },
# │   readout_integration_length=8e-07,
# │   readout_integration_delay=3.2e-07,
# │   readout_integration_kernels_type='default',
# │   readout_integration_kernels=None,
# │   readout_integration_discrimination_thresholds=None,
# │   reset_delay_length=0.0001,
# │   drive_range=10,
# │   readout_range_out=0,
# │   readout_range_in=0,
# │   spectroscopy_length=1e-05,
# │   spectroscopy_amplitude=0.002,
# │   spectroscopy_pulse={
# │   │   'function': 'GaussianSquare',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0
# │   },
# │   user_defined={}
# )

# %%
qubits[1].parameters.readout_integration_delay = 400e-9
qubits[1].parameters.readout_resonator_frequency = 7.236e9
qubits[1].parameters.readout_length = 1.2e-6
qubits[1].parameters.readout_integration_length = 600e-9
qubits[1].parameters.readout_range_out = 0

# %%
from experiments import iq_time_trace as iq_t

####################################################################################
q=qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temp_pars.readout_length = 1.2e-6
temp_pars.readout_integration_length = 0.6e-6
temp_pars.readout_integration_delay = 0.4e-6
temp_pars.readout_resonator_frequency = 7.236e9
temp_pars.readout_amplitude = 0.7
# temp_pars.readout_range_out = 15

temporary_parameters[q.uid] = temp_pars
#######################################################################
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
pprint(q.readout_parameters())
#######################################################################
options = iq_t.experiment_workflow.options()
options.count(2**14)
options.do_analysis(True)


#print(workflow.show_fields(options))

###################################################################
iq_trace_wf = iq_t.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    options=options,
    states='ge',
    temporary_parameters=temporary_parameters
)

iq_traj_result = iq_trace_wf.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
iq_traj_result.tasks['analysis_workflow'].tasks['plot_iq_time_traces'].output[q.uid]
# Out:
# DRIVE range (dBm) : 10, READOUT range (dBm) : 0
# ('measure',
#  {'amplitude': 0.4,
#   'length': 1.2e-06,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# [2026.01.04 22:56:53.566] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:56:53.567] INFO      Workflow 'iq_time_trace': execution started at 2026-01-04 13:56:53.566255Z
# [2026.01.04 22:56:53.567] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:56:53.575] INFO    Task 'temporary_qpu': started at 2026-01-04 13:56:53.575082Z
# [2026.01.04 22:56:53.576] INFO    Task 'temporary_qpu': ended at 2026-01-04 13:56:53.576113Z
# [2026.01.04 22:56:53.578] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-04
# [2026.01.04 22:56:53.579] INFO    13:56:53.578504Z
# [2026.01.04 22:56:53.579] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-04 13:56:53.579315Z
# [2026.01.04 22:56:53.580] INFO    Task 'create_experiment': started at 2026-01-04 13:56:53.580216Z
# [2026.01.04 22:56:53.585] INFO    Task 'create_experiment': ended at 2026-01-04 13:56:53.585468Z
# [2026.01.04 22:56:53.586] INFO    Task 'compile_experiment': started at 2026-01-04 13:56:53.586745Z
# [2026.01.04 22:56:53.588] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal '/logical_signal_groups/q1/acquire' to SOFTWARE
# [2026.01.04 22:56:53.588] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.04 22:56:53.589] INFO    Starting LabOne Q Compiler run...
# [2026.01.04 22:56:53.590] INFO    Schedule completed. [0.001 s]
# [2026.01.04 22:56:53.592] INFO    Code generation completed for all AWGs. [0.001 s]
# [2026.01.04 22:56:53.592] INFO    Completed compilation step 1 of 1. [0.002 s]
# [2026.01.04 22:56:53.593] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:56:53.594] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.04 22:56:53.594] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:56:53.595] INFO      SHFQC_DEV12256        0          9            0           1      4800
# [2026.01.04 22:56:53.595] INFO      SHFQC_DEV12256_sg     1         12            2           1       256
# [2026.01.04 22:56:53.595] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:56:53.595] INFO      TOTAL                           21            2                  5056
# [2026.01.04 22:56:53.595] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:56:53.598] INFO    Finished LabOne Q Compiler run.
# [2026.01.04 22:56:53.599] INFO    Task 'compile_experiment': ended at 2026-01-04 13:56:53.599420Z
# [2026.01.04 22:56:53.606] INFO    Task 'run_experiment': started at 2026-01-04 13:56:53.606478Z
# [2026.01.04 22:56:53.673] INFO    Starting near-time execution...
# [2026.01.04 22:56:57.141] INFO    Finished near-time execution.
# [2026.01.04 22:56:57.209] INFO    Task 'run_experiment': ended at 2026-01-04 13:56:57.209592Z
# [2026.01.04 22:56:57.211] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:56:57.211] INFO      Workflow 'analysis_workflow': execution started at 2026-01-04
# [2026.01.04 22:56:57.212] INFO      13:56:57.211311Z
# [2026.01.04 22:56:57.212] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:56:57.213] INFO    Task 'demodulate_time_traces': started at 2026-01-04 13:56:57.213192Z
# [2026.01.04 22:56:57.213] INFO    Task 'demodulate_time_traces': ended at 2026-01-04 13:56:57.213773Z
# [2026.01.04 22:56:57.214] INFO    Task 'average_chunk_time_traces': started at 2026-01-04 13:56:57.214408Z
# [2026.01.04 22:56:57.215] INFO    Task 'average_chunk_time_traces': ended at 2026-01-04 13:56:57.215211Z
# [2026.01.04 22:56:57.215] INFO    Task 'plot_iq_time_traces': started at 2026-01-04 13:56:57.215627Z
# [2026.01.04 22:56:57.236] INFO    Task 'plot_iq_time_traces': ended at 2026-01-04 13:56:57.236611Z
# [2026.01.04 22:56:57.431] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:56:57.432] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-04 13:56:57.430787Z
# [2026.01.04 22:56:57.433] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:56:57.433] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:56:57.434] INFO      Workflow 'iq_time_trace': execution ended at 2026-01-04 13:56:57.433783Z
# [2026.01.04 22:56:57.435] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# #### SAVING DATA

# %%
# from laboneq.simple import save, load


# #save(obj=iq_traj_result.output, filename='traj_test')

# RDATA = load(filename='traj_test')

# %% [markdown]
# - For $2\mu s$ acquire we have  2000ns/0.5ns=4000 sample

# %% [markdown]
# # Time Trace

# %%
qubits[0].readout_parameters()

# %%
from laboneq_applications.experiments import time_traces

q=qubits[0]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
# temp_pars.readout_amplitude = 0.4
# temp_pars.drive_lo_frequency = 4.6e9
# temp_pars.readout_length = 0.8e-6
# temp_pars.readout_integration_length=1e-6
temporary_parameters[q.uid] = temp_pars
#######################################################################
pprint(q.readout_parameters())
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")

cf = 50e6
#######################################################################
options = time_traces.experiment_workflow.options()
options.update(False)
options.filter_kernels(True)
options.filter_cutoff_frequency(cf)
options.granularity(1)

#print(workflow.show_fields(options))

###################################################################
raw_trace = time_traces.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    options=options,
    states='ge',
    temporary_parameters=temporary_parameters
)

raw_trace_result = raw_trace.run()
raw_trace_analysis_result = raw_trace_result.tasks['analysis_workflow'].output
print(raw_trace_analysis_result)

# %%
# from laboneq.simple import show_pulse_sheet
# from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

# show_pulse_sheet(compiled_experiment=raw_trace_result.tasks["compile_experiment"].output,name='test', interactive=True)
# plot_simulation(compiled_experiment=raw_trace_result.tasks["compile_experiment"].output)

# %%
import matplotlib.pyplot as plt
tr_t=raw_trace_result.tasks['analysis_workflow'].tasks['truncate_time_traces'].output
#raw_trace_result.tasks['analysis_workflow'].tasks['extract_kernels_thresholds'].output

r=tr_t["q2"]


plt.plot(r[2])

# %%
import scipy as sp
krn=kernels
sos = sp.signal.butter(N=10, Wn=90e6,btype="lowpass", fs=2e9,output="sos")
fkrn=sp.signal.sosfiltfilt(sos, krn)

plt.plot(fkrn.real)
plt.plot(fkrn.imag)
# from analysis import time_traces
# time_traces.filter_integration_kernels(qubits=)

# %%
raw_trace_result.tasks['analysis_workflow'].tasks["plot_kernels_fft"].output['q2']

# %%
from laboneq_applications.analysis import time_traces
e_raw = raw_trace_result.output.data['q2']['result/e'].data
g_raw = raw_trace_result.output.data['q2']['result/g'].data

# %% [markdown]
# # Save Qubit Parameters

# %%
from helper import load_qubit_parameters, save_qubit_parameters
save_qubit_parameters(qubits={ qubit.uid : qubit for qubit in qubits}, save_folder="./qubit_parameters", filename="sample2")
# Out:
# Qubit parameters stored as JSON in /home/yalgaeahn/JSAHN/qubit-experiment/examples/selectiveRIP/qubit_parameters/20260104-2259_sample2.json
