# %% [markdown]
# # 2nd_sample_1229

# %% [markdown]
# # Initialization

# %%
import numpy as np
from pprint import pprint
from copy import deepcopy


from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
#from laboneq.contrib.example_helpers.generate_device_setup import generate_device_setup
from laboneq.dsl.device import DeviceSetup




descriptor = generate_descriptor(
    #pqsc=[""], # 장비 여러개 사용시
    shfqc_6=["DEV12256"],
    number_data_qubits=6,
    multiplex=True,
    number_multiplex=6,
    include_cr_lines=True,
    include_ef_lines=True,
    get_zsync=False,  # Only set to True when using real device
    save = True,
    filename="TG_RIP_2",
    ip_address="192.168.0.83"
)


#descriptor
setup = DeviceSetup.from_descriptor(yaml_text=descriptor, server_host="192.168.0.83")
#setup
setup.instruments[0].device_options = 'SHFQC/PLUS/QC6CH'
#setup.instruments

# %%
from laboneq.simple import Session
session = Session(setup)
session.connect(ignore_version_mismatch=False, do_emulation=True)
#session.disconnect()
# Out:
# [2026.01.06 15:17:03.406] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /Users/yalgaeahn/JSAHN/qubit-experiment/examples/selectiveRIP/laboneq_output/log
# [2026.01.06 15:17:03.408] INFO    VERSION: laboneq 25.10.2
# [2026.01.06 15:17:03.408] INFO    Connecting to data server at 192.168.0.83:8004
# [2026.01.06 15:17:03.409] INFO    Connected to Zurich Instruments LabOne Data Server version 25.10.1.4 at 192.168.0.83:8004
# [2026.01.06 15:17:03.410] INFO    Configuring the device setup
# [2026.01.06 15:17:03.411] INFO    The device setup is configured

# %%
from qpu_types import TransmonQubit, TransmonQubitParameters
from helper import load_qubit_parameters, save_qubit_parameters
from operations import TransmonOperations
from laboneq.dsl.quantum.qpu import QPU, QuantumPlatform



_loaded_qubits = load_qubit_parameters(filename="latest") 
#qubits = TransmonQubit.from_device_setup(setup) # Also can be done with load_qubit_parameters 
qubits = list(_loaded_qubits.values())





qpu = QPU(quantum_elements=qubits, quantum_operations=TransmonOperations())
#quantum_platform = QuantumPlatform(setup=setup, qpu=qpu)

# qpu.topology.add_edge("bus", "q16", "q17")
# qpu.topology.add_edge("bus", "q17", "q18")å
# qpu.topology.add_edge("bus", "q18", "q19")
# qpu.topology.plot()




from laboneq.simple import workflow
folder_store = workflow.logbook.FolderStore("./experiment_store") 
folder_store.activate()
#folder_store.deactivate()
#workflow.logbook.LoggingStore().activate()
#workflow.logbook.LogbookStore().deactivate()
# Out:
# LOADED:./qubit_parameters/20250911-2317_KRISS_q1718_cal.json

# %% [markdown]
# BF 7

# %%
# 0 : 15 , 1 : 16 , 2 : 17, 3 : 18, 4 : 19
# for q in qubits:
#     #q.parameters.ge_drive_pulse["sigma"] = 0.25
#     q.parameters.readout_amplitude = 1.0
#     q.parameters.reset_delay_length = 20e-6

#     q.parameters.readout_range_out = -10
#     q.parameters.readout_range_in = 0
#     q.parameters.drive_range = 10

#     q.parameters.readout_lo_frequency = 7.6e9
#     q.parameters.drive_lo_frequency = 4.8e9

#     q.parameters.spectroscopy_length = 10e-6

#     q.parameters.ge_drive_length =64e-9
#     q.parameters.readout_integration_delay =  200e-9#####



# #Q2
# qubits[0].parameters.resonance_frequency_ge = 4.123e9
# qubits[0].parameters.readout_resonator_frequency = 7.5584e9

# #Q3
# qubits[1].parameters.resonance_frequency_ge = 3.9542e9
# qubits[1].parameters.readout_resonator_frequency = 7.2371e9

# #Q1
# qubits[5].parameters.resonance_frequency_ge = 4.704e9
# qubits[5].parameters.readout_resonator_frequency = 7.3116e9



# qubits[2].parameters.drive_lo_frequency = 5.6e9
# qubits[2].parameters.resonance_targ_frequency = 5.6e9
# # qubits[2].parameters.resonance_frequency_ge = 4.716e9
# qubits[3].parameters.resonance_frequency_ge = 4.664e9
# qubits[4].parameters.resonance_frequency_ge = 4.779e9

# qubits[2].parameters.readout_resonator_frequency = 6.9226e9
# qubits[3].parameters.readout_resonator_frequency = 6.8433e9
# qubits[4].parameters.readout_resonator_frequency = 6.7739e9

# %% [markdown]
# 3 oscillator to be calibrated
# - `drive_local_osc`
# - `readout_local_osc`
# - `readout_acquire_osc`

# %%
# from laboneq.dsl.calibration import Calibration, Oscillator, SignalCalibration

# sibal= SignalCalibration()
# sibal.delay_signal

# %%
# from experiments import signal_propagation_delay
# options = signal_propagation_delay.experiment_workflow.options()
#workflow.show_fields(options)

# %% [markdown]
# Correcting propagation delay.
#
# $\Delta \phi =-2\pi f t$ $\implies$ $\tau = \frac{1}{\Delta f}$

# %%
# from experiments import signal_propagation_delay
# ####################################################################################
# qubits[0].parameters.readout_amplitude =1.0
# q=qubits[0]
# delays=np.linspace(0e-9, 200e9, 51)
# measure_delays = 40e-6
# pprint(q.readout_parameters())
# print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
# #####################################################################################
# options = signal_propagation_delay.experiment_workflow.options()
# #workflow.show_fields(options)
# options.update(False)
# ######################################################################################
# # Build and run resonator_spectroscopy_amplitude wormflow
# prop_delay = signal_propagation_delay.experiment_workflow(
#     session=session,
#     qpu=qpu,
#     qubit=q,
#     delays=delays,
#     measure_delay=measure_delays,
#     options=options
# )
# prop_delay_result=prop_delay.run()
# prop_delay_analysis_result = prop_delay_result.tasks["analysis_workflow"]
# pprint(prop_delay_analysis_result.output)

# %%
prop_delay_analysis_result.tasks["plot_data"].output['q0']

# %% [markdown]
# # 1. Spectroscopy

# %%
from helper import adjust_amplitude_for_output_range, calculate_power
adjust_amplitude_for_output_range(initial_output_dbm=0, initial_amplitude= 0.002, new_output_dbm=-5)
calculate_power(output_dbm=0, amplitude=0.001,attenuation=[])

# %% [markdown]
# ### 1.1 Resonator spectroscopy with amplitude sweep
#
# STRATEGY
# 1. CW spectroscpy for wide range scan
#     * CW spectroscopy can be done for wide range scan
#     * amplitude, frequency 2D sweep 을 통해  power에 따른 broadening 및 SNR 경향 관찰
#     * $\Delta F$ : frequency span,  $\Delta f_r$
#     * Pick $\Delta F / \Delta f_r$ 1~2

# %%
#qubits[5].parameters.drive_lo_frequency = 4.0e9
#qubits[5].parameters.readout_lo_frequency 
#qubits[5].parameters.readout_resonator_frequency =7.0350e9
# qubits[5].parameters.readout_amplitude = 0.3

# %%
from experiments import resonator_spectroscopy_amplitude

####################################################################################
q=qubits[5]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
#temp_pars.readout_amplitude = 1.0
#temp_pars.readout_resonator_frequency = 7.6283e9 #6.04036e9 #mode1
#temp_pars.readout_range_out = -10

temporary_parameters[q.uid] = temp_pars

pprint(q.readout_parameters())
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
frequencies = temp_pars.readout_resonator_frequency + np.linspace(-4e6,4e6,501)
amplitudes = np.linspace(0.0, 0.3, 21) #This works as scaling factor!!!!!!!!!!!!
#####################################################################################
options = resonator_spectroscopy_amplitude.experiment_workflow.options()
#workflow.show_fields(options)
options.update(False)
options.use_cw(True)

options.do_analysis(True)
######################################################################################
# Build and run resonator_spectroscopy_amplitude wormflow
res_spec_amp = resonator_spectroscopy_amplitude.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=q,
    frequencies=frequencies,
    amplitudes=amplitudes,
    temporary_parameters=temporary_parameters,
    options=options
)
res_spec_amp_result=res_spec_amp.run()

# %%
res_spec_amp_result.tasks["analysis_workflow"].tasks["plot_signal_magnitude_and_phase_2d"].output["q1"]

# %% [markdown]
# ### 1.2 Resonator Spectroscopy
# * CW not recommended

# %%
from experiments import resonator_spectroscopy

####################################################################################
q=qubits[5]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
#temp_pars.readout_resonator_frequency = 7.6283e9 #6.04036e9 #mode1
# temp_pars.readout_range_out = 15
# temp_pars.readout_amplitude = 1.0
# temp_pars.reset_delay_length =200e-6
#temp_pars.readout_lo_frequency = 5.6e9
# temp_pars.readout_range_out = 0
# temp_pars.readout_amplitude = 0.5
temp_pars.readout_resonator_frequency = 6.9182e9
temp_pars.readout_range_out = -10
temp_pars.readout_amplitude = 0.7
temporary_parameters[q.uid] = temp_pars
print(q.readout_parameters())
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#frequencies = q.parameters.readout_resonator_frequency + np.linspace(-10e6,10e6,501)
frequencies = temp_pars.readout_resonator_frequency + np.linspace(-2e6,2e6,2001)
#####################################################################################
options = resonator_spectroscopy.experiment_workflow.options()
#workflow.show_fields(options)
options.count(1024)
options.update(True)
options.use_cw(True) #qop.measure 
#options.fit_complex_resonator(False)
#options.fit_lorentzian(True)
######################################################################################
# Build and run resonator_spectroscopy_amplitude wormflow
res_spec = resonator_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=q,
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)
res_spec_result = res_spec.run()
res_spec_analysis_result = res_spec_result.tasks["analysis_workflow"]
pprint(res_spec_analysis_result.output)

# %%
qubits[0].parameters.readout_resonator_frequency

# %%
# res_spec_result.tasks["analysis_workflow"].tasks["plot_real_imaginary"].output

# %%
from laboneq.simple import show_pulse_sheet
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

#show_pulse_sheet(compiled_experiment=res_spec_result.tasks["compile_experiment"].output,name='test', interactive=True)
#plot_simulation(compiled_experiment=res_spec_result.tasks["compile_experiment"].output)

# %% [markdown]
# ### 2.1 Qubit Spectroscopy with Amplitude Sweep
# * Current qubit spectroscopy modules do not support CW
# * Recommended to use long enough spectroscopy drive (pulsed) to see steady state signals

# %%
from experiments import qubit_spectroscopy_amplitude

###############################################################
q = qubits[5]
frequencies = q.parameters.resonance_frequency_ge + np.linspace(-2e6, 2e6, 101)
amplitudes = np.linspace(0.01, 1.0, 11)
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")

pprint(q.readout_parameters())
pprint(q.spectroscopy_parameters())
################################################################
options = qubit_spectroscopy_amplitude.experiment_workflow.options()
options.update(False)
# workflow.show_fields(options)
###################################################################
qubit_spec_amp = qubit_spectroscopy_amplitude.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    frequencies=frequencies,
    amplitudes=amplitudes,
    options=options
)

qubit_spec_amp_result = qubit_spec_amp.run()
qubit_spec_amp_result

# %% [markdown]
# ### 2.2 Qubit Spectroscopy

# %%
qubits[5].parameters.drive_lo_frequency = 4.4e9
qubits[5].parameters.readout_resonator_frequency

# %%
from experiments import qubit_spectroscopy

###############################################################
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
# temp_pars.spectroscopy_amplitude = 0.15 #0.006 #0.003
# temp_pars.resonance_frequency_ge = 4.48e9
temp_pars.readout_range_out = -10
temp_pars.readout_amplitude = 0.7
temporary_parameters[q.uid] = temp_pars

#q.parameters.readout_amplitude = 1.0
frequencies = temp_pars.resonance_frequency_ge+ np.linspace(-8e6, 8e6, 101)
#print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
pprint(q.readout_parameters())
pprint(q.spectroscopy_parameters())
################################################################
options = qubit_spectroscopy.experiment_workflow.options()
options.update(False)
options.count(1024)
# workflow.show_fields(options)
###################################################################
qubit_spec = qubit_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)

qubit_spec_result = qubit_spec.run()
qubit_spec_result

# %%
qubit_spec_result.tasks['analysis_workflow'].tasks['plot_qubit_spectroscopy'].output['q1']

# %% [markdown]
# # T1

# %%
from laboneq_applications.experiments import lifetime_measurement


###############################################################
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
# temp_pars.readout_length = 1.6e-6
# temp_pars.readout_integration_length = 1.6e-6
temp_pars.readout_length = 1.2e-6
temp_pars.readout_integration_length = 1.2e-6
temporary_parameters[q.uid] = temp_pars


print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
pprint(q.readout_parameters())
pprint(q.spectroscopy_parameters())
################################################################
options = lifetime_measurement.experiment_workflow.options()
options.update(True)
options.count(1024)
# workflow.show_fields(options)
###################################################################
t1 = lifetime_measurement.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    options=options,
    delays = np.linspace(0e-6, 20e-6, 101),
    temporary_parameters = temporary_parameters, 
)

t1_result = t1.run()

# %% [markdown]
# # 2. Rabi

# %% [markdown]
# ## 2.1 Rabi Amplitude

# %%
qubits[0].parameters.ge_drive_length

# %%
q=qubits[1]
res_freq = qubits[1].parameters.readout_resonator_frequency
res_lo_freq = qubits[1].parameters.readout_lo_frequency
res_amp_range = qubits[1].parameters.readout_range_out
res_amp = qubits[1].parameters.readout_amplitude

q_freq = qubits[1].parameters.resonance_frequency_ge 
q_lo_freq = qubits[1].parameters.drive_lo_frequency 
q_amp_range = qubits[1].parameters.drive_range
q_amp = qubits[1].parameters.spectroscopy_amplitude #0.003


print(res_freq)
print(res_lo_freq)
print(res_amp_range)
print(res_amp)
print("==================")
print(q_freq)
print(q_lo_freq)
print(q_amp_range)
print(q_amp)
q.parameters

# %%
from laboneq_applications.experiments import amplitude_rabi
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)

# temp_pars.ge_drive_length =64e-9
# temp_pars.drive_range= 10
temp_pars.readout_length = 1.2e-6
temp_pars.readout_integration_length = 1.2e-6
temporary_parameters[q.uid] = temp_pars

#######################################################################
amplitudes = np.linspace(0.0, 1.0,101)
print(q.parameters.ge_drive_amplitude_pi)
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = amplitude_rabi.experiment_workflow.options()
options.update(False)
options.use_cal_traces(True)
options.count(1024)
#print(workflow.show_fields(options))

###################################################################
rabi_amp = amplitude_rabi.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    amplitudes=amplitudes,
    options=options,
    temporary_parameters = temporary_parameters
)

rabi_amp_result = rabi_amp.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(rabi_amp_result.tasks['analysis_workflow'].output)

# %% [markdown]
# ## 2.2 (optional) Rabi Amplitude Chevron

# %%
from experiments import amplitude_rabi_chevron

#######################################################################
q = qubits[0]
amplitudes = np.linspace(0,1.0,11)
frequencies = q.parameters.resonance_frequency_ge + np.linspace(-3e6, 3e6, 51)
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = amplitude_rabi_chevron.experiment_workflow.options()

#print(workflow.show_fields(options))

###################################################################
rabi_amp_chev = amplitude_rabi_chevron.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    frequencies=frequencies,
    amplitudes=amplitudes,
    options=options
)

rabi_amp_chev_result = rabi_amp_chev.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(rabi_amp_chev_result.tasks['analysis_workflow'].output)

# %% [markdown]
# ## 2.3 (optional) Rabi Length
# - Not working yet

# %%
from experiments import time_rabi
#######################################################################
q = qubits[0]
q.parameters.ge_drive_amplitude_pi = 1.0
lengths = np.linspace(0.0, 240e-9, 21 ),
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = time_rabi.experiment_workflow.options()

#print(workflow.show_fields(options))

###################################################################
rabi_length = time_rabi.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    lengths=lengths,
    options=options
)

rabi_length_result = rabi_length.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(rabi_length_result.tasks['analysis_workflow'].outfput)

# %% [markdown]
# ## 2.2 (optional) Rabi Length Chevron

# %%
# from experiments import time_rabi_chevron
# #######################################################################
# q = qubits[4]

# frequencies = q.parameters.resonance_frequency_ge + np.linspace(-5e6, 5e6, 21)
# lengths = np.linspace(0.0, 240e-9, 21 ),
# print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
# #######################################################################
# options = time_rabi_chevron.experiment_workflow.options()

# #print(workflow.show_fields(options))

# ###################################################################
# rabi_length_chev = time_rabi_chevron.experiment_workflow(
#     session=session,
#     qpu=qpu,
#     qubits=q,
#     frequencies=frequencies,
#     lengths=lengths,
#     options=options
# )

# rabi_length_chev_result = rabi_length_chev.run()
# #qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
# print(rabi_length_chev_result.tasks['analysis_workflow'].output)

# %% [markdown]
# # 3. Ramsey

# %%
qubits[0].parameters.resonance_frequency_ge = 4.82e9

# %%
q = qubits[0] if isinstance(qubits, (list, tuple)) else qubits
setup = session.device_setup
ls = setup.logical_signal_by_uid(f"{q.uid}/drive")
print(ls.physical_channel.uid, ls.physical_channel.type)

q = qubits[0] if isinstance(qubits, (list, tuple)) else qubits
print(q.parameters.drive_lo_frequency, q.parameters.resonance_frequency_ge)
print(q.parameters.drive_frequency_ge)  # None이면 oscillator가 안 만들어짐
q = qubits[0] if isinstance(qubits, (list, tuple)) else qubits
cal = q.calibration()
drive_sig = q.signals["drive"]
print(cal[drive_sig].oscillator)

if cal[drive_sig].oscillator:
    print(cal[drive_sig].oscillator.modulation_type)
# Out:
# SHFQC_DEV12256/sgchannels_0_output PhysicalChannelType.IQ_CHANNEL
# 4800000000.0 4820000000.0
# 20000000.0
# Oscillator(
# │   uid='q0_drive_ge_osc',
# │   frequency=20000000.0,
# │   modulation_type=ModulationType.AUTO,
# │   carrier_type=None
# )
#
# ModulationType.AUTO

# %%
q = qubits[0] if isinstance(qubits, (list, tuple)) else qubits

# 1) 실제 매핑 확인
ls = session.device_setup.logical_signal_by_uid(f"{q.uid}/drive")
print(ls.physical_channel.uid, ls.physical_channel.type)

# 2) 오실레이터 생성 가능 여부 확인
print(q.parameters.drive_lo_frequency, q.parameters.resonance_frequency_ge)
print(q.parameters.drive_frequency_ge)
# Out:
# SHFQC_DEV12256/sgchannels_0_output PhysicalChannelType.IQ_CHANNEL
# 4800000000.0 4820000000.0
# 20000000.0

# %%
from experiments import modified_ramsey
q = qubits[0]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temp_pars.resonance_frequency_ge = 4.9528e9
temp_pars.readout_length = 1.2e-6
temp_pars.readout_integration_length =1.2e-6
temporary_parameters[q.uid] = temp_pars
#######################################################################
delays = np.linspace(0,10e-6,301)
detunings = 0.6e6,
pprint(q.readout_parameters())
#######################################################################
options = modified_ramsey.experiment_workflow.options()
options.update(False)
options.count(512)
options.use_cal_traces(True)
# Build and run Ramsey workflow (no explicit command table options required)
ramsey_wf = modified_ramsey.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    delays=delays,
    detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)
ramsey_result = ramsey_wf.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(ramsey_result.tasks['analysis_workflow'].output)
# Out:
# ('measure',
#  {'amplitude': 1.0,
#   'length': 2e-06,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# [2026.01.06 15:25:06.247] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.06 15:25:06.247] INFO      Workflow 'ramsey': execution started at 2026-01-06 06:25:06.246881Z
# [2026.01.06 15:25:06.248] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.06 15:25:06.260] INFO    Task 'temporary_qpu': started at 2026-01-06 06:25:06.260229Z
# [2026.01.06 15:25:06.263] INFO    Task 'temporary_qpu': ended at 2026-01-06 06:25:06.262738Z
# [2026.01.06 15:25:06.273] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-06
# [2026.01.06 15:25:06.274] INFO    06:25:06.272768Z
# [2026.01.06 15:25:06.277] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-06 06:25:06.276674Z
# [2026.01.06 15:25:06.281] INFO    Task 'create_experiment': started at 2026-01-06 06:25:06.280349Z
# [2026.01.06 15:25:06.295] INFO    Task 'create_experiment': ended at 2026-01-06 06:25:06.295002Z
# [2026.01.06 15:25:06.297] INFO    Task 'compile_experiment': started at 2026-01-06 06:25:06.296980Z
# [2026.01.06 15:25:06.299] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal '/logical_signal_groups/q0/drive' to HARDWARE
# [2026.01.06 15:25:06.300] INFO    Starting LabOne Q Compiler run...
# [2026.01.06 15:25:06.375] INFO    Schedule completed. [0.073 s]
# [2026.01.06 15:25:06.405] INFO    Task 'compile_experiment': ended at 2026-01-06 06:25:06.405247Z
# thread '<unnamed>' panicked at src/rust/codegenerator/src/passes/handle_signatures.rs:24:9:
# cannot increment oscillator phase w/o command table
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# Cell In[9], line 28
#      18 # Build and run Ramsey workflow (no explicit command table options required)
#      19 ramsey_wf = modified_ramsey.experiment_workflow(
#      20     session=session,
#      21     qpu=qpu,
#    (...)     26     temporary_parameters=temporary_parameters
#      27 )
# ---> 28 ramsey_result = ramsey_wf.run()
#      29 #qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
#      30 print(ramsey_result.tasks['analysis_workflow'].output)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/core.py:221, in Workflow.run(self, until)
#     217 for logstore in self._logstores():
#     218     state.add_recorder(
#     219         logstore.create_logbook(self, start_time=state.start_time)
#     220     )
# --> 221 return self._execute(state)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/core.py:131, in Workflow._execute(self, state)
#     129 try:
#     130     with executor.ExecutorStateContext.scoped(state):
# --> 131         self._root.execute(state)
#     132 except Exception:
#     133     if self._recovery is not None:
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/blocks/workflow_block.py:159, in WorkflowBlock.execute(self, executor)
#     154     if executor.get_block_status(block) in (
#     155         ExecutionStatus.FINISHED,
#     156         ExecutionStatus.SKIPPED,
#     157     ):
#     158         continue
# --> 159     block.execute(executor)
#     160 body_loop_finished = True
#     161 executor.set_block_status(self, ExecutionStatus.FINISHED)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/blocks/task_block.py:61, in TaskBlock.execute(self, executor)
#      59     self._exucute_hidden(executor)
#      60 else:
# ---> 61     self._execute_visible(executor)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/blocks/task_block.py:91, in TaskBlock._execute_visible(self, executor)
#      89 executor.set_block_status(self, ExecutionStatus.IN_PROGRESS)
#      90 try:
# ---> 91     task._output = self.task.func(**params)
#      92 except Exception as error:
#      93     task._end_time = utc_now()
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/tasks/compile_experiment.py:58, in compile_experiment(session, experiment, options)
#      40 """A task to compile the specified experiment for a given setup.
#      41
#      42 This task is used to prepare a LabOne Q DSL experiment for execution on a quantum
#    (...)     55         The `laboneq` compiled experiment.
#      56 """
#      57 opts = CompileExperimentOptions() if options is None else options
# ---> 58 return session.compile(
#      59     experiment=experiment,
#      60     compiler_settings=opts.compiler_settings,
#      61 )
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/dsl/session.py:392, in Session.compile(self, experiment, compiler_settings)
#     383 """Compiles the specified experiment and stores it in the compiled_experiment property.
#     384
#     385 Requires connected LabOne Q session (`session.connect()`) either with or without emulation mode.
#    (...)    389     compiler_settings: Extra options passed to the compiler.
#     390 """
#     391 self._experiment_definition = experiment
# --> 392 self._compiled_experiment = laboneq_compile(
#     393     device_setup=self.device_setup,
#     394     experiment=self.experiment,
#     395     compiler_settings={
#     396         **(compiler_settings or {}),
#     397     },
#     398 )
#     399 self._last_results = None
#     400 return self._compiled_experiment
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/core/utilities/laboneq_compile.py:33, in laboneq_compile(device_setup, experiment, compiler_settings)
#      30 signal_mapping = convert_signal_map(experiment)
#      32 payload_builder = PayloadBuilder()
# ---> 33 payload = payload_builder.build_payload(
#      34     new_setup,
#      35     new_experiment,
#      36     signal_mapping,
#      37     compiler_settings,
#      38 )
#      40 compiled_experiment = CompiledExperiment(
#      41     device_setup=device_setup,
#      42     experiment=experiment,
#    (...)     45     scheduled_experiment=payload.scheduled_experiment,
#      46 )
#      47 return compiled_experiment
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/implementation/payload_builder/payload_builder.py:45, in PayloadBuilder.build_payload(self, device_setup, experiment, signal_mappings, compiler_settings)
#      39 """
#      40 Compose an experiment from a setup descriptor and an experiment descriptor.
#      41 """
#      42 job = self.create_compilation_job(
#      43     device_setup, experiment, signal_mappings, compiler_settings
#      44 )
# ---> 45 scheduled_experiment = _compile(job)
#      46 target_setup = TargetSetupGenerator.from_setup(device_setup)
#      47 run_job = ExecutionPayload(
#      48     uid=uuid.uuid4().hex,
#      49     target_setup=target_setup,
#      50     compiled_experiment_hash=scheduled_experiment.uid,
#      51     scheduled_experiment=scheduled_experiment,
#      52 )
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/implementation/payload_builder/payload_builder.py:23, in _compile(job)
#      21 def _compile(job: CompilationJob):
#      22     compiler = Compiler(job.compiler_settings)
# ---> 23     compiler_output = compiler.run(job)
#      24     compiler_output.scheduled_experiment.uid = uuid.uuid4().hex
#      25     compiler_output.scheduled_experiment.device_setup_fingerprint = (
#      26         job.experiment_info.device_setup_fingerprint
#      27     )
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/compiler/workflow/compiler.py:880, in Compiler.run(self, data)
#     878 self.use_experiment(data)
#     879 self._analyze_setup(self._experiment_dao)
# --> 880 self._process_experiment()
#     882 awgs: list[AWGInfo] = sorted(self._awgs, key=lambda awg: awg.key)
#     884 device_class, combined_output = (
#     885     self._combined_compiler_output.get_first_combined_output()
#     886 )
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/compiler/workflow/compiler.py:614, in Compiler._process_experiment(self)
#     609         raise LabOneQException(
#     610             f"Chunk count ({chunk_count}) does not evenly divide sweep length ({chunking.sweep_iterations})"
#     611         )
#     613 try:
# --> 614     self._combined_compiler_output = self._compile_whole_or_with_chunks(
#     615         chunk_count=chunk_count
#     616     )
#     617     self._final_chunk_count = chunk_count
#     618 except ResourceLimitationError as err:
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/compiler/workflow/compiler.py:566, in Compiler._compile_whole_or_with_chunks(self, chunk_count)
#     558 rt_compiler = RealtimeCompiler(
#     559     self._experiment_dao,
#     560     self._sampling_rate_tracker,
#    (...)    563     self._settings,
#     564 )
#     565 executor = NtCompilerExecutor(rt_compiler, self._settings, chunk_count)
# --> 566 executor.run(self._execution)
#     568 combined_compiler_output = executor.combined_compiler_output()
#     569 if combined_compiler_output is None:
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/executor/executor.py:480, in ExecutorBase.run(self, root_sequence)
#     478 scope = ExecutionScope(None, self)
#     479 for notification in root_sequence.run(scope):
# --> 480     self._handlers_map[notification.statement_type](**notification.args)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/compiler/workflow/neartime_execution.py:148, in NtCompilerExecutor.rt_entry_handler(self, count, uid, averaging_mode, acquisition_type)
#     140 def rt_entry_handler(
#     141     self,
#     142     count: int,
#    (...)    145     acquisition_type,
#     146 ):
#     147     if self._chunk_count is None:
# --> 148         self._rt_entry_handler()
#     149     else:
#     150         for i in range(self._chunk_count):
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/compiler/workflow/neartime_execution.py:188, in NtCompilerExecutor._rt_entry_handler(self)
#     184 parameter_store = ParameterStore[str, float](
#     185     self._iteration_stack.nt_parameter_values()
#     186 )
#     187 tracker = parameter_store.create_tracker()
# --> 188 new_compiler_output = self._rt_compiler.run(parameter_store)
#     190 if self._required_parameters is None:
#     191     self._required_parameters = tracker.queries()
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/compiler/workflow/realtime_compiler.py:124, in RealtimeCompiler.run(self, near_time_parameters)
#     121 _logger.info(f"Schedule completed. [{time_delta:.3f} s]")
#     123 time_start = time.perf_counter()
# --> 124 self._generate_code()
#     126 outputs: dict[int, RTCompilerOutput] = {
#     127     device_class: code_generator.get_output()
#     128     for device_class, code_generator in self._code_generators.items()
#     129 }
#     131 compiler_output = RTCompilerOutputContainer(
#     132     codegen_output=outputs, schedule=schedule
#     133 )
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/compiler/workflow/realtime_compiler.py:111, in RealtimeCompiler._generate_code(self)
#     108 if self._settings.FORCE_IR_ROUNDTRIP:
#     109     ir.round_trip()
# --> 111 self._lower_ir_to_code(ir)
#     112 _logger.debug("lowering IR to code complete")
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/compiler/workflow/realtime_compiler.py:98, in RealtimeCompiler._lower_ir_to_code(self, ir)
#      85     signals = [
#      86         s
#      87         for s in self._signal_objects.values()
#      88         if s.awg.device_class == device_class
#      89     ]
#      90     self._code_generators[device_class] = get_compiler_hooks(
#      91         device_class
#      92     ).code_generator()(
#    (...)     96         feedback_register_layout=self._feedback_register_layout,
#      97     )
# ---> 98     self._code_generators[device_class].generate_code()
#     100 _logger.debug("Code generation completed")
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/compiler/seqc/code_generator.py:368, in CodeGenerator.generate_code(self)
#     349 awgs_sorted = sorted(
#     350     self._awgs.values(),
#     351     key=lambda item: item.key,
#     352 )
#     353 settings: dict[str, bool | int | float] = {
#     354     "HDAWG_MIN_PLAYWAVE_HINT": self._settings.HDAWG_MIN_PLAYWAVE_HINT,
#     355     "HDAWG_MIN_PLAYZERO_HINT": self._settings.HDAWG_MIN_PLAYZERO_HINT,
#    (...)    366     "EMIT_TIMING_COMMENTS": self._settings.EMIT_TIMING_COMMENTS,
#     367 }
# --> 368 codegen_result = codegen_rs.generate_code(
#     369     ir=self._ir,
#     370     awgs=awgs_sorted,
#     371     waveform_sampler=WaveformSampler(pulse_defs=pulse_defs),
#     372     feedback_register_layout=self._feedback_register_layout,
#     373     acquisition_type=self._ir.root.acquisition_type
#     374     or AcquisitionType.INTEGRATION,  # Any default if no acquire
#     375     settings=settings,
#     376 )
#     377 self._total_execution_time = codegen_result.total_execution_time
#     378 self._simultaneous_acquires = codegen_result.simultaneous_acquires
#
# PanicException: cannot increment oscillator phase w/o command table

# %%
from laboneq_applications.experiments import ramsey
q = qubits[0]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
#temp_pars.resonance_frequency_ge = 4.9528e9
temp_pars.readout_length = 1.2e-6
temp_pars.readout_integration_length =1.2e-6
temporary_parameters[q.uid] = temp_pars
#######################################################################
delays = np.linspace(0,10e-6,301)
detunings = 0.6e6,
pprint(q.readout_parameters())
#######################################################################
options = ramsey.experiment_workflow.options()
options.update(False)
options.count(512)
options.use_cal_traces(True)
# Build and run Ramsey workflow (no explicit command table options required)
ramsey_wf = ramsey.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    delays=delays,
    detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)
ramsey_result = ramsey_wf.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(ramsey_result.tasks['analysis_workflow'].output)
# Out:
# ('measure',
#  {'amplitude': 1.0,
#   'length': 2e-06,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# [2026.01.06 15:27:03.448] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.06 15:27:03.449] INFO      Workflow 'ramsey': execution started at 2026-01-06 06:27:03.448503Z
# [2026.01.06 15:27:03.449] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.06 15:27:03.467] INFO    Task 'temporary_qpu': started at 2026-01-06 06:27:03.466815Z
# [2026.01.06 15:27:03.468] INFO    Task 'temporary_qpu': ended at 2026-01-06 06:27:03.468698Z
# [2026.01.06 15:27:03.472] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-06
# [2026.01.06 15:27:03.472] INFO    06:27:03.471878Z
# [2026.01.06 15:27:03.473] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-06 06:27:03.472919Z
# [2026.01.06 15:27:03.474] INFO    Task 'create_experiment': started at 2026-01-06 06:27:03.474070Z
# [2026.01.06 15:27:03.480] INFO    Task 'create_experiment': ended at 2026-01-06 06:27:03.479773Z
# [2026.01.06 15:27:03.481] INFO    Task 'compile_experiment': started at 2026-01-06 06:27:03.481456Z
# [2026.01.06 15:27:03.483] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal '/logical_signal_groups/q0/drive' to HARDWARE
# [2026.01.06 15:27:03.484] INFO    Starting LabOne Q Compiler run...
# [2026.01.06 15:27:03.569] INFO    Schedule completed. [0.083 s]
# [2026.01.06 15:27:03.605] INFO    Code generation completed for all AWGs. [0.035 s]
# [2026.01.06 15:27:03.606] INFO    Completed compilation step 1 of 1. [0.120 s]
# [2026.01.06 15:27:03.607] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.06 15:27:03.608] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.06 15:27:03.608] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.06 15:27:03.608] INFO      SHFQC_DEV12256        0       1215            0           1      4800
# [2026.01.06 15:27:03.608] INFO      SHFQC_DEV12256_sg     0       1679           57          55     14240
# [2026.01.06 15:27:03.609] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.06 15:27:03.609] INFO      TOTAL                         2894           57                 19040
# [2026.01.06 15:27:03.609] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.06 15:27:03.639] INFO    Finished LabOne Q Compiler run.
# [2026.01.06 15:27:03.639] INFO    Task 'compile_experiment': ended at 2026-01-06 06:27:03.639768Z
# [2026.01.06 15:27:03.648] INFO    Task 'run_experiment': started at 2026-01-06 06:27:03.647971Z
# [2026.01.06 15:27:03.650] INFO    Starting near-time execution...
# [2026.01.06 15:27:03.656] INFO    Estimated RT execution time: 47.52 s.
# [2026.01.06 15:27:03.666] INFO    Finished near-time execution.
# [2026.01.06 15:27:03.673] INFO    Task 'run_experiment': ended at 2026-01-06 06:27:03.673176Z
# [2026.01.06 15:27:03.674] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.06 15:27:03.674] INFO      Workflow 'analysis_workflow': execution started at 2026-01-06
# [2026.01.06 15:27:03.675] INFO      06:27:03.674493Z
# [2026.01.06 15:27:03.675] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.06 15:27:03.677] INFO    Task 'calculate_qubit_population': started at 2026-01-06 06:27:03.677672Z
# [2026.01.06 15:27:03.678] INFO    Task 'calculate_qubit_population': ended at 2026-01-06 06:27:03.678727Z
# [2026.01.06 15:27:03.679] INFO    Task 'fit_data': started at 2026-01-06 06:27:03.679478Z
# [2026.01.06 15:27:03.683] INFO    Task 'fit_data': ended at 2026-01-06 06:27:03.683158Z
# [2026.01.06 15:27:03.683] INFO    Task 'extract_qubit_parameters': started at 2026-01-06 06:27:03.683835Z
# [2026.01.06 15:27:03.685] INFO    Task 'extract_qubit_parameters': ended at 2026-01-06 06:27:03.685397Z
# [2026.01.06 15:27:03.686] INFO    Task 'plot_raw_complex_data_1d': started at 2026-01-06 06:27:03.686490Z
# [2026.01.06 15:27:03.708] INFO    Artifact: 'Raw_data_q0' of type 'Figure' logged at 2026-01-06 06:27:03.708093Z
# [2026.01.06 15:27:03.863] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-01-06 06:27:03.862971Z
# [2026.01.06 15:27:03.864] INFO    Task 'plot_population': started at 2026-01-06 06:27:03.863874Z
# [2026.01.06 15:27:03.870] INFO    Artifact: 'Ramsey_q0' of type 'Figure' logged at 2026-01-06 06:27:03.870540Z
# [2026.01.06 15:27:03.924] INFO    Task 'plot_population': ended at 2026-01-06 06:27:03.924498Z
# [2026.01.06 15:27:03.925] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.06 15:27:03.925] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-06 06:27:03.925277Z
# [2026.01.06 15:27:03.925] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.06 15:27:03.926] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.06 15:27:03.926] INFO      Workflow 'ramsey': execution ended at 2026-01-06 06:27:03.926593Z
# [2026.01.06 15:27:03.927] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'old_parameter_values': {'q0': {'resonance_frequency_ge': 4820000000.0, 'ge_T2_star': 0}}, 'new_parameter_values': {'q0': {'resonance_frequency_ge': 4818208697.665961+/-783936.080172305, 'ge_T2_star': 0.09006737376817386+/-20018.825646133057}}}

# %%
ramsey_result.tasks['compile_experiment'].output.command_tables
# Out:
# [{'seqc': 'seq_SHFQC_DEV12256_sg_0_[].seqc',
#   'ct': {'$schema': 'https://docs.zhinst.com/shfsg/commandtable/v1_2/schema',
#    'header': {'version': '1.2.0'},
#    'table': [{'index': 0, 'phase': {'value': 0.0}},
#     {'index': 1,
#      'waveform': {'index': 0},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 2,
#      'waveform': {'index': 1},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 3,
#      'waveform': {'index': 2},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 4,
#      'waveform': {'index': 3},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 5,
#      'waveform': {'index': 4},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 6,
#      'waveform': {'index': 5},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 7,
#      'waveform': {'index': 6},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 8,
#      'waveform': {'index': 7},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 9,
#      'waveform': {'index': 8},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 10,
#      'waveform': {'index': 9},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 11,
#      'waveform': {'index': 10},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 12,
#      'waveform': {'index': 11},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 13,
#      'waveform': {'index': 12},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 14,
#      'waveform': {'index': 13},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 15,
#      'waveform': {'index': 14},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 16,
#      'waveform': {'index': 15},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 17,
#      'waveform': {'index': 16},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 18,
#      'waveform': {'index': 17},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 19,
#      'waveform': {'index': 18},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 20,
#      'waveform': {'index': 19},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 21,
#      'waveform': {'index': 20},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 22,
#      'waveform': {'index': 21},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 23,
#      'waveform': {'index': 22},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 24,
#      'waveform': {'index': 23},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 25,
#      'waveform': {'index': 24},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 26,
#      'waveform': {'index': 25},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 27,
#      'waveform': {'index': 26},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 28,
#      'waveform': {'index': 27},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 29,
#      'waveform': {'index': 28},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 30,
#      'waveform': {'index': 29},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 31,
#      'waveform': {'index': 30},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 32,
#      'waveform': {'index': 31},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 33,
#      'waveform': {'index': 32},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 34,
#      'waveform': {'index': 33},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 35,
#      'waveform': {'index': 34},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 36,
#      'waveform': {'index': 35},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 37,
#      'waveform': {'index': 36},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 38,
#      'waveform': {'index': 37},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 39,
#      'waveform': {'index': 38},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 40,
#      'waveform': {'index': 39},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 41,
#      'waveform': {'index': 40},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 42,
#      'waveform': {'index': 41},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 43,
#      'waveform': {'index': 42},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 44,
#      'waveform': {'index': 43},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 45,
#      'waveform': {'index': 44},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 46,
#      'waveform': {'index': 45},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 47,
#      'waveform': {'index': 46},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 48,
#      'waveform': {'index': 47},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 49,
#      'waveform': {'index': 48},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 50,
#      'waveform': {'index': 49},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 51,
#      'waveform': {'index': 50},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 52,
#      'waveform': {'index': 51},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 53,
#      'waveform': {'index': 52},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 54,
#      'waveform': {'index': 53},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 55,
#      'waveform': {'index': 54},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.09999847412109375},
#      'amplitude10': {'value': 0.09999847412109375},
#      'amplitude11': {'value': 0.09999847412109375},
#      'amplitude01': {'value': -0.09999847412109375}},
#     {'index': 56,
#      'waveform': {'index': 0},
#      'oscillatorSelect': {'value': 0},
#      'amplitude00': {'value': 0.20000076293945312},
#      'amplitude10': {'value': 0.20000076293945312},
#      'amplitude11': {'value': 0.20000076293945312},
#      'amplitude01': {'value': -0.20000076293945312}}]}}]

# %%
# from experiments import modified_ramsey
# # ssibal 갑자기 안됨

# q = qubits[1]
# temporary_parameters = {}
# temp_pars =deepcopy(q.parameters)
# #temp_pars.resonance_frequency_ge = 4.9528e9
# temporary_parameters[q.uid] = temp_pars
# #######################################################################
# delays = np.linspace(0,10e-6,301)
# detunings = 0.7e6,
# pprint(q.readout_parameters())
# #######################################################################
# options = modified_ramsey.experiment_workflow.options()
# options.update(False)
# options.count(1024)
# options.use_cal_traces(True)
# # Build and run Ramsey workflow (no explicit command table options required)
# ramsey_wf = modified_ramsey.experiment_workflow(
#     session=session,
#     qpu=qpu,
#     qubits=q,
#     delays=delays,
#     detunings=detunings,
#     options=options,
#     temporary_parameters=temporary_parameters
# )
# ramsey_result = ramsey_wf.run()
# #qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
# print(ramsey_result.tasks['analysis_workflow'].output)

# %%
from experiments import echo
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
#temp_pars.resonance_frequency_ge = 4.9528e9
temporary_parameters[q.uid] = temp_pars
#######################################################################
delays = np.linspace(0,10e-6,301)
detunings = 0.6e6,
pprint(q.readout_parameters())
#######################################################################
options = echo.experiment_workflow.options()
options.update(True)
options.count(1024)
options.use_cal_traces(True)
# Build and run Ramsey workflow (no explicit command table options required)
ramsey_echo = echo.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    delays=delays,
    #detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)
ramsey_echo_result = ramsey_echo.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(ramsey_echo_result.tasks['analysis_workflow'].output)

# %% [markdown]
# # x180

# %%
from laboneq_applications.experiments import amplitude_fine
q = qubits[0]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temporary_parameters[q.uid] = temp_pars

#######################################################################
repetitions =np.arange(1,14) # Due to short T1, 20   
#######################################################################
options = amplitude_fine.experiment_workflow_x180.options()
options.update(False)
options.use_cal_traces(True)
#options.do_pca(False)

#print(workflow.show_fields(options))

###################################################################
error_amp = amplitude_fine.experiment_workflow_x180(
    session=session,
    qpu=qpu,
    qubits=q,
    repetitions=repetitions,
    temporary_parameters=temporary_parameters,
    options=options
)

error_amp_result = error_amp.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(error_amp_result.tasks['analysis_workflow'].output)

# %% [markdown]
# # X90

# %%
from laboneq_applications.experiments import amplitude_fine
q = qubits[0]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temporary_parameters[q.uid] = temp_pars
#######################################################################
repetitions =np.arange(1,10)
#######################################################################
options = amplitude_fine.experiment_workflow_x90.options()
options.update(False)
options.use_cal_traces(True)
options.do_pca(False)
options.count(1024)

#print(workflow.show_fields(options))

###################################################################
error_amp_half = amplitude_fine.experiment_workflow_x90(
    session=session,
    qpu=qpu,
    qubits=q,
    repetitions=repetitions,
    temporary_parameters=temporary_parameters,
    options=options
)

error_amp_half_result = error_amp_half.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(error_amp_half_result.tasks['analysis_workflow'].output)

# %% [markdown]
# # DRAG

# %%
from laboneq_applications.experiments import drag_q_scaling
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temp_pars.ge_drive_pulse['beta'] =0
temporary_parameters[q.uid] = temp_pars
#######################################################################
q_scalings = np.linspace(-0.05,0.1,51)
#######################################################################
options = drag_q_scaling.experiment_workflow.options()
options.update(False)



#print(workflow.show_fields(options))

###################################################################
drag = drag_q_scaling.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    q_scalings=q_scalings,
    options=options
)

drag_result = drag.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(drag_result.tasks['analysis_workflow'].output)

# %% [markdown]
# # RB
#
# Emulation 상에서는 돌아가는데 실제 돌리면 cannot increment w/o  command table

# %%
#from laboneq_applications.experiments import 
from experiments import single_qubit_randomized_benchmarking
q = qubits[1]
# temporary_parameters = {}
# temp_pars =deepcopy(q.parameters)
# temporary_parameters[q.uid] = temp_pars

#############################################
options = single_qubit_randomized_benchmarking.experiment_workflow.options()
options.count(10)
options.transition("ge")


rb = single_qubit_randomized_benchmarking.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    length_cliffords=[1,5,10,20,50],
    variations=5,
    options=options,
)

rb_result = rb.run()

#######################################################################

# %% [markdown]
# # RIP
#
# This notebook is dedicated to TG's RIP gate calibration
#
# ### Current issues
#
# 1. phase sweep for detuning is not implemented
# 2. First prepare state section takes 80ns length for unknown reason (might be related to port delay calibration setting)
# 3. Folderstore not working...

# %%
from experiments import rip2

#q = qubits[1]
#temporary_parameters = q.parameters.copy()

#######################################################################

#######################################################################
options = rip2.experiment_workflow.options()
options.update(False)

#print(workflow.show_fields(options))

###################################################################
bus_freq = 6.534e9
bus_amp = 1.0

rip_drive_controlg = rip2.experiment_workflow(
    session=session,
    qpu=qpu,
    ctrl=qubits[1],
    targ=qubits[0],
    bus=qubits[2],
    bus_frequency=bus_freq,
    bus_amplitude=bus_amp,
    delays=np.linspace(80e-9, 880e-9, 201),
    detunings=0.0e6,
    c_prep = "g",
    #frequencies=qubits[2].parameters.resonance_targ_frequency + np.linspace(-10e6,10e6,6),
    #amplitudes=np.linspace(0.0, 1.0, 11),
    options=options 
)
rip_drive_controle = rip2.experiment_workflow(
    session=session,
    qpu=qpu,
    ctrl=qubits[1],
    targ=qubits[0],
    bus=qubits[2],
    bus_frequency=bus_freq,
    bus_amplitude=bus_amp,
    delays=np.linspace(80e-9, 880e-9, 201),
    detunings=0.0e6,
    c_prep = "e",
    #frequencies=qubits[2].parameters.resonance_targ_frequency + np.linspace(-10e6,10e6,6),
    #amplitudes=np.linspace(0.0, 1.0, 11),
    options=options 
)

rip_result_control_g = rip_drive_controlg.run()
rip_result_control_e = rip_drive_controle.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
#print(drag_result.tasks['analysis_workflow'].output)

# %%
rip_data_control_g = rip_result_control_g.output
rip_data_control_e = rip_result_control_e.output
duration = rip_data_control_g.data['q0']['result'].axis[0][0]


phase_control_g = rip_data_control_g.data['q0']['result'].data
phase_control_e = rip_data_control_e.data['q0']['result'].data
import matplotlib.pyplot as plt

control_g_g_point = rip_data_control_g.data['q0']['cal_trace'].g.data
control_g_e_point = rip_data_control_g.data['q0']['cal_trace'].e.data

control_e_g_point = rip_data_control_e.data['q0']['cal_trace'].g.data
control_e_e_point = rip_data_control_e.data['q0']['cal_trace'].e.data


plt.figure(figsize=(6,6))

plt.scatter(control_g_g_point.real, control_g_g_point.imag, color="red", label="|0> reference (g)")
plt.scatter(control_g_e_point.real, control_g_e_point.imag, color="blue", label="|1> reference (e)")
plt.scatter(control_e_g_point.real, control_e_g_point.imag, color="red", label="|0> reference (g)")
plt.scatter(control_e_e_point.real, control_e_e_point.imag, color="blue", label="|1> reference (e)")

plt.axvline(x=0, color='black', linestyle='--', linewidth=0.8)
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.legend()

# %%
from experiments import rip2

#q = qubits[1]
#temporary_parameters = q.parameters.copy()

#######################################################################

#######################################################################
options = rip2.experiment_workflow.options()
options.update(False)

#print(workflow.show_fields(options))

###################################################################
bus_freq = 5.99e9
bus_amp = 1.0

bus_freq_sweep = np.linspace(5.99e9,6.08e9,31)

ctrl_g = []
ctrl_e = []

for bf in bus_freq_sweep:
    print(f"Bus frequency : {bf/1e9} GHz")
    rip_drive_controlg = rip2.experiment_workflow(
        session=session,
        qpu=qpu,
        ctrl=qubits[1],
        targ=qubits[0],
        bus=qubits[2],
        bus_frequency=bf,
        bus_amplitude=bus_amp,
        delays=np.linspace(80e-9, 1600e-9, 153),
        detunings=0.0e6,
        c_prep = "g",
        #frequencies=qubits[2].parameters.resonance_targ_frequency + np.linspace(-10e6,10e6,6),
        #amplitudes=np.linspace(0.0, 1.0, 11),
        options=options 
    )
    rip_drive_controle = rip2.experiment_workflow(
        session=session,
        qpu=qpu,
        ctrl=qubits[1],
        targ=qubits[0],
        bus=qubits[2],
        bus_frequency=bf,
        bus_amplitude=bus_amp,
        delays=np.linspace(80e-9, 1600e-9, 153),
        detunings=0.0e6,
        c_prep = "e",
        #frequencies=qubits[2].parameters.resonance_targ_frequency + np.linspace(-10e6,10e6,6),
        #amplitudes=np.linspace(0.0, 1.0, 11),
        options=options 
    )

    rip_result_control_g = rip_drive_controlg.run()
    rip_result_control_e = rip_drive_controle.run()

    ctrl_g.append(rip_result_control_g)
    ctrl_e.append(rip_result_control_e)

# %%
# rip_data_control_g = rip_result_control_g.output
# rip_data_control_e = rip_result_control_e.output

rip_data_control_g = ctrl_g[29].output
rip_data_control_e = ctrl_e[29].output

# %%
duration = rip_data_control_g.data['q0']['result'].axis[0][0]

phase_control_g = rip_data_control_g.data['q0']['result'].data
phase_control_e = rip_data_control_e.data['q0']['result'].data

# %%
import matplotlib.pyplot as plt

control_g_g_point = rip_data_control_g.data['q0']['cal_trace'].g.data
control_g_e_point = rip_data_control_g.data['q0']['cal_trace'].e.data

control_e_g_point = rip_data_control_e.data['q0']['cal_trace'].g.data
control_e_e_point = rip_data_control_e.data['q0']['cal_trace'].e.data


plt.figure(figsize=(6,6))

plt.scatter(control_g_g_point.real, control_g_g_point.imag, color="red", label="|0> reference (g)")
plt.scatter(control_g_e_point.real, control_g_e_point.imag, color="blue", label="|1> reference (e)")
plt.scatter(control_e_g_point.real, control_e_g_point.imag, color="red", label="|0> reference (g)")
plt.scatter(control_e_e_point.real, control_e_e_point.imag, color="blue", label="|1> reference (e)")

plt.axvline(x=0, color='black', linestyle='--', linewidth=0.8)
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.legend()

# %%
def normalize_population(points, g, e):
    """
    points: list or numpy array of complex numbers
    return: array of normalized values in [0,1]
    """
    points = np.array(points, dtype=complex)
    d0 = np.abs(points - g)
    d1 = np.abs(points - e)
    return d0 / (d0 + d1)

new_phase_control_g = []
new_phase_control_e = []

for i in range(len(phase_control_g)):
    # 2. Calculate the value and append it to the new row
    normalized_value = normalize_population(phase_control_g[i], control_g_g_point, control_g_e_point)
    new_phase_control_g.append(normalized_value)
for k in range(len(phase_control_e)):
    # 2. Calculate the value and append it to the new row
    normalized_value = normalize_population(phase_control_e[k], control_e_g_point, control_e_e_point)
    new_phase_control_e.append(normalized_value)
# 3. Append the completed row to the main population list

population_control_g = new_phase_control_g
population_control_e = new_phase_control_e
plt.figure(figsize=(8,6))
plt.plot(duration, population_control_g, color="#ff5500", label = r'control: |g>')
plt.plot(duration, population_control_e, color="#0055aa", label = r'control: |e>')
plt.ylim([-0.1,1.1])
plt.xlabel("RIP duration (s)", fontsize=16)
plt.ylabel("population", fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.legend(fontsize=14)

# %% [markdown]
# # SAVING data

# %%
#ctrl_g[0].output

# %%
from laboneq.simple import save, load

bus_freq_sweep * 1e-9


for i, bf in enumerate(bus_freq_sweep *1e-9):
    save(ctrl_g[i].output, filename=f'1029_rip_control_g_bf_{bf:.3f}_amp1.0')
    save(ctrl_e[i].output, filename=f'1029_rip_control_e_bf_{bf:.3f}_amp1.0')


#save(rip_result_control_g.output, filename='1023_control_g_bf_5.535_amp1.0')
#save(rip_result_control_e.output, filename='1023_control_e_bf_5.535_amp1.0')

# %%
qubits[2].parameters.resonance_targ_frequency = 5.6e9
qubits[2].parameters.resonance_targ_frequency

# %%
from laboneq.simple import show_pulse_sheet
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

#show_pulse_sheet(compiled_experiment=rip_result.tasks["compile_experiment"].output,name='test', interactive=True, max_events_to_publish=100000)
plot_simulation(compiled_experiment=rip_result_control_g.tasks["compile_experiment"].output)
plot_simulation(compiled_experiment=rip_result_control_e.tasks["compile_experiment"].output)

# %%
from laboneq.simple import save, load

save(rip_result.output, filename='0909n_e_0.6')
load(filename='0909n_e_0.6')

# %%
from laboneq_applications.analysis.calibration_traces_rotation import (
    calculate_qubit_population_2d,
    calculate_qubit_population
)
targ= qubits[0]
delays=np.linspace(300e-9, 2000e-9,101)
frequencies = qubits[2].parameters.resonance_targ_frequency + np.linspace(-10e6,10e6,6)
processed_d=calculate_qubit_population_2d(qubits=targ, result=rip_result.output, sweep_points_1d=delays, sweep_points_2d=frequencies)

# %%
import matplotlib.pyplot as plt
plt.plot(processed_d['q0']['population'][1,:])
plt.ylim([-0.1, 1.1])
plt.show()

# %%
from laboneq_applications.analysis import iq_blobs
from laboneq_applications.experiments import iq_blobs

#######################################################################
q = qubits[0]

print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = iq_blobs.experiment_workflow.options()

#print(workflow.show_fields(options))

###################################################################
iq = iq_blobs.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    options=options,
    states='ge'
)

iq_result = iq.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(iq_result.tasks['analysis_workflow'].output)

# %% [markdown]
# # Basic Readout optimization
# Here we optimize SNR via
#
# * `readout_length`
# * `readout-amplitude`
#
# * `readout_integration_length`
# * `readout_integration_delay`
# * `readout_integration_weight`

# %% [markdown]
# # Dispersive shift

# %%
from experiments import dispersive_shift

#######################################################################
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)

#temp_pars.readout_resonator_frequency = 7.5582e9
temporary_parameters[q.uid] = temp_pars

print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = dispersive_shift.experiment_workflow.options()
options.count(1024)
options.update(False)
#print(workflow.show_fields(options))

###################################################################
dispersive = dispersive_shift.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=q,
    frequencies=q.parameters.readout_resonator_frequency + np.linspace(-5e6,5e6,201),
    options=options,
    states='ge',
    temporary_parameters=temporary_parameters
)

dispersive_result = dispersive.run() 
print(dispersive_result.tasks['analysis_workflow'].output)

# %% [markdown]
# # Save Qubit Parameters

# %%
from helper import load_qubit_parameters, save_qubit_parameters
save_qubit_parameters(qubits={ qubit.uid : qubit for qubit in qubits}, save_folder="./qubit_parameters/", filename="fake")
