# %% [markdown]
# # 2nd_sample_1229

# %% [markdown]
# # Initialization

# %%
import numpy as np
from pprint import pprint
from copy import deepcopy


from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
#from laboneq.contrib.example_helpers.generate_device_setup import generate_device_setup
from laboneq.dsl.device import DeviceSetup




descriptor = generate_descriptor(
    #pqsc=[""], # 장비 여러개 사용시
    shfqc_6=["DEV12256"],
    number_data_qubits=6,
    multiplex=True,
    number_multiplex=6,
    include_cr_lines=True,
    include_ef_lines=True,
    get_zsync=False,  # Only set to True when using real device
    save = True,
    filename="TG_RIP_2",
    ip_address="192.168.0.83"
)


#descriptor
setup = DeviceSetup.from_descriptor(yaml_text=descriptor, server_host="192.168.0.83")
#setup
setup.instruments[0].device_options = 'SHFQC/PLUS/QC6CH'
#setup.instruments

# %%
from laboneq.simple import Session
session = Session(setup)
session.connect(ignore_version_mismatch=False, do_emulation=False)
#session.disconnect()
# Out:
# [2026.01.04 23:32:08.353] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /home/yalgaeahn/JSAHN/qubit-experiment/examples/selectiveRIP/laboneq_output/log
# [2026.01.04 23:32:08.354] INFO    VERSION: laboneq 25.10.2
# [2026.01.04 23:32:08.355] INFO    Connecting to data server at 192.168.0.83:8004
# [2026.01.04 23:32:08.427] INFO    Connected to Zurich Instruments LabOne Data Server version 25.10.1.4 at 192.168.0.83:8004
# [2026.01.04 23:32:08.457] INFO    Configuring the device setup
# [2026.01.04 23:32:08.481] INFO    The device setup is configured

# %%
from qpu_types import TransmonQubit, TransmonQubitParameters
from helper import load_qubit_parameters, save_qubit_parameters
from operations import TransmonOperations
from laboneq.dsl.quantum.qpu import QPU, QuantumPlatform



_loaded_qubits = load_qubit_parameters(filename="latest") 
#qubits = TransmonQubit.from_device_setup(setup) # Also can be done with load_qubit_parameters 
qubits = list(_loaded_qubits.values())





qpu = QPU(quantum_elements=qubits, quantum_operations=TransmonOperations())
#quantum_platform = QuantumPlatform(setup=setup, qpu=qpu)

# qpu.topology.add_edge("bus", "q16", "q17")
# qpu.topology.add_edge("bus", "q17", "q18")
# qpu.topology.add_edge("bus", "q18", "q19")
# qpu.topology.plot()




from laboneq.simple import workflow
folder_store = workflow.logbook.FolderStore("./experiment_store") 
folder_store.activate()
#folder_store.deactivate()
#workflow.logbook.LoggingStore().activate()
#workflow.logbook.LogbookStore().deactivate()
# Out:
# LOADED:./qubit_parameters/20260104-2259_sample2.json

# %% [markdown]
# BF 7

# %%
# 0 : 15 , 1 : 16 , 2 : 17, 3 : 18, 4 : 19
# for q in qubits:
#     #q.parameters.ge_drive_pulse["sigma"] = 0.25
#     q.parameters.readout_amplitude = 1.0
#     q.parameters.reset_delay_length = 20e-6

#     q.parameters.readout_range_out = -10
#     q.parameters.readout_range_in = 0
#     q.parameters.drive_range = 10

#     q.parameters.readout_lo_frequency = 7.6e9
#     q.parameters.drive_lo_frequency = 4.8e9

#     q.parameters.spectroscopy_length = 10e-6

#     q.parameters.ge_drive_length =64e-9
#     q.parameters.readout_integration_delay =  200e-9#####

 

# #Q2
# qubits[0].parameters.resonance_frequency_ge = 4.123e9
# qubits[0].parameters.readout_resonator_frequency = 7.5584e9

# #Q3
# qubits[1].parameters.resonance_frequency_ge = 3.9542e9
# qubits[1].parameters.readout_resonator_frequency = 7.2371e9

# #Q1
# qubits[5].parameters.resonance_frequency_ge = 4.704e9
# qubits[5].parameters.readout_resonator_frequency = 7.3116e9



# qubits[2].parameters.drive_lo_frequency = 5.6e9
# qubits[2].parameters.resonance_targ_frequency = 5.6e9
# # qubits[2].parameters.resonance_frequency_ge = 4.716e9
# qubits[3].parameters.resonance_frequency_ge = 4.664e9
# qubits[4].parameters.resonance_frequency_ge = 4.779e9

# qubits[2].parameters.readout_resonator_frequency = 6.9226e9
# qubits[3].parameters.readout_resonator_frequency = 6.8433e9
# qubits[4].parameters.readout_resonator_frequency = 6.7739e9

# %% [markdown]
# 3 oscillator to be calibrated
# - `drive_local_osc`
# - `readout_local_osc`
# - `readout_acquire_osc`

# %%
# from laboneq.dsl.calibration import Calibration, Oscillator, SignalCalibration

# sibal= SignalCalibration()
# sibal.delay_signal

# %%
# from experiments import signal_propagation_delay
# options = signal_propagation_delay.experiment_workflow.options()
#workflow.show_fields(options)

# %% [markdown]
# Correcting propagation delay.
#
# $\Delta \phi =-2\pi f t$ $\implies$ $\tau = \frac{1}{\Delta f}$

# %%
# from experiments import signal_propagation_delay
# ####################################################################################
# qubits[0].parameters.readout_amplitude =1.0
# q=qubits[0]
# delays=np.linspace(0e-9, 200e9, 51)
# measure_delays = 40e-6
# pprint(q.readout_parameters())
# print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
# #####################################################################################
# options = signal_propagation_delay.experiment_workflow.options()
# #workflow.show_fields(options)
# options.update(False)
# ######################################################################################
# # Build and run resonator_spectroscopy_amplitude wormflow
# prop_delay = signal_propagation_delay.experiment_workflow(
#     session=session,
#     qpu=qpu,
#     qubit=q,
#     delays=delays,
#     measure_delay=measure_delays,
#     options=options
# )
# prop_delay_result=prop_delay.run()
# prop_delay_analysis_result = prop_delay_result.tasks["analysis_workflow"]
# pprint(prop_delay_analysis_result.output)

# %%
prop_delay_analysis_result.tasks["plot_data"].output['q0']

# %% [markdown]
# # 1. Spectroscopy

# %%
from helper import adjust_amplitude_for_output_range, calculate_power
adjust_amplitude_for_output_range(initial_output_dbm=0, initial_amplitude= 0.002, new_output_dbm=-5)
calculate_power(output_dbm=0, amplitude=0.001,attenuation=[])

# %% [markdown]
# ### 1.1 Resonator spectroscopy with amplitude sweep
#
# STRATEGY
# 1. CW spectroscpy for wide range scan
#     * CW spectroscopy can be done for wide range scan
#     * amplitude, frequency 2D sweep 을 통해  power에 따른 broadening 및 SNR 경향 관찰
#     * $\Delta F$ : frequency span,  $\Delta f_r$
#     * Pick $\Delta F / \Delta f_r$ 1~2

# %%
#qubits[5].parameters.drive_lo_frequency = 4.0e9
#qubits[5].parameters.readout_lo_frequency 
#qubits[5].parameters.readout_resonator_frequency =7.0350e9
# qubits[5].parameters.readout_amplitude = 0.3

# %%
from experiments import resonator_spectroscopy_amplitude

####################################################################################
q=qubits[5]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
#temp_pars.readout_amplitude = 1.0
#temp_pars.readout_resonator_frequency = 7.6283e9 #6.04036e9 #mode1
#temp_pars.readout_range_out = -10

temporary_parameters[q.uid] = temp_pars

pprint(q.readout_parameters())
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
frequencies = temp_pars.readout_resonator_frequency + np.linspace(-4e6,4e6,501)
amplitudes = np.linspace(0.0, 0.3, 21) #This works as scaling factor!!!!!!!!!!!!
#####################################################################################
options = resonator_spectroscopy_amplitude.experiment_workflow.options()
#workflow.show_fields(options)
options.update(False)
options.use_cw(True)

options.do_analysis(True)
######################################################################################
# Build and run resonator_spectroscopy_amplitude wormflow
res_spec_amp = resonator_spectroscopy_amplitude.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=q,
    frequencies=frequencies,
    amplitudes=amplitudes,
    temporary_parameters=temporary_parameters,
    options=options
)
res_spec_amp_result=res_spec_amp.run()

# %%
res_spec_amp_result.tasks["analysis_workflow"].tasks["plot_signal_magnitude_and_phase_2d"].output["q1"]

# %% [markdown]
# ### 1.2 Resonator Spectroscopy
# * CW not recommended

# %%
from experiments import resonator_spectroscopy

####################################################################################
q=qubits[5]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
#temp_pars.readout_resonator_frequency = 7.6283e9 #6.04036e9 #mode1
# temp_pars.readout_range_out = 15
# temp_pars.readout_amplitude = 1.0
# temp_pars.reset_delay_length =200e-6
#temp_pars.readout_lo_frequency = 5.6e9
# temp_pars.readout_range_out = 0
# temp_pars.readout_amplitude = 0.5
temp_pars.readout_resonator_frequency = 6.9182e9
temp_pars.readout_range_out = -10
temp_pars.readout_amplitude = 0.7
temporary_parameters[q.uid] = temp_pars
print(q.readout_parameters())
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#frequencies = q.parameters.readout_resonator_frequency + np.linspace(-10e6,10e6,501)
frequencies = temp_pars.readout_resonator_frequency + np.linspace(-2e6,2e6,2001)
#####################################################################################
options = resonator_spectroscopy.experiment_workflow.options()
#workflow.show_fields(options)
options.count(1024)
options.update(True)
options.use_cw(True) #qop.measure 
#options.fit_complex_resonator(False)
#options.fit_lorentzian(True)
######################################################################################
# Build and run resonator_spectroscopy_amplitude wormflow
res_spec = resonator_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=q,
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)
res_spec_result = res_spec.run()
res_spec_analysis_result = res_spec_result.tasks["analysis_workflow"]
pprint(res_spec_analysis_result.output)

# %%
qubits[0].parameters.readout_resonator_frequency

# %%
# res_spec_result.tasks["analysis_workflow"].tasks["plot_real_imaginary"].output

# %%
from laboneq.simple import show_pulse_sheet
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

#show_pulse_sheet(compiled_experiment=res_spec_result.tasks["compile_experiment"].output,name='test', interactive=True)
#plot_simulation(compiled_experiment=res_spec_result.tasks["compile_experiment"].output)

# %% [markdown]
# ### 2.1 Qubit Spectroscopy with Amplitude Sweep
# * Current qubit spectroscopy modules do not support CW
# * Recommended to use long enough spectroscopy drive (pulsed) to see steady state signals

# %%
from experiments import qubit_spectroscopy_amplitude

###############################################################
q = qubits[5]
frequencies = q.parameters.resonance_frequency_ge + np.linspace(-2e6, 2e6, 101)
amplitudes = np.linspace(0.01, 1.0, 11)
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")

pprint(q.readout_parameters())
pprint(q.spectroscopy_parameters())
################################################################
options = qubit_spectroscopy_amplitude.experiment_workflow.options()
options.update(False)
# workflow.show_fields(options)
###################################################################
qubit_spec_amp = qubit_spectroscopy_amplitude.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    frequencies=frequencies,
    amplitudes=amplitudes,
    options=options
)

qubit_spec_amp_result = qubit_spec_amp.run()
qubit_spec_amp_result

# %% [markdown]
# ### 2.2 Qubit Spectroscopy

# %%
qubits[5].parameters.drive_lo_frequency = 4.4e9
qubits[5].parameters.readout_resonator_frequency

# %%
from experiments import qubit_spectroscopy

###############################################################
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
# temp_pars.spectroscopy_amplitude = 0.15 #0.006 #0.003
# temp_pars.resonance_frequency_ge = 4.48e9
temp_pars.readout_range_out = -10
temp_pars.readout_amplitude = 0.7
temporary_parameters[q.uid] = temp_pars

#q.parameters.readout_amplitude = 1.0
frequencies = temp_pars.resonance_frequency_ge+ np.linspace(-8e6, 8e6, 101)
#print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
pprint(q.readout_parameters())
pprint(q.spectroscopy_parameters())
################################################################
options = qubit_spectroscopy.experiment_workflow.options()
options.update(False)
options.count(1024)
# workflow.show_fields(options)
###################################################################
qubit_spec = qubit_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    frequencies=frequencies,
    options=options,
    temporary_parameters=temporary_parameters
)

qubit_spec_result = qubit_spec.run()
qubit_spec_result

# %%
qubit_spec_result.tasks['analysis_workflow'].tasks['plot_qubit_spectroscopy'].output['q1']

# %% [markdown]
# # T1

# %%
from laboneq_applications.experiments import lifetime_measurement


###############################################################
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
# temp_pars.readout_length = 1.6e-6
# temp_pars.readout_integration_length = 1.6e-6
temp_pars.readout_length = 1.2e-6
temp_pars.readout_integration_length = 1.2e-6
temporary_parameters[q.uid] = temp_pars


print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
pprint(q.readout_parameters())
pprint(q.spectroscopy_parameters())
################################################################
options = lifetime_measurement.experiment_workflow.options()
options.update(True)
options.count(1024)
# workflow.show_fields(options)
###################################################################
t1 = lifetime_measurement.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    options=options,
    delays = np.linspace(0e-6, 20e-6, 101),
    temporary_parameters = temporary_parameters, 
)

t1_result = t1.run()
# Out:
# DRIVE range (dBm) : 10, READOUT range (dBm) : 0
# ('measure',
#  {'amplitude': 0.4,
#   'length': 1.2e-06,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# ('drive',
#  {'amplitude': 0.002,
#   'length': 1e-05,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# [2026.01.04 22:40:33.133] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:40:33.133] INFO      Workflow 'lifetime_measurement': execution started at 2026-01-04
# [2026.01.04 22:40:33.134] INFO      13:40:33.133138Z
# [2026.01.04 22:40:33.134] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:40:33.142] INFO    Task 'temporary_qpu': started at 2026-01-04 13:40:33.142226Z
# [2026.01.04 22:40:33.143] INFO    Task 'temporary_qpu': ended at 2026-01-04 13:40:33.143321Z
# [2026.01.04 22:40:33.145] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-04
# [2026.01.04 22:40:33.145] INFO    13:40:33.145401Z
# [2026.01.04 22:40:33.146] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-04 13:40:33.146406Z
# [2026.01.04 22:40:33.147] INFO    Task 'create_experiment': started at 2026-01-04 13:40:33.147293Z
# [2026.01.04 22:40:33.152] INFO    Task 'create_experiment': ended at 2026-01-04 13:40:33.152093Z
# [2026.01.04 22:40:33.153] INFO    Task 'compile_experiment': started at 2026-01-04 13:40:33.153665Z
# [2026.01.04 22:40:33.155] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal '/logical_signal_groups/q1/acquire' to SOFTWARE
# [2026.01.04 22:40:33.155] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.04 22:40:33.155] INFO    Starting LabOne Q Compiler run...
# [2026.01.04 22:40:33.174] INFO    Schedule completed. [0.018 s]
# [2026.01.04 22:40:33.182] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.01.04 22:40:33.182] INFO    Completed compilation step 1 of 1. [0.026 s]
# [2026.01.04 22:40:33.184] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:40:33.184] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.04 22:40:33.184] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:40:33.185] INFO      SHFQC_DEV12256        0        312            0           1      4800
# [2026.01.04 22:40:33.185] INFO      SHFQC_DEV12256_sg     1        214            2           1       256
# [2026.01.04 22:40:33.185] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:40:33.185] INFO      TOTAL                          526            2                  5056
# [2026.01.04 22:40:33.185] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:40:33.192] INFO    Finished LabOne Q Compiler run.
# [2026.01.04 22:40:33.192] INFO    Task 'compile_experiment': ended at 2026-01-04 13:40:33.192503Z
# [2026.01.04 22:40:33.197] INFO    Task 'run_experiment': started at 2026-01-04 13:40:33.197012Z
# [2026.01.04 22:40:33.297] INFO    Starting near-time execution...
# [2026.01.04 22:40:33.454] INFO    Estimated RT execution time: 11.71 s.
# [2026.01.04 22:40:45.329] INFO    Finished near-time execution.
# [2026.01.04 22:40:45.444] INFO    Task 'run_experiment': ended at 2026-01-04 13:40:45.444418Z
# [2026.01.04 22:40:45.445] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:40:45.446] INFO      Workflow 'analysis_workflow': execution started at 2026-01-04
# [2026.01.04 22:40:45.446] INFO      13:40:45.445753Z
# [2026.01.04 22:40:45.446] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:40:45.448] INFO    Task 'calculate_qubit_population': started at 2026-01-04 13:40:45.448053Z
# [2026.01.04 22:40:45.448] INFO    Task 'calculate_qubit_population': ended at 2026-01-04 13:40:45.448806Z
# [2026.01.04 22:40:45.449] INFO    Task 'fit_data': started at 2026-01-04 13:40:45.449287Z
# [2026.01.04 22:40:45.451] INFO    Task 'fit_data': ended at 2026-01-04 13:40:45.451519Z
# [2026.01.04 22:40:45.452] INFO    Task 'extract_qubit_parameters': started at 2026-01-04 13:40:45.452116Z
# [2026.01.04 22:40:45.452] INFO    Task 'extract_qubit_parameters': ended at 2026-01-04 13:40:45.452858Z
# [2026.01.04 22:40:45.453] INFO    Task 'plot_raw_complex_data_1d': started at 2026-01-04 13:40:45.453297Z
# [2026.01.04 22:40:45.462] INFO    Artifact: 'Raw_data_q1' of type 'Figure' logged at 2026-01-04 13:40:45.462640Z
# [2026.01.04 22:40:45.529] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-01-04 13:40:45.529285Z
# [2026.01.04 22:40:45.530] INFO    Task 'plot_population': started at 2026-01-04 13:40:45.530010Z
# [2026.01.04 22:40:45.536] INFO    Artifact: 'T1_q1' of type 'Figure' logged at 2026-01-04 13:40:45.536355Z
# [2026.01.04 22:40:45.589] INFO    Task 'plot_population': ended at 2026-01-04 13:40:45.589074Z
# [2026.01.04 22:40:45.590] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:40:45.590] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-04 13:40:45.590044Z
# [2026.01.04 22:40:45.590] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:40:45.591] INFO    Task 'update_qpu': started at 2026-01-04 13:40:45.590968Z
# [2026.01.04 22:40:45.591] INFO    Task 'update_qpu': ended at 2026-01-04 13:40:45.591395Z
# [2026.01.04 22:40:45.591] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:40:45.592] INFO      Workflow 'lifetime_measurement': execution ended at 2026-01-04
# [2026.01.04 22:40:45.592] INFO      13:40:45.591726Z
# [2026.01.04 22:40:45.592] INFO     ──────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# # 2. Rabi

# %% [markdown]
# ## 2.1 Rabi Amplitude

# %%
qubits[0].parameters.ge_drive_length

# %%
q=qubits[1]
res_freq = qubits[1].parameters.readout_resonator_frequency
res_lo_freq = qubits[1].parameters.readout_lo_frequency
res_amp_range = qubits[1].parameters.readout_range_out
res_amp = qubits[1].parameters.readout_amplitude

q_freq = qubits[1].parameters.resonance_frequency_ge 
q_lo_freq = qubits[1].parameters.drive_lo_frequency 
q_amp_range = qubits[1].parameters.drive_range
q_amp = qubits[1].parameters.spectroscopy_amplitude #0.003


print(res_freq)
print(res_lo_freq)
print(res_amp_range)
print(res_amp)
print("==================")
print(q_freq)
print(q_lo_freq)
print(q_amp_range)
print(q_amp)
q.parameters
# Out:
# 7237131085.767722
# 7200000000.0
# 0
# 0.4
# ==================
# 3954845560.928186
# 4000000000.0
# 10
# 0.002
# TransmonQubitParameters(
# │   custom={},
# │   ge_T1=1.1272547581702817e-05,
# │   ge_T2=0,
# │   ge_T2_star=7.50613533972988e-06,
# │   ef_T1=0,
# │   ef_T2=0,
# │   ef_T2_star=0,
# │   drive_lo_frequency=4000000000.0,
# │   readout_lo_frequency=7200000000.0,
# │   resonance_frequency_ge=3954845560.928186,
# │   resonance_frequency_ef=None,
# │   readout_resonator_frequency=7237131085.767722,
# │   resonance_targ_frequency=None,
# │   ge_drive_amplitude_pi=0.5604222981695024,
# │   ge_drive_amplitude_pi2=0.27733901485856194,
# │   ge_drive_length=6.4e-08,
# │   ge_drive_pulse={
# │   │   'function': 'drag',
# │   │   'beta': 0,
# │   │   'sigma': 0.25
# │   },
# │   ef_drive_amplitude_pi=0.2,
# │   ef_drive_amplitude_pi2=0.1,
# │   ef_drive_length=5e-08,
# │   ef_drive_pulse={
# │   │   'function': 'drag',
# │   │   'beta': 0,
# │   │   'sigma': 0.25
# │   },
# │   cr_drive_amplitude=None,
# │   cr_drive_length=None,
# │   cr_drive_phase=None,
# │   cr_drive_pulse={
# │   │   'function': 'GaussianSquareDRAG',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0,
# │   │   'beta0': 0.0,
# │   │   'beta1': 0.0
# │   },
# │   cr_drive_cancel_amplitude=None,
# │   cr_drive_cancel_length=None,
# │   cr_drive_cancel_phase=None,
# │   cr_drive_cancel_pulse={
# │   │   'function': 'GaussianSquareDRAG',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0,
# │   │   'beta0': 0.0,
# │   │   'beta1': 0.0
# │   },
# │   qubit_resonator_coupling_strength_g=0,
# │   ge_chi_shift=0,
# │   readout_amplitude=0.4,
# │   readout_length=1e-06,
# │   readout_pulse={
# │   │   'function': 'GaussianSquare',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0
# │   },
# │   readout_integration_length=8e-07,
# │   readout_integration_delay=3.2e-07,
# │   readout_integration_kernels_type='default',
# │   readout_integration_kernels=None,
# │   readout_integration_discrimination_thresholds=None,
# │   reset_delay_length=0.0001,
# │   drive_range=10,
# │   readout_range_out=0,
# │   readout_range_in=0,
# │   spectroscopy_length=1e-05,
# │   spectroscopy_amplitude=0.002,
# │   spectroscopy_pulse={
# │   │   'function': 'GaussianSquare',
# │   │   'sigma': 0.2,
# │   │   'risefall_sigma_ratio': 3.0
# │   },
# │   user_defined={}
# )

# %%
from laboneq_applications.experiments import amplitude_rabi
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)

# temp_pars.ge_drive_length =64e-9
# temp_pars.drive_range= 10
temp_pars.readout_length = 1.2e-6
temp_pars.readout_integration_length = 1.2e-6
temporary_parameters[q.uid] = temp_pars

#######################################################################
amplitudes = np.linspace(0.0, 1.0,101)
print(q.parameters.ge_drive_amplitude_pi)
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = amplitude_rabi.experiment_workflow.options()
options.update(False)
options.use_cal_traces(True)
options.count(1024)
#print(workflow.show_fields(options))

###################################################################
rabi_amp = amplitude_rabi.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    amplitudes=amplitudes,
    options=options,
    temporary_parameters = temporary_parameters
)

rabi_amp_result = rabi_amp.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(rabi_amp_result.tasks['analysis_workflow'].output)
# Out:
# 0.5604222981695024
# DRIVE range (dBm) : 10, READOUT range (dBm) : 0
# [2026.01.04 22:18:45.318] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:18:45.319] INFO      Workflow 'amplitude_rabi': execution started at 2026-01-04 13:18:45.318246Z
# [2026.01.04 22:18:45.319] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:18:45.329] INFO    Task 'temporary_qpu': started at 2026-01-04 13:18:45.329404Z
# [2026.01.04 22:18:45.331] INFO    Task 'temporary_qpu': ended at 2026-01-04 13:18:45.330906Z
# [2026.01.04 22:18:45.333] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-04
# [2026.01.04 22:18:45.334] INFO    13:18:45.333412Z
# [2026.01.04 22:18:45.334] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-04 13:18:45.334328Z
# [2026.01.04 22:18:45.335] INFO    Task 'create_experiment': started at 2026-01-04 13:18:45.335207Z
# [2026.01.04 22:18:45.341] INFO    Task 'create_experiment': ended at 2026-01-04 13:18:45.341443Z
# [2026.01.04 22:18:45.343] INFO    Task 'compile_experiment': started at 2026-01-04 13:18:45.343328Z
# [2026.01.04 22:18:45.345] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal '/logical_signal_groups/q1/acquire' to SOFTWARE
# [2026.01.04 22:18:45.346] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.04 22:18:45.346] INFO    Starting LabOne Q Compiler run...
# [2026.01.04 22:18:45.367] INFO    Schedule completed. [0.019 s]
# [2026.01.04 22:18:45.376] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.01.04 22:18:45.377] INFO    Completed compilation step 1 of 1. [0.030 s]
# [2026.01.04 22:18:45.379] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:18:45.379] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.04 22:18:45.379] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:18:45.380] INFO      SHFQC_DEV12256        0         17            0           1      4800
# [2026.01.04 22:18:45.380] INFO      SHFQC_DEV12256_sg     1        217          103           2       512
# [2026.01.04 22:18:45.380] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:18:45.380] INFO      TOTAL                          234          103                  5312
# [2026.01.04 22:18:45.380] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:18:45.385] INFO    Finished LabOne Q Compiler run.
# [2026.01.04 22:18:45.386] INFO    Task 'compile_experiment': ended at 2026-01-04 13:18:45.385801Z
# [2026.01.04 22:18:45.392] INFO    Task 'run_experiment': started at 2026-01-04 13:18:45.392561Z
# [2026.01.04 22:18:45.487] INFO    Starting near-time execution...
# [2026.01.04 22:18:45.706] INFO    Estimated RT execution time: 10.68 s.
# [2026.01.04 22:18:56.566] INFO    Finished near-time execution.
# [2026.01.04 22:18:56.618] INFO    Task 'run_experiment': ended at 2026-01-04 13:18:56.618629Z
# [2026.01.04 22:18:56.620] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:18:56.621] INFO      Workflow 'analysis_workflow': execution started at 2026-01-04
# [2026.01.04 22:18:56.621] INFO      13:18:56.620567Z
# [2026.01.04 22:18:56.621] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:18:56.623] INFO    Task 'calculate_qubit_population': started at 2026-01-04 13:18:56.623372Z
# [2026.01.04 22:18:56.624] INFO    Task 'calculate_qubit_population': ended at 2026-01-04 13:18:56.624241Z
# [2026.01.04 22:18:56.624] INFO    Task 'fit_data': started at 2026-01-04 13:18:56.624795Z
# [2026.01.04 22:18:56.628] INFO    Task 'fit_data': ended at 2026-01-04 13:18:56.627861Z
# [2026.01.04 22:18:56.628] INFO    Task 'extract_qubit_parameters': started at 2026-01-04 13:18:56.628435Z
# [2026.01.04 22:18:56.630] INFO    Task 'extract_qubit_parameters': ended at 2026-01-04 13:18:56.630095Z
# [2026.01.04 22:18:56.630] INFO    Task 'plot_raw_complex_data_1d': started at 2026-01-04 13:18:56.630737Z
# [2026.01.04 22:18:56.642] INFO    Artifact: 'Raw_data_q1' of type 'Figure' logged at 2026-01-04 13:18:56.642439Z
# [2026.01.04 22:18:56.716] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-01-04 13:18:56.716214Z
# [2026.01.04 22:18:56.717] INFO    Task 'plot_population': started at 2026-01-04 13:18:56.717078Z
# [2026.01.04 22:18:56.723] INFO    Artifact: 'Rabi_q1' of type 'Figure' logged at 2026-01-04 13:18:56.723304Z
# [2026.01.04 22:18:56.778] INFO    Task 'plot_population': ended at 2026-01-04 13:18:56.777918Z
# [2026.01.04 22:18:56.778] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:18:56.779] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-04 13:18:56.778712Z
# [2026.01.04 22:18:56.779] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:18:56.780] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:18:56.780] INFO      Workflow 'amplitude_rabi': execution ended at 2026-01-04 13:18:56.780112Z
# [2026.01.04 22:18:56.780] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'old_parameter_values': {'q1': {'ge_drive_amplitude_pi': 0.5604222981695024, 'ge_drive_amplitude_pi2': 0.27733901485856194}}, 'new_parameter_values': {'q1': {'ge_drive_amplitude_pi': 0.5599306152020628+/-0.007948039326987108, 'ge_drive_amplitude_pi2': 0.2769398926555516+/-0.006331494717142509}}}

# %% [markdown]
# ## 2.2 (optional) Rabi Amplitude Chevron

# %%
from experiments import amplitude_rabi_chevron

#######################################################################
q = qubits[0]
amplitudes = np.linspace(0,1.0,11)
frequencies = q.parameters.resonance_frequency_ge + np.linspace(-3e6, 3e6, 51)
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = amplitude_rabi_chevron.experiment_workflow.options()

#print(workflow.show_fields(options))

###################################################################
rabi_amp_chev = amplitude_rabi_chevron.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    frequencies=frequencies,
    amplitudes=amplitudes,
    options=options
)

rabi_amp_chev_result = rabi_amp_chev.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(rabi_amp_chev_result.tasks['analysis_workflow'].output)

# %% [markdown]
# ## 2.3 (optional) Rabi Length
# - Not working yet

# %%
from experiments import time_rabi
#######################################################################
q = qubits[0]
q.parameters.ge_drive_amplitude_pi = 1.0
lengths = np.linspace(0.0, 240e-9, 21 ),
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = time_rabi.experiment_workflow.options()

#print(workflow.show_fields(options))

###################################################################
rabi_length = time_rabi.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    lengths=lengths,
    options=options
)

rabi_length_result = rabi_length.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(rabi_length_result.tasks['analysis_workflow'].outfput)

# %% [markdown]
# ## 2.2 (optional) Rabi Length Chevron

# %%
# from experiments import time_rabi_chevron
# #######################################################################
# q = qubits[4]

# frequencies = q.parameters.resonance_frequency_ge + np.linspace(-5e6, 5e6, 21)
# lengths = np.linspace(0.0, 240e-9, 21 ),
# print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
# #######################################################################
# options = time_rabi_chevron.experiment_workflow.options()

# #print(workflow.show_fields(options))

# ###################################################################
# rabi_length_chev = time_rabi_chevron.experiment_workflow(
#     session=session,
#     qpu=qpu,
#     qubits=q,
#     frequencies=frequencies,
#     lengths=lengths,
#     options=options
# )

# rabi_length_chev_result = rabi_length_chev.run()
# #qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
# print(rabi_length_chev_result.tasks['analysis_workflow'].output)

# %% [markdown]
# # 3. Ramsey

# %%
from laboneq_applications.experiments import ramsey
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
#temp_pars.resonance_frequency_ge = 4.9528e9
temp_pars.readout_integration_length =1.2e-6
temporary_parameters[q.uid] = temp_pars
#######################################################################
delays = np.linspace(0,10e-6,301)
detunings = 0.6e6,
pprint(q.readout_parameters())
#######################################################################
options = ramsey.experiment_workflow.options()
options.update(False)
options.count(1024)
options.use_cal_traces(True)
# Build and run Ramsey workflow (no explicit command table options required)
ramsey_wf = ramsey.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    delays=delays,
    detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)
ramsey_result = ramsey_wf.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(ramsey_result.tasks['analysis_workflow'].output)
# Out:
# ('measure',
#  {'amplitude': 0.3,
#   'length': 1.2e-06,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# [2026.01.05 00:46:25.205] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 00:46:25.205] INFO      Workflow 'ramsey': execution started at 2026-01-04 15:46:25.204825Z
# [2026.01.05 00:46:25.205] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 00:46:25.214] INFO    Task 'temporary_qpu': started at 2026-01-04 15:46:25.213804Z
# [2026.01.05 00:46:25.214] INFO    Task 'temporary_qpu': ended at 2026-01-04 15:46:25.214828Z
# [2026.01.05 00:46:25.216] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-04
# [2026.01.05 00:46:25.217] INFO    15:46:25.216705Z
# [2026.01.05 00:46:25.217] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-04 15:46:25.217265Z
# [2026.01.05 00:46:25.218] INFO    Task 'create_experiment': started at 2026-01-04 15:46:25.217936Z
# [2026.01.05 00:46:25.222] INFO    Task 'create_experiment': ended at 2026-01-04 15:46:25.222692Z
# [2026.01.05 00:46:25.224] INFO    Task 'compile_experiment': started at 2026-01-04 15:46:25.224101Z
# [2026.01.05 00:46:25.225] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal '/logical_signal_groups/q1/acquire' to SOFTWARE
# [2026.01.05 00:46:25.226] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.05 00:46:25.226] INFO    Starting LabOne Q Compiler run...
# [2026.01.05 00:46:25.291] INFO    Schedule completed. [0.064 s]
# [2026.01.05 00:46:25.320] INFO    Code generation completed for all AWGs. [0.028 s]
# [2026.01.05 00:46:25.320] INFO    Completed compilation step 1 of 1. [0.094 s]
# [2026.01.05 00:46:25.322] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 00:46:25.322] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.05 00:46:25.322] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 00:46:25.323] INFO      SHFQC_DEV12256        0        912            0           1      4800
# [2026.01.05 00:46:25.323] INFO      SHFQC_DEV12256_sg     1       1377           57          55     14240
# [2026.01.05 00:46:25.323] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 00:46:25.323] INFO      TOTAL                         2289           57                 19040
# [2026.01.05 00:46:25.323] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 00:46:25.342] INFO    Finished LabOne Q Compiler run.
# [2026.01.05 00:46:25.343] INFO    Task 'compile_experiment': ended at 2026-01-04 15:46:25.343396Z
# [2026.01.05 00:46:25.351] INFO    Task 'run_experiment': started at 2026-01-04 15:46:25.351411Z
# [2026.01.05 00:46:25.448] INFO    Starting near-time execution...
# [2026.01.05 00:46:25.635] INFO    Estimated RT execution time: 32.98 s.
# [2026.01.05 00:46:58.775] CRITICAL Error(s) happened on device(s) during the execution of the experiment. Error messages:
# SHFQC/QA:dev12256: (SYNCIGNORED) Synchronization check ignored because ITU is the only participant
# SHFQC/SG:dev12256: (SYNCIGNORED) Synchronization check ignored because ITU is the only participant
# [2026.01.05 00:46:58.775] CRITICAL Error(s) happened on device(s) during the execution of the experiment. Error messages:
# SHFQC/QA:dev12256: (SYNCIGNORED) Synchronization check ignored because ITU is the only participant
# SHFQC/SG:dev12256: (SYNCIGNORED) Synchronization check ignored because ITU is the only participant
# [2026.01.05 00:46:58.882] WARNING Error(s) happened on device(s) during the execution of the experiment. Error messages:
# SHFQC/QA:dev12256: (SYNCIGNORED) Synchronization check ignored because ITU is the only participant
# SHFQC/SG:dev12256: (SYNCIGNORED) Synchronization check ignored because ITU is the only participant
# [2026.01.05 00:46:58.996] ERROR   Task 'run_experiment': failed at 2026-01-04 15:46:58.995941Z with:
# [2026.01.05 00:46:58.996] ERROR   Task 'run_experiment': failed at 2026-01-04 15:46:58.995941Z with:
# [2026.01.05 00:46:58.998] ERROR   LabOneQControllerException('Error(s) happened on device(s) during the execution
# [2026.01.05 00:46:58.998] ERROR   LabOneQControllerException('Error(s) happened on device(s) during the execution
# [2026.01.05 00:46:58.999] ERROR   of the experiment. Error messages:\nSHFQC/QA:dev12256: (SYNCIGNORED)
# [2026.01.05 00:46:58.999] ERROR   of the experiment. Error messages:\nSHFQC/QA:dev12256: (SYNCIGNORED)
# [2026.01.05 00:46:59.000] ERROR   Synchronization check ignored because ITU is the only
# [2026.01.05 00:46:59.000] ERROR   Synchronization check ignored because ITU is the only
# [2026.01.05 00:46:59.001] ERROR   participant\nSHFQC/SG:dev12256: (SYNCIGNORED) Synchronization check ignored
# [2026.01.05 00:46:59.001] ERROR   participant\nSHFQC/SG:dev12256: (SYNCIGNORED) Synchronization check ignored
# [2026.01.05 00:46:59.002] ERROR   because ITU is the only participant')
# [2026.01.05 00:46:59.002] ERROR   because ITU is the only participant')
# [2026.01.05 00:46:59.003] INFO    Task 'run_experiment': ended at 2026-01-04 15:46:59.003317Z
# [2026.01.05 00:46:59.004] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 00:46:59.004] INFO      Workflow 'ramsey': execution ended at 2026-01-04 15:46:59.003853Z
# [2026.01.05 00:46:59.004] INFO     ──────────────────────────────────────────────────────────────────────────────
# ---------------------------------------------------------------------------
# LabOneQControllerException                Traceback (most recent call last)
# Cell In[6], line 27
#      17 # Build and run Ramsey workflow (no explicit command table options required)
#      18 ramsey_wf = ramsey.experiment_workflow(
#      19     session=session,
#      20     qpu=qpu,
#    (...)     25     temporary_parameters=temporary_parameters
#      26 )
# ---> 27 ramsey_result = ramsey_wf.run()
#      28 #qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
#      29 print(ramsey_result.tasks['analysis_workflow'].output)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/core.py:221, in Workflow.run(self, until)
#     217 for logstore in self._logstores():
#     218     state.add_recorder(
#     219         logstore.create_logbook(self, start_time=state.start_time)
#     220     )
# --> 221 return self._execute(state)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/core.py:131, in Workflow._execute(self, state)
#     129 try:
#     130     with executor.ExecutorStateContext.scoped(state):
# --> 131         self._root.execute(state)
#     132 except Exception:
#     133     if self._recovery is not None:
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/blocks/workflow_block.py:159, in WorkflowBlock.execute(self, executor)
#     154     if executor.get_block_status(block) in (
#     155         ExecutionStatus.FINISHED,
#     156         ExecutionStatus.SKIPPED,
#     157     ):
#     158         continue
# --> 159     block.execute(executor)
#     160 body_loop_finished = True
#     161 executor.set_block_status(self, ExecutionStatus.FINISHED)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/blocks/task_block.py:61, in TaskBlock.execute(self, executor)
#      59     self._exucute_hidden(executor)
#      60 else:
# ---> 61     self._execute_visible(executor)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/blocks/task_block.py:91, in TaskBlock._execute_visible(self, executor)
#      89 executor.set_block_status(self, ExecutionStatus.IN_PROGRESS)
#      90 try:
# ---> 91     task._output = self.task.func(**params)
#      92 except Exception as error:
#      93     task._end_time = utc_now()
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/tasks/run_experiment.py:99, in run_experiment(session, compiled_experiment, options)
#      89     warnings.warn(
#      90         "The 'return_legacy_results' option is deprecated."
#      91         " Use the 'include_results_metadata' option instead.",
#      92         FutureWarning,
#      93         stacklevel=2,
#      94     )
#      96 include_results_metadata = (
#      97     opts.include_results_metadata or opts.return_legacy_results
#      98 )
# ---> 99 results = session.run(
#     100     compiled_experiment,
#     101     include_results_metadata=include_results_metadata,
#     102 )
#     103 return results
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/dsl/session.py:475, in Session.run(self, experiment, include_results_metadata)
#     471 try:
#     472     handle = controller.submit_compiled(
#     473         self.compiled_experiment.scheduled_experiment
#     474     )
# --> 475     controller.wait_submission(handle)
#     476 finally:
#     477     controller.stop_workers()
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/controller.py:356, in Controller.wait_submission(self, submission)
#     355 def wait_submission(self, submission: ControllerSubmission):
# --> 356     self._event_loop.run(self._wait_submission_async, submission=submission)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/core/utilities/async_helpers.py:39, in EventLoopHolder.run(self, func, *args, **kwargs)
#      37 self._ensure_event_loop()
#      38 with self._override_sigint_handler():
# ---> 39     return self._wait_with_yielding(
#      40         asyncio.run_coroutine_threadsafe(func(*args, **kwargs), self._loop)
#      41     )
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/core/utilities/async_helpers.py:80, in EventLoopHolder._wait_with_yielding(self, future)
#      76 while True:
#      77     try:
#      78         # Exit future wait every 0.1s to handle SIGINT, balancing
#      79         # responsiveness and CPU load.
# ---> 80         return future.result(timeout=0.1)  # @IgnoreException
#      81     except concurrent.futures.TimeoutError:  # noqa: PERF203
#      82         pass
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/controller.py:377, in Controller._wait_submission_async(self, submission)
#     376 async def _wait_submission_async(self, submission: ControllerSubmission):
# --> 377     await submission.completion_future
#     378     await submission.temp_run_future
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/controller.py:386, in Controller._run_one_experiment(self, submission)
#     384 async def _run_one_experiment(self, submission: ControllerSubmission):
#     385     try:
# --> 386         await self._execute_compiled_async(submission=submission)
#     387     except BaseException as e:
#     388         # completion_future maybe cancelled by SIGINT handler, avoid InvalidStateError in that case
#     389         if not submission.completion_future.done():
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/controller.py:426, in Controller._execute_compiled_async(self, submission)
#     424 _logger.info("Starting near-time execution...")
#     425 try:
# --> 426     await NearTimeRunner(
#     427         controller=self,
#     428         parent_session_ref=self._parent_session_ref,
#     429         execution_context=execution_context,
#     430     ).run(recipe_data.execution)
#     431 except AbortExecution:
#     432     # eat the exception
#     433     pass
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/executor/executor.py:547, in AsyncExecutorBase.run(self, root_sequence)
#     545 scope = ExecutionScope(None, self)
#     546 for notification in root_sequence.run(scope):
# --> 547     await self._handlers_map[notification.statement_type](**notification.args)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/near_time_runner.py:124, in NearTimeRunner.rt_entry_handler(self, count, uid, averaging_mode, acquisition_type)
#     117 async def rt_entry_handler(
#     118     self,
#     119     count: int,
#    (...)    122     acquisition_type: AcquisitionType,
#     123 ):
# --> 124     self.last_nt_step_result_completed = await self.controller._execute_one_step(
#     125         execution_context=self.execution_context,
#     126         sweep_params_tracker=self.sweep_params_tracker,
#     127         user_set_nodes=self.user_set_nodes,
#     128         nt_step=self.nt_step(),
#     129     )
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/controller.py:284, in Controller._execute_one_step(self, execution_context, sweep_params_tracker, user_set_nodes, nt_step, timeout_s)
#     276     # TODO(2K): introduce "hard" controller exceptions
#     277     execution_context.submission.results.execution_errors.append(
#     278         (
#     279             list(nt_step.indices),
#    (...)    282         )
#     283     )
# --> 284 await self._after_nt_step()
#     285 return nt_step_result_completed
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/controller.py:178, in Controller._after_nt_step(self)
#     176 device_errors = await self._devices.fetch_device_errors()
#     177 if device_errors is not None:
# --> 178     raise LabOneQControllerException(device_errors)
#
# LabOneQControllerException: Error(s) happened on device(s) during the execution of the experiment. Error messages:
# SHFQC/QA:dev12256: (SYNCIGNORED) Synchronization check ignored because ITU is the only participant
# SHFQC/SG:dev12256: (SYNCIGNORED) Synchronization check ignored because ITU is the only participant

# %%
# from experiments import modified_ramsey
# # ssibal 갑자기 안됨

# q = qubits[1]
# temporary_parameters = {}
# temp_pars =deepcopy(q.parameters)
# #temp_pars.resonance_frequency_ge = 4.9528e9
# temporary_parameters[q.uid] = temp_pars
# #######################################################################
# delays = np.linspace(0,10e-6,301)
# detunings = 0.7e6,
# pprint(q.readout_parameters())
# #######################################################################
# options = modified_ramsey.experiment_workflow.options()
# options.update(False)
# options.count(1024)
# options.use_cal_traces(True)
# # Build and run Ramsey workflow (no explicit command table options required)
# ramsey_wf = modified_ramsey.experiment_workflow(
#     session=session,
#     qpu=qpu,
#     qubits=q,
#     delays=delays,
#     detunings=detunings,
#     options=options,
#     temporary_parameters=temporary_parameters
# )
# ramsey_result = ramsey_wf.run()
# #qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
# print(ramsey_result.tasks['analysis_workflow'].output)

# %%
from experiments import echo
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
#temp_pars.resonance_frequency_ge = 4.9528e9
temporary_parameters[q.uid] = temp_pars
#######################################################################
delays = np.linspace(0,10e-6,301)
detunings = 0.6e6,
pprint(q.readout_parameters())
#######################################################################
options = echo.experiment_workflow.options()
options.update(True)
options.count(1024)
options.use_cal_traces(True)
# Build and run Ramsey workflow (no explicit command table options required)
ramsey_echo = echo.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    delays=delays,
    #detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)
ramsey_echo_result = ramsey_echo.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(ramsey_echo_result.tasks['analysis_workflow'].output)
# Out:
# ('measure',
#  {'amplitude': 0.4,
#   'length': 1.2e-06,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# [2026.01.04 22:42:34.760] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:42:34.761] INFO      Workflow 'echo': execution started at 2026-01-04 13:42:34.760479Z
# [2026.01.04 22:42:34.761] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:42:34.769] INFO    Task 'temporary_qpu': started at 2026-01-04 13:42:34.769761Z
# [2026.01.04 22:42:34.770] INFO    Task 'temporary_qpu': ended at 2026-01-04 13:42:34.770602Z
# [2026.01.04 22:42:34.772] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-04
# [2026.01.04 22:42:34.772] INFO    13:42:34.772539Z
# [2026.01.04 22:42:34.773] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-04 13:42:34.773159Z
# [2026.01.04 22:42:34.774] INFO    Task 'create_experiment': started at 2026-01-04 13:42:34.774104Z
# [2026.01.04 22:42:34.779] INFO    Task 'create_experiment': ended at 2026-01-04 13:42:34.779717Z
# [2026.01.04 22:42:34.781] INFO    Task 'compile_experiment': started at 2026-01-04 13:42:34.781339Z
# [2026.01.04 22:42:34.783] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal '/logical_signal_groups/q1/acquire' to SOFTWARE
# [2026.01.04 22:42:34.784] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.04 22:42:34.784] INFO    Starting LabOne Q Compiler run...
# [2026.01.04 22:42:34.881] INFO    Schedule completed. [0.096 s]
# [2026.01.04 22:42:34.918] INFO    Code generation completed for all AWGs. [0.036 s]
# [2026.01.04 22:42:34.918] INFO    Completed compilation step 1 of 1. [0.133 s]
# [2026.01.04 22:42:34.920] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:42:34.920] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.04 22:42:34.921] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:42:34.921] INFO      SHFQC_DEV12256        0        912            0           1      4800
# [2026.01.04 22:42:34.921] INFO      SHFQC_DEV12256_sg     1       1873           23          21      6176
# [2026.01.04 22:42:34.921] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:42:34.921] INFO      TOTAL                         2785           23                 10976
# [2026.01.04 22:42:34.921] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:42:34.949] INFO    Finished LabOne Q Compiler run.
# [2026.01.04 22:42:34.950] INFO    Task 'compile_experiment': ended at 2026-01-04 13:42:34.950357Z
# [2026.01.04 22:42:34.958] INFO    Task 'run_experiment': started at 2026-01-04 13:42:34.958121Z
# [2026.01.04 22:42:35.070] INFO    Starting near-time execution...
# [2026.01.04 22:42:35.387] INFO    Estimated RT execution time: 33.00 s.
# [2026.01.04 22:43:08.584] INFO    Finished near-time execution.
# [2026.01.04 22:43:08.701] INFO    Task 'run_experiment': ended at 2026-01-04 13:43:08.700786Z
# [2026.01.04 22:43:08.702] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:43:08.702] INFO      Workflow 'analysis_workflow': execution started at 2026-01-04
# [2026.01.04 22:43:08.703] INFO      13:43:08.702241Z
# [2026.01.04 22:43:08.703] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:43:08.705] INFO    Task 'calculate_qubit_population': started at 2026-01-04 13:43:08.705088Z
# [2026.01.04 22:43:08.706] INFO    Task 'calculate_qubit_population': ended at 2026-01-04 13:43:08.705997Z
# [2026.01.04 22:43:08.706] INFO    Task 'fit_data': started at 2026-01-04 13:43:08.706604Z
# [2026.01.04 22:43:08.709] INFO    Task 'fit_data': ended at 2026-01-04 13:43:08.709280Z
# [2026.01.04 22:43:08.710] INFO    Task 'extract_qubit_parameters': started at 2026-01-04 13:43:08.709971Z
# [2026.01.04 22:43:08.711] INFO    Task 'extract_qubit_parameters': ended at 2026-01-04 13:43:08.710913Z
# [2026.01.04 22:43:08.711] INFO    Task 'plot_raw_complex_data_1d': started at 2026-01-04 13:43:08.711427Z
# [2026.01.04 22:43:08.724] INFO    Artifact: 'Raw_data_q1' of type 'Figure' logged at 2026-01-04 13:43:08.724105Z
# [2026.01.04 22:43:08.954] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-01-04 13:43:08.954760Z
# [2026.01.04 22:43:08.955] INFO    Task 'plot_population': started at 2026-01-04 13:43:08.955527Z
# [2026.01.04 22:43:08.961] INFO    Artifact: 'T2_q1' of type 'Figure' logged at 2026-01-04 13:43:08.961443Z
# [2026.01.04 22:43:09.012] INFO    Task 'plot_population': ended at 2026-01-04 13:43:09.012285Z
# [2026.01.04 22:43:09.013] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:43:09.014] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-04 13:43:09.013468Z
# [2026.01.04 22:43:09.015] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:43:09.015] INFO    Task 'update_qpu': started at 2026-01-04 13:43:09.015536Z
# [2026.01.04 22:43:09.016] INFO    Task 'update_qpu': ended at 2026-01-04 13:43:09.016515Z
# [2026.01.04 22:43:09.017] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:43:09.017] INFO      Workflow 'echo': execution ended at 2026-01-04 13:43:09.017229Z
# [2026.01.04 22:43:09.017] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'old_parameter_values': {'q1': {'ge_T2': 0}}, 'new_parameter_values': {'q1': {'ge_T2': 1.0944085857767516e-05+/-1.6787842702978684e-07}}}

# %% [markdown]
# # x180

# %%
qubits[0].parameters

# %%
from laboneq_applications.experiments import amplitude_fine
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temporary_parameters[q.uid] = temp_pars

#######################################################################
repetitions =np.arange(1,10) # Due to short T1, 20   
#######################################################################
options = amplitude_fine.experiment_workflow_x180.options()
options.update(False)
options.use_cal_traces(True)
#options.do_pca(False)

#print(workflow.show_fields(options))

###################################################################
error_amp = amplitude_fine.experiment_workflow_x180(
    session=session,
    qpu=qpu,
    qubits=q,
    repetitions=repetitions,
    temporary_parameters=temporary_parameters,
    options=options
)

error_amp_result = error_amp.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(error_amp_result.tasks['analysis_workflow'].output)
# Out:
# [2026.01.04 22:33:15.969] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:15.970] INFO      Workflow 'experiment_workflow_x180': execution started at 2026-01-04
# [2026.01.04 22:33:15.970] INFO      13:33:15.969286Z
# [2026.01.04 22:33:15.970] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:15.979] INFO    Task 'temporary_qpu': started at 2026-01-04 13:33:15.979434Z
# [2026.01.04 22:33:15.980] INFO    Task 'temporary_qpu': ended at 2026-01-04 13:33:15.980462Z
# [2026.01.04 22:33:15.982] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-04
# [2026.01.04 22:33:15.982] INFO    13:33:15.982416Z
# [2026.01.04 22:33:15.983] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-04 13:33:15.983162Z
# [2026.01.04 22:33:15.984] INFO    Task 'create_experiment': started at 2026-01-04 13:33:15.983890Z
# [2026.01.04 22:33:15.990] INFO    Task 'create_experiment': ended at 2026-01-04 13:33:15.990398Z
# [2026.01.04 22:33:15.992] INFO    Task 'compile_experiment': started at 2026-01-04 13:33:15.992075Z
# [2026.01.04 22:33:15.994] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal '/logical_signal_groups/q1/acquire' to SOFTWARE
# [2026.01.04 22:33:15.995] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.04 22:33:15.995] INFO    Starting LabOne Q Compiler run...
# [2026.01.04 22:33:15.999] INFO    Schedule completed. [0.003 s]
# [2026.01.04 22:33:16.001] INFO    Code generation completed for all AWGs. [0.002 s]
# [2026.01.04 22:33:16.002] INFO    Completed compilation step 1 of 1. [0.006 s]
# [2026.01.04 22:33:16.003] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:16.004] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.04 22:33:16.004] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:16.004] INFO      SHFQC_DEV12256        0         36            0           1      4800
# [2026.01.04 22:33:16.004] INFO      SHFQC_DEV12256_sg     1         54            3           1       256
# [2026.01.04 22:33:16.004] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:16.005] INFO      TOTAL                           90            3                  5056
# [2026.01.04 22:33:16.005] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:16.008] INFO    Finished LabOne Q Compiler run.
# [2026.01.04 22:33:16.009] INFO    Task 'compile_experiment': ended at 2026-01-04 13:33:16.008989Z
# [2026.01.04 22:33:16.014] INFO    Task 'run_experiment': started at 2026-01-04 13:33:16.014359Z
# [2026.01.04 22:33:16.063] INFO    Starting near-time execution...
# [2026.01.04 22:33:17.489] INFO    Finished near-time execution.
# [2026.01.04 22:33:17.564] INFO    Task 'run_experiment': ended at 2026-01-04 13:33:17.564465Z
# [2026.01.04 22:33:17.566] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:17.567] INFO      Workflow 'analysis_workflow': execution started at 2026-01-04
# [2026.01.04 22:33:17.568] INFO      13:33:17.566752Z
# [2026.01.04 22:33:17.568] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:17.573] INFO    Task 'calculate_qubit_population': started at 2026-01-04 13:33:17.573448Z
# [2026.01.04 22:33:17.575] INFO    Task 'calculate_qubit_population': ended at 2026-01-04 13:33:17.575097Z
# [2026.01.04 22:33:17.576] INFO    Task 'fit_data': started at 2026-01-04 13:33:17.575982Z
# [2026.01.04 22:33:17.578] INFO    Task 'fit_data': ended at 2026-01-04 13:33:17.578792Z
# [2026.01.04 22:33:17.579] INFO    Task 'process_fit_results': started at 2026-01-04 13:33:17.579408Z
# [2026.01.04 22:33:17.580] INFO    Task 'process_fit_results': ended at 2026-01-04 13:33:17.580514Z
# [2026.01.04 22:33:17.581] INFO    Task 'extract_qubit_parameters': started at 2026-01-04 13:33:17.581730Z
# [2026.01.04 22:33:17.584] INFO    Task 'extract_qubit_parameters': ended at 2026-01-04 13:33:17.584401Z
# [2026.01.04 22:33:17.585] INFO    Task 'xaxis_label': started at 2026-01-04 13:33:17.585440Z
# [2026.01.04 22:33:17.586] INFO    Task 'xaxis_label': ended at 2026-01-04 13:33:17.586516Z
# [2026.01.04 22:33:17.587] INFO    Task 'plot_raw_complex_data_1d': started at 2026-01-04 13:33:17.587275Z
# [2026.01.04 22:33:17.602] INFO    Artifact: 'Raw_data_q1' of type 'Figure' logged at 2026-01-04 13:33:17.602612Z
# [2026.01.04 22:33:17.678] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-01-04 13:33:17.677932Z
# [2026.01.04 22:33:17.678] INFO    Task 'plot_population': started at 2026-01-04 13:33:17.678755Z
# [2026.01.04 22:33:17.685] INFO    Artifact: 'Amplitude_Fine_q1' of type 'Figure' logged at 2026-01-04
# [2026.01.04 22:33:17.685] INFO    13:33:17.684909Z
# [2026.01.04 22:33:17.737] INFO    Task 'plot_population': ended at 2026-01-04 13:33:17.737067Z
# [2026.01.04 22:33:17.737] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:17.738] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-04 13:33:17.737792Z
# [2026.01.04 22:33:17.738] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:17.738] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:17.738] INFO      Workflow 'experiment_workflow_x180': execution ended at 2026-01-04
# [2026.01.04 22:33:17.739] INFO      13:33:17.738590Z
# [2026.01.04 22:33:17.739] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'old_parameter_values': {'q1': {'ge_drive_amplitude_pi': 0.5556284789634386}}, 'new_parameter_values': {'q1': {'ge_drive_amplitude_pi': 0.5550899913748806+/-0.0013603437598125774}}}

# %% [markdown]
# # X90

# %%
from laboneq_applications.experiments import amplitude_fine
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temporary_parameters[q.uid] = temp_pars
#######################################################################
repetitions =np.arange(1,10)
#######################################################################
options = amplitude_fine.experiment_workflow_x90.options()
options.update(False)
options.use_cal_traces(True)
options.do_pca(False)
options.count(1024)

#print(workflow.show_fields(options))

###################################################################
error_amp_half = amplitude_fine.experiment_workflow_x90(
    session=session,
    qpu=qpu,
    qubits=q,
    repetitions=repetitions,
    temporary_parameters=temporary_parameters,
    options=options
)

error_amp_half_result = error_amp_half.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(error_amp_half_result.tasks['analysis_workflow'].output)
# Out:
# [2026.01.04 22:33:23.948] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:23.948] INFO      Workflow 'experiment_workflow_x90': execution started at 2026-01-04
# [2026.01.04 22:33:23.949] INFO      13:33:23.948028Z
# [2026.01.04 22:33:23.949] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:23.957] INFO    Task 'temporary_qpu': started at 2026-01-04 13:33:23.957377Z
# [2026.01.04 22:33:23.958] INFO    Task 'temporary_qpu': ended at 2026-01-04 13:33:23.958600Z
# [2026.01.04 22:33:23.961] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-04
# [2026.01.04 22:33:23.961] INFO    13:33:23.960967Z
# [2026.01.04 22:33:23.962] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-04 13:33:23.962206Z
# [2026.01.04 22:33:23.963] INFO    Task 'create_experiment': started at 2026-01-04 13:33:23.963064Z
# [2026.01.04 22:33:23.971] INFO    Task 'create_experiment': ended at 2026-01-04 13:33:23.970702Z
# [2026.01.04 22:33:23.973] INFO    Task 'compile_experiment': started at 2026-01-04 13:33:23.972908Z
# [2026.01.04 22:33:23.975] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal '/logical_signal_groups/q1/acquire' to SOFTWARE
# [2026.01.04 22:33:23.975] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.04 22:33:23.976] INFO    Starting LabOne Q Compiler run...
# [2026.01.04 22:33:23.980] INFO    Schedule completed. [0.003 s]
# [2026.01.04 22:33:23.983] INFO    Code generation completed for all AWGs. [0.003 s]
# [2026.01.04 22:33:23.983] INFO    Completed compilation step 1 of 1. [0.007 s]
# [2026.01.04 22:33:23.985] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:23.986] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.04 22:33:23.986] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:23.986] INFO      SHFQC_DEV12256        0         36            0           1      4800
# [2026.01.04 22:33:23.986] INFO      SHFQC_DEV12256_sg     1         47            3           1       256
# [2026.01.04 22:33:23.987] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:23.987] INFO      TOTAL                           83            3                  5056
# [2026.01.04 22:33:23.987] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:23.990] INFO    Finished LabOne Q Compiler run.
# [2026.01.04 22:33:23.991] INFO    Task 'compile_experiment': ended at 2026-01-04 13:33:23.991376Z
# [2026.01.04 22:33:23.997] INFO    Task 'run_experiment': started at 2026-01-04 13:33:23.997721Z
# [2026.01.04 22:33:24.068] INFO    Starting near-time execution...
# [2026.01.04 22:33:25.479] INFO    Finished near-time execution.
# [2026.01.04 22:33:25.547] INFO    Task 'run_experiment': ended at 2026-01-04 13:33:25.547648Z
# [2026.01.04 22:33:25.549] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:25.549] INFO      Workflow 'analysis_workflow': execution started at 2026-01-04
# [2026.01.04 22:33:25.549] INFO      13:33:25.548969Z
# [2026.01.04 22:33:25.549] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:25.551] INFO    Task 'calculate_qubit_population': started at 2026-01-04 13:33:25.551776Z
# [2026.01.04 22:33:25.552] INFO    Task 'calculate_qubit_population': ended at 2026-01-04 13:33:25.552813Z
# [2026.01.04 22:33:25.553] INFO    Task 'fit_data': started at 2026-01-04 13:33:25.553425Z
# [2026.01.04 22:33:25.557] INFO    Task 'fit_data': ended at 2026-01-04 13:33:25.557624Z
# [2026.01.04 22:33:25.558] INFO    Task 'process_fit_results': started at 2026-01-04 13:33:25.558182Z
# [2026.01.04 22:33:25.559] INFO    Task 'process_fit_results': ended at 2026-01-04 13:33:25.559019Z
# [2026.01.04 22:33:25.559] INFO    Task 'extract_qubit_parameters': started at 2026-01-04 13:33:25.559480Z
# [2026.01.04 22:33:25.560] INFO    Task 'extract_qubit_parameters': ended at 2026-01-04 13:33:25.560251Z
# [2026.01.04 22:33:25.560] INFO    Task 'xaxis_label': started at 2026-01-04 13:33:25.560795Z
# [2026.01.04 22:33:25.561] INFO    Task 'xaxis_label': ended at 2026-01-04 13:33:25.561146Z
# [2026.01.04 22:33:25.561] INFO    Task 'plot_raw_complex_data_1d': started at 2026-01-04 13:33:25.561640Z
# [2026.01.04 22:33:25.573] INFO    Artifact: 'Raw_data_q1' of type 'Figure' logged at 2026-01-04 13:33:25.573155Z
# [2026.01.04 22:33:25.649] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-01-04 13:33:25.649652Z
# [2026.01.04 22:33:25.650] INFO    Task 'plot_population': started at 2026-01-04 13:33:25.650554Z
# [2026.01.04 22:33:25.656] INFO    Artifact: 'Amplitude_Fine_q1' of type 'Figure' logged at 2026-01-04
# [2026.01.04 22:33:25.657] INFO    13:33:25.656465Z
# [2026.01.04 22:33:25.710] INFO    Task 'plot_population': ended at 2026-01-04 13:33:25.709858Z
# [2026.01.04 22:33:25.710] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:25.711] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-04 13:33:25.710758Z
# [2026.01.04 22:33:25.711] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:25.711] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 22:33:25.712] INFO      Workflow 'experiment_workflow_x90': execution ended at 2026-01-04
# [2026.01.04 22:33:25.712] INFO      13:33:25.711733Z
# [2026.01.04 22:33:25.712] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'old_parameter_values': {'q1': {'ge_drive_amplitude_pi2': 0.27733901485856194}}, 'new_parameter_values': {'q1': {'ge_drive_amplitude_pi2': 0.2805084493753882+/-0.0034558095053547817}}}

# %% [markdown]
# # DRAG

# %%
from laboneq_applications.experiments import drag_q_scaling
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temp_pars.ge_drive_pulse['beta'] =0
temporary_parameters[q.uid] = temp_pars
#######################################################################
q_scalings = np.linspace(-0.05,0.1,51)
#######################################################################
options = drag_q_scaling.experiment_workflow.options()
options.update(False)



#print(workflow.show_fields(options))

###################################################################
drag = drag_q_scaling.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    q_scalings=q_scalings,
    options=options
)

drag_result = drag.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(drag_result.tasks['analysis_workflow'].output)

# %% [markdown]
# # RB
#
# LaboneQ Benchmark 확인필요

# %%
from laboneq_applications.experiments import d
 
#######################################################################

# %% [markdown]
# # RIP
#
# This notebook is dedicated to TG's RIP gate calibration
#
# ### Current issues
#
# 1. phase sweep for detuning is not implemented
# 2. First prepare state section takes 80ns length for unknown reason (might be related to port delay calibration setting)
# 3. Folderstore not working...

# %%
from experiments import rip2

#q = qubits[1]
#temporary_parameters = q.parameters.copy()

#######################################################################

#######################################################################
options = rip2.experiment_workflow.options()
options.update(False)

#print(workflow.show_fields(options))

###################################################################
bus_freq = 6.534e9
bus_amp = 1.0

rip_drive_controlg = rip2.experiment_workflow(
    session=session,
    qpu=qpu,
    ctrl=qubits[1],
    targ=qubits[0],
    bus=qubits[2],
    bus_frequency=bus_freq,
    bus_amplitude=bus_amp,
    delays=np.linspace(80e-9, 880e-9, 201),
    detunings=0.0e6,
    c_prep = "g",
    #frequencies=qubits[2].parameters.resonance_targ_frequency + np.linspace(-10e6,10e6,6),
    #amplitudes=np.linspace(0.0, 1.0, 11),
    options=options 
)
rip_drive_controle = rip2.experiment_workflow(
    session=session,
    qpu=qpu,
    ctrl=qubits[1],
    targ=qubits[0],
    bus=qubits[2],
    bus_frequency=bus_freq,
    bus_amplitude=bus_amp,
    delays=np.linspace(80e-9, 880e-9, 201),
    detunings=0.0e6,
    c_prep = "e",
    #frequencies=qubits[2].parameters.resonance_targ_frequency + np.linspace(-10e6,10e6,6),
    #amplitudes=np.linspace(0.0, 1.0, 11),
    options=options 
)

rip_result_control_g = rip_drive_controlg.run()
rip_result_control_e = rip_drive_controle.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
#print(drag_result.tasks['analysis_workflow'].output)

# %%
rip_data_control_g = rip_result_control_g.output
rip_data_control_e = rip_result_control_e.output
duration = rip_data_control_g.data['q0']['result'].axis[0][0]


phase_control_g = rip_data_control_g.data['q0']['result'].data
phase_control_e = rip_data_control_e.data['q0']['result'].data
import matplotlib.pyplot as plt

control_g_g_point = rip_data_control_g.data['q0']['cal_trace'].g.data
control_g_e_point = rip_data_control_g.data['q0']['cal_trace'].e.data

control_e_g_point = rip_data_control_e.data['q0']['cal_trace'].g.data
control_e_e_point = rip_data_control_e.data['q0']['cal_trace'].e.data


plt.figure(figsize=(6,6))

plt.scatter(control_g_g_point.real, control_g_g_point.imag, color="red", label="|0> reference (g)")
plt.scatter(control_g_e_point.real, control_g_e_point.imag, color="blue", label="|1> reference (e)")
plt.scatter(control_e_g_point.real, control_e_g_point.imag, color="red", label="|0> reference (g)")
plt.scatter(control_e_e_point.real, control_e_e_point.imag, color="blue", label="|1> reference (e)")

plt.axvline(x=0, color='black', linestyle='--', linewidth=0.8)
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.legend()

# %%
from experiments import rip2

#q = qubits[1]
#temporary_parameters = q.parameters.copy()

#######################################################################

#######################################################################
options = rip2.experiment_workflow.options()
options.update(False)

#print(workflow.show_fields(options))

###################################################################
bus_freq = 5.99e9
bus_amp = 1.0

bus_freq_sweep = np.linspace(5.99e9,6.08e9,31)

ctrl_g = []
ctrl_e = []

for bf in bus_freq_sweep:
    print(f"Bus frequency : {bf/1e9} GHz")
    rip_drive_controlg = rip2.experiment_workflow(
        session=session,
        qpu=qpu,
        ctrl=qubits[1],
        targ=qubits[0],
        bus=qubits[2],
        bus_frequency=bf,
        bus_amplitude=bus_amp,
        delays=np.linspace(80e-9, 1600e-9, 153),
        detunings=0.0e6,
        c_prep = "g",
        #frequencies=qubits[2].parameters.resonance_targ_frequency + np.linspace(-10e6,10e6,6),
        #amplitudes=np.linspace(0.0, 1.0, 11),
        options=options 
    )
    rip_drive_controle = rip2.experiment_workflow(
        session=session,
        qpu=qpu,
        ctrl=qubits[1],
        targ=qubits[0],
        bus=qubits[2],
        bus_frequency=bf,
        bus_amplitude=bus_amp,
        delays=np.linspace(80e-9, 1600e-9, 153),
        detunings=0.0e6,
        c_prep = "e",
        #frequencies=qubits[2].parameters.resonance_targ_frequency + np.linspace(-10e6,10e6,6),
        #amplitudes=np.linspace(0.0, 1.0, 11),
        options=options 
    )

    rip_result_control_g = rip_drive_controlg.run()
    rip_result_control_e = rip_drive_controle.run()

    ctrl_g.append(rip_result_control_g)
    ctrl_e.append(rip_result_control_e)

# %%
# rip_data_control_g = rip_result_control_g.output
# rip_data_control_e = rip_result_control_e.output

rip_data_control_g = ctrl_g[29].output
rip_data_control_e = ctrl_e[29].output

# %%
duration = rip_data_control_g.data['q0']['result'].axis[0][0]

phase_control_g = rip_data_control_g.data['q0']['result'].data
phase_control_e = rip_data_control_e.data['q0']['result'].data

# %%
import matplotlib.pyplot as plt

control_g_g_point = rip_data_control_g.data['q0']['cal_trace'].g.data
control_g_e_point = rip_data_control_g.data['q0']['cal_trace'].e.data

control_e_g_point = rip_data_control_e.data['q0']['cal_trace'].g.data
control_e_e_point = rip_data_control_e.data['q0']['cal_trace'].e.data


plt.figure(figsize=(6,6))

plt.scatter(control_g_g_point.real, control_g_g_point.imag, color="red", label="|0> reference (g)")
plt.scatter(control_g_e_point.real, control_g_e_point.imag, color="blue", label="|1> reference (e)")
plt.scatter(control_e_g_point.real, control_e_g_point.imag, color="red", label="|0> reference (g)")
plt.scatter(control_e_e_point.real, control_e_e_point.imag, color="blue", label="|1> reference (e)")

plt.axvline(x=0, color='black', linestyle='--', linewidth=0.8)
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.legend()

# %%
def normalize_population(points, g, e):
    """
    points: list or numpy array of complex numbers
    return: array of normalized values in [0,1]
    """
    points = np.array(points, dtype=complex)
    d0 = np.abs(points - g)
    d1 = np.abs(points - e)
    return d0 / (d0 + d1)

new_phase_control_g = []
new_phase_control_e = []

for i in range(len(phase_control_g)):
    # 2. Calculate the value and append it to the new row
    normalized_value = normalize_population(phase_control_g[i], control_g_g_point, control_g_e_point)
    new_phase_control_g.append(normalized_value)
for k in range(len(phase_control_e)):
    # 2. Calculate the value and append it to the new row
    normalized_value = normalize_population(phase_control_e[k], control_e_g_point, control_e_e_point)
    new_phase_control_e.append(normalized_value)
# 3. Append the completed row to the main population list

population_control_g = new_phase_control_g
population_control_e = new_phase_control_e
plt.figure(figsize=(8,6))
plt.plot(duration, population_control_g, color="#ff5500", label = r'control: |g>')
plt.plot(duration, population_control_e, color="#0055aa", label = r'control: |e>')
plt.ylim([-0.1,1.1])
plt.xlabel("RIP duration (s)", fontsize=16)
plt.ylabel("population", fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.legend(fontsize=14)

# %% [markdown]
# # SAVING data

# %%
#ctrl_g[0].output

# %%
from laboneq.simple import save, load

bus_freq_sweep * 1e-9


for i, bf in enumerate(bus_freq_sweep *1e-9):
    save(ctrl_g[i].output, filename=f'1029_rip_control_g_bf_{bf:.3f}_amp1.0')
    save(ctrl_e[i].output, filename=f'1029_rip_control_e_bf_{bf:.3f}_amp1.0')


#save(rip_result_control_g.output, filename='1023_control_g_bf_5.535_amp1.0')
#save(rip_result_control_e.output, filename='1023_control_e_bf_5.535_amp1.0')

# %%
qubits[2].parameters.resonance_targ_frequency = 5.6e9
qubits[2].parameters.resonance_targ_frequency

# %%
from laboneq.simple import show_pulse_sheet
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

#show_pulse_sheet(compiled_experiment=rip_result.tasks["compile_experiment"].output,name='test', interactive=True, max_events_to_publish=100000)
plot_simulation(compiled_experiment=rip_result_control_g.tasks["compile_experiment"].output)
plot_simulation(compiled_experiment=rip_result_control_e.tasks["compile_experiment"].output)

# %%
from laboneq.simple import save, load

save(rip_result.output, filename='0909n_e_0.6')
load(filename='0909n_e_0.6')

# %%
from laboneq_applications.analysis.calibration_traces_rotation import (
    calculate_qubit_population_2d,
    calculate_qubit_population
)
targ= qubits[0]
delays=np.linspace(300e-9, 2000e-9,101)
frequencies = qubits[2].parameters.resonance_targ_frequency + np.linspace(-10e6,10e6,6)
processed_d=calculate_qubit_population_2d(qubits=targ, result=rip_result.output, sweep_points_1d=delays, sweep_points_2d=frequencies)

# %%
import matplotlib.pyplot as plt
plt.plot(processed_d['q0']['population'][1,:])
plt.ylim([-0.1, 1.1])
plt.show()

# %%
from laboneq_applications.analysis import iq_blobs
from laboneq_applications.experiments import iq_blobs

#######################################################################
q = qubits[0]

print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = iq_blobs.experiment_workflow.options()

#print(workflow.show_fields(options))

###################################################################
iq = iq_blobs.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    options=options,
    states='ge'
)

iq_result = iq.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(iq_result.tasks['analysis_workflow'].output)

# %% [markdown]
# # Basic Readout optimization
# Here we optimize SNR via
#
# * `readout_length`
# * `readout-amplitude`
#
# * `readout_integration_length`
# * `readout_integration_delay`
# * `readout_integration_weight`

# %% [markdown]
# # Dispersive shift

# %%
from experiments import dispersive_shift

#######################################################################
q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)

#temp_pars.readout_resonator_frequency = 7.5582e9
temporary_parameters[q.uid] = temp_pars

print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = dispersive_shift.experiment_workflow.options()
options.count(1024)
options.update(False)
#print(workflow.show_fields(options))

###################################################################
dispersive = dispersive_shift.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=q,
    frequencies=q.parameters.readout_resonator_frequency + np.linspace(-5e6,5e6,201),
    options=options,
    states='ge',
    temporary_parameters=temporary_parameters
)

dispersive_result = dispersive.run() 
print(dispersive_result.tasks['analysis_workflow'].output)
# Out:
# DRIVE range (dBm) : 10, READOUT range (dBm) : 0
# [2026.01.04 01:09:34.513] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 01:09:34.514] INFO      Workflow 'dispersive_shift': execution started at 2026-01-03
# [2026.01.04 01:09:34.514] INFO      16:09:34.513557Z
# [2026.01.04 01:09:34.514] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 01:09:34.521] INFO    Task 'temporary_qpu': started at 2026-01-03 16:09:34.521714Z
# [2026.01.04 01:09:34.522] INFO    Task 'temporary_qpu': ended at 2026-01-03 16:09:34.522691Z
# [2026.01.04 01:09:34.524] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-03
# [2026.01.04 01:09:34.525] INFO    16:09:34.524431Z
# [2026.01.04 01:09:34.525] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-03 16:09:34.525513Z
# [2026.01.04 01:09:34.526] INFO    Task 'create_experiment': started at 2026-01-03 16:09:34.526736Z
# [2026.01.04 01:09:34.533] INFO    Task 'create_experiment': ended at 2026-01-03 16:09:34.532754Z
# [2026.01.04 01:09:34.535] INFO    Task 'compile_experiment': started at 2026-01-03 16:09:34.535012Z
# [2026.01.04 01:09:34.537] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.04 01:09:34.538] INFO    Starting LabOne Q Compiler run...
# [2026.01.04 01:09:34.591] INFO    Schedule completed. [0.052 s]
# [2026.01.04 01:09:34.696] INFO    Code generation completed for all AWGs. [0.105 s]
# [2026.01.04 01:09:34.697] INFO    Completed compilation step 1 of 1. [0.159 s]
# [2026.01.04 01:09:34.700] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 01:09:34.702] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.04 01:09:34.702] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 01:09:34.703] INFO      SHFQC_DEV12256        0         27            0           1      4000
# [2026.01.04 01:09:34.704] INFO      SHFQC_DEV12256_sg     1         14            2           1       256
# [2026.01.04 01:09:34.705] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 01:09:34.705] INFO      TOTAL                           41            2                  4256
# [2026.01.04 01:09:34.705] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.04 01:09:34.709] INFO    Finished LabOne Q Compiler run.
# [2026.01.04 01:09:34.709] INFO    Task 'compile_experiment': ended at 2026-01-03 16:09:34.709550Z
# [2026.01.04 01:09:34.714] INFO    Task 'run_experiment': started at 2026-01-03 16:09:34.714173Z
# [2026.01.04 01:09:34.810] INFO    Starting near-time execution...
# [2026.01.04 01:09:34.902] INFO    Estimated RT execution time: 41.61 s.
# [2026.01.04 01:10:16.592] INFO    Finished near-time execution.
# [2026.01.04 01:10:16.666] INFO    Task 'run_experiment': ended at 2026-01-03 16:10:16.666624Z
# [2026.01.04 01:10:16.668] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 01:10:16.669] INFO      Workflow 'analysis_workflow': execution started at 2026-01-03
# [2026.01.04 01:10:16.669] INFO      16:10:16.668263Z
# [2026.01.04 01:10:16.669] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 01:10:16.671] INFO    Task 'calculate_signal_differences': started at 2026-01-03 16:10:16.671147Z
# [2026.01.04 01:10:16.671] INFO    Task 'calculate_signal_differences': ended at 2026-01-03 16:10:16.671799Z
# [2026.01.04 01:10:16.672] INFO    Task 'extract_qubit_parameters': started at 2026-01-03 16:10:16.672372Z
# [2026.01.04 01:10:16.672] INFO    Task 'extract_qubit_parameters': ended at 2026-01-03 16:10:16.672837Z
# [2026.01.04 01:10:16.673] INFO    Task 'plot_dispersive_shift': started at 2026-01-03 16:10:16.673189Z
# [2026.01.04 01:10:16.680] INFO    Artifact: 'Dispersive_shift_q1' of type 'Figure' logged at 2026-01-03
# [2026.01.04 01:10:16.680] INFO    16:10:16.679844Z
# [2026.01.04 01:10:16.735] INFO    Task 'plot_dispersive_shift': ended at 2026-01-03 16:10:16.735580Z
# [2026.01.04 01:10:16.736] INFO    Task 'plot_signal_distances': started at 2026-01-03 16:10:16.736408Z
# [2026.01.04 01:10:16.741] INFO    Artifact: 'Signal_distances_q1' of type 'Figure' logged at 2026-01-03
# [2026.01.04 01:10:16.742] INFO    16:10:16.741803Z
# [2026.01.04 01:10:16.791] INFO    Task 'plot_signal_distances': ended at 2026-01-03 16:10:16.791072Z
# [2026.01.04 01:10:16.792] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 01:10:16.792] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-03 16:10:16.791844Z
# [2026.01.04 01:10:16.792] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 01:10:16.792] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.04 01:10:16.793] INFO      Workflow 'dispersive_shift': execution ended at 2026-01-03 16:10:16.792845Z
# [2026.01.04 01:10:16.793] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'old_parameter_values': {'q1': {'readout_resonator_frequency': 7236100000.0}}, 'new_parameter_values': {'q1': {'readout_resonator_frequency': np.float64(7236650000.0)}}}

# %% [markdown]
# # Save Qubit Parameters

# %%
from helper import load_qubit_parameters, save_qubit_parameters
save_qubit_parameters(qubits={ qubit.uid : qubit for qubit in qubits}, save_folder="./qubit_parameters/", filename="sample2")
# Out:
# Qubit parameters stored as JSON in /home/yalgaeahn/JSAHN/qubit-experiment/examples/selectiveRIP/qubit_parameters/20260104-2228_sample2.json
