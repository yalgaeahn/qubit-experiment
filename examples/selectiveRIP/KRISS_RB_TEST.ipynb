# %%
import numpy as np
from pprint import pprint
from copy import deepcopy


from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
#from laboneq.contrib.example_helpers.generate_device_setup import generate_device_setup
from laboneq.dsl.device import DeviceSetup




descriptor = generate_descriptor(
    #pqsc=[""], # 장비 여러개 사용시
    shfqc_6=["DEV12256"],
    number_data_qubits=6,
    multiplex=True,
    number_multiplex=6,
    include_cr_lines=True,
    include_ef_lines=True,
    get_zsync=False,  # Only set to True when using real device
    save = True,
    filename="BF5_KRISS",
    ip_address="10.171.11.45"
)


#descriptor
setup = DeviceSetup.from_descriptor(yaml_text=descriptor, server_host="10.171.11.45")
#setup
setup.instruments[0].device_options = 'SHFQC/PLUS/QC6CH'
#setup.instruments

# %%
from laboneq.simple import Session
session = Session(setup)
session.connect(ignore_version_mismatch=False, do_emulation=False)
#session.disconnect()
# Out:
# [2026.01.06 14:20:29.502] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /Users/yalgaeahn/JSAHN/qubit-experiment/examples/selectiveRIP/laboneq_output/log
# [2026.01.06 14:20:29.505] INFO    VERSION: laboneq 25.10.2
# [2026.01.06 14:20:29.506] INFO    Connecting to data server at 10.171.11.45:8004
# ---------------------------------------------------------------------------
# UnavailableError                          Traceback (most recent call last)
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/zhinst/comms_schemas/labone/core/errors.py:111, in async_translate_comms_error.<locals>.wrapper(*args, **kwargs)
#     110 try:
# --> 111     return await func(*args, **kwargs)
#     112 except zhinst.comms.errors.CancelledError as e:
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/zhinst/comms_schemas/labone/core/kernel_session.py:126, in KernelSession.create(kernel_info, host, port, context, timeout)
#     125     context = get_default_context()
# --> 126 core_session = await context.connect_labone(
#     127     host,
#     128     port,
#     129     kernel_info,
#     130     schema=hpk_schema.get_schema_loader().get_interface_schema(HPK_SCHEMA_ID),
#     131     timeout=timeout,
#     132 )
#     133 compatibility_version = version.Version(
#     134     (await core_session.getSessionVersion()).version,
#     135 )
#
# UnavailableError: Connection failed due to inaccessible port 8004 on host '10.171.11.45'.
#
# The above exception was the direct cause of the following exception:
#
# UnavailableError                          Traceback (most recent call last)
# Cell In[4], line 3
#       1 from laboneq.simple import Session
#       2 session = Session(setup)
# ----> 3 session.connect(ignore_version_mismatch=False, do_emulation=False)
#       4 #session.disconnect()
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/dsl/session.py:302, in Session.connect(self, do_emulation, ignore_version_mismatch, reset_devices, use_async_api, disable_runtime_checks, timeout)
#     294 target_setup = convert_dsl_to_target_setup(self._device_setup)
#     296 controller = Controller(
#     297     target_setup=target_setup,
#     298     ignore_version_mismatch=ignore_version_mismatch,
#     299     neartime_callbacks=self._neartime_callbacks,
#     300     parent_session=self,
#     301 )
# --> 302 controller.connect(
#     303     do_emulation=self._connection_state.emulated,
#     304     reset_devices=reset_devices,
#     305     disable_runtime_checks=disable_runtime_checks,
#     306     timeout_s=timeout,
#     307 )
#     308 self._controller = controller
#     309 if self._connection_state.emulated:
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/controller.py:297, in Controller.connect(self, do_emulation, reset_devices, disable_runtime_checks, timeout_s)
#     295 self._do_emulation = do_emulation
#     296 self._devices.set_timeout(timeout_s)
# --> 297 self._event_loop.run(
#     298     self._connect_async,
#     299     reset_devices=reset_devices,
#     300     disable_runtime_checks=disable_runtime_checks,
#     301 )
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/core/utilities/async_helpers.py:39, in EventLoopHolder.run(self, func, *args, **kwargs)
#      37 self._ensure_event_loop()
#      38 with self._override_sigint_handler():
# ---> 39     return self._wait_with_yielding(
#      40         asyncio.run_coroutine_threadsafe(func(*args, **kwargs), self._loop)
#      41     )
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/core/utilities/async_helpers.py:80, in EventLoopHolder._wait_with_yielding(self, future)
#      76 while True:
#      77     try:
#      78         # Exit future wait every 0.1s to handle SIGINT, balancing
#      79         # responsiveness and CPU load.
# ---> 80         return future.result(timeout=0.1)  # @IgnoreException
#      81     except concurrent.futures.TimeoutError:  # noqa: PERF203
#      82         pass
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/controller.py:311, in Controller._connect_async(self, reset_devices, disable_runtime_checks)
#     306 now = time.monotonic()
#     307 if (
#     308     self._last_connect_check_ts is None
#     309     or now - self._last_connect_check_ts > CONNECT_CHECK_HOLDOFF
#     310 ):
# --> 311     await self._devices.connect(
#     312         do_emulation=self._do_emulation,
#     313         reset_devices=reset_devices,
#     314         disable_runtime_checks=disable_runtime_checks,
#     315     )
#     316 self._last_connect_check_ts = now
#     317 async with self._devices.capture_logs():
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/devices/device_collection.py:131, in DeviceCollection.connect(self, do_emulation, reset_devices, disable_runtime_checks)
#     125 async def connect(
#     126     self,
#     127     do_emulation: bool,
#     128     reset_devices: bool = False,
#     129     disable_runtime_checks: bool = False,
#     130 ):
# --> 131     await self._prepare_data_servers(do_emulation=do_emulation)
#     132     self._prepare_devices()
#     133     await self.for_each(
#     134         DeviceZI.connect,
#     135         emulator_state=self.emulator_state if do_emulation else None,
#     136         disable_runtime_checks=disable_runtime_checks,
#     137         timeout_s=self._timeout_s,
#     138     )
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/devices/device_collection.py:347, in DeviceCollection._prepare_data_servers(self, do_emulation)
#     341 else:
#     342     _logger.info(
#     343         "Connecting to data server at %s:%s",
#     344         server_qualifier.host,
#     345         server_qualifier.port,
#     346     )
# --> 347     data_server_connection = await DataServerConnection.connect(
#     348         server_qualifier=server_qualifier,
#     349         emulator_state=self.emulator_state if do_emulation else None,
#     350         timeout_s=self._timeout_s,
#     351         setup_caps=self._ds.setup_caps,
#     352     )
#     353     data_server_connection.check_dataserver_device_compatibility(
#     354         self._ignore_version_mismatch,
#     355         self._ds.server_device_serials(server_uid),
#     356     )
#     357 updated_data_servers.add(server_uid, data_server_connection)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/controller/devices/async_support.py:185, in DataServerConnection.connect(cls, server_qualifier, emulator_state, timeout_s, setup_caps)
#     183 port = server_qualifier.port
#     184 if emulator_state is None:
# --> 185     data_server = await KernelSession.create(
#     186         kernel_info=KernelInfo.zi_connection(),
#     187         host=host,
#     188         port=port,
#     189         timeout=to_l1_timeout(timeout_s),
#     190     )
#     191 else:
#     192     # Fool the type checker that the KernelSessionEmulator is a KernelSession
#     193     data_server = cast(
#     194         KernelSession,
#     195         KernelSessionEmulator(serial="ZI", emulator_state=emulator_state),
#     196     )
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/zhinst/comms_schemas/labone/core/errors.py:123, in async_translate_comms_error.<locals>.wrapper(*args, **kwargs)
#     121     raise LabOneCoreError(str(e)) from e
#     122 except zhinst.comms.errors.UnavailableError as e:
# --> 123     raise UnavailableError(str(e)) from e
#     124 except zhinst.comms.errors.TimeoutError as e:
#     125     raise LabOneTimeoutError(str(e)) from e
#
# UnavailableError: Connection failed due to inaccessible port 8004 on host '10.171.11.45'.
