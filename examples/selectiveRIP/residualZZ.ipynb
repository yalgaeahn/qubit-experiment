# %% [markdown]
#  Residual ZZ extraction with conditional echo Ramsey

# %% [markdown]
# ## INIT

# %%
import numpy as np
from pprint import pprint
from copy import deepcopy
import sys
from pathlib import Path


from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
#from laboneq.contrib.example_helpers.generate_device_setup import generate_device_setup
from laboneq.dsl.device import DeviceSetup
from laboneq.simple import *
from laboneq.dsl.device import DeviceSetup
from laboneq.dsl.calibration import Oscillator, SignalCalibration
from laboneq.dsl.enums import ModulationType




# descriptor = generate_descriptor(
#     #pqsc=[""], # 장비 여러개 사용시
#     shfqc_6=["DEV12256"], 
#     number_data_qubits=3,
#     multiplex=True,
#     number_multiplex=6,
#     include_cr_lines=False,
#     include_ef_lines=True,
#     get_zsync=False,  # Only set to True when using real device
#     save = True,
#     filename="1port",
#     ip_address="192.168.0.83"
# )


#descriptor
#setup = DeviceSetup.from_descriptor(yaml_text=descriptor, server_host="192.168.0.83")
descriptor_candidates = [
    Path("examples/selectiveRIP/Descriptors/1port.yaml"),
    Path("Descriptors/1port.yaml"),
]
descriptor_path = next((p for p in descriptor_candidates if p.exists()), descriptor_candidates[0])
setup = DeviceSetup.from_yaml(filepath=str(descriptor_path.resolve()), server_host="192.168.0.83")
#setup
setup.instruments[0].device_options = 'SHFQC/PLUS/QC6CH'
#setup.instruments


bus_ids = [f"b{i}" for i in range(3)]
bus_port = [3,4,5] #used 1,2,3 for qubit drive

for i, bus in zip(bus_port,bus_ids):
    setup.add_connections(
        setup.instruments[0].uid,
        # each bus uses its own drive:
        create_connection(
            to_signal=f"{bus}/drive",
            ports=f"SGCHANNELS/{i}/OUTPUT"
        ))

# Calibrate qubit drive/measure lines for oscillator phase increments
qubit_ids = [uid for uid in setup.logical_signal_groups if uid.startswith("q")]
for qubit in qubit_ids:
    for line, frequency, mod_type in [
        ("drive", 5e9, ModulationType.HARDWARE),
        ("drive_ef", 6e9, ModulationType.HARDWARE),
        ("measure", 4e9, ModulationType.SOFTWARE),
    ]:
        logical_signal = setup.logical_signal_by_uid(f"{qubit}/{line}")
        oscillator = Oscillator(modulation_type=mod_type)
        logical_signal.calibration = SignalCalibration(
            local_oscillator=Oscillator(frequency=frequency),
            oscillator=oscillator,
        )
        if line == "measure":
            acquire_signal = setup.logical_signal_by_uid(f"{qubit}/acquire")
            acquire_signal.calibration = SignalCalibration(
                local_oscillator=Oscillator(frequency=frequency),
                oscillator=oscillator,
            )

project_root = next(
    (p for p in [Path.cwd(), *Path.cwd().parents] if (p / "qpu_types").exists() and (p / "helper.py").exists()),
    Path.cwd(),
)
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from qpu_types.fixed_transmon import FixedTransmonQubit, FixedTransmonQubitParameters
from qpu_types.bus_cavity import BusCavity, BusCavityParameters
from qpu_types.fixed_transmon.operations import FixedTransmonOperations
from qpu_types.bus_cavity.operations import BusCavityOperations
from laboneq.dsl.quantum.qpu import QPU, QuantumPlatform
from helper import load_qubit_parameters, save_qubit_parameters

qubit_uids = [uid for uid in setup.logical_signal_groups if uid.startswith("q")]
bus_uids = [uid for uid in setup.logical_signal_groups if uid.startswith("b")]

qubits = FixedTransmonQubit.from_device_setup(
    setup, qubit_uids=qubit_uids)
buses = BusCavity.from_device_setup(
    setup, qubit_uids=bus_uids)

qpu = QPU(quantum_elements={"qubits" : qubits, "bus" : buses}, quantum_operations=[FixedTransmonOperations, BusCavityOperations])

import os
from datetime import datetime
def find_latest_json(folder_path):
    files = [f for f in os.listdir(folder_path)]
    timestamps = []
    for file in files:
        try:
            # Extract a timestamp assuming it's included in the filename
            timestamp_str = file.split('_', 1)[0]  # Assuming YYYYMMDDHHMMSS format
            timestamp = datetime.strptime(timestamp_str, '%Y%m%d-%H%M%S')
            timestamps.append((timestamp, file))
        except ValueError:
            print("fuck")
            continue  # Skip files that do not match the timestamp format

       # Find the most recent file
    if timestamps:
        latest_file = max(timestamps, key=lambda x: x[0])[1]
        return os.path.join(folder_path, latest_file)
    return None

qb_pars_file = find_latest_json("./qpu_parameters/")
print(f"LOADED: {qb_pars_file}")

from qpu_types.fixed_transmon.operations import FixedTransmonOperations
from qpu_types.bus_cavity.operations import BusCavityOperations
import laboneq.dsl.quantum.qpu as qpu_mod

class CombinedOperations(FixedTransmonOperations, BusCavityOperations):
    pass

qpu_mod.CombinedOperations = CombinedOperations

qpu = load(qb_pars_file)

buses = qpu.groups.bus
qubits = qpu.groups.qubits


from laboneq.simple import workflow
folder_store = workflow.logbook.FolderStore("/Users/yalgaeahn/Library/CloudStorage/SynologyDrive-RIPDATA/RIP_APS_2026/experiment_store")
folder_store.activate()
# Out:
# fuck
# LOADED: ./qpu_parameters/20260303-0948_3Q_tomo

# %%
from laboneq.simple import Session
session = Session(setup)
session.connect(ignore_version_mismatch=False, do_emulation=False)
#session.disconnect()
# Out:
# [2026.03.04 09:54:27.815] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /Users/yalgaeahn/Research/03_Code/qubit-experiment/examples/selectiveRIP/laboneq_output/log
# [2026.03.04 09:54:27.817] INFO    VERSION: laboneq 25.10.3
# [2026.03.04 09:54:27.818] INFO    Connecting to data server at 192.168.0.83:8004
# [2026.03.04 09:54:27.887] INFO    Connected to Zurich Instruments LabOne Data Server version 25.10.1.4 at 192.168.0.83:8004
# [2026.03.04 09:54:27.994] INFO    Configuring the device setup
# [2026.03.04 09:54:28.046] INFO    The device setup is configured

# %% [markdown]
# ## Ramsey Echo

# %%
from experiments import echo
q = qubits[0]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temporary_parameters[q.uid] = temp_pars
#######################################################################
delays = np.linspace(0,25e-6,201)
pprint(q.readout_parameters())
#######################################################################
options = echo.experiment_workflow.options()
options.update(False)
options.count(1024)
options.use_cal_traces(True)
# Build and run Ramsey workflow (no explicit command table options required)
ramsey_echo = echo.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    delays=delays,
    options=options,
    temporary_parameters=temporary_parameters
)
ramsey_echo_result = ramsey_echo.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(ramsey_echo_result.tasks['analysis_workflow'].output)

# %% [markdown]
# # Residual ZZ

# %%
from experiments import residual_zz_echo

q_ctrl = [qubits[0], qubits[1], qubits[2]]
q_targ = [qubits[0], qubits[1], qubits[2]]

temporary_parameters = {}
for q in q_targ:
    temporary_parameters[q.uid] = deepcopy(q.parameters)

#######################################################################
delays_single = np.linspace(0, 25e-6, 201)
delays = [delays_single for _ in q_targ]
detunings = [0.3e6 for _ in q_targ]
for q in q_targ:
    pprint({q.uid: q.readout_parameters()})
#######################################################################
options = residual_zz_echo.experiment_workflow.options()
options.update(False)
options.count(1024 * 2)
options.use_cal_traces(True)
options.mapping_mode("all_pairs")

residual_zz_wf = residual_zz_echo.experiment_workflow(
    session=session,
    qpu=qpu,
    ctrl=q_ctrl,
    targ=q_targ,
    delays=delays,
    detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters,
)
residual_zz_result = residual_zz_wf.run()
analysis_output = residual_zz_result.tasks["analysis_workflow"].output
pprint(analysis_output["residual_zz"])
# Out:
# {'q0': ('measure',
#         {'amplitude': 0.29013333333333335,
#          'length': 1.8e-06,
#          'pulse': {'function': 'GaussianSquare',
#                    'risefall_sigma_ratio': 3.0,
#                    'sigma': 0.03}})}
# {'q1': ('measure',
#         {'amplitude': 0.21333333333333335,
#          'length': 1.8e-06,
#          'pulse': {'function': 'GaussianSquare',
#                    'risefall_sigma_ratio': 3.0,
#                    'sigma': 0.03}})}
# {'q2': ('measure',
#         {'amplitude': 0.16,
#          'length': 1.8e-06,
#          'pulse': {'function': 'GaussianSquare',
#                    'risefall_sigma_ratio': 3.0,
#                    'sigma': 0.03}})}
# [2026.03.04 09:54:36.064] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.04 09:54:36.065] INFO      Workflow 'residual_zz_echo': execution started at 2026-03-04
# [2026.03.04 09:54:36.065] INFO      00:54:36.064266Z
# [2026.03.04 09:54:36.065] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.04 09:54:36.081] INFO    Task 'temporary_qpu': started at 2026-03-04 00:54:36.081260Z
# [2026.03.04 09:54:36.082] INFO    Task 'temporary_qpu': ended at 2026-03-04 00:54:36.082493Z
# [2026.03.04 09:54:36.085] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-03-04
# [2026.03.04 09:54:36.085] INFO    00:54:36.085019Z
# [2026.03.04 09:54:36.086] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-03-04 00:54:36.086591Z
# [2026.03.04 09:54:36.090] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-03-04
# [2026.03.04 09:54:36.091] INFO    00:54:36.090267Z
# [2026.03.04 09:54:36.091] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-03-04 00:54:36.091712Z
# [2026.03.04 09:54:36.094] INFO    Task 'validate_and_convert_qubits_sweeps': started at 2026-03-04
# [2026.03.04 09:54:36.095] INFO    00:54:36.094374Z
# [2026.03.04 09:54:36.096] INFO    Task 'validate_and_convert_qubits_sweeps': ended at 2026-03-04 00:54:36.096135Z
# [2026.03.04 09:54:36.096] INFO    Task 'build_pair_plan': started at 2026-03-04 00:54:36.096797Z
# [2026.03.04 09:54:36.097] INFO    Task 'build_pair_plan': ended at 2026-03-04 00:54:36.097440Z
# [2026.03.04 09:54:36.098] INFO    Task '_filter_ctrl_for_pair': started at 2026-03-04 00:54:36.098009Z
# [2026.03.04 09:54:36.098] INFO    Task '_filter_ctrl_for_pair': ended at 2026-03-04 00:54:36.098565Z
# [2026.03.04 09:54:36.099] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 00:54:36.099162Z
# [2026.03.04 09:54:36.104] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 00:54:36.099791Z
# [2026.03.04 09:54:36.111] INFO    Task 'create_experiment': started at 2026-03-04 00:54:36.110042Z
# [2026.03.04 09:54:36.156] INFO    Task 'create_experiment': ended at 2026-03-04 00:54:36.155779Z
# [2026.03.04 09:54:36.162] INFO    Task 'compile_experiment': started at 2026-03-04 00:54:36.161833Z
# [2026.03.04 09:54:36.170] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.04 09:54:36.171] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.04 09:54:36.171] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.04 09:54:36.171] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal 'q1/acquire' to SOFTWARE
# [2026.03.04 09:54:36.172] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal 'q1/drive' to HARDWARE
# [2026.03.04 09:54:36.172] INFO    Resolved modulation type of oscillator 'q1_drive_ef_osc' on signal 'q1/drive_ef' to HARDWARE
# [2026.03.04 09:54:36.172] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.04 09:54:36.173] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.04 09:54:36.173] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.04 09:54:36.173] INFO    Starting LabOne Q Compiler run...
# [2026.03.04 09:54:36.439] INFO    Schedule completed. [0.265 s]
# [2026.03.04 09:54:36.499] INFO    Code generation completed for all AWGs. [0.059 s]
# [2026.03.04 09:54:36.500] INFO    Completed compilation step 1 of 1. [0.325 s]
# [2026.03.04 09:54:36.502] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:54:36.502] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.04 09:54:36.502] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:54:36.503] INFO      SHFQC_DEV12256        0       4839            0           1      7200
# [2026.03.04 09:54:36.503] INFO      SHFQC_DEV12256_sg     0       7445          107          26     11968
# [2026.03.04 09:54:36.503] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:54:36.503] INFO      TOTAL                        12284          107                 19168
# [2026.03.04 09:54:36.504] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:54:36.836] INFO    Auto-chunked sweep divided into 1 chunks
# [2026.03.04 09:54:36.838] INFO    Finished LabOne Q Compiler run.
# [2026.03.04 09:54:36.838] INFO    Task 'compile_experiment': ended at 2026-03-04 00:54:36.838577Z
# [2026.03.04 09:54:36.849] INFO    Task 'run_experiment': started at 2026-03-04 00:54:36.849668Z
# [2026.03.04 09:54:36.947] INFO    Starting near-time execution...
# [2026.03.04 09:54:37.333] INFO    Estimated RT execution time: 127.88 s.
# [2026.03.04 09:56:45.308] INFO    Finished near-time execution.
# [2026.03.04 09:56:45.398] INFO    Task 'run_experiment': ended at 2026-03-04 00:56:45.398096Z
# [2026.03.04 09:56:45.400] INFO    Task '_build_run_record': started at 2026-03-04 00:56:45.400363Z
# [2026.03.04 09:56:45.401] INFO    Task '_build_run_record': ended at 2026-03-04 00:56:45.401063Z
# [2026.03.04 09:56:45.401] INFO    Task '_append_item': started at 2026-03-04 00:56:45.401691Z
# [2026.03.04 09:56:45.402] INFO    Task '_append_item': ended at 2026-03-04 00:56:45.402335Z
# [2026.03.04 09:56:45.403] INFO    Task '_filter_ctrl_for_pair': started at 2026-03-04 00:56:45.402909Z
# [2026.03.04 09:56:45.403] INFO    Task '_filter_ctrl_for_pair': ended at 2026-03-04 00:56:45.403523Z
# [2026.03.04 09:56:45.404] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 00:56:45.404079Z
# [2026.03.04 09:56:45.404] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 00:56:45.404589Z
# [2026.03.04 09:56:45.405] INFO    Task 'create_experiment': started at 2026-03-04 00:56:45.405112Z
# [2026.03.04 09:56:45.408] INFO    Task 'create_experiment': ended at 2026-03-04 00:56:45.408590Z
# [2026.03.04 09:56:45.410] INFO    Task 'compile_experiment': started at 2026-03-04 00:56:45.410373Z
# [2026.03.04 09:56:45.412] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.04 09:56:45.412] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.04 09:56:45.413] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.04 09:56:45.413] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal 'q1/acquire' to SOFTWARE
# [2026.03.04 09:56:45.413] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal 'q1/drive' to HARDWARE
# [2026.03.04 09:56:45.413] INFO    Resolved modulation type of oscillator 'q1_drive_ef_osc' on signal 'q1/drive_ef' to HARDWARE
# [2026.03.04 09:56:45.413] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.04 09:56:45.414] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.04 09:56:45.414] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.04 09:56:45.414] INFO    Starting LabOne Q Compiler run...
# [2026.03.04 09:56:45.613] INFO    Schedule completed. [0.198 s]
# [2026.03.04 09:56:45.728] INFO    Code generation completed for all AWGs. [0.114 s]
# [2026.03.04 09:56:45.729] INFO    Completed compilation step 1 of 1. [0.313 s]
# [2026.03.04 09:56:45.730] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:56:45.730] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.04 09:56:45.731] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:56:45.731] INFO      SHFQC_DEV12256        0       4839            0           1      7200
# [2026.03.04 09:56:45.731] INFO      SHFQC_DEV12256_sg     0       7445          107          26     11968
# [2026.03.04 09:56:45.731] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:56:45.732] INFO      TOTAL                        12284          107                 19168
# [2026.03.04 09:56:45.732] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:56:46.051] INFO    Auto-chunked sweep divided into 1 chunks
# [2026.03.04 09:56:46.052] INFO    Finished LabOne Q Compiler run.
# [2026.03.04 09:56:46.053] INFO    Task 'compile_experiment': ended at 2026-03-04 00:56:46.053203Z
# [2026.03.04 09:56:46.061] INFO    Task 'run_experiment': started at 2026-03-04 00:56:46.061753Z
# [2026.03.04 09:56:46.152] INFO    Starting near-time execution...
# [2026.03.04 09:56:46.417] INFO    Estimated RT execution time: 127.88 s.
# [2026.03.04 09:58:54.586] INFO    Finished near-time execution.
# [2026.03.04 09:58:54.682] INFO    Task 'run_experiment': ended at 2026-03-04 00:58:54.681805Z
# [2026.03.04 09:58:54.684] INFO    Task '_build_run_record': started at 2026-03-04 00:58:54.684236Z
# [2026.03.04 09:58:54.685] INFO    Task '_build_run_record': ended at 2026-03-04 00:58:54.684938Z
# [2026.03.04 09:58:54.685] INFO    Task '_append_item': started at 2026-03-04 00:58:54.685594Z
# [2026.03.04 09:58:54.686] INFO    Task '_append_item': ended at 2026-03-04 00:58:54.686133Z
# [2026.03.04 09:58:54.686] INFO    Task '_filter_ctrl_for_pair': started at 2026-03-04 00:58:54.686715Z
# [2026.03.04 09:58:54.687] INFO    Task '_filter_ctrl_for_pair': ended at 2026-03-04 00:58:54.687345Z
# [2026.03.04 09:58:54.687] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 00:58:54.687879Z
# [2026.03.04 09:58:54.688] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 00:58:54.688356Z
# [2026.03.04 09:58:54.688] INFO    Task 'create_experiment': started at 2026-03-04 00:58:54.688857Z
# [2026.03.04 09:58:54.692] INFO    Task 'create_experiment': ended at 2026-03-04 00:58:54.692395Z
# [2026.03.04 09:58:54.694] INFO    Task 'compile_experiment': started at 2026-03-04 00:58:54.694251Z
# [2026.03.04 09:58:54.696] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.04 09:58:54.696] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.04 09:58:54.697] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.04 09:58:54.697] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal 'q1/acquire' to SOFTWARE
# [2026.03.04 09:58:54.697] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal 'q1/drive' to HARDWARE
# [2026.03.04 09:58:54.697] INFO    Resolved modulation type of oscillator 'q1_drive_ef_osc' on signal 'q1/drive_ef' to HARDWARE
# [2026.03.04 09:58:54.698] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.04 09:58:54.698] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.04 09:58:54.698] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.04 09:58:54.698] INFO    Starting LabOne Q Compiler run...
# [2026.03.04 09:58:54.902] INFO    Schedule completed. [0.202 s]
# [2026.03.04 09:58:54.959] INFO    Code generation completed for all AWGs. [0.057 s]
# [2026.03.04 09:58:54.960] INFO    Completed compilation step 1 of 1. [0.260 s]
# [2026.03.04 09:58:54.961] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:58:54.962] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.04 09:58:54.962] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:58:54.962] INFO      SHFQC_DEV12256        0       4839            0           1      7200
# [2026.03.04 09:58:54.962] INFO      SHFQC_DEV12256_sg     0       7445          107          26     11968
# [2026.03.04 09:58:54.962] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:58:54.963] INFO      TOTAL                        12284          107                 19168
# [2026.03.04 09:58:54.963] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 09:58:55.287] INFO    Auto-chunked sweep divided into 1 chunks
# [2026.03.04 09:58:55.288] INFO    Finished LabOne Q Compiler run.
# [2026.03.04 09:58:55.289] INFO    Task 'compile_experiment': ended at 2026-03-04 00:58:55.289334Z
# [2026.03.04 09:58:55.298] INFO    Task 'run_experiment': started at 2026-03-04 00:58:55.298349Z
# [2026.03.04 09:58:55.391] INFO    Starting near-time execution...
# [2026.03.04 09:58:55.755] INFO    Estimated RT execution time: 127.88 s.
# [2026.03.04 10:01:03.775] INFO    Finished near-time execution.
# [2026.03.04 10:01:03.890] INFO    Task 'run_experiment': ended at 2026-03-04 01:01:03.890072Z
# [2026.03.04 10:01:03.892] INFO    Task '_build_run_record': started at 2026-03-04 01:01:03.892482Z
# [2026.03.04 10:01:03.893] INFO    Task '_build_run_record': ended at 2026-03-04 01:01:03.893252Z
# [2026.03.04 10:01:03.894] INFO    Task '_append_item': started at 2026-03-04 01:01:03.893879Z
# [2026.03.04 10:01:03.894] INFO    Task '_append_item': ended at 2026-03-04 01:01:03.894484Z
# [2026.03.04 10:01:03.895] INFO    Task '_filter_ctrl_for_pair': started at 2026-03-04 01:01:03.895020Z
# [2026.03.04 10:01:03.895] INFO    Task '_filter_ctrl_for_pair': ended at 2026-03-04 01:01:03.895527Z
# [2026.03.04 10:01:03.896] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 01:01:03.896095Z
# [2026.03.04 10:01:03.896] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 01:01:03.896819Z
# [2026.03.04 10:01:03.897] INFO    Task 'create_experiment': started at 2026-03-04 01:01:03.897391Z
# [2026.03.04 10:01:03.900] INFO    Task 'create_experiment': ended at 2026-03-04 01:01:03.900595Z
# [2026.03.04 10:01:03.902] INFO    Task 'compile_experiment': started at 2026-03-04 01:01:03.902343Z
# [2026.03.04 10:01:03.904] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.04 10:01:03.904] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.04 10:01:03.905] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.04 10:01:03.905] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal 'q1/acquire' to SOFTWARE
# [2026.03.04 10:01:03.905] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal 'q1/drive' to HARDWARE
# [2026.03.04 10:01:03.906] INFO    Resolved modulation type of oscillator 'q1_drive_ef_osc' on signal 'q1/drive_ef' to HARDWARE
# [2026.03.04 10:01:03.906] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.04 10:01:03.906] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.04 10:01:03.906] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.04 10:01:03.907] INFO    Starting LabOne Q Compiler run...
# [2026.03.04 10:01:04.100] INFO    Schedule completed. [0.192 s]
# [2026.03.04 10:01:04.216] INFO    Code generation completed for all AWGs. [0.115 s]
# [2026.03.04 10:01:04.216] INFO    Completed compilation step 1 of 1. [0.308 s]
# [2026.03.04 10:01:04.218] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:01:04.218] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.04 10:01:04.218] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:01:04.219] INFO      SHFQC_DEV12256        0       4839            0           1      7200
# [2026.03.04 10:01:04.219] INFO      SHFQC_DEV12256_sg     0       7445          107          26     11968
# [2026.03.04 10:01:04.219] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:01:04.219] INFO      TOTAL                        12284          107                 19168
# [2026.03.04 10:01:04.220] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:01:04.537] INFO    Auto-chunked sweep divided into 1 chunks
# [2026.03.04 10:01:04.539] INFO    Finished LabOne Q Compiler run.
# [2026.03.04 10:01:04.539] INFO    Task 'compile_experiment': ended at 2026-03-04 01:01:04.539496Z
# [2026.03.04 10:01:04.548] INFO    Task 'run_experiment': started at 2026-03-04 01:01:04.548363Z
# [2026.03.04 10:01:04.678] INFO    Starting near-time execution...
# [2026.03.04 10:01:05.018] INFO    Estimated RT execution time: 127.88 s.
# [2026.03.04 10:03:13.348] INFO    Finished near-time execution.
# [2026.03.04 10:03:13.415] INFO    Task 'run_experiment': ended at 2026-03-04 01:03:13.415116Z
# [2026.03.04 10:03:13.417] INFO    Task '_build_run_record': started at 2026-03-04 01:03:13.417544Z
# [2026.03.04 10:03:13.418] INFO    Task '_build_run_record': ended at 2026-03-04 01:03:13.418238Z
# [2026.03.04 10:03:13.418] INFO    Task '_append_item': started at 2026-03-04 01:03:13.418800Z
# [2026.03.04 10:03:13.419] INFO    Task '_append_item': ended at 2026-03-04 01:03:13.419510Z
# [2026.03.04 10:03:13.420] INFO    Task '_filter_ctrl_for_pair': started at 2026-03-04 01:03:13.420229Z
# [2026.03.04 10:03:13.420] INFO    Task '_filter_ctrl_for_pair': ended at 2026-03-04 01:03:13.420789Z
# [2026.03.04 10:03:13.421] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 01:03:13.421293Z
# [2026.03.04 10:03:13.421] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 01:03:13.421778Z
# [2026.03.04 10:03:13.422] INFO    Task 'create_experiment': started at 2026-03-04 01:03:13.422320Z
# [2026.03.04 10:03:13.425] INFO    Task 'create_experiment': ended at 2026-03-04 01:03:13.425403Z
# [2026.03.04 10:03:13.427] INFO    Task 'compile_experiment': started at 2026-03-04 01:03:13.427404Z
# [2026.03.04 10:03:13.429] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.04 10:03:13.430] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.04 10:03:13.430] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.04 10:03:13.430] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal 'q1/acquire' to SOFTWARE
# [2026.03.04 10:03:13.430] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal 'q1/drive' to HARDWARE
# [2026.03.04 10:03:13.431] INFO    Resolved modulation type of oscillator 'q1_drive_ef_osc' on signal 'q1/drive_ef' to HARDWARE
# [2026.03.04 10:03:13.431] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.04 10:03:13.431] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.04 10:03:13.431] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.04 10:03:13.432] INFO    Starting LabOne Q Compiler run...
# [2026.03.04 10:03:13.649] INFO    Schedule completed. [0.217 s]
# [2026.03.04 10:03:13.708] INFO    Code generation completed for all AWGs. [0.058 s]
# [2026.03.04 10:03:13.711] INFO    Completed compilation step 1 of 1. [0.278 s]
# [2026.03.04 10:03:13.712] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:03:13.713] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.04 10:03:13.713] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:03:13.713] INFO      SHFQC_DEV12256        0       4839            0           1      7200
# [2026.03.04 10:03:13.714] INFO      SHFQC_DEV12256_sg     0       7445          107          26     11968
# [2026.03.04 10:03:13.714] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:03:13.714] INFO      TOTAL                        12284          107                 19168
# [2026.03.04 10:03:13.714] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:03:14.040] INFO    Auto-chunked sweep divided into 1 chunks
# [2026.03.04 10:03:14.041] INFO    Finished LabOne Q Compiler run.
# [2026.03.04 10:03:14.042] INFO    Task 'compile_experiment': ended at 2026-03-04 01:03:14.042216Z
# [2026.03.04 10:03:14.051] INFO    Task 'run_experiment': started at 2026-03-04 01:03:14.051206Z
# [2026.03.04 10:03:14.188] INFO    Starting near-time execution...
# [2026.03.04 10:03:14.504] INFO    Estimated RT execution time: 127.88 s.
# [2026.03.04 10:05:22.583] INFO    Finished near-time execution.
# [2026.03.04 10:05:22.661] INFO    Task 'run_experiment': ended at 2026-03-04 01:05:22.661573Z
# [2026.03.04 10:05:22.663] INFO    Task '_build_run_record': started at 2026-03-04 01:05:22.663701Z
# [2026.03.04 10:05:22.664] INFO    Task '_build_run_record': ended at 2026-03-04 01:05:22.664493Z
# [2026.03.04 10:05:22.665] INFO    Task '_append_item': started at 2026-03-04 01:05:22.665134Z
# [2026.03.04 10:05:22.665] INFO    Task '_append_item': ended at 2026-03-04 01:05:22.665692Z
# [2026.03.04 10:05:22.666] INFO    Task '_filter_ctrl_for_pair': started at 2026-03-04 01:05:22.666272Z
# [2026.03.04 10:05:22.667] INFO    Task '_filter_ctrl_for_pair': ended at 2026-03-04 01:05:22.666895Z
# [2026.03.04 10:05:22.667] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 01:05:22.667454Z
# [2026.03.04 10:05:22.668] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 01:05:22.668099Z
# [2026.03.04 10:05:22.668] INFO    Task 'create_experiment': started at 2026-03-04 01:05:22.668709Z
# [2026.03.04 10:05:22.671] INFO    Task 'create_experiment': ended at 2026-03-04 01:05:22.671758Z
# [2026.03.04 10:05:22.673] INFO    Task 'compile_experiment': started at 2026-03-04 01:05:22.673397Z
# [2026.03.04 10:05:22.675] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal 'q0/acquire' to SOFTWARE
# [2026.03.04 10:05:22.675] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal 'q0/drive' to HARDWARE
# [2026.03.04 10:05:22.675] INFO    Resolved modulation type of oscillator 'q0_drive_ef_osc' on signal 'q0/drive_ef' to HARDWARE
# [2026.03.04 10:05:22.676] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal 'q1/acquire' to SOFTWARE
# [2026.03.04 10:05:22.676] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal 'q1/drive' to HARDWARE
# [2026.03.04 10:05:22.676] INFO    Resolved modulation type of oscillator 'q1_drive_ef_osc' on signal 'q1/drive_ef' to HARDWARE
# [2026.03.04 10:05:22.676] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal 'q2/acquire' to SOFTWARE
# [2026.03.04 10:05:22.676] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal 'q2/drive' to HARDWARE
# [2026.03.04 10:05:22.677] INFO    Resolved modulation type of oscillator 'q2_drive_ef_osc' on signal 'q2/drive_ef' to HARDWARE
# [2026.03.04 10:05:22.677] INFO    Starting LabOne Q Compiler run...
# [2026.03.04 10:05:22.874] INFO    Schedule completed. [0.196 s]
# [2026.03.04 10:05:22.994] INFO    Code generation completed for all AWGs. [0.120 s]
# [2026.03.04 10:05:22.995] INFO    Completed compilation step 1 of 1. [0.317 s]
# [2026.03.04 10:05:22.996] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:05:22.997] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.03.04 10:05:22.997] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:05:22.997] INFO      SHFQC_DEV12256        0       4839            0           1      7200
# [2026.03.04 10:05:22.997] INFO      SHFQC_DEV12256_sg     0       7445          107          26     11968
# [2026.03.04 10:05:22.998] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:05:22.998] INFO      TOTAL                        12284          107                 19168
# [2026.03.04 10:05:22.998] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.03.04 10:05:23.316] INFO    Auto-chunked sweep divided into 1 chunks
# [2026.03.04 10:05:23.318] INFO    Finished LabOne Q Compiler run.
# [2026.03.04 10:05:23.318] INFO    Task 'compile_experiment': ended at 2026-03-04 01:05:23.318428Z
# [2026.03.04 10:05:23.327] INFO    Task 'run_experiment': started at 2026-03-04 01:05:23.327825Z
# [2026.03.04 10:05:23.413] INFO    Starting near-time execution...
# [2026.03.04 10:05:23.809] INFO    Estimated RT execution time: 127.88 s.
# [2026.03.04 10:07:31.794] INFO    Finished near-time execution.
# [2026.03.04 10:07:31.852] INFO    Task 'run_experiment': ended at 2026-03-04 01:07:31.852131Z
# [2026.03.04 10:07:31.855] INFO    Task '_build_run_record': started at 2026-03-04 01:07:31.854899Z
# [2026.03.04 10:07:31.855] INFO    Task '_build_run_record': ended at 2026-03-04 01:07:31.855612Z
# [2026.03.04 10:07:31.856] INFO    Task '_append_item': started at 2026-03-04 01:07:31.856215Z
# [2026.03.04 10:07:31.856] INFO    Task '_append_item': ended at 2026-03-04 01:07:31.856819Z
# [2026.03.04 10:07:31.857] INFO    Task '_records_to_pair_results': started at 2026-03-04 01:07:31.857374Z
# [2026.03.04 10:07:31.858] INFO    Task '_records_to_pair_results': ended at 2026-03-04 01:07:31.857922Z
# [2026.03.04 10:07:31.858] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.04 10:07:31.858] INFO      Workflow 'analysis_workflow': execution started at 2026-03-04
# [2026.03.04 10:07:31.859] INFO      01:07:31.858463Z
# [2026.03.04 10:07:31.859] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.04 10:07:31.859] WARNING Type <class 'dict'> has the following unsupported values: {'q0->q1': value=<Results id=5560925648 errors=False len(acquired_results)=3 len(neartime_callbacks)=0> type=Results, 'q0->q2': value=<Results id=5600391248 errors=False len(acquired_results)=3 len(neartime_callbacks)=0> type=Results, 'q1->q0': value=<Results id=5580432848 errors=False len(acquired_results)=3 len(neartime_callbacks)=0> type=Results, 'q1->q2': value=<Results id=5594830032 errors=False len(acquired_results)=3 len(neartime_callbacks)=0> type=Results, 'q2->q0': value=<Results id=5609105488 errors=False len(acquired_results)=3 len(neartime_callbacks)=0> type=Results, 'q2->q1': value=<Results id=5577177296 errors=False len(acquired_results)=3 len(neartime_callbacks)=0> type=Results}. Only dictionaries with values of the following types are supported: [NoneType, int, float, complex, bool, str, dict, list, tuple, integer, ndarray, ModelResult, Variable, AffineScalarFunc, BaseEstimator]. [name: analysis_workflow.input.result].
# [2026.03.04 10:07:31.861] INFO    Task '_resolve_mapping_mode_for_result': started at 2026-03-04 01:07:31.861115Z
# [2026.03.04 10:07:31.861] INFO    Task '_resolve_mapping_mode_for_result': ended at 2026-03-04 01:07:31.861650Z
# [2026.03.04 10:07:31.862] INFO    Task 'build_pair_plan': started at 2026-03-04 01:07:31.862170Z
# [2026.03.04 10:07:31.862] INFO    Task 'build_pair_plan': ended at 2026-03-04 01:07:31.862668Z
# [2026.03.04 10:07:31.863] INFO    Task '_materialize_pair_results': started at 2026-03-04 01:07:31.863131Z
# [2026.03.04 10:07:31.863] INFO    Task '_materialize_pair_results': ended at 2026-03-04 01:07:31.863676Z
# [2026.03.04 10:07:31.864] INFO    Task '_select_pair_result': started at 2026-03-04 01:07:31.864227Z
# [2026.03.04 10:07:31.865] INFO    Task '_select_pair_result': ended at 2026-03-04 01:07:31.864980Z
# [2026.03.04 10:07:31.865] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 01:07:31.865799Z
# [2026.03.04 10:07:31.866] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 01:07:31.866393Z
# [2026.03.04 10:07:31.867] INFO    Task 'process_conditional_population': started at 2026-03-04 01:07:31.866913Z
# [2026.03.04 10:07:31.868] INFO    Task 'process_conditional_population': ended at 2026-03-04 01:07:31.868104Z
# [2026.03.04 10:07:31.869] INFO    Task 'fit_data': started at 2026-03-04 01:07:31.869086Z
# [2026.03.04 10:07:33.073] INFO    Task 'fit_data': ended at 2026-03-04 01:07:33.072916Z
# [2026.03.04 10:07:33.074] INFO    Task '_extract_pair_payload': started at 2026-03-04 01:07:33.074207Z
# [2026.03.04 10:07:33.075] INFO    Task '_extract_pair_payload': ended at 2026-03-04 01:07:33.075002Z
# [2026.03.04 10:07:33.076] INFO    Task '_append_item': started at 2026-03-04 01:07:33.075899Z
# [2026.03.04 10:07:33.076] INFO    Task '_append_item': ended at 2026-03-04 01:07:33.076387Z
# [2026.03.04 10:07:33.076] INFO    Task 'plot_population': started at 2026-03-04 01:07:33.076852Z
# [2026.03.04 10:07:33.095] INFO    Artifact: 'ResidualZZEcho_q0_to_q1' of type 'Figure' logged at 2026-03-04
# [2026.03.04 10:07:33.095] INFO    01:07:33.095347Z
# [2026.03.04 10:07:33.152] INFO    Task 'plot_population': ended at 2026-03-04 01:07:33.151982Z
# [2026.03.04 10:07:33.152] INFO    Task '_select_pair_result': started at 2026-03-04 01:07:33.152722Z
# [2026.03.04 10:07:33.153] INFO    Task '_select_pair_result': ended at 2026-03-04 01:07:33.153245Z
# [2026.03.04 10:07:33.153] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 01:07:33.153739Z
# [2026.03.04 10:07:33.154] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 01:07:33.154376Z
# [2026.03.04 10:07:33.154] INFO    Task 'process_conditional_population': started at 2026-03-04 01:07:33.154815Z
# [2026.03.04 10:07:33.155] INFO    Task 'process_conditional_population': ended at 2026-03-04 01:07:33.155596Z
# [2026.03.04 10:07:33.156] INFO    Task 'fit_data': started at 2026-03-04 01:07:33.156281Z
# [2026.03.04 10:07:34.337] INFO    Task 'fit_data': ended at 2026-03-04 01:07:34.336920Z
# [2026.03.04 10:07:34.338] INFO    Task '_extract_pair_payload': started at 2026-03-04 01:07:34.338218Z
# [2026.03.04 10:07:34.339] INFO    Task '_extract_pair_payload': ended at 2026-03-04 01:07:34.338975Z
# [2026.03.04 10:07:34.339] INFO    Task '_append_item': started at 2026-03-04 01:07:34.339685Z
# [2026.03.04 10:07:34.340] INFO    Task '_append_item': ended at 2026-03-04 01:07:34.340202Z
# [2026.03.04 10:07:34.340] INFO    Task '_select_pair_result': started at 2026-03-04 01:07:34.340787Z
# [2026.03.04 10:07:34.341] INFO    Task '_select_pair_result': ended at 2026-03-04 01:07:34.341251Z
# [2026.03.04 10:07:34.341] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 01:07:34.341723Z
# [2026.03.04 10:07:34.342] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 01:07:34.342207Z
# [2026.03.04 10:07:34.342] INFO    Task 'process_conditional_population': started at 2026-03-04 01:07:34.342651Z
# [2026.03.04 10:07:34.343] INFO    Task 'process_conditional_population': ended at 2026-03-04 01:07:34.343410Z
# [2026.03.04 10:07:34.344] INFO    Task 'fit_data': started at 2026-03-04 01:07:34.344032Z
# [2026.03.04 10:07:35.537] INFO    Task 'fit_data': ended at 2026-03-04 01:07:35.537167Z
# [2026.03.04 10:07:35.538] INFO    Task '_extract_pair_payload': started at 2026-03-04 01:07:35.538380Z
# [2026.03.04 10:07:35.539] INFO    Task '_extract_pair_payload': ended at 2026-03-04 01:07:35.539250Z
# [2026.03.04 10:07:35.540] INFO    Task '_append_item': started at 2026-03-04 01:07:35.540520Z
# [2026.03.04 10:07:35.541] INFO    Task '_append_item': ended at 2026-03-04 01:07:35.541135Z
# [2026.03.04 10:07:35.541] INFO    Task '_select_pair_result': started at 2026-03-04 01:07:35.541688Z
# [2026.03.04 10:07:35.542] INFO    Task '_select_pair_result': ended at 2026-03-04 01:07:35.542174Z
# [2026.03.04 10:07:35.542] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 01:07:35.542662Z
# [2026.03.04 10:07:35.543] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 01:07:35.543121Z
# [2026.03.04 10:07:35.543] INFO    Task 'process_conditional_population': started at 2026-03-04 01:07:35.543527Z
# [2026.03.04 10:07:35.544] INFO    Task 'process_conditional_population': ended at 2026-03-04 01:07:35.544298Z
# [2026.03.04 10:07:35.545] INFO    Task 'fit_data': started at 2026-03-04 01:07:35.544952Z
# [2026.03.04 10:07:36.877] INFO    Task 'fit_data': ended at 2026-03-04 01:07:36.876862Z
# [2026.03.04 10:07:36.878] INFO    Task '_extract_pair_payload': started at 2026-03-04 01:07:36.878069Z
# [2026.03.04 10:07:36.878] INFO    Task '_extract_pair_payload': ended at 2026-03-04 01:07:36.878861Z
# [2026.03.04 10:07:36.879] INFO    Task '_append_item': started at 2026-03-04 01:07:36.879842Z
# [2026.03.04 10:07:36.880] INFO    Task '_append_item': ended at 2026-03-04 01:07:36.880425Z
# [2026.03.04 10:07:36.881] INFO    Task '_select_pair_result': started at 2026-03-04 01:07:36.880975Z
# [2026.03.04 10:07:36.881] INFO    Task '_select_pair_result': ended at 2026-03-04 01:07:36.881451Z
# [2026.03.04 10:07:36.881] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 01:07:36.881874Z
# [2026.03.04 10:07:36.882] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 01:07:36.882290Z
# [2026.03.04 10:07:36.882] INFO    Task 'process_conditional_population': started at 2026-03-04 01:07:36.882684Z
# [2026.03.04 10:07:36.883] INFO    Task 'process_conditional_population': ended at 2026-03-04 01:07:36.883425Z
# [2026.03.04 10:07:36.884] INFO    Task 'fit_data': started at 2026-03-04 01:07:36.884086Z
# [2026.03.04 10:07:38.086] INFO    Task 'fit_data': ended at 2026-03-04 01:07:38.086199Z
# [2026.03.04 10:07:38.087] INFO    Task '_extract_pair_payload': started at 2026-03-04 01:07:38.087422Z
# [2026.03.04 10:07:38.088] INFO    Task '_extract_pair_payload': ended at 2026-03-04 01:07:38.088293Z
# [2026.03.04 10:07:38.089] INFO    Task '_append_item': started at 2026-03-04 01:07:38.089243Z
# [2026.03.04 10:07:38.089] INFO    Task '_append_item': ended at 2026-03-04 01:07:38.089814Z
# [2026.03.04 10:07:38.090] INFO    Task '_select_pair_result': started at 2026-03-04 01:07:38.090350Z
# [2026.03.04 10:07:38.090] INFO    Task '_select_pair_result': ended at 2026-03-04 01:07:38.090819Z
# [2026.03.04 10:07:38.091] INFO    Task '_select_qubit_by_uid': started at 2026-03-04 01:07:38.091246Z
# [2026.03.04 10:07:38.091] INFO    Task '_select_qubit_by_uid': ended at 2026-03-04 01:07:38.091664Z
# [2026.03.04 10:07:38.092] INFO    Task 'process_conditional_population': started at 2026-03-04 01:07:38.092020Z
# [2026.03.04 10:07:38.092] INFO    Task 'process_conditional_population': ended at 2026-03-04 01:07:38.092751Z
# [2026.03.04 10:07:38.093] INFO    Task 'fit_data': started at 2026-03-04 01:07:38.093396Z
# [2026.03.04 10:07:39.382] INFO    Task 'fit_data': ended at 2026-03-04 01:07:39.382373Z
# [2026.03.04 10:07:39.383] INFO    Task '_extract_pair_payload': started at 2026-03-04 01:07:39.383636Z
# [2026.03.04 10:07:39.384] INFO    Task '_extract_pair_payload': ended at 2026-03-04 01:07:39.384515Z
# [2026.03.04 10:07:39.385] INFO    Task '_append_item': started at 2026-03-04 01:07:39.385422Z
# [2026.03.04 10:07:39.386] INFO    Task '_append_item': ended at 2026-03-04 01:07:39.386353Z
# [2026.03.04 10:07:39.387] INFO    Task '_materialize_list': started at 2026-03-04 01:07:39.387296Z
# [2026.03.04 10:07:39.387] INFO    Task '_materialize_list': ended at 2026-03-04 01:07:39.387868Z
# [2026.03.04 10:07:39.388] INFO    Task '_merge_pair_payloads': started at 2026-03-04 01:07:39.388379Z
# [2026.03.04 10:07:39.388] INFO    Task '_merge_pair_payloads': ended at 2026-03-04 01:07:39.388892Z
# [2026.03.04 10:07:39.389] INFO    Task 'plot_residual_zz_summary': started at 2026-03-04 01:07:39.389348Z
# [2026.03.04 10:07:39.397] INFO    Artifact: 'ResidualZZEcho_summary' of type 'Figure' logged at 2026-03-04
# [2026.03.04 10:07:39.397] INFO    01:07:39.397158Z
# [2026.03.04 10:07:39.432] INFO    Task 'plot_residual_zz_summary': ended at 2026-03-04 01:07:39.432319Z
# [2026.03.04 10:07:39.433] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.04 10:07:39.433] INFO      Workflow 'analysis_workflow': execution ended at 2026-03-04 01:07:39.433138Z
# [2026.03.04 10:07:39.433] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.04 10:07:39.435] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.03.04 10:07:39.436] INFO      Workflow 'residual_zz_echo': execution ended at 2026-03-04 01:07:39.435440Z
# [2026.03.04 10:07:39.436] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'q0->q1': {'ci95_hz': (2975.070939397812, 4994.194229865074),
#             'ctrl_uid': 'q0',
#             'nominal_hz': 3937.7856826782227,
#             'quality_flag': 'ok',
#             'sigma_boot_hz': 517.664220744588,
#             'sigma_final_hz': 517.664220744588,
#             'sigma_model_hz': 462.8391309673978,
#             'std_dev_hz': 462.8391309673978,
#             'targ_uid': 'q1',
#             'value': 3937.7856826782227+/-462.8391309673978},
#  'q0->q2': {'ci95_hz': (-754.4993071317673, 685.8636582612991),
#             'ctrl_uid': 'q0',
#             'nominal_hz': -3.624593734741211,
#             'quality_flag': 'ok',
#             'sigma_boot_hz': 370.2879836290942,
#             'sigma_final_hz': 370.2879836290942,
#             'sigma_model_hz': 357.40519746387366,
#             'std_dev_hz': 357.40519746387366,
#             'targ_uid': 'q2',
#             'value': -3.624593734741211+/-357.40519746387366},
#  'q1->q0': {'ci95_hz': (1417.9979968070984, 3159.0561639666557),
#             'ctrl_uid': 'q1',
#             'nominal_hz': 2311.6427669525146,
#             'quality_flag': 'ok',
#             'sigma_boot_hz': 440.10674315910694,
#             'sigma_final_hz': 440.10674315910694,
#             'sigma_model_hz': 419.22991996556095,
#             'std_dev_hz': 419.22991996556095,
#             'targ_uid': 'q0',
#             'value': 2311.6427669525146+/-419.22991996556095},
#  'q1->q2': {'ci95_hz': (6631.493387007713, 10347.231760668754),
#             'ctrl_uid': 'q1',
#             'nominal_hz': 8622.031922340393,
#             'quality_flag': 'ok',
#             'sigma_boot_hz': 938.2595913390124,
#             'sigma_final_hz': 938.2595913390124,
#             'sigma_model_hz': 924.0699118698972,
#             'std_dev_hz': 924.0699118698972,
#             'targ_uid': 'q2',
#             'value': 8622.031922340393+/-924.0699118698972},
#  'q2->q0': {'ci95_hz': (-329.3524619579315, 1484.4922981500622),
#             'ctrl_uid': 'q2',
#             'nominal_hz': 607.0314435958862,
#             'quality_flag': 'ok',
#             'sigma_boot_hz': 470.3006563345777,
#             'sigma_final_hz': 470.3006563345777,
#             'sigma_model_hz': 448.5202086802886,
#             'std_dev_hz': 448.5202086802886,
#             'targ_uid': 'q0',
#             'value': 607.0314435958862+/-448.5202086802886},
#  'q2->q1': {'ci95_hz': (11309.381074380875, 15208.796111130714),
#             'ctrl_uid': 'q2',
#             'nominal_hz': 13212.183671951294,
#             'quality_flag': 'ok',
#             'sigma_boot_hz': 999.7308238835113,
#             'sigma_final_hz': 999.7308238835113,
#             'sigma_model_hz': 949.3602157790563,
#             'std_dev_hz': 949.3602157790563,
#             'targ_uid': 'q1',
#             'value': 13212.183671951294+/-949.3602157790563}}
