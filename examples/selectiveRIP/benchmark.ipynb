# %% [markdown]
# Version update
# - `LabOneQ` 25.10.2 -> 25.10.3   + 개발자 모드로 필요한 패키지 추가 설치
# - `Application Livrary` 25.10.0 ->
#
#
# https://docs.zhinst.com/labone_q_user_manual/core/benchmarking/benchmarking.html?h=bench#installing-the-benchmark-package

# %%
import pickle

import matplotlib.pyplot as plt
import numpy as np

from laboneq import __version__ as laboneq_version
from laboneq.laboneq_benchmark import benchmark, extract_duration, extract_metadata
from laboneq_benchmark.device_setups import (
    create_benchmark_device_setup,
    create_benchmark_device_setup_qpu,
)
from laboneq_benchmark.experiments import (
    ramsey_parallel,
    rb_parallel,
    # amplitude_rabi_parallel,
    two_qubit_RB,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 import numpy as np
#       6 from laboneq import __version__ as laboneq_version
# ----> 7 from laboneq.laboneq_benchmark import benchmark, extract_duration, extract_metadata
#       8 from laboneq_benchmark.device_setups import (
#       9     create_benchmark_device_setup,
#      10     create_benchmark_device_setup_qpu,
#      11 )
#      12 from laboneq_benchmark.experiments import (
#      13     ramsey_parallel,
#      14     rb_parallel,
#      15     # amplitude_rabi_parallel,
#      16     two_qubit_RB,
#      17 )
#
# ModuleNotFoundError: No module named 'laboneq.laboneq_benchmark'

# %%
from laboneq
# Out:
#   Cell In[2], line 1
#     from laboneq
#                 ^
# SyntaxError: invalid syntax
