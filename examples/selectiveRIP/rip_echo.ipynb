# %%
import numpy as np
from pprint import pprint
from copy import deepcopy


from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
#from laboneq.contrib.example_helpers.generate_device_setup import generate_device_setup
from laboneq.dsl.device import DeviceSetup




descriptor = generate_descriptor(
    #pqsc=[""], # 장비 여러개 사용시
    shfqc_6=["DEV12256"],
    number_data_qubits=6,
    multiplex=True,
    number_multiplex=6,
    include_cr_lines=True,
    include_ef_lines=True,
    get_zsync=False,  # Only set to True when using real device
    save = True,
    filename="TG_RIP_2",
    ip_address="192.168.0.83"
)


#descriptor
setup = DeviceSetup.from_descriptor(yaml_text=descriptor, server_host="192.168.0.83")
#setup
setup.instruments[0].device_options = 'SHFQC/PLUS/QC6CH'
#setup.instruments

# %%
from laboneq.simple import Session
session = Session(setup)
session.connect(ignore_version_mismatch=False, do_emulation=False)
#session.disconnect()
# Out:
# [2026.01.05 21:20:48.933] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /home/yalgaeahn/JSAHN/qubit-experiment/examples/selectiveRIP/laboneq_output/log
# [2026.01.05 21:20:48.935] INFO    VERSION: laboneq 25.10.3
# [2026.01.05 21:20:48.937] INFO    Connecting to data server at 192.168.0.83:8004
# [2026.01.05 21:20:48.952] INFO    Connected to Zurich Instruments LabOne Data Server version 25.10.1.4 at 192.168.0.83:8004
# [2026.01.05 21:20:48.974] INFO    Configuring the device setup
# [2026.01.05 21:20:48.992] INFO    The device setup is configured

# %%
from qpu_types import TransmonQubit, TransmonQubitParameters
from helper import load_qubit_parameters, save_qubit_parameters
from operations import TransmonOperations
from laboneq.dsl.quantum.qpu import QPU, QuantumPlatform


_loaded_qubits = load_qubit_parameters(filename="latest") 
#qubits = TransmonQubit.from_device_setup(setup) # Also can be done with load_qubit_parameters 
qubits = list(_loaded_qubits.values())


qpu = QPU(quantum_elements=qubits, quantum_operations=TransmonOperations())
#quantum_platform = QuantumPlatform(setup=setup, qpu=qpu)

# qpu.topology.add_edge("bus", "q16", "q117")
# qpu.topology.add_edge("bus", "q17", "q18")
# qpu.topology.add_edge("bus", "q18", "q19")
# qpu.topology.plot()




from laboneq.simple import workflow
folder_store = workflow.logbook.FolderStore("./experiment_store") 
folder_store.activate()
#folder_store.deactivate()
#workflow.logbook.LoggingStore().activate()
#workflow.logbook.LogbookStore().deactivate()
# Out:
# LOADED:./qubit_parameters/20260105-2039_sample2.json

# %%
# from experiments import rip4

# #q = qubits[1]
# #temporary_parameters = q.parameters.copy()

# #######################################################################

# #######################################################################
# options = rip4.experiment_workflow.options()
# options.update(False)

# #print(workflow.show_fields(options))

# ###################################################################
# bus_freq = qubits[2].parameters.resonance_frequency_ge - 45e6+26e6 
# bus_amp = 1.0

# bus2_freq = qubits[4].parameters.resonance_frequency_ge - 9e6  
# bus2_amp = 0.0

# rip_drive_controlg = rip4.experiment_workflow(
#     session=session,
#     qpu=qpu,
#     ctrl=qubits[1],
#     targ=qubits[0],
#     bus=qubits[2], #mode1 
#     bus2=qubits[4], #mode3 
#     bus_frequency=bus_freq,
#     bus_amplitude=bus_amp,
#     bus2_frequency=bus2_freq,
#     bus2_amplitude=bus2_amp,
#     delays=np.linspace(350e-9, 500e-9, 151),
#     detunings=0,
#     c_prep = "g",
#     options=options 
# )
# rip_drive_controle = rip4.experiment_workflow(
#     session=session,
#     qpu=qpu,
#     ctrl=qubits[1],
#     targ=qubits[0],
#     bus=qubits[2],
#     bus2=qubits[4],
#     bus_frequency=bus_freq,
#     bus_amplitude=bus_amp,
#     bus2_frequency=bus2_freq,
#     bus2_amplitude=bus2_amp,
#     delays=np.linspace(350e-9, 500e-9, 151),
#     detunings=0,
#     c_prep = "e",
#     options=options 
# )

# rip_result_control_g = rip_drive_controlg.run()
# rip_result_control_e = rip_drive_controle.run()
# #qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
# #print(drag_result.tasks['analysis_workflow'].output)

# %%
# from laboneq.simple import show_pulse_sheet
# from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

# show_pulse_sheet(compiled_experiment=rip_result_control_e.tasks["compile_experiment"].output,name='test', interactive=True)
# #plot_simulation(compiled_experiment=rip_result_control_e.tasks["compile_experiment"].output)

# %%
qubits[4].parameters.resonance_frequency_ge # mode1
# Out:
# 6420000000.0

# %% [markdown]
# # RIP echo

# %%
from experiments import rip_echo

#q = qubits[1]
#temporary_parameters = q.parameters.copy()

#######################################################################

#######################################################################
options = rip_echo.experiment_workflow.options()
options.update(False)

#print(workflow.show_fields(options))

###################################################################
bus_freq = qubits[2].parameters.resonance_frequency_ge - 13e6#45e6+26e6 
bus_amp = 0.45

bus2_freq = qubits[4].parameters.resonance_frequency_ge - 9e6  
bus2_amp = 0.0

rip_echo_controlg = rip_echo.experiment_workflow(
    session=session,
    qpu=qpu,
    ctrl=qubits[1],
    targ=qubits[0],
    bus=qubits[2], #mode1 
    bus2=qubits[4], #mode3 
    bus_frequency=bus_freq,
    bus_amplitude=bus_amp,
    bus2_frequency=bus2_freq,
    bus2_amplitude=bus2_amp,
    delays=np.linspace(80e-9, 2400e-9, 200),
    detunings=0,
    c_prep = "g",
    options=options 
)
rip_echo_controle = rip_echo.experiment_workflow(
    session=session,
    qpu=qpu,
    ctrl=qubits[1],
    targ=qubits[0],
    bus=qubits[2],
    bus2=qubits[4],
    bus_frequency=bus_freq, 
    bus_amplitude=bus_amp,
    bus2_frequency=bus2_freq,
    bus2_amplitude=bus2_amp,
    delays=np.linspace(80e-9, 2400e-9, 200),
    detunings=0,
    c_prep = "e",
    options=options 
)

rip_echo_result_control_g = rip_echo_controlg.run()
rip_echo_result_control_e = rip_echo_controle.run()
# Out:
# [2026.01.05 21:35:04.962] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:04.963] INFO      Workflow 'rip_echo': execution started at 2026-01-05 12:35:04.962515Z
# [2026.01.05 21:35:04.963] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:04.972] INFO    Task 'temporary_qpu': started at 2026-01-05 12:35:04.972283Z
# [2026.01.05 21:35:04.973] INFO    Task 'temporary_qpu': ended at 2026-01-05 12:35:04.973324Z
# [2026.01.05 21:35:04.975] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-05
# [2026.01.05 21:35:04.975] INFO    12:35:04.975404Z
# [2026.01.05 21:35:04.976] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-05 12:35:04.976197Z
# [2026.01.05 21:35:04.977] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-05
# [2026.01.05 21:35:04.977] INFO    12:35:04.976920Z
# [2026.01.05 21:35:04.977] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-05 12:35:04.977505Z
# [2026.01.05 21:35:04.978] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-05
# [2026.01.05 21:35:04.978] INFO    12:35:04.978123Z
# [2026.01.05 21:35:04.978] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-05 12:35:04.978605Z
# [2026.01.05 21:35:04.979] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-05
# [2026.01.05 21:35:04.979] INFO    12:35:04.979289Z
# [2026.01.05 21:35:04.979] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-05 12:35:04.979788Z
# [2026.01.05 21:35:04.980] INFO    Task 'create_experiment': started at 2026-01-05 12:35:04.980521Z
# [2026.01.05 21:35:04.986] INFO    Task 'create_experiment': ended at 2026-01-05 12:35:04.986005Z
# [2026.01.05 21:35:04.987] INFO    Task 'compile_experiment': started at 2026-01-05 12:35:04.987617Z
# [2026.01.05 21:35:04.989] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal '/logical_signal_groups/q0/acquire' to SOFTWARE
# [2026.01.05 21:35:04.990] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal '/logical_signal_groups/q0/drive' to HARDWARE
# [2026.01.05 21:35:04.990] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal '/logical_signal_groups/q1/acquire' to SOFTWARE
# [2026.01.05 21:35:04.990] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.05 21:35:04.990] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal '/logical_signal_groups/q2/acquire' to SOFTWARE
# [2026.01.05 21:35:04.990] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal '/logical_signal_groups/q2/drive' to HARDWARE
# [2026.01.05 21:35:04.990] INFO    Resolved modulation type of oscillator 'q2_drive_cr_osc' on signal '/logical_signal_groups/q2/drive_cr' to HARDWARE
# [2026.01.05 21:35:04.991] INFO    Resolved modulation type of oscillator 'q4_drive_ge_osc' on signal '/logical_signal_groups/q4/drive' to HARDWARE
# [2026.01.05 21:35:04.991] INFO    Starting LabOne Q Compiler run...
# [2026.01.05 21:35:05.245] INFO    Schedule completed. [0.253 s]
# [2026.01.05 21:35:05.374] INFO    Code generation completed for all AWGs. [0.129 s]
# [2026.01.05 21:35:05.375] INFO    Completed compilation step 1 of 1. [0.383 s]
# [2026.01.05 21:35:05.378] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.379] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.05 21:35:05.379] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.379] INFO      SHFQC_DEV12256        0        609            0           1      4800
# [2026.01.05 21:35:05.379] INFO      SHFQC_DEV12256_sg     0       1281           26          24      6848
# [2026.01.05 21:35:05.379] INFO      SHFQC_DEV12256_sg     1        655           17          16      4576
# [2026.01.05 21:35:05.379] INFO      SHFQC_DEV12256_sg     2       2165          387         386   1923296
# [2026.01.05 21:35:05.379] INFO      SHFQC_DEV12256_sg     4       2165          387         386   1923296
# [2026.01.05 21:35:05.380] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.380] INFO      TOTAL                         6875          817               3862816
# [2026.01.05 21:35:05.380] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.415] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:05.422] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.01.05 21:35:05.423] INFO    Completed compilation step 1 of 20. [0.016 s]
# [2026.01.05 21:35:05.429] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:05.439] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.01.05 21:35:05.440] INFO    Completed compilation step 2 of 20. [0.017 s]
# [2026.01.05 21:35:05.448] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:05.458] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:05.460] INFO    Completed compilation step 3 of 20. [0.019 s]
# [2026.01.05 21:35:05.467] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:05.478] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:05.479] INFO    Completed compilation step 4 of 20. [0.019 s]
# [2026.01.05 21:35:05.633] INFO    Schedule completed. [0.153 s]
# [2026.01.05 21:35:05.643] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:05.645] INFO    Completed compilation step 5 of 20. [0.165 s]
# [2026.01.05 21:35:05.651] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:05.662] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:05.663] INFO    Completed compilation step 6 of 20. [0.018 s]
# [2026.01.05 21:35:05.669] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:05.680] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:05.682] INFO    Completed compilation step 7 of 20. [0.018 s]
# [2026.01.05 21:35:05.688] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:05.699] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:05.700] INFO    Completed compilation step 8 of 20. [0.018 s]
# [2026.01.05 21:35:05.706] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:05.718] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:05.719] INFO    Completed compilation step 9 of 20. [0.019 s]
# [2026.01.05 21:35:05.726] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:05.736] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:05.737] INFO    Completed compilation step 10 of 20. [0.018 s]
# [2026.01.05 21:35:05.744] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:05.754] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:05.756] INFO    Completed compilation step 11 of 20. [0.018 s]
# [2026.01.05 21:35:05.762] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:05.773] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:05.774] INFO    Completed compilation step 12 of 20. [0.018 s]
# [2026.01.05 21:35:05.781] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:05.793] INFO    Code generation completed for all AWGs. [0.012 s]
# [2026.01.05 21:35:05.795] INFO    Completed compilation step 13 of 20. [0.020 s]
# [2026.01.05 21:35:05.801] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:05.812] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:05.814] INFO    Completed compilation step 14 of 20. [0.019 s]
# [2026.01.05 21:35:05.823] INFO    Schedule completed. [0.009 s]
# [2026.01.05 21:35:05.834] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:05.836] INFO    Completed compilation step 15 of 20. [0.022 s]
# [2026.01.05 21:35:05.843] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:05.855] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:05.856] INFO    Completed compilation step 16 of 20. [0.020 s]
# [2026.01.05 21:35:05.864] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:05.875] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:05.877] INFO    Completed compilation step 17 of 20. [0.020 s]
# [2026.01.05 21:35:05.884] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:05.895] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:05.897] INFO    Completed compilation step 18 of 20. [0.020 s]
# [2026.01.05 21:35:05.904] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:05.916] INFO    Code generation completed for all AWGs. [0.012 s]
# [2026.01.05 21:35:05.918] INFO    Completed compilation step 19 of 20. [0.021 s]
# [2026.01.05 21:35:05.925] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:05.939] INFO    Code generation completed for all AWGs. [0.013 s]
# [2026.01.05 21:35:05.940] INFO    Completed compilation step 20 of 20. [0.022 s]
# [2026.01.05 21:35:05.971] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.972] INFO      Step   Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.05 21:35:05.972] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.972] INFO      0      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.972] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.972] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.972] INFO             SHFQC_DEV12256_sg     2        114           20          19     10688
# [2026.01.05 21:35:05.973] INFO             SHFQC_DEV12256_sg     4        114           20          19     10688
# [2026.01.05 21:35:05.973] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.973] INFO      1      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.973] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.973] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.973] INFO             SHFQC_DEV12256_sg     2        114           20          19     19488
# [2026.01.05 21:35:05.974] INFO             SHFQC_DEV12256_sg     4        114           20          19     19488
# [2026.01.05 21:35:05.974] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.974] INFO      2      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.974] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.974] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.974] INFO             SHFQC_DEV12256_sg     2        114           20          19     28224
# [2026.01.05 21:35:05.975] INFO             SHFQC_DEV12256_sg     4        114           20          19     28224
# [2026.01.05 21:35:05.975] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.975] INFO      3      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.975] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.975] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.975] INFO             SHFQC_DEV12256_sg     2        114           20          19     37056
# [2026.01.05 21:35:05.975] INFO             SHFQC_DEV12256_sg     4        114           20          19     37056
# [2026.01.05 21:35:05.976] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.976] INFO      4      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.976] INFO             SHFQC_DEV12256_sg     0        123           20          18      5120
# [2026.01.05 21:35:05.976] INFO             SHFQC_DEV12256_sg     1         67           11          10      2880
# [2026.01.05 21:35:05.976] INFO             SHFQC_DEV12256_sg     2        117           21          20     48384
# [2026.01.05 21:35:05.976] INFO             SHFQC_DEV12256_sg     4        117           21          20     48384
# [2026.01.05 21:35:05.976] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.977] INFO      5      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.977] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.977] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.977] INFO             SHFQC_DEV12256_sg     2        114           20          19     54592
# [2026.01.05 21:35:05.977] INFO             SHFQC_DEV12256_sg     4        114           20          19     54592
# [2026.01.05 21:35:05.977] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.977] INFO      6      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.978] INFO             SHFQC_DEV12256_sg     0        123           20          18      5152
# [2026.01.05 21:35:05.978] INFO             SHFQC_DEV12256_sg     1         67           11          10      2880
# [2026.01.05 21:35:05.978] INFO             SHFQC_DEV12256_sg     2        117           21          20     67040
# [2026.01.05 21:35:05.978] INFO             SHFQC_DEV12256_sg     4        117           21          20     67040
# [2026.01.05 21:35:05.978] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.978] INFO      7      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.978] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.979] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.979] INFO             SHFQC_DEV12256_sg     2        114           20          19     72704
# [2026.01.05 21:35:05.979] INFO             SHFQC_DEV12256_sg     4        114           20          19     72704
# [2026.01.05 21:35:05.979] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.979] INFO      8      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.979] INFO             SHFQC_DEV12256_sg     0        123           20          18      5120
# [2026.01.05 21:35:05.980] INFO             SHFQC_DEV12256_sg     1         67           11          10      2880
# [2026.01.05 21:35:05.980] INFO             SHFQC_DEV12256_sg     2        117           21          20     85664
# [2026.01.05 21:35:05.980] INFO             SHFQC_DEV12256_sg     4        117           21          20     85664
# [2026.01.05 21:35:05.980] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.980] INFO      9      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.980] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.980] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.981] INFO             SHFQC_DEV12256_sg     2        114           20          19     90240
# [2026.01.05 21:35:05.981] INFO             SHFQC_DEV12256_sg     4        114           20          19     90240
# [2026.01.05 21:35:05.981] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.981] INFO      10     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.981] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.981] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.981] INFO             SHFQC_DEV12256_sg     2        114           20          19     99072
# [2026.01.05 21:35:05.981] INFO             SHFQC_DEV12256_sg     4        114           20          19     99072
# [2026.01.05 21:35:05.982] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.982] INFO      11     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.982] INFO             SHFQC_DEV12256_sg     0        123           20          18      5120
# [2026.01.05 21:35:05.982] INFO             SHFQC_DEV12256_sg     1         67           11          10      2880
# [2026.01.05 21:35:05.982] INFO             SHFQC_DEV12256_sg     2        117           21          20    113664
# [2026.01.05 21:35:05.982] INFO             SHFQC_DEV12256_sg     4        117           21          20    113664
# [2026.01.05 21:35:05.983] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.983] INFO      12     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.983] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.983] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.983] INFO             SHFQC_DEV12256_sg     2        114           20          19    116640
# [2026.01.05 21:35:05.983] INFO             SHFQC_DEV12256_sg     4        114           20          19    116640
# [2026.01.05 21:35:05.983] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.984] INFO      13     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.984] INFO             SHFQC_DEV12256_sg     0        123           20          18      5152
# [2026.01.05 21:35:05.984] INFO             SHFQC_DEV12256_sg     1         67           11          10      2880
# [2026.01.05 21:35:05.984] INFO             SHFQC_DEV12256_sg     2        117           21          20    132320
# [2026.01.05 21:35:05.984] INFO             SHFQC_DEV12256_sg     4        117           21          20    132320
# [2026.01.05 21:35:05.984] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.984] INFO      14     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.985] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.985] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.985] INFO             SHFQC_DEV12256_sg     2        114           20          19    134720
# [2026.01.05 21:35:05.985] INFO             SHFQC_DEV12256_sg     4        114           20          19    134720
# [2026.01.05 21:35:05.985] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.985] INFO      15     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.986] INFO             SHFQC_DEV12256_sg     0        123           20          18      5120
# [2026.01.05 21:35:05.986] INFO             SHFQC_DEV12256_sg     1         67           11          10      2880
# [2026.01.05 21:35:05.986] INFO             SHFQC_DEV12256_sg     2        117           21          20    150944
# [2026.01.05 21:35:05.986] INFO             SHFQC_DEV12256_sg     4        117           21          20    150944
# [2026.01.05 21:35:05.986] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.986] INFO      16     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.986] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.987] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.987] INFO             SHFQC_DEV12256_sg     2        114           20          19    152288
# [2026.01.05 21:35:05.987] INFO             SHFQC_DEV12256_sg     4        114           20          19    152288
# [2026.01.05 21:35:05.987] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.987] INFO      17     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.987] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.988] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.988] INFO             SHFQC_DEV12256_sg     2        114           20          19    161088
# [2026.01.05 21:35:05.988] INFO             SHFQC_DEV12256_sg     4        114           20          19    161088
# [2026.01.05 21:35:05.988] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.988] INFO      18     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.988] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.988] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.989] INFO             SHFQC_DEV12256_sg     2        114           20          19    169824
# [2026.01.05 21:35:05.989] INFO             SHFQC_DEV12256_sg     4        114           20          19    169824
# [2026.01.05 21:35:05.989] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.989] INFO      19     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:05.989] INFO             SHFQC_DEV12256_sg     0        120           19          17      4832
# [2026.01.05 21:35:05.989] INFO             SHFQC_DEV12256_sg     1         67           11          10      2848
# [2026.01.05 21:35:05.989] INFO             SHFQC_DEV12256_sg     2        114           20          19    178656
# [2026.01.05 21:35:05.990] INFO             SHFQC_DEV12256_sg     4        114           20          19    178656
# [2026.01.05 21:35:05.990] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:05.990] INFO             TOTAL                         9134         1418               4098176
# [2026.01.05 21:35:05.990] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:06.006] INFO    Auto-chunked sweep divided into 20 chunks
# [2026.01.05 21:35:06.007] INFO    Finished LabOne Q Compiler run.
# [2026.01.05 21:35:06.008] INFO    Task 'compile_experiment': ended at 2026-01-05 12:35:06.008032Z
# [2026.01.05 21:35:06.239] INFO    Task 'run_experiment': started at 2026-01-05 12:35:06.238872Z
# [2026.01.05 21:35:06.403] INFO    Starting near-time execution...
# [2026.01.05 21:35:07.572] INFO    Estimated RT execution time: 25.90 s.
# [2026.01.05 21:35:33.169] INFO    Finished near-time execution.
# [2026.01.05 21:35:33.381] INFO    Task 'run_experiment': ended at 2026-01-05 12:35:33.380588Z
# [2026.01.05 21:35:33.386] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.387] INFO      Workflow 'analysis_workflow': execution started at 2026-01-05
# [2026.01.05 21:35:33.387] INFO      12:35:33.385719Z
# [2026.01.05 21:35:33.387] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.390] INFO    Task 'calculate_qubit_population': started at 2026-01-05 12:35:33.390135Z
# [2026.01.05 21:35:33.391] INFO    Task 'calculate_qubit_population': ended at 2026-01-05 12:35:33.391209Z
# [2026.01.05 21:35:33.391] INFO    Task 'fit_data': started at 2026-01-05 12:35:33.391847Z
# [2026.01.05 21:35:33.395] INFO    Task 'fit_data': ended at 2026-01-05 12:35:33.395788Z
# [2026.01.05 21:35:33.396] INFO    Task 'extract_qubit_parameters': started at 2026-01-05 12:35:33.396477Z
# [2026.01.05 21:35:33.397] INFO    Task 'extract_qubit_parameters': ended at 2026-01-05 12:35:33.397646Z
# [2026.01.05 21:35:33.398] INFO    Task 'plot_raw_complex_data_1d': started at 2026-01-05 12:35:33.398372Z
# [2026.01.05 21:35:33.411] INFO    Artifact: 'Raw_data_q0' of type 'Figure' logged at 2026-01-05 12:35:33.411327Z
# [2026.01.05 21:35:33.491] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-01-05 12:35:33.491709Z
# [2026.01.05 21:35:33.492] INFO    Task 'plot_population': started at 2026-01-05 12:35:33.492477Z
# [2026.01.05 21:35:33.498] INFO    Artifact: 'Ramsey_q0' of type 'Figure' logged at 2026-01-05 12:35:33.498357Z
# [2026.01.05 21:35:33.558] INFO    Task 'plot_population': ended at 2026-01-05 12:35:33.558340Z
# [2026.01.05 21:35:33.559] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.560] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-05 12:35:33.559626Z
# [2026.01.05 21:35:33.561] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.562] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.562] INFO      Workflow 'rip_echo': execution ended at 2026-01-05 12:35:33.562158Z
# [2026.01.05 21:35:33.563] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.567] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.567] INFO      Workflow 'rip_echo': execution started at 2026-01-05 12:35:33.567031Z
# [2026.01.05 21:35:33.567] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.575] INFO    Task 'temporary_qpu': started at 2026-01-05 12:35:33.575670Z
# [2026.01.05 21:35:33.576] INFO    Task 'temporary_qpu': ended at 2026-01-05 12:35:33.576701Z
# [2026.01.05 21:35:33.578] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-05
# [2026.01.05 21:35:33.579] INFO    12:35:33.578651Z
# [2026.01.05 21:35:33.579] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-05 12:35:33.579500Z
# [2026.01.05 21:35:33.580] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-05
# [2026.01.05 21:35:33.580] INFO    12:35:33.580286Z
# [2026.01.05 21:35:33.581] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-05 12:35:33.580905Z
# [2026.01.05 21:35:33.581] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-05
# [2026.01.05 21:35:33.581] INFO    12:35:33.581566Z
# [2026.01.05 21:35:33.582] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-05 12:35:33.582043Z
# [2026.01.05 21:35:33.582] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-01-05
# [2026.01.05 21:35:33.583] INFO    12:35:33.582834Z
# [2026.01.05 21:35:33.583] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-01-05 12:35:33.583438Z
# [2026.01.05 21:35:33.584] INFO    Task 'create_experiment': started at 2026-01-05 12:35:33.584082Z
# [2026.01.05 21:35:33.589] INFO    Task 'create_experiment': ended at 2026-01-05 12:35:33.589286Z
# [2026.01.05 21:35:33.590] INFO    Task 'compile_experiment': started at 2026-01-05 12:35:33.590748Z
# [2026.01.05 21:35:33.592] INFO    Resolved modulation type of oscillator 'q0_readout_acquire_osc' on signal '/logical_signal_groups/q0/acquire' to SOFTWARE
# [2026.01.05 21:35:33.593] INFO    Resolved modulation type of oscillator 'q0_drive_ge_osc' on signal '/logical_signal_groups/q0/drive' to HARDWARE
# [2026.01.05 21:35:33.593] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal '/logical_signal_groups/q1/acquire' to SOFTWARE
# [2026.01.05 21:35:33.593] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal '/logical_signal_groups/q1/drive' to HARDWARE
# [2026.01.05 21:35:33.593] INFO    Resolved modulation type of oscillator 'q2_readout_acquire_osc' on signal '/logical_signal_groups/q2/acquire' to SOFTWARE
# [2026.01.05 21:35:33.593] INFO    Resolved modulation type of oscillator 'q2_drive_ge_osc' on signal '/logical_signal_groups/q2/drive' to HARDWARE
# [2026.01.05 21:35:33.593] INFO    Resolved modulation type of oscillator 'q2_drive_cr_osc' on signal '/logical_signal_groups/q2/drive_cr' to HARDWARE
# [2026.01.05 21:35:33.594] INFO    Resolved modulation type of oscillator 'q4_drive_ge_osc' on signal '/logical_signal_groups/q4/drive' to HARDWARE
# [2026.01.05 21:35:33.594] INFO    Starting LabOne Q Compiler run...
# [2026.01.05 21:35:33.814] INFO    Schedule completed. [0.219 s]
# [2026.01.05 21:35:33.933] INFO    Code generation completed for all AWGs. [0.119 s]
# [2026.01.05 21:35:33.935] INFO    Completed compilation step 1 of 1. [0.340 s]
# [2026.01.05 21:35:33.939] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.940] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.05 21:35:33.940] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.941] INFO      SHFQC_DEV12256        0        609            0           1      4800
# [2026.01.05 21:35:33.942] INFO      SHFQC_DEV12256_sg     0       1481           26          24      6848
# [2026.01.05 21:35:33.943] INFO      SHFQC_DEV12256_sg     1        855           17          16      4576
# [2026.01.05 21:35:33.943] INFO      SHFQC_DEV12256_sg     2       2165          387         386   1923296
# [2026.01.05 21:35:33.944] INFO      SHFQC_DEV12256_sg     4       2165          387         386   1923296
# [2026.01.05 21:35:33.944] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.944] INFO      TOTAL                         7275          817               3862816
# [2026.01.05 21:35:33.944] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:33.976] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:33.983] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.01.05 21:35:33.984] INFO    Completed compilation step 1 of 20. [0.015 s]
# [2026.01.05 21:35:33.990] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:34.000] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.01.05 21:35:34.001] INFO    Completed compilation step 2 of 20. [0.017 s]
# [2026.01.05 21:35:34.008] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:34.018] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.01.05 21:35:34.019] INFO    Completed compilation step 3 of 20. [0.018 s]
# [2026.01.05 21:35:34.027] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:34.038] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:34.039] INFO    Completed compilation step 4 of 20. [0.020 s]
# [2026.01.05 21:35:34.047] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:34.058] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:34.060] INFO    Completed compilation step 5 of 20. [0.020 s]
# [2026.01.05 21:35:34.067] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:34.077] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:34.079] INFO    Completed compilation step 6 of 20. [0.019 s]
# [2026.01.05 21:35:34.087] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:34.098] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:34.099] INFO    Completed compilation step 7 of 20. [0.020 s]
# [2026.01.05 21:35:34.107] INFO    Schedule completed. [0.008 s]
# [2026.01.05 21:35:34.118] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:34.119] INFO    Completed compilation step 8 of 20. [0.020 s]
# [2026.01.05 21:35:34.127] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:34.138] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:34.140] INFO    Completed compilation step 9 of 20. [0.020 s]
# [2026.01.05 21:35:34.292] INFO    Schedule completed. [0.152 s]
# [2026.01.05 21:35:34.311] INFO    Code generation completed for all AWGs. [0.017 s]
# [2026.01.05 21:35:34.312] INFO    Completed compilation step 10 of 20. [0.172 s]
# [2026.01.05 21:35:34.319] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:34.330] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:34.332] INFO    Completed compilation step 11 of 20. [0.019 s]
# [2026.01.05 21:35:34.339] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:34.351] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:34.352] INFO    Completed compilation step 12 of 20. [0.020 s]
# [2026.01.05 21:35:34.359] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:34.369] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:34.371] INFO    Completed compilation step 13 of 20. [0.018 s]
# [2026.01.05 21:35:34.377] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:34.388] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:34.390] INFO    Completed compilation step 14 of 20. [0.019 s]
# [2026.01.05 21:35:34.396] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:34.407] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:34.408] INFO    Completed compilation step 15 of 20. [0.018 s]
# [2026.01.05 21:35:34.415] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:34.426] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:34.427] INFO    Completed compilation step 16 of 20. [0.019 s]
# [2026.01.05 21:35:34.434] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:34.444] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:34.445] INFO    Completed compilation step 17 of 20. [0.018 s]
# [2026.01.05 21:35:34.452] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:34.463] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:34.464] INFO    Completed compilation step 18 of 20. [0.019 s]
# [2026.01.05 21:35:34.471] INFO    Schedule completed. [0.006 s]
# [2026.01.05 21:35:34.481] INFO    Code generation completed for all AWGs. [0.010 s]
# [2026.01.05 21:35:34.483] INFO    Completed compilation step 19 of 20. [0.018 s]
# [2026.01.05 21:35:34.489] INFO    Schedule completed. [0.007 s]
# [2026.01.05 21:35:34.501] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.01.05 21:35:34.502] INFO    Completed compilation step 20 of 20. [0.020 s]
# [2026.01.05 21:35:34.536] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.536] INFO      Step   Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.01.05 21:35:34.537] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.537] INFO      0      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.537] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.538] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.538] INFO             SHFQC_DEV12256_sg     2        114           20          19     10688
# [2026.01.05 21:35:34.538] INFO             SHFQC_DEV12256_sg     4        114           20          19     10688
# [2026.01.05 21:35:34.538] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.538] INFO      1      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.538] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.539] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.539] INFO             SHFQC_DEV12256_sg     2        114           20          19     19488
# [2026.01.05 21:35:34.539] INFO             SHFQC_DEV12256_sg     4        114           20          19     19488
# [2026.01.05 21:35:34.539] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.539] INFO      2      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.539] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.539] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.539] INFO             SHFQC_DEV12256_sg     2        114           20          19     28224
# [2026.01.05 21:35:34.540] INFO             SHFQC_DEV12256_sg     4        114           20          19     28224
# [2026.01.05 21:35:34.540] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.540] INFO      3      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.540] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.540] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.541] INFO             SHFQC_DEV12256_sg     2        114           20          19     37056
# [2026.01.05 21:35:34.541] INFO             SHFQC_DEV12256_sg     4        114           20          19     37056
# [2026.01.05 21:35:34.541] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.541] INFO      4      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.541] INFO             SHFQC_DEV12256_sg     0        133           20          18      5120
# [2026.01.05 21:35:34.541] INFO             SHFQC_DEV12256_sg     1         80           12          11      3136
# [2026.01.05 21:35:34.542] INFO             SHFQC_DEV12256_sg     2        117           21          20     48384
# [2026.01.05 21:35:34.542] INFO             SHFQC_DEV12256_sg     4        117           21          20     48384
# [2026.01.05 21:35:34.542] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.542] INFO      5      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.542] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.542] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.542] INFO             SHFQC_DEV12256_sg     2        114           20          19     54592
# [2026.01.05 21:35:34.542] INFO             SHFQC_DEV12256_sg     4        114           20          19     54592
# [2026.01.05 21:35:34.543] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.543] INFO      6      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.543] INFO             SHFQC_DEV12256_sg     0        133           20          18      5152
# [2026.01.05 21:35:34.543] INFO             SHFQC_DEV12256_sg     1         80           12          11      3136
# [2026.01.05 21:35:34.543] INFO             SHFQC_DEV12256_sg     2        117           21          20     67040
# [2026.01.05 21:35:34.543] INFO             SHFQC_DEV12256_sg     4        117           21          20     67040
# [2026.01.05 21:35:34.543] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.544] INFO      7      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.544] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.544] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.544] INFO             SHFQC_DEV12256_sg     2        114           20          19     72704
# [2026.01.05 21:35:34.544] INFO             SHFQC_DEV12256_sg     4        114           20          19     72704
# [2026.01.05 21:35:34.544] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.544] INFO      8      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.544] INFO             SHFQC_DEV12256_sg     0        133           20          18      5120
# [2026.01.05 21:35:34.544] INFO             SHFQC_DEV12256_sg     1         80           12          11      3136
# [2026.01.05 21:35:34.545] INFO             SHFQC_DEV12256_sg     2        117           21          20     85664
# [2026.01.05 21:35:34.545] INFO             SHFQC_DEV12256_sg     4        117           21          20     85664
# [2026.01.05 21:35:34.545] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.545] INFO      9      SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.545] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.545] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.545] INFO             SHFQC_DEV12256_sg     2        114           20          19     90240
# [2026.01.05 21:35:34.546] INFO             SHFQC_DEV12256_sg     4        114           20          19     90240
# [2026.01.05 21:35:34.546] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.546] INFO      10     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.546] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.546] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.546] INFO             SHFQC_DEV12256_sg     2        114           20          19     99072
# [2026.01.05 21:35:34.546] INFO             SHFQC_DEV12256_sg     4        114           20          19     99072
# [2026.01.05 21:35:34.546] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.546] INFO      11     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.547] INFO             SHFQC_DEV12256_sg     0        133           20          18      5120
# [2026.01.05 21:35:34.547] INFO             SHFQC_DEV12256_sg     1         80           12          11      3136
# [2026.01.05 21:35:34.547] INFO             SHFQC_DEV12256_sg     2        117           21          20    113664
# [2026.01.05 21:35:34.547] INFO             SHFQC_DEV12256_sg     4        117           21          20    113664
# [2026.01.05 21:35:34.547] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.547] INFO      12     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.548] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.548] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.548] INFO             SHFQC_DEV12256_sg     2        114           20          19    116640
# [2026.01.05 21:35:34.548] INFO             SHFQC_DEV12256_sg     4        114           20          19    116640
# [2026.01.05 21:35:34.548] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.548] INFO      13     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.548] INFO             SHFQC_DEV12256_sg     0        133           20          18      5152
# [2026.01.05 21:35:34.549] INFO             SHFQC_DEV12256_sg     1         80           12          11      3136
# [2026.01.05 21:35:34.549] INFO             SHFQC_DEV12256_sg     2        117           21          20    132320
# [2026.01.05 21:35:34.549] INFO             SHFQC_DEV12256_sg     4        117           21          20    132320
# [2026.01.05 21:35:34.549] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.549] INFO      14     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.549] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.549] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.549] INFO             SHFQC_DEV12256_sg     2        114           20          19    134720
# [2026.01.05 21:35:34.550] INFO             SHFQC_DEV12256_sg     4        114           20          19    134720
# [2026.01.05 21:35:34.550] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.550] INFO      15     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.550] INFO             SHFQC_DEV12256_sg     0        133           20          18      5120
# [2026.01.05 21:35:34.550] INFO             SHFQC_DEV12256_sg     1         80           12          11      3136
# [2026.01.05 21:35:34.550] INFO             SHFQC_DEV12256_sg     2        117           21          20    150944
# [2026.01.05 21:35:34.550] INFO             SHFQC_DEV12256_sg     4        117           21          20    150944
# [2026.01.05 21:35:34.551] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.551] INFO      16     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.551] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.551] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.551] INFO             SHFQC_DEV12256_sg     2        114           20          19    152288
# [2026.01.05 21:35:34.551] INFO             SHFQC_DEV12256_sg     4        114           20          19    152288
# [2026.01.05 21:35:34.551] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.551] INFO      17     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.552] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.552] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.552] INFO             SHFQC_DEV12256_sg     2        114           20          19    161088
# [2026.01.05 21:35:34.552] INFO             SHFQC_DEV12256_sg     4        114           20          19    161088
# [2026.01.05 21:35:34.552] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.552] INFO      18     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.552] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.552] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.553] INFO             SHFQC_DEV12256_sg     2        114           20          19    169824
# [2026.01.05 21:35:34.553] INFO             SHFQC_DEV12256_sg     4        114           20          19    169824
# [2026.01.05 21:35:34.553] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.553] INFO      19     SHFQC_DEV12256        0         39            0           1      4800
# [2026.01.05 21:35:34.553] INFO             SHFQC_DEV12256_sg     0        130           19          17      4832
# [2026.01.05 21:35:34.553] INFO             SHFQC_DEV12256_sg     1         77           11          10      2848
# [2026.01.05 21:35:34.554] INFO             SHFQC_DEV12256_sg     2        114           20          19    178656
# [2026.01.05 21:35:34.554] INFO             SHFQC_DEV12256_sg     4        114           20          19    178656
# [2026.01.05 21:35:34.554] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.554] INFO             TOTAL                         9552         1424               4099712
# [2026.01.05 21:35:34.554] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:35:34.569] INFO    Auto-chunked sweep divided into 20 chunks
# [2026.01.05 21:35:34.570] INFO    Finished LabOne Q Compiler run.
# [2026.01.05 21:35:34.571] INFO    Task 'compile_experiment': ended at 2026-01-05 12:35:34.570988Z
# [2026.01.05 21:35:34.665] INFO    Task 'run_experiment': started at 2026-01-05 12:35:34.665001Z
# [2026.01.05 21:35:34.785] INFO    Starting near-time execution...
# [2026.01.05 21:35:35.975] INFO    Estimated RT execution time: 25.92 s.
# [2026.01.05 21:36:01.582] INFO    Finished near-time execution.
# [2026.01.05 21:36:01.749] INFO    Task 'run_experiment': ended at 2026-01-05 12:36:01.748088Z
# [2026.01.05 21:36:01.752] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:36:01.753] INFO      Workflow 'analysis_workflow': execution started at 2026-01-05
# [2026.01.05 21:36:01.753] INFO      12:36:01.752345Z
# [2026.01.05 21:36:01.754] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:36:01.756] INFO    Task 'calculate_qubit_population': started at 2026-01-05 12:36:01.756786Z
# [2026.01.05 21:36:01.757] INFO    Task 'calculate_qubit_population': ended at 2026-01-05 12:36:01.757705Z
# [2026.01.05 21:36:01.758] INFO    Task 'fit_data': started at 2026-01-05 12:36:01.758268Z
# [2026.01.05 21:36:01.762] INFO    Task 'fit_data': ended at 2026-01-05 12:36:01.762228Z
# [2026.01.05 21:36:01.762] INFO    Task 'extract_qubit_parameters': started at 2026-01-05 12:36:01.762841Z
# [2026.01.05 21:36:01.763] INFO    Task 'extract_qubit_parameters': ended at 2026-01-05 12:36:01.763809Z
# [2026.01.05 21:36:01.764] INFO    Task 'plot_raw_complex_data_1d': started at 2026-01-05 12:36:01.764344Z
# [2026.01.05 21:36:01.776] INFO    Artifact: 'Raw_data_q0' of type 'Figure' logged at 2026-01-05 12:36:01.776507Z
# [2026.01.05 21:36:01.854] INFO    Task 'plot_raw_complex_data_1d': ended at 2026-01-05 12:36:01.854741Z
# [2026.01.05 21:36:01.855] INFO    Task 'plot_population': started at 2026-01-05 12:36:01.855468Z
# [2026.01.05 21:36:01.861] INFO    Artifact: 'Ramsey_q0' of type 'Figure' logged at 2026-01-05 12:36:01.861266Z
# [2026.01.05 21:36:01.920] INFO    Task 'plot_population': ended at 2026-01-05 12:36:01.920116Z
# [2026.01.05 21:36:01.921] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:36:01.921] INFO      Workflow 'analysis_workflow': execution ended at 2026-01-05 12:36:01.920936Z
# [2026.01.05 21:36:01.921] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:36:01.921] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.01.05 21:36:01.922] INFO      Workflow 'rip_echo': execution ended at 2026-01-05 12:36:01.921821Z
# [2026.01.05 21:36:01.922] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
# from laboneq.simple import show_pulse_sheet
# from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

# show_pulse_sheet(compiled_experiment=rip_echo_result_control_e.tasks["compile_experiment"].output,name='test', interactive=True)
# #plot_simulation(compiled_experiment=rip_result_control_e.tasks["compile_experiment"].output)

# %%
rip_echo_result_control_g.tasks['analysis_workflow'].tasks['plot_population'].output['q0']
#rip_echo_result_control_e.tasks['analysis_workflow'].tasks['plot_population'].output['q0']

# %%
rip_echo_result_control_e.tasks['analysis_workflow'].tasks['plot_population'].output['q0']

# %% [markdown]
# # RIP4
#
# q2 for mode 1
#
#
# - drive lo 5.4
# - 5.4945

# %%
qubits[2].parameters

# %%
qubits[0].parameters.readout_resonator_frequency
#qubits[1].parameters.readout_resonator_frequency

qubits[0].parameters.readout_lo_frequency = 7.4e9


qubits[4].parameters.readout_lo_frequency = 7.4e9


qubits[2]

# %%
from experiments import rip4

#q = qubits[1]
#temporary_parameters = q.parameters.copy()

#######################################################################

#######################################################################
options = rip4.experiment_workflow.options()
options.update(False)

#print(workflow.show_fields(options))

###################################################################
bus_freq = qubits[2].parameters.resonance_frequency_ge - 13e6  #45e6+26e6 
bus_amp = 0.6

bus2_freq = qubits[4].parameters.resonance_frequency_ge - 9e6  
bus2_amp = 0.0

rip_drive_controlg = rip4.experiment_workflow(
    session=session,
    qpu=qpu,
    ctrl=qubits[1],
    targ=qubits[0],
    bus=qubits[2], #mode1 
    bus2=qubits[4], #mode3 
    bus_frequency=bus_freq,
    bus_amplitude=bus_amp,
    bus2_frequency=bus2_freq,
    bus2_amplitude=bus2_amp,
    delays=np.linspace(80e-9, 1200e-9, 180),
    detunings=0,
    c_prep = "g",
    options=options 
)
rip_drive_controle = rip4.experiment_workflow(
    session=session,
    qpu=qpu,
    ctrl=qubits[1],
    targ=qubits[0],
    bus=qubits[2],
    bus2=qubits[4],
    bus_frequency=bus_freq,
    bus_amplitude=bus_amp,
    bus2_frequency=bus2_freq,
    bus2_amplitude=bus2_amp,
    delays=np.linspace(80e-9, 1200e-9, 180),
    detunings=0,
    c_prep = "e",
    options=options 
)

rip_result_control_g = rip_drive_controlg.run()
rip_result_control_e = rip_drive_controle.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
#print(drag_result.tasks['analysis_workflow'].output)

# %%
rip_data_control_g = rip_result_control_g.output
rip_data_control_e = rip_result_control_e.output

# %%
duration = rip_data_control_g.data['q0']['result'].axis[0][0]


phase_control_g = rip_data_control_g.data['q0']['result'].data
phase_control_e = rip_data_control_e.data['q0']['result'].data

# %%
import matplotlib.pyplot as plt

control_g_g_point = rip_data_control_g.data['q0']['cal_trace'].g.data
control_g_e_point = rip_data_control_g.data['q0']['cal_trace'].e.data

control_e_g_point = rip_data_control_e.data['q0']['cal_trace'].g.data
control_e_e_point = rip_data_control_e.data['q0']['cal_trace'].e.data


plt.figure(figsize=(6,6))

plt.scatter(control_g_g_point.real, control_g_g_point.imag, color="red", label="|0> reference (g)")
plt.scatter(control_g_e_point.real, control_g_e_point.imag, color="blue", label="|1> reference (e)")
plt.scatter(control_e_g_point.real, control_e_g_point.imag, color="red", label="|0> reference (g)")
plt.scatter(control_e_e_point.real, control_e_e_point.imag, color="blue", label="|1> reference (e)")

plt.axvline(x=0, color='black', linestyle='--', linewidth=0.8)
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.legend()

# %%
def normalize_population(points, g, e):
    """
    points: list or numpy array of complex numbers
    return: array of normalized values in [0,1]
    """
    points = np.array(points, dtype=complex)
    d0 = np.abs(points - g)
    d1 = np.abs(points - e)
    return d0 / (d0 + d1)

new_phase_control_g = []
new_phase_control_e = []

for i in range(len(phase_control_g)):
    # 2. Calculate the value and append it to the new row
    normalized_value = normalize_population(phase_control_g[i], control_g_g_point, control_g_e_point)
    new_phase_control_g.append(normalized_value)
for k in range(len(phase_control_e)):
    # 2. Calculate the value and append it to the new row
    normalized_value = normalize_population(phase_control_e[k], control_e_g_point, control_e_e_point)
    new_phase_control_e.append(normalized_value)
# 3. Append the completed row to the main population list

population_control_g = new_phase_control_g
population_control_e = new_phase_control_e
plt.figure(figsize=(8,6))
plt.plot(duration, population_control_g, color="#ff5500", label = r'control: |g>')
plt.plot(duration, population_control_e, color="#0055aa", label = r'control: |e>')
plt.ylim([-0.1,1.1])
plt.xlabel("RIP duration (s)", fontsize=16)
plt.ylabel("population", fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.legend(fontsize=14)

# %% [markdown]
# # RIP5

# %%
# from experiments import rip5

# #q = qubits[1]
# #temporary_parameters = q.parameters.copy()

# #######################################################################

# #######################################################################
# options = rip5.experiment_workflow.options()
# options.update(False)

# #print(workflow.show_fields(options))

# ###################################################################
# bus_freq = qubits[2].parameters.resonance_frequency_ge - 20e6#45e6+26e6 
# bus_amp = 1.0

# bus2_freq = qubits[4].parameters.resonance_frequency_ge - 9e6  
# bus2_amp = 0.0

# rip_drive_controlg = rip5.experiment_workflow(
#     session=session,
#     qpu=qpu,
#     ctrl=qubits[1],
#     targ=qubits[0],
#     bus=qubits[2], #mode1 
#     bus2=qubits[4], #mode3 
#     bus_frequency=bus_freq,
#     bus_amplitude=bus_amp,
#     bus2_frequency=bus2_freq,
#     bus2_amplitude=bus2_amp,
#     delays=np.linspace(800e-9, 5000e-9, 301),
#     detunings=-22e6,
#     c_prep = "g",
#     options=options 
# )
# # rip_drive_controle = rip5.experiment_workflow(
# #     session=session,
# #     qpu=qpu,
# #     ctrl=qubits[1],
# #     targ=qubits[0],
# #     bus=qubits[2],
# #     bus2=qubits[4],
# #     bus_frequency=bus_freq,
# #     bus_amplitude=bus_amp,
# #     bus2_frequency=bus2_freq,
# #     bus2_amplitude=bus2_amp,
# #     delays=np.linspace(300e-9, 1500e-9, 145),
# #     detunings=0,
# #     c_prep = "e",
# #     options=options 
# # )

# rip5_result_control_g = rip_drive_controlg.run()
# #rip5_result_control_e = rip_drive_controle.run()
# #qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
# #print(drag_result.tasks['analysis_workflow'].output)

# %%
rip5_result_control_g.tasks['analysis_workflow'].tasks['plot_population'].output['q0']

# %%
rip5_result_control_e.tasks['analysis_workflow'].tasks['plot_population'].output['q0']

# %%
g_freq = rip5_result_control_g.tasks['analysis_workflow'].output['new_parameter_values']['q0']['resonance_frequency_ge']
e_freq = rip5_result_control_e.tasks['analysis_workflow'].output['new_parameter_values']['q0']['resonance_frequency_ge']
old_g_freq = rip5_result_control_g.tasks['analysis_workflow'].output['old_parameter_values']['q0']['resonance_frequency_ge']
old_e_freq = rip5_result_control_e.tasks['analysis_workflow'].output['old_parameter_values']['q0']['resonance_frequency_ge']

detun_g = g_freq - old_g_freq
detun_e = e_freq - old_e_freq

detune = (detun_g+detun_e )/2 
detune #= -8114780.064202309

# %%
detun_g = g_freq - old_g_freq
detun_e = e_freq - old_e_freq


detune = (detun_g+detun_e )/2 
detune #= -8114780.064202309

# %%
from laboneq.simple import show_pulse_sheet
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

show_pulse_sheet(compiled_experiment=rip5_result_control_e.tasks["compile_experiment"].output,name='test', interactive=True)
#plot_simulation(compiled_experiment=rip5_result_control_e.tasks["compile_experiment"].output)

# %% [markdown]
# # SAVE

# %%
from helper import load_qubit_parameters, save_qubit_parameters
save_qubit_parameters(qubits={ qubit.uid : qubit for qubit in qubits}, save_folder="./qubit_parameters/", filename="sample2")
