# %%
import numpy as np
from pprint import pprint
from copy import deepcopy


from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
#from laboneq.contrib.example_helpers.generate_device_setup import generate_device_setup
from laboneq.dsl.device import DeviceSetup
from laboneq.simple import *
from laboneq.dsl.device import DeviceSetup
from laboneq.dsl.calibration import Oscillator, SignalCalibration
from laboneq.dsl.enums import ModulationType




# descriptor = generate_descriptor(
#     #pqsc=[""], # 장비 여러개 사용시
#     shfqc_6=["DEV12256"],
#     number_data_qubits=3,
#     multiplex=True,
#     number_multiplex=6,
#     include_cr_lines=False,
#     include_ef_lines=True,
#     get_zsync=False,  # Only set to True when using real device
#     save = True,
#     filename="1port",
#     ip_address="192.168.0.83"
# )


#descriptor
#setup = DeviceSetup.from_descriptor(yaml_text=descriptor, server_host="192.168.0.83")
setup = DeviceSetup.from_yaml(filepath="/Users/yalgaeahn/JSAHN/qubit-experiment/examples/selectiveRIP/Descriptors/1port.yaml" , server_host="192.168.0.83")
#setup
setup.instruments[0].device_options = 'SHFQC/PLUS/QC6CH'
#setup.instruments

# %%
bus_ids = [f"b{i}" for i in range(3)]
bus_port = [4,5,6] #used 1,2,3 for qubit drive

for i, bus in zip(bus_port,bus_ids):
    setup.add_connections(
        setup.instruments[0].uid,
        # each bus uses its own drive:
        create_connection(
            to_signal=f"{bus}/drive",
            ports=f"SGCHANNELS/{i}/OUTPUT"
        ))

# Calibrate qubit drive/measure lines for oscillator phase increments
qubit_ids = [uid for uid in setup.logical_signal_groups if uid.startswith("q")]
for qubit in qubit_ids:
    for line, frequency, mod_type in [
        ("drive", 5e9, ModulationType.HARDWARE),
        ("drive_ef", 6e9, ModulationType.HARDWARE),
        ("measure", 4e9, ModulationType.SOFTWARE),
    ]:
        logical_signal = setup.logical_signal_by_uid(f"{qubit}/{line}")
        oscillator = Oscillator(modulation_type=mod_type)
        logical_signal.calibration = SignalCalibration(
            local_oscillator=Oscillator(frequency=frequency),
            oscillator=oscillator,
        )
        if line == "measure":
            acquire_signal = setup.logical_signal_by_uid(f"{qubit}/acquire")
            acquire_signal.calibration = SignalCalibration(
                local_oscillator=Oscillator(frequency=frequency),
                oscillator=oscillator,
            )

# %%
from qpu_types.fixed_transmon import FixedTransmonQubit, FixedTransmonQubitParameters
from qpu_types.bus_cavity import BusCavity, BusCavityParameters
from qpu_types.fixed_transmon.operations import FixedTransmonOperations
from qpu_types.bus_cavity.operations import BusCavityOperations
from laboneq.dsl.quantum.qpu import QPU, QuantumPlatform
from helper import load_qubit_parameters, save_qubit_parameters

qubit_uids = [uid for uid in setup.logical_signal_groups if uid.startswith("q")]
bus_uids = [uid for uid in setup.logical_signal_groups if uid.startswith("b")]

qubits = FixedTransmonQubit.from_device_setup(
    setup, qubit_uids=qubit_uids)
buses = BusCavity.from_device_setup(
    setup, qubit_uids=bus_uids)

qpu = QPU(quantum_elements={"qubits" : qubits, "bus" : buses}, quantum_operations=[FixedTransmonOperations, BusCavityOperations])


# from laboneq.simple import workflow
# folder_store = workflow.logbook.FolderStore("./experiment_store") 
# folder_store.activate()
# #folder_store.deactivate()
# #workflow.logbook.LoggingStore().activate()
# #workflow.logbook.LogbookStore().deactivate()

# %% [markdown]
# # LOAD QPU

# %%
import os
from datetime import datetime
def find_latest_json(folder_path):
    files = [f for f in os.listdir(folder_path)]
    timestamps = []
    for file in files:
        try:
            # Extract a timestamp assuming it's included in the filename
            timestamp_str = file.split('_', 1)[0]  # Assuming YYYYMMDDHHMMSS format
            timestamp = datetime.strptime(timestamp_str, '%Y%m%d-%H%M%S')
            timestamps.append((timestamp, file))
        except ValueError:
            print("fuck")
            continue  # Skip files that do not match the timestamp format

       # Find the most recent file
    if timestamps:
        latest_file = max(timestamps, key=lambda x: x[0])[1]
        return os.path.join(folder_path, latest_file)
    return None

qb_pars_file = find_latest_json("./qpu_parameters/")
print(f"LOADED: {qb_pars_file}")

from qpu_types.fixed_transmon.operations import FixedTransmonOperations
from qpu_types.bus_cavity.operations import BusCavityOperations
import laboneq.dsl.quantum.qpu as qpu_mod

class CombinedOperations(FixedTransmonOperations, BusCavityOperations):
    pass

qpu_mod.CombinedOperations = CombinedOperations

qpu = load(qb_pars_file)

buses = qpu.groups.bus
qubits = qpu.groups.qubits
# Out:
# fuck
# LOADED: ./qpu_parameters/20260116-1729_multiplexing_test

# %% [markdown]
# # Connection

# %%
from laboneq.simple import Session
session = Session(setup)
session.connect(ignore_version_mismatch=False, do_emulation=True)
#session.disconnect()
# Out:
# [2026.02.01 15:36:13.254] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /Users/yalgaeahn/JSAHN/qubit-experiment/examples/selectiveRIP/laboneq_output/log
# [2026.02.01 15:36:13.257] INFO    VERSION: laboneq 25.10.3
# [2026.02.01 15:36:13.259] INFO    Connecting to data server at 192.168.0.83:8004
# [2026.02.01 15:36:13.261] INFO    Connected to Zurich Instruments LabOne Data Server version 25.10.1.4 at 192.168.0.83:8004
# [2026.02.01 15:36:13.264] INFO    Configuring the device setup
# [2026.02.01 15:36:13.267] INFO    The device setup is configured

# %% [markdown]
# # Ramsey Echo

# %%
from experiments import echo 

q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temporary_parameters[q.uid] = temp_pars
#######################################################################
delays = np.linspace(0,20e-6,301)
detunings = 0.5e6,
pprint(q.readout_parameters())
#######################################################################
options = echo.experiment_workflow.options()
options.update(False)
options.count(1024)
options.use_cal_traces(True)
# Build and run Ramsey workflow (no explicit command table options required)
ramsey_wf = echo.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    delays=delays,
    #detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)
ramsey_result = ramsey_wf.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(ramsey_result.tasks['analysis_workflow'].output)
ramsey_result.tasks['analysis_workflow'].tasks['plot_population'].output['q1']

# %% [markdown]
# # Ramsey

# %%
from laboneq_applications.experiments import ramsey

q = qubits[1]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
#temp_pars.readout_integration_length= 1e-6
temporary_parameters[q.uid] = temp_pars
#######################################################################
delays = np.linspace(0,5e-6,301)
detunings = 2e6 #4e6,
pprint(q.readout_parameters())
#######################################################################
options = ramsey.experiment_workflow.options()
options.update(False)
options.count(512)
options.use_cal_traces(True)
# Build and run Ramsey workflow (no explicit command table options required)
ramsey_wf = ramsey.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    delays=delays,
    detunings=detunings,
    options=options,
    temporary_parameters=temporary_parameters
)
ramsey_result = ramsey_wf.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(ramsey_result.tasks['analysis_workflow'].output)
#ramsey_result.tasks['analysis_workflow'].tasks['plot_population'].output['q0']

# %%
qubits[0].parameters.resonance_frequency_ge

# %% [markdown]
# # Power calculation

# %%
from helper import adjust_amplitude_for_output_range, calculate_power
#adjust_amplitude_for_output_range(initial_output_dbm=0, initial_amplitude= 0.002, new_output_dbm=-5)
calculate_power(output_dbm=10, amplitude=0.004,attenuation=[])

# %% [markdown]
# # Coherence Spectroscopy
#
# ECHO 제거함

# %%
qubits[4].parameters.resonance_frequency_ge = 6.4203e9 #mode3
qubits[2].parameters.resonance_frequency_ge = 5.4947e9 #mode1

qubits[2].parameters.readout_integration_delay = 320e-9

# %%
from experiments import coherence_spectroscopy


####################################################################################
q=qubits[1]
b=buses[0]
temporary_parameters = {}
q_temp_pars =deepcopy(q.parameters)
q_temp_pars.readout_amplitude = 0.4
q_temp_pars.readout_integration_length =1.2e-6
b_temp_pars =deepcopy(b.parameters)
#b_temp_pars.readout_integration_length =1e-6
b_temp_pars.rip_length = 10e-6
# b_temp_pars.drive_lo_frequency = 6.0e9
temporary_parameters[q.uid] = q_temp_pars
temporary_parameters[b.uid] = b_temp_pars

print(q.readout_parameters())

#####################################################################################
options = coherence_spectroscopy.experiment_workflow.options()
#workflow.show_fields(options)
options.count(256)
options.update(False)
options.do_analysis(True)
options.ring_up(10e-6)
options.ring_down(100e-9)

######################################################################################
# Build and run resonator_spectroscopy_amplitude wormflow
co_spec = coherence_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=q,
    bus= b,
    delays=np.linspace(0,20e-6,51), #delays=np.linspace(0,5e-6,21), 포인트 확보 중요
    CW_frequencies= b.parameters.resonance_frequency_bus+np.linspace(-1.0e6,1.0e6,11),
    #CW_frequencies= 5.5555e9 +np.linspace(-0.6e6,0.6e6,101),
    CW_amplitude=0.0018,
    CW_phase=0.0,
    detunings=0.4e6,
    temporary_parameters=temporary_parameters,
    options=options
)
co_spec_result = co_spec.run()
#co_spec_analysis_result = co_spec_result.tasks["analysis_workflow"]
# Out:
# ('measure', {'amplitude': 0.5, 'length': 1e-06, 'pulse': {'function': 'GaussianSquare', 'risefall_sigma_ratio': 3.0, 'sigma': 0.2}})
# [2026.02.01 15:44:50.707] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:50.708] INFO      Workflow 'coherence_spectroscopy': execution started at 2026-02-01
# [2026.02.01 15:44:50.708] INFO      06:44:50.706934Z
# [2026.02.01 15:44:50.708] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:50.709] INFO    Task 'temporary_qpu': started at 2026-02-01 06:44:50.709029Z
# [2026.02.01 15:44:50.710] INFO    Task 'temporary_qpu': ended at 2026-02-01 06:44:50.709932Z
# [2026.02.01 15:44:50.710] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-02-01
# [2026.02.01 15:44:50.710] INFO    06:44:50.710399Z
# [2026.02.01 15:44:50.711] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-02-01 06:44:50.711190Z
# [2026.02.01 15:44:50.711] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-02-01
# [2026.02.01 15:44:50.712] INFO    06:44:50.711683Z
# [2026.02.01 15:44:50.713] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-02-01 06:44:50.713109Z
# [2026.02.01 15:44:50.714] INFO    Task 'create_experiment': started at 2026-02-01 06:44:50.713887Z
# [2026.02.01 15:44:50.715] INFO    Task 'create_experiment': ended at 2026-02-01 06:44:50.715800Z
# [2026.02.01 15:44:50.716] INFO    Task 'compile_experiment': started at 2026-02-01 06:44:50.716461Z
# [2026.02.01 15:44:50.718] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.02.01 15:44:50.719] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal 'q1/acquire' to SOFTWARE
# [2026.02.01 15:44:50.719] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal 'q1/drive' to HARDWARE
# [2026.02.01 15:44:50.719] INFO    Resolved modulation type of oscillator 'q1_drive_ef_osc' on signal 'q1/drive_ef' to HARDWARE
# [2026.02.01 15:44:50.720] INFO    Starting LabOne Q Compiler run...
# [2026.02.01 15:44:51.653] INFO    Schedule completed. [0.931 s]
# [2026.02.01 15:44:51.767] INFO    Code generation completed for all AWGs. [0.113 s]
# [2026.02.01 15:44:51.767] INFO    Completed compilation step 1 of 1. [1.046 s]
# [2026.02.01 15:44:51.769] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:51.769] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.02.01 15:44:51.769] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:51.770] INFO      SHFQC_DEV12256        0       1247            0           1      4000
# [2026.02.01 15:44:51.770] INFO      SHFQC_DEV12256_sg     0       1748           28           1       256
# [2026.02.01 15:44:51.770] INFO      SHFQC_DEV12256_sg     4       1143          103         102    832288
# [2026.02.01 15:44:51.770] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:51.770] INFO      TOTAL                         4138          131                836544
# [2026.02.01 15:44:51.771] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:51.812] INFO    Schedule completed. [0.009 s]
# [2026.02.01 15:44:51.820] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.02.01 15:44:51.821] INFO    Completed compilation step 1 of 17. [0.017 s]
# [2026.02.01 15:44:51.829] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:51.837] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.02.01 15:44:51.838] INFO    Completed compilation step 2 of 17. [0.017 s]
# [2026.02.01 15:44:51.846] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:51.854] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.02.01 15:44:51.854] INFO    Completed compilation step 3 of 17. [0.016 s]
# [2026.02.01 15:44:51.862] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:51.870] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.02.01 15:44:51.870] INFO    Completed compilation step 4 of 17. [0.016 s]
# [2026.02.01 15:44:51.878] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:51.886] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.02.01 15:44:51.887] INFO    Completed compilation step 5 of 17. [0.016 s]
# [2026.02.01 15:44:51.895] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:51.902] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.02.01 15:44:51.903] INFO    Completed compilation step 6 of 17. [0.016 s]
# [2026.02.01 15:44:51.911] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:51.919] INFO    Code generation completed for all AWGs. [0.007 s]
# [2026.02.01 15:44:51.919] INFO    Completed compilation step 7 of 17. [0.016 s]
# [2026.02.01 15:44:51.927] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:51.935] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.02.01 15:44:51.936] INFO    Completed compilation step 8 of 17. [0.016 s]
# [2026.02.01 15:44:51.944] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:51.955] INFO    Code generation completed for all AWGs. [0.011 s]
# [2026.02.01 15:44:51.956] INFO    Completed compilation step 9 of 17. [0.020 s]
# [2026.02.01 15:44:52.068] INFO    Schedule completed. [0.112 s]
# [2026.02.01 15:44:52.076] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.02.01 15:44:52.076] INFO    Completed compilation step 10 of 17. [0.121 s]
# [2026.02.01 15:44:52.085] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:52.094] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.02.01 15:44:52.094] INFO    Completed compilation step 11 of 17. [0.017 s]
# [2026.02.01 15:44:52.102] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:52.111] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.02.01 15:44:52.111] INFO    Completed compilation step 12 of 17. [0.017 s]
# [2026.02.01 15:44:52.120] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:52.128] INFO    Code generation completed for all AWGs. [0.008 s]
# [2026.02.01 15:44:52.129] INFO    Completed compilation step 13 of 17. [0.017 s]
# [2026.02.01 15:44:52.137] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:52.146] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.02.01 15:44:52.147] INFO    Completed compilation step 14 of 17. [0.017 s]
# [2026.02.01 15:44:52.155] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:52.164] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.02.01 15:44:52.165] INFO    Completed compilation step 15 of 17. [0.018 s]
# [2026.02.01 15:44:52.173] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:52.182] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.02.01 15:44:52.182] INFO    Completed compilation step 16 of 17. [0.018 s]
# [2026.02.01 15:44:52.191] INFO    Schedule completed. [0.008 s]
# [2026.02.01 15:44:52.200] INFO    Code generation completed for all AWGs. [0.009 s]
# [2026.02.01 15:44:52.201] INFO    Completed compilation step 17 of 17. [0.018 s]
# [2026.02.01 15:44:52.212] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.212] INFO      Step   Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.02.01 15:44:52.213] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.213] INFO      0      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.213] INFO             SHFQC_DEV12256_sg     0        116            6           1       256
# [2026.02.01 15:44:52.213] INFO             SHFQC_DEV12256_sg     4         87            7           6     25888
# [2026.02.01 15:44:52.214] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.214] INFO      1      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.214] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.214] INFO             SHFQC_DEV12256_sg     4         87            7           6     28832
# [2026.02.01 15:44:52.215] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.215] INFO      2      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.215] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.215] INFO             SHFQC_DEV12256_sg     4         87            7           6     31648
# [2026.02.01 15:44:52.215] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.215] INFO      3      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.216] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.216] INFO             SHFQC_DEV12256_sg     4         87            7           6     34592
# [2026.02.01 15:44:52.216] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.216] INFO      4      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.216] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.217] INFO             SHFQC_DEV12256_sg     4         87            7           6     37408
# [2026.02.01 15:44:52.217] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.217] INFO      5      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.217] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.217] INFO             SHFQC_DEV12256_sg     4         87            7           6     40352
# [2026.02.01 15:44:52.218] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.218] INFO      6      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.218] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.218] INFO             SHFQC_DEV12256_sg     4         87            7           6     43168
# [2026.02.01 15:44:52.218] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.218] INFO      7      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.219] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.219] INFO             SHFQC_DEV12256_sg     4         87            7           6     46112
# [2026.02.01 15:44:52.219] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.219] INFO      8      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.219] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.219] INFO             SHFQC_DEV12256_sg     4         87            7           6     48928
# [2026.02.01 15:44:52.219] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.220] INFO      9      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.220] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.220] INFO             SHFQC_DEV12256_sg     4         87            7           6     51872
# [2026.02.01 15:44:52.220] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.220] INFO      10     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.220] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.221] INFO             SHFQC_DEV12256_sg     4         87            7           6     54688
# [2026.02.01 15:44:52.221] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.221] INFO      11     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.221] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.221] INFO             SHFQC_DEV12256_sg     4         87            7           6     57632
# [2026.02.01 15:44:52.221] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.222] INFO      12     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.222] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.222] INFO             SHFQC_DEV12256_sg     4         87            7           6     60448
# [2026.02.01 15:44:52.222] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.222] INFO      13     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.223] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.223] INFO             SHFQC_DEV12256_sg     4         87            7           6     63392
# [2026.02.01 15:44:52.223] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.223] INFO      14     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.223] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.223] INFO             SHFQC_DEV12256_sg     4         87            7           6     66208
# [2026.02.01 15:44:52.224] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.224] INFO      15     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.224] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.224] INFO             SHFQC_DEV12256_sg     4         87            7           6     69152
# [2026.02.01 15:44:52.224] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.224] INFO      16     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:44:52.225] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:44:52.225] INFO             SHFQC_DEV12256_sg     4         87            7           6     71968
# [2026.02.01 15:44:52.225] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.225] INFO             TOTAL                         5226          221                904640
# [2026.02.01 15:44:52.225] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.245] INFO    Auto-chunked sweep divided into 17 chunks
# [2026.02.01 15:44:52.247] INFO    Finished LabOne Q Compiler run.
# [2026.02.01 15:44:52.247] INFO    Task 'compile_experiment': ended at 2026-02-01 06:44:52.247361Z
# [2026.02.01 15:44:52.247] INFO    Task 'run_experiment': started at 2026-02-01 06:44:52.247761Z
# [2026.02.01 15:44:52.251] INFO    Starting near-time execution...
# [2026.02.01 15:44:52.266] INFO    Estimated RT execution time: 19.73 s.
# [2026.02.01 15:44:52.277] INFO    Finished near-time execution.
# [2026.02.01 15:44:52.293] INFO    Task 'run_experiment': ended at 2026-02-01 06:44:52.293193Z
# [2026.02.01 15:44:52.293] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.294] INFO      Workflow 'analysis_workflow': execution started at 2026-02-01
# [2026.02.01 15:44:52.294] INFO      06:44:52.293691Z
# [2026.02.01 15:44:52.294] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.295] INFO    Task 'calculate_qubit_population_2d': started at 2026-02-01 06:44:52.294909Z
# [2026.02.01 15:44:52.295] INFO    Task 'calculate_qubit_population_2d': ended at 2026-02-01 06:44:52.295513Z
# [2026.02.01 15:44:52.295] INFO    Task 'fit_data': started at 2026-02-01 06:44:52.295859Z
# [2026.02.01 15:44:52.366] INFO    Task 'fit_data': ended at 2026-02-01 06:44:52.366467Z
# [2026.02.01 15:44:52.367] INFO    Task 'extract_qubit_parameters': started at 2026-02-01 06:44:52.367109Z
# [2026.02.01 15:44:52.367] INFO    Task 'extract_qubit_parameters': ended at 2026-02-01 06:44:52.367641Z
# [2026.02.01 15:44:52.368] INFO    Task 'fit_mid_rate_data': started at 2026-02-01 06:44:52.367963Z
# [2026.02.01 15:44:52.371] INFO    Task 'fit_mid_rate_data': ended at 2026-02-01 06:44:52.371582Z
# [2026.02.01 15:44:52.372] INFO    Task 'plot_raw_iq_heatmap_2d': started at 2026-02-01 06:44:52.372018Z
# [2026.02.01 15:44:52.384] INFO    Task 'plot_raw_iq_heatmap_2d': ended at 2026-02-01 06:44:52.384079Z
# [2026.02.01 15:44:52.384] INFO    Task 'plot_population_heatmap_2d': started at 2026-02-01 06:44:52.384563Z
# [2026.02.01 15:44:52.390] INFO    Task 'plot_population_heatmap_2d': ended at 2026-02-01 06:44:52.389932Z
# [2026.02.01 15:44:52.390] INFO    Task 'plot_population': started at 2026-02-01 06:44:52.390455Z
# [2026.02.01 15:44:52.395] INFO    Artifact: 'Ramsey_q1' of type 'Figure' logged at 2026-02-01 06:44:52.394952Z
# [2026.02.01 15:44:52.395] INFO    Task 'plot_population': ended at 2026-02-01 06:44:52.395468Z
# [2026.02.01 15:44:52.395] INFO    Task 'plot_t2_star_vs_frequency': started at 2026-02-01 06:44:52.395820Z
# [2026.02.01 15:44:52.400] INFO    Task 'plot_t2_star_vs_frequency': ended at 2026-02-01 06:44:52.399974Z
# [2026.02.01 15:44:52.400] INFO    Task 'plot_MID_rate_vs_frequency': started at 2026-02-01 06:44:52.400433Z
# [2026.02.01 15:44:52.404] INFO    Task 'plot_MID_rate_vs_frequency': ended at 2026-02-01 06:44:52.404417Z
# [2026.02.01 15:44:52.404] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.405] INFO      Workflow 'analysis_workflow': execution ended at 2026-02-01 06:44:52.404810Z
# [2026.02.01 15:44:52.405] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.405] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:44:52.406] INFO      Workflow 'coherence_spectroscopy': execution ended at 2026-02-01
# [2026.02.01 15:44:52.406] INFO      06:44:52.405757Z
# [2026.02.01 15:44:52.406] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
co_spec_analysis_result = co_spec_result.tasks["analysis_workflow"]
fit = co_spec_analysis_result.tasks['fit_mid_rate_data'].output['q1']
fit.best_values
# Out:
# {'kappa': 726157.7622190354,
#  'chi': 921432.660761669,
#  'epsilon_rf': 2.6094008429877014,
#  'bare_freq': 5494484245.151458}

# %%
from laboneq.simple import show_pulse_sheet
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

#show_pulse_sheet(compiled_experiment=co_spec_result.tasks["compile_experiment"].output,name='test', interactive=True)
plot_simulation(compiled_experiment=co_spec_result.tasks["compile_experiment"].output, length=20e-6)

# %% [markdown]
# # Checking power dependece

# %%
from experiments import coherence_spectroscopy


####################################################################################
q=qubits[1]
b=buses[0]
temporary_parameters = {}
q_temp_pars =deepcopy(q.parameters)
q_temp_pars.readout_amplitude = 0.4
q_temp_pars.readout_integration_length =1.2e-6
b_temp_pars =deepcopy(b.parameters)
#b_temp_pars.readout_integration_length =1e-6
b_temp_pars.rip_length = 10e-6
# b_temp_pars.drive_lo_frequency = 6.0e9
temporary_parameters[q.uid] = q_temp_pars
temporary_parameters[b.uid] = b_temp_pars

print(q.readout_parameters())

#####################################################################################
options = coherence_spectroscopy.experiment_workflow.options()
#workflow.show_fields(options)
options.count(256)
options.update(False)
options.do_analysis(True)
options.ring_up(10e-6)
options.ring_down(100e-9)

######################################################################################
# Build and run resonator_spectroscopy_amplitude wormflow

#EXample
CW_amps = [0.0014,0.0016,0.0018]

chis=[]
kappas=[]
epsilons=[]
frs=[]

for CW_amp in CW_amps: 
    co_spec = coherence_spectroscopy.experiment_workflow(
        session=session,
        qpu=qpu,
        qubit=q,
        bus= b,
        delays=np.linspace(0,20e-6,51), #delays=np.linspace(0,5e-6,21), 포인트 확보 중요
        CW_frequencies= b.parameters.resonance_frequency_bus+np.linspace(-1.0e6,1.0e6,201),
        #CW_frequencies= 5.5555e9 +np.linspace(-0.6e6,0.6e6,101),
        CW_amplitude=0.0018,
        CW_phase=0.0,
        detunings=0.4e6,
        temporary_parameters=temporary_parameters,
        options=options
    )
    co_spec_result = co_spec.run()
    co_spec_analysis_result = co_spec_result.tasks["analysis_workflow"]
    co_spec_analysis_result = co_spec_result.tasks["analysis_workflow"]
    fit = co_spec_analysis_result.tasks['fit_mid_rate_data'].output['q1']
    kappas.append(fit.best_values['kappa'])
    chis.append(fit.best_values['chi'])
    epsilons.append(fit.best_values['epsilon_rf'])
    frs.append(fit.best_values['bare_freq'])

# %%
import numpy as np
import matplotlib.pyplot as plt

CW_amps = np.array([0.0014, 0.0016, 0.0018])

results = {k: {"val": [], "err": []} for k in ["kappa","chi","epsilon_rf","bare_freq"]}

for CW_amp in CW_amps:
    co_spec = coherence_spectroscopy.experiment_workflow(
        session=session,
        qpu=qpu,
        qubit=q,
        bus=b,
        delays=np.linspace(0, 20e-6, 51),
        CW_frequencies=b.parameters.resonance_frequency_bus + np.linspace(-1.0e6, 1.0e6, 201),
        CW_amplitude=CW_amp,   # <-- 
        CW_phase=0.0,
        detunings=0.4e6,
        temporary_parameters=temporary_parameters,
        options=options
    )
    co_spec_result = co_spec.run()
    fit = co_spec_result.tasks["analysis_workflow"].tasks["fit_mid_rate_data"].output["q1"]

    # fit 실패 대비
    if fit is None:
        for k in results:
            results[k]["val"].append(np.nan)
            results[k]["err"].append(np.nan)
        continue

    for k in results:
        p = fit.params[k]
        results[k]["val"].append(p.value)
        results[k]["err"].append(p.stderr if p.stderr is not None else np.nan)

# plot (4개 파라미터)
fig, axes = plt.subplots(2, 2, figsize=(8,6), sharex=True)
axes = axes.ravel()
for ax, k in zip(axes, ["kappa","chi","epsilon_rf","bare_freq"]):
    ax.errorbar(CW_amps, results[k]["val"], yerr=results[k]["err"], fmt="o-", capsize=3)
    ax.set_title(k)
    ax.set_xlabel("CW amplitude")
    ax.set_ylabel(k)
plt.tight_layout()
# Out:
# [2026.02.01 15:57:55.067] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:57:55.069] INFO      Workflow 'coherence_spectroscopy': execution started at 2026-02-01
# [2026.02.01 15:57:55.070] INFO      06:57:55.067522Z
# [2026.02.01 15:57:55.070] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:57:55.071] INFO    Task 'temporary_qpu': started at 2026-02-01 06:57:55.070830Z
# [2026.02.01 15:57:55.071] INFO    Task 'temporary_qpu': ended at 2026-02-01 06:57:55.071775Z
# [2026.02.01 15:57:55.072] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-02-01
# [2026.02.01 15:57:55.073] INFO    06:57:55.072504Z
# [2026.02.01 15:57:55.073] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-02-01 06:57:55.073359Z
# [2026.02.01 15:57:55.074] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-02-01
# [2026.02.01 15:57:55.074] INFO    06:57:55.073885Z
# [2026.02.01 15:57:55.075] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-02-01 06:57:55.075004Z
# [2026.02.01 15:57:55.075] INFO    Task 'create_experiment': started at 2026-02-01 06:57:55.075702Z
# [2026.02.01 15:57:55.077] INFO    Task 'create_experiment': ended at 2026-02-01 06:57:55.077360Z
# [2026.02.01 15:57:55.078] INFO    Task 'compile_experiment': started at 2026-02-01 06:57:55.077938Z
# [2026.02.01 15:57:55.080] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.02.01 15:57:55.081] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal 'q1/acquire' to SOFTWARE
# [2026.02.01 15:57:55.081] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal 'q1/drive' to HARDWARE
# [2026.02.01 15:57:55.081] INFO    Resolved modulation type of oscillator 'q1_drive_ef_osc' on signal 'q1/drive_ef' to HARDWARE
# [2026.02.01 15:57:55.082] INFO    Starting LabOne Q Compiler run...
# [2026.02.01 15:57:58.586] INFO    Schedule completed. [3.502 s]
# [2026.02.01 15:58:00.054] INFO    Code generation completed for all AWGs. [1.468 s]
# [2026.02.01 15:58:00.055] INFO    Completed compilation step 1 of 1. [4.971 s]
# [2026.02.01 15:58:00.057] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:00.057] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.02.01 15:58:00.057] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:00.057] INFO      SHFQC_DEV12256        0       1247            0           1      4000
# [2026.02.01 15:58:00.058] INFO      SHFQC_DEV12256_sg     0       1748           28           1       256
# [2026.02.01 15:58:00.058] INFO      SHFQC_DEV12256_sg     4       1143          103         102    832288
# [2026.02.01 15:58:00.058] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:00.058] INFO      TOTAL                         4138          131                836544
# [2026.02.01 15:58:00.058] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:00.222] INFO    Schedule completed. [0.132 s]
# [2026.02.01 15:58:00.289] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:00.289] INFO    Completed compilation step 1 of 17. [0.200 s]
# [2026.02.01 15:58:00.423] INFO    Schedule completed. [0.133 s]
# [2026.02.01 15:58:00.488] INFO    Code generation completed for all AWGs. [0.065 s]
# [2026.02.01 15:58:00.489] INFO    Completed compilation step 2 of 17. [0.199 s]
# [2026.02.01 15:58:01.477] INFO    Schedule completed. [0.988 s]
# [2026.02.01 15:58:01.544] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:01.545] INFO    Completed compilation step 3 of 17. [1.056 s]
# [2026.02.01 15:58:01.800] INFO    Schedule completed. [0.254 s]
# [2026.02.01 15:58:01.864] INFO    Code generation completed for all AWGs. [0.065 s]
# [2026.02.01 15:58:01.865] INFO    Completed compilation step 4 of 17. [0.320 s]
# [2026.02.01 15:58:01.995] INFO    Schedule completed. [0.129 s]
# [2026.02.01 15:58:02.203] INFO    Code generation completed for all AWGs. [0.208 s]
# [2026.02.01 15:58:02.204] INFO    Completed compilation step 5 of 17. [0.338 s]
# [2026.02.01 15:58:02.336] INFO    Schedule completed. [0.132 s]
# [2026.02.01 15:58:02.404] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:02.405] INFO    Completed compilation step 6 of 17. [0.201 s]
# [2026.02.01 15:58:02.708] INFO    Schedule completed. [0.303 s]
# [2026.02.01 15:58:02.774] INFO    Code generation completed for all AWGs. [0.066 s]
# [2026.02.01 15:58:02.775] INFO    Completed compilation step 7 of 17. [0.370 s]
# [2026.02.01 15:58:02.908] INFO    Schedule completed. [0.133 s]
# [2026.02.01 15:58:02.975] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:02.976] INFO    Completed compilation step 8 of 17. [0.201 s]
# [2026.02.01 15:58:03.309] INFO    Schedule completed. [0.333 s]
# [2026.02.01 15:58:03.378] INFO    Code generation completed for all AWGs. [0.069 s]
# [2026.02.01 15:58:03.379] INFO    Completed compilation step 9 of 17. [0.403 s]
# [2026.02.01 15:58:03.512] INFO    Schedule completed. [0.133 s]
# [2026.02.01 15:58:03.582] INFO    Code generation completed for all AWGs. [0.069 s]
# [2026.02.01 15:58:03.583] INFO    Completed compilation step 10 of 17. [0.203 s]
# [2026.02.01 15:58:03.948] INFO    Schedule completed. [0.365 s]
# [2026.02.01 15:58:04.016] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:04.017] INFO    Completed compilation step 11 of 17. [0.434 s]
# [2026.02.01 15:58:04.151] INFO    Schedule completed. [0.134 s]
# [2026.02.01 15:58:04.218] INFO    Code generation completed for all AWGs. [0.066 s]
# [2026.02.01 15:58:04.218] INFO    Completed compilation step 12 of 17. [0.201 s]
# [2026.02.01 15:58:04.356] INFO    Schedule completed. [0.138 s]
# [2026.02.01 15:58:04.423] INFO    Code generation completed for all AWGs. [0.066 s]
# [2026.02.01 15:58:04.423] INFO    Completed compilation step 13 of 17. [0.205 s]
# [2026.02.01 15:58:04.833] INFO    Schedule completed. [0.409 s]
# [2026.02.01 15:58:04.899] INFO    Code generation completed for all AWGs. [0.066 s]
# [2026.02.01 15:58:04.899] INFO    Completed compilation step 14 of 17. [0.476 s]
# [2026.02.01 15:58:05.035] INFO    Schedule completed. [0.136 s]
# [2026.02.01 15:58:05.105] INFO    Code generation completed for all AWGs. [0.069 s]
# [2026.02.01 15:58:05.105] INFO    Completed compilation step 15 of 17. [0.206 s]
# [2026.02.01 15:58:05.239] INFO    Schedule completed. [0.134 s]
# [2026.02.01 15:58:05.307] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:05.307] INFO    Completed compilation step 16 of 17. [0.202 s]
# [2026.02.01 15:58:05.759] INFO    Schedule completed. [0.452 s]
# [2026.02.01 15:58:05.825] INFO    Code generation completed for all AWGs. [0.066 s]
# [2026.02.01 15:58:05.826] INFO    Completed compilation step 17 of 17. [0.519 s]
# [2026.02.01 15:58:05.837] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.838] INFO      Step   Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.02.01 15:58:05.838] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.838] INFO      0      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.838] INFO             SHFQC_DEV12256_sg     0        116            6           1       256
# [2026.02.01 15:58:05.839] INFO             SHFQC_DEV12256_sg     4         87            7           6     25888
# [2026.02.01 15:58:05.839] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.839] INFO      1      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.839] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.840] INFO             SHFQC_DEV12256_sg     4         87            7           6     28832
# [2026.02.01 15:58:05.840] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.840] INFO      2      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.840] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.841] INFO             SHFQC_DEV12256_sg     4         87            7           6     31648
# [2026.02.01 15:58:05.841] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.841] INFO      3      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.841] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.841] INFO             SHFQC_DEV12256_sg     4         87            7           6     34592
# [2026.02.01 15:58:05.842] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.842] INFO      4      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.842] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.842] INFO             SHFQC_DEV12256_sg     4         87            7           6     37408
# [2026.02.01 15:58:05.842] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.843] INFO      5      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.843] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.843] INFO             SHFQC_DEV12256_sg     4         87            7           6     40352
# [2026.02.01 15:58:05.843] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.843] INFO      6      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.843] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.844] INFO             SHFQC_DEV12256_sg     4         87            7           6     43168
# [2026.02.01 15:58:05.844] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.844] INFO      7      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.844] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.844] INFO             SHFQC_DEV12256_sg     4         87            7           6     46112
# [2026.02.01 15:58:05.845] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.845] INFO      8      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.845] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.845] INFO             SHFQC_DEV12256_sg     4         87            7           6     48928
# [2026.02.01 15:58:05.846] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.846] INFO      9      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.846] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.846] INFO             SHFQC_DEV12256_sg     4         87            7           6     51872
# [2026.02.01 15:58:05.846] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.846] INFO      10     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.846] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.847] INFO             SHFQC_DEV12256_sg     4         87            7           6     54688
# [2026.02.01 15:58:05.847] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.847] INFO      11     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.847] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.848] INFO             SHFQC_DEV12256_sg     4         87            7           6     57632
# [2026.02.01 15:58:05.848] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.848] INFO      12     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.848] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.848] INFO             SHFQC_DEV12256_sg     4         87            7           6     60448
# [2026.02.01 15:58:05.848] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.849] INFO      13     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.849] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.849] INFO             SHFQC_DEV12256_sg     4         87            7           6     63392
# [2026.02.01 15:58:05.849] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.849] INFO      14     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.849] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.850] INFO             SHFQC_DEV12256_sg     4         87            7           6     66208
# [2026.02.01 15:58:05.850] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.850] INFO      15     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.850] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.850] INFO             SHFQC_DEV12256_sg     4         87            7           6     69152
# [2026.02.01 15:58:05.850] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.851] INFO      16     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:05.851] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:05.851] INFO             SHFQC_DEV12256_sg     4         87            7           6     71968
# [2026.02.01 15:58:05.851] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.851] INFO             TOTAL                         5226          221                904640
# [2026.02.01 15:58:05.851] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.870] INFO    Auto-chunked sweep divided into 17 chunks
# [2026.02.01 15:58:05.871] INFO    Finished LabOne Q Compiler run.
# [2026.02.01 15:58:05.871] INFO    Task 'compile_experiment': ended at 2026-02-01 06:58:05.871837Z
# [2026.02.01 15:58:05.872] INFO    Task 'run_experiment': started at 2026-02-01 06:58:05.872172Z
# [2026.02.01 15:58:05.875] INFO    Starting near-time execution...
# [2026.02.01 15:58:05.889] INFO    Estimated RT execution time: 344.85 s.
# [2026.02.01 15:58:05.901] INFO    Finished near-time execution.
# [2026.02.01 15:58:05.916] INFO    Task 'run_experiment': ended at 2026-02-01 06:58:05.916703Z
# [2026.02.01 15:58:05.917] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.917] INFO      Workflow 'analysis_workflow': execution started at 2026-02-01
# [2026.02.01 15:58:05.917] INFO      06:58:05.917144Z
# [2026.02.01 15:58:05.917] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:05.918] INFO    Task 'calculate_qubit_population_2d': started at 2026-02-01 06:58:05.918235Z
# [2026.02.01 15:58:05.921] INFO    Task 'calculate_qubit_population_2d': ended at 2026-02-01 06:58:05.921601Z
# [2026.02.01 15:58:05.922] INFO    Task 'fit_data': started at 2026-02-01 06:58:05.921936Z
# [2026.02.01 15:58:07.200] INFO    Task 'fit_data': ended at 2026-02-01 06:58:07.200392Z
# [2026.02.01 15:58:07.201] INFO    Task 'extract_qubit_parameters': started at 2026-02-01 06:58:07.200989Z
# [2026.02.01 15:58:07.202] INFO    Task 'extract_qubit_parameters': ended at 2026-02-01 06:58:07.202686Z
# [2026.02.01 15:58:07.203] INFO    Task 'fit_mid_rate_data': started at 2026-02-01 06:58:07.203156Z
# [2026.02.01 15:58:07.208] INFO    Task 'fit_mid_rate_data': ended at 2026-02-01 06:58:07.208372Z
# [2026.02.01 15:58:07.209] INFO    Task 'plot_raw_iq_heatmap_2d': started at 2026-02-01 06:58:07.208904Z
# [2026.02.01 15:58:07.223] INFO    Task 'plot_raw_iq_heatmap_2d': ended at 2026-02-01 06:58:07.222965Z
# [2026.02.01 15:58:07.223] INFO    Task 'plot_population_heatmap_2d': started at 2026-02-01 06:58:07.223569Z
# [2026.02.01 15:58:07.230] INFO    Task 'plot_population_heatmap_2d': ended at 2026-02-01 06:58:07.230291Z
# [2026.02.01 15:58:07.231] INFO    Task 'plot_population': started at 2026-02-01 06:58:07.230934Z
# [2026.02.01 15:58:07.238] INFO    Artifact: 'Ramsey_q1' of type 'Figure' logged at 2026-02-01 06:58:07.238742Z
# [2026.02.01 15:58:07.239] INFO    Task 'plot_population': ended at 2026-02-01 06:58:07.239317Z
# [2026.02.01 15:58:07.239] INFO    Task 'plot_t2_star_vs_frequency': started at 2026-02-01 06:58:07.239721Z
# [2026.02.01 15:58:07.245] INFO    Task 'plot_t2_star_vs_frequency': ended at 2026-02-01 06:58:07.245514Z
# [2026.02.01 15:58:07.246] INFO    Task 'plot_MID_rate_vs_frequency': started at 2026-02-01 06:58:07.245968Z
# [2026.02.01 15:58:07.252] INFO    Task 'plot_MID_rate_vs_frequency': ended at 2026-02-01 06:58:07.251967Z
# [2026.02.01 15:58:07.252] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:07.252] INFO      Workflow 'analysis_workflow': execution ended at 2026-02-01 06:58:07.252414Z
# [2026.02.01 15:58:07.253] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:07.253] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:07.253] INFO      Workflow 'coherence_spectroscopy': execution ended at 2026-02-01
# [2026.02.01 15:58:07.253] INFO      06:58:07.253345Z
# [2026.02.01 15:58:07.254] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:07.255] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:07.255] INFO      Workflow 'coherence_spectroscopy': execution started at 2026-02-01
# [2026.02.01 15:58:07.255] INFO      06:58:07.255251Z
# [2026.02.01 15:58:07.256] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:07.256] INFO    Task 'temporary_qpu': started at 2026-02-01 06:58:07.256315Z
# [2026.02.01 15:58:07.256] INFO    Task 'temporary_qpu': ended at 2026-02-01 06:58:07.256797Z
# [2026.02.01 15:58:07.257] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-02-01
# [2026.02.01 15:58:07.257] INFO    06:58:07.257032Z
# [2026.02.01 15:58:07.257] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-02-01 06:58:07.257505Z
# [2026.02.01 15:58:07.257] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-02-01
# [2026.02.01 15:58:07.258] INFO    06:58:07.257805Z
# [2026.02.01 15:58:07.258] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-02-01 06:58:07.258209Z
# [2026.02.01 15:58:07.258] INFO    Task 'create_experiment': started at 2026-02-01 06:58:07.258477Z
# [2026.02.01 15:58:07.259] INFO    Task 'create_experiment': ended at 2026-02-01 06:58:07.259495Z
# [2026.02.01 15:58:07.259] INFO    Task 'compile_experiment': started at 2026-02-01 06:58:07.259782Z
# [2026.02.01 15:58:07.260] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.02.01 15:58:07.261] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal 'q1/acquire' to SOFTWARE
# [2026.02.01 15:58:07.261] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal 'q1/drive' to HARDWARE
# [2026.02.01 15:58:07.261] INFO    Resolved modulation type of oscillator 'q1_drive_ef_osc' on signal 'q1/drive_ef' to HARDWARE
# [2026.02.01 15:58:07.261] INFO    Starting LabOne Q Compiler run...
# [2026.02.01 15:58:11.260] INFO    Schedule completed. [3.998 s]
# [2026.02.01 15:58:12.749] INFO    Code generation completed for all AWGs. [1.489 s]
# [2026.02.01 15:58:12.750] INFO    Completed compilation step 1 of 1. [5.488 s]
# [2026.02.01 15:58:12.752] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:12.752] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.02.01 15:58:12.752] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:12.753] INFO      SHFQC_DEV12256        0       1247            0           1      4000
# [2026.02.01 15:58:12.753] INFO      SHFQC_DEV12256_sg     0       1748           28           1       256
# [2026.02.01 15:58:12.753] INFO      SHFQC_DEV12256_sg     4       1143          103         102    832288
# [2026.02.01 15:58:12.753] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:12.754] INFO      TOTAL                         4138          131                836544
# [2026.02.01 15:58:12.754] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:12.918] INFO    Schedule completed. [0.134 s]
# [2026.02.01 15:58:12.983] INFO    Code generation completed for all AWGs. [0.064 s]
# [2026.02.01 15:58:12.984] INFO    Completed compilation step 1 of 17. [0.199 s]
# [2026.02.01 15:58:13.120] INFO    Schedule completed. [0.136 s]
# [2026.02.01 15:58:13.186] INFO    Code generation completed for all AWGs. [0.066 s]
# [2026.02.01 15:58:13.187] INFO    Completed compilation step 2 of 17. [0.203 s]
# [2026.02.01 15:58:14.198] INFO    Schedule completed. [1.011 s]
# [2026.02.01 15:58:14.289] INFO    Code generation completed for all AWGs. [0.090 s]
# [2026.02.01 15:58:14.289] INFO    Completed compilation step 3 of 17. [1.102 s]
# [2026.02.01 15:58:14.559] INFO    Schedule completed. [0.269 s]
# [2026.02.01 15:58:14.625] INFO    Code generation completed for all AWGs. [0.066 s]
# [2026.02.01 15:58:14.626] INFO    Completed compilation step 4 of 17. [0.336 s]
# [2026.02.01 15:58:14.767] INFO    Schedule completed. [0.141 s]
# [2026.02.01 15:58:14.836] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:14.836] INFO    Completed compilation step 5 of 17. [0.210 s]
# [2026.02.01 15:58:15.123] INFO    Schedule completed. [0.286 s]
# [2026.02.01 15:58:15.191] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:15.192] INFO    Completed compilation step 6 of 17. [0.355 s]
# [2026.02.01 15:58:15.325] INFO    Schedule completed. [0.133 s]
# [2026.02.01 15:58:15.572] INFO    Code generation completed for all AWGs. [0.246 s]
# [2026.02.01 15:58:15.572] INFO    Completed compilation step 7 of 17. [0.380 s]
# [2026.02.01 15:58:15.705] INFO    Schedule completed. [0.133 s]
# [2026.02.01 15:58:15.771] INFO    Code generation completed for all AWGs. [0.065 s]
# [2026.02.01 15:58:15.771] INFO    Completed compilation step 8 of 17. [0.198 s]
# [2026.02.01 15:58:15.908] INFO    Schedule completed. [0.137 s]
# [2026.02.01 15:58:16.183] INFO    Code generation completed for all AWGs. [0.275 s]
# [2026.02.01 15:58:16.184] INFO    Completed compilation step 9 of 17. [0.412 s]
# [2026.02.01 15:58:16.320] INFO    Schedule completed. [0.136 s]
# [2026.02.01 15:58:16.388] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:16.388] INFO    Completed compilation step 10 of 17. [0.204 s]
# [2026.02.01 15:58:16.526] INFO    Schedule completed. [0.138 s]
# [2026.02.01 15:58:16.595] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:16.595] INFO    Completed compilation step 11 of 17. [0.206 s]
# [2026.02.01 15:58:16.976] INFO    Schedule completed. [0.381 s]
# [2026.02.01 15:58:17.043] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:17.044] INFO    Completed compilation step 12 of 17. [0.448 s]
# [2026.02.01 15:58:17.179] INFO    Schedule completed. [0.135 s]
# [2026.02.01 15:58:17.248] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:17.248] INFO    Completed compilation step 13 of 17. [0.204 s]
# [2026.02.01 15:58:17.385] INFO    Schedule completed. [0.137 s]
# [2026.02.01 15:58:17.453] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:17.454] INFO    Completed compilation step 14 of 17. [0.205 s]
# [2026.02.01 15:58:17.894] INFO    Schedule completed. [0.440 s]
# [2026.02.01 15:58:17.963] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:17.963] INFO    Completed compilation step 15 of 17. [0.509 s]
# [2026.02.01 15:58:18.099] INFO    Schedule completed. [0.136 s]
# [2026.02.01 15:58:18.168] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:18.169] INFO    Completed compilation step 16 of 17. [0.205 s]
# [2026.02.01 15:58:18.305] INFO    Schedule completed. [0.136 s]
# [2026.02.01 15:58:18.379] INFO    Code generation completed for all AWGs. [0.073 s]
# [2026.02.01 15:58:18.379] INFO    Completed compilation step 17 of 17. [0.210 s]
# [2026.02.01 15:58:18.390] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.391] INFO      Step   Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.02.01 15:58:18.391] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.391] INFO      0      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.392] INFO             SHFQC_DEV12256_sg     0        116            6           1       256
# [2026.02.01 15:58:18.392] INFO             SHFQC_DEV12256_sg     4         87            7           6     25888
# [2026.02.01 15:58:18.392] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.393] INFO      1      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.393] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.393] INFO             SHFQC_DEV12256_sg     4         87            7           6     28832
# [2026.02.01 15:58:18.393] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.393] INFO      2      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.394] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.394] INFO             SHFQC_DEV12256_sg     4         87            7           6     31648
# [2026.02.01 15:58:18.394] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.394] INFO      3      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.394] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.395] INFO             SHFQC_DEV12256_sg     4         87            7           6     34592
# [2026.02.01 15:58:18.395] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.395] INFO      4      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.395] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.395] INFO             SHFQC_DEV12256_sg     4         87            7           6     37408
# [2026.02.01 15:58:18.396] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.396] INFO      5      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.396] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.396] INFO             SHFQC_DEV12256_sg     4         87            7           6     40352
# [2026.02.01 15:58:18.396] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.396] INFO      6      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.397] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.397] INFO             SHFQC_DEV12256_sg     4         87            7           6     43168
# [2026.02.01 15:58:18.397] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.397] INFO      7      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.397] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.398] INFO             SHFQC_DEV12256_sg     4         87            7           6     46112
# [2026.02.01 15:58:18.398] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.398] INFO      8      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.398] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.398] INFO             SHFQC_DEV12256_sg     4         87            7           6     48928
# [2026.02.01 15:58:18.398] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.399] INFO      9      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.399] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.399] INFO             SHFQC_DEV12256_sg     4         87            7           6     51872
# [2026.02.01 15:58:18.399] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.399] INFO      10     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.400] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.400] INFO             SHFQC_DEV12256_sg     4         87            7           6     54688
# [2026.02.01 15:58:18.400] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.400] INFO      11     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.400] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.401] INFO             SHFQC_DEV12256_sg     4         87            7           6     57632
# [2026.02.01 15:58:18.401] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.401] INFO      12     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.401] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.401] INFO             SHFQC_DEV12256_sg     4         87            7           6     60448
# [2026.02.01 15:58:18.402] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.402] INFO      13     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.402] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.402] INFO             SHFQC_DEV12256_sg     4         87            7           6     63392
# [2026.02.01 15:58:18.402] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.403] INFO      14     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.403] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.403] INFO             SHFQC_DEV12256_sg     4         87            7           6     66208
# [2026.02.01 15:58:18.403] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.403] INFO      15     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.403] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.404] INFO             SHFQC_DEV12256_sg     4         87            7           6     69152
# [2026.02.01 15:58:18.404] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.404] INFO      16     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:18.404] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:18.404] INFO             SHFQC_DEV12256_sg     4         87            7           6     71968
# [2026.02.01 15:58:18.404] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.405] INFO             TOTAL                         5226          221                904640
# [2026.02.01 15:58:18.405] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.423] INFO    Auto-chunked sweep divided into 17 chunks
# [2026.02.01 15:58:18.424] INFO    Finished LabOne Q Compiler run.
# [2026.02.01 15:58:18.425] INFO    Task 'compile_experiment': ended at 2026-02-01 06:58:18.425241Z
# [2026.02.01 15:58:18.425] INFO    Task 'run_experiment': started at 2026-02-01 06:58:18.425627Z
# [2026.02.01 15:58:18.429] INFO    Starting near-time execution...
# [2026.02.01 15:58:18.443] INFO    Estimated RT execution time: 344.85 s.
# [2026.02.01 15:58:18.455] INFO    Finished near-time execution.
# [2026.02.01 15:58:18.471] INFO    Task 'run_experiment': ended at 2026-02-01 06:58:18.471499Z
# [2026.02.01 15:58:18.472] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.472] INFO      Workflow 'analysis_workflow': execution started at 2026-02-01
# [2026.02.01 15:58:18.472] INFO      06:58:18.471994Z
# [2026.02.01 15:58:18.472] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:18.473] INFO    Task 'calculate_qubit_population_2d': started at 2026-02-01 06:58:18.473107Z
# [2026.02.01 15:58:18.476] INFO    Task 'calculate_qubit_population_2d': ended at 2026-02-01 06:58:18.476601Z
# [2026.02.01 15:58:18.477] INFO    Task 'fit_data': started at 2026-02-01 06:58:18.476965Z
# [2026.02.01 15:58:19.755] INFO    Task 'fit_data': ended at 2026-02-01 06:58:19.755580Z
# [2026.02.01 15:58:19.756] INFO    Task 'extract_qubit_parameters': started at 2026-02-01 06:58:19.756152Z
# [2026.02.01 15:58:19.757] INFO    Task 'extract_qubit_parameters': ended at 2026-02-01 06:58:19.757857Z
# [2026.02.01 15:58:19.758] INFO    Task 'fit_mid_rate_data': started at 2026-02-01 06:58:19.758267Z
# [2026.02.01 15:58:19.762] INFO    Task 'fit_mid_rate_data': ended at 2026-02-01 06:58:19.762853Z
# [2026.02.01 15:58:19.763] INFO    Task 'plot_raw_iq_heatmap_2d': started at 2026-02-01 06:58:19.763289Z
# [2026.02.01 15:58:19.775] INFO    Task 'plot_raw_iq_heatmap_2d': ended at 2026-02-01 06:58:19.775730Z
# [2026.02.01 15:58:19.776] INFO    Task 'plot_population_heatmap_2d': started at 2026-02-01 06:58:19.776428Z
# [2026.02.01 15:58:19.783] INFO    Task 'plot_population_heatmap_2d': ended at 2026-02-01 06:58:19.782757Z
# [2026.02.01 15:58:19.783] INFO    Task 'plot_population': started at 2026-02-01 06:58:19.783726Z
# [2026.02.01 15:58:19.790] INFO    Artifact: 'Ramsey_q1' of type 'Figure' logged at 2026-02-01 06:58:19.790830Z
# [2026.02.01 15:58:19.791] INFO    Task 'plot_population': ended at 2026-02-01 06:58:19.791346Z
# [2026.02.01 15:58:19.791] INFO    Task 'plot_t2_star_vs_frequency': started at 2026-02-01 06:58:19.791713Z
# [2026.02.01 15:58:19.797] INFO    Task 'plot_t2_star_vs_frequency': ended at 2026-02-01 06:58:19.797463Z
# [2026.02.01 15:58:19.798] INFO    Task 'plot_MID_rate_vs_frequency': started at 2026-02-01 06:58:19.797897Z
# [2026.02.01 15:58:19.803] INFO    Task 'plot_MID_rate_vs_frequency': ended at 2026-02-01 06:58:19.803798Z
# [2026.02.01 15:58:19.804] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:19.804] INFO      Workflow 'analysis_workflow': execution ended at 2026-02-01 06:58:19.804313Z
# [2026.02.01 15:58:19.805] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:19.807] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:19.807] INFO      Workflow 'coherence_spectroscopy': execution ended at 2026-02-01
# [2026.02.01 15:58:19.808] INFO      06:58:19.807072Z
# [2026.02.01 15:58:19.808] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:19.811] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:19.812] INFO      Workflow 'coherence_spectroscopy': execution started at 2026-02-01
# [2026.02.01 15:58:19.812] INFO      06:58:19.811620Z
# [2026.02.01 15:58:19.812] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:19.813] INFO    Task 'temporary_qpu': started at 2026-02-01 06:58:19.812950Z
# [2026.02.01 15:58:19.813] INFO    Task 'temporary_qpu': ended at 2026-02-01 06:58:19.813577Z
# [2026.02.01 15:58:19.814] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-02-01
# [2026.02.01 15:58:19.814] INFO    06:58:19.813929Z
# [2026.02.01 15:58:19.814] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-02-01 06:58:19.814396Z
# [2026.02.01 15:58:19.814] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2026-02-01
# [2026.02.01 15:58:19.815] INFO    06:58:19.814767Z
# [2026.02.01 15:58:19.815] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2026-02-01 06:58:19.815238Z
# [2026.02.01 15:58:19.815] INFO    Task 'create_experiment': started at 2026-02-01 06:58:19.815556Z
# [2026.02.01 15:58:19.816] INFO    Task 'create_experiment': ended at 2026-02-01 06:58:19.816820Z
# [2026.02.01 15:58:19.817] INFO    Task 'compile_experiment': started at 2026-02-01 06:58:19.817207Z
# [2026.02.01 15:58:19.818] INFO    Resolved modulation type of oscillator 'b0_drive_osc' on signal 'b0/drive' to HARDWARE
# [2026.02.01 15:58:19.818] INFO    Resolved modulation type of oscillator 'q1_readout_acquire_osc' on signal 'q1/acquire' to SOFTWARE
# [2026.02.01 15:58:19.819] INFO    Resolved modulation type of oscillator 'q1_drive_ge_osc' on signal 'q1/drive' to HARDWARE
# [2026.02.01 15:58:19.819] INFO    Resolved modulation type of oscillator 'q1_drive_ef_osc' on signal 'q1/drive_ef' to HARDWARE
# [2026.02.01 15:58:19.819] INFO    Starting LabOne Q Compiler run...
# [2026.02.01 15:58:24.107] INFO    Schedule completed. [4.287 s]
# [2026.02.01 15:58:25.640] INFO    Code generation completed for all AWGs. [1.532 s]
# [2026.02.01 15:58:25.641] INFO    Completed compilation step 1 of 1. [5.820 s]
# [2026.02.01 15:58:25.642] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:25.642] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.02.01 15:58:25.643] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:25.643] INFO      SHFQC_DEV12256        0       1247            0           1      4000
# [2026.02.01 15:58:25.643] INFO      SHFQC_DEV12256_sg     0       1748           28           1       256
# [2026.02.01 15:58:25.643] INFO      SHFQC_DEV12256_sg     4       1143          103         102    832288
# [2026.02.01 15:58:25.644] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:25.644] INFO      TOTAL                         4138          131                836544
# [2026.02.01 15:58:25.644] INFO     ───────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:25.810] INFO    Schedule completed. [0.135 s]
# [2026.02.01 15:58:25.879] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:25.879] INFO    Completed compilation step 1 of 17. [0.205 s]
# [2026.02.01 15:58:26.017] INFO    Schedule completed. [0.137 s]
# [2026.02.01 15:58:26.085] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:26.085] INFO    Completed compilation step 2 of 17. [0.205 s]
# [2026.02.01 15:58:26.226] INFO    Schedule completed. [0.140 s]
# [2026.02.01 15:58:26.295] INFO    Code generation completed for all AWGs. [0.069 s]
# [2026.02.01 15:58:26.296] INFO    Completed compilation step 3 of 17. [0.210 s]
# [2026.02.01 15:58:27.320] INFO    Schedule completed. [1.024 s]
# [2026.02.01 15:58:27.392] INFO    Code generation completed for all AWGs. [0.071 s]
# [2026.02.01 15:58:27.392] INFO    Completed compilation step 4 of 17. [1.096 s]
# [2026.02.01 15:58:27.682] INFO    Schedule completed. [0.290 s]
# [2026.02.01 15:58:27.753] INFO    Code generation completed for all AWGs. [0.070 s]
# [2026.02.01 15:58:27.753] INFO    Completed compilation step 5 of 17. [0.361 s]
# [2026.02.01 15:58:27.887] INFO    Schedule completed. [0.134 s]
# [2026.02.01 15:58:27.954] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:27.955] INFO    Completed compilation step 6 of 17. [0.201 s]
# [2026.02.01 15:58:28.289] INFO    Schedule completed. [0.333 s]
# [2026.02.01 15:58:28.358] INFO    Code generation completed for all AWGs. [0.069 s]
# [2026.02.01 15:58:28.358] INFO    Completed compilation step 7 of 17. [0.403 s]
# [2026.02.01 15:58:28.492] INFO    Schedule completed. [0.134 s]
# [2026.02.01 15:58:28.561] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:28.562] INFO    Completed compilation step 8 of 17. [0.203 s]
# [2026.02.01 15:58:28.903] INFO    Schedule completed. [0.341 s]
# [2026.02.01 15:58:28.971] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:28.972] INFO    Completed compilation step 9 of 17. [0.410 s]
# [2026.02.01 15:58:29.105] INFO    Schedule completed. [0.133 s]
# [2026.02.01 15:58:29.172] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:29.173] INFO    Completed compilation step 10 of 17. [0.201 s]
# [2026.02.01 15:58:29.553] INFO    Schedule completed. [0.380 s]
# [2026.02.01 15:58:29.623] INFO    Code generation completed for all AWGs. [0.069 s]
# [2026.02.01 15:58:29.623] INFO    Completed compilation step 11 of 17. [0.450 s]
# [2026.02.01 15:58:29.757] INFO    Schedule completed. [0.134 s]
# [2026.02.01 15:58:29.824] INFO    Code generation completed for all AWGs. [0.066 s]
# [2026.02.01 15:58:29.825] INFO    Completed compilation step 12 of 17. [0.201 s]
# [2026.02.01 15:58:29.962] INFO    Schedule completed. [0.137 s]
# [2026.02.01 15:58:30.031] INFO    Code generation completed for all AWGs. [0.069 s]
# [2026.02.01 15:58:30.032] INFO    Completed compilation step 13 of 17. [0.207 s]
# [2026.02.01 15:58:30.450] INFO    Schedule completed. [0.418 s]
# [2026.02.01 15:58:30.519] INFO    Code generation completed for all AWGs. [0.068 s]
# [2026.02.01 15:58:30.519] INFO    Completed compilation step 14 of 17. [0.487 s]
# [2026.02.01 15:58:30.654] INFO    Schedule completed. [0.135 s]
# [2026.02.01 15:58:30.722] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:30.723] INFO    Completed compilation step 15 of 17. [0.203 s]
# [2026.02.01 15:58:30.857] INFO    Schedule completed. [0.134 s]
# [2026.02.01 15:58:30.925] INFO    Code generation completed for all AWGs. [0.067 s]
# [2026.02.01 15:58:30.925] INFO    Completed compilation step 16 of 17. [0.202 s]
# [2026.02.01 15:58:31.395] INFO    Schedule completed. [0.469 s]
# [2026.02.01 15:58:31.464] INFO    Code generation completed for all AWGs. [0.069 s]
# [2026.02.01 15:58:31.464] INFO    Completed compilation step 17 of 17. [0.539 s]
# [2026.02.01 15:58:31.476] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.476] INFO      Step   Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2026.02.01 15:58:31.476] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.476] INFO      0      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.477] INFO             SHFQC_DEV12256_sg     0        116            6           1       256
# [2026.02.01 15:58:31.477] INFO             SHFQC_DEV12256_sg     4         87            7           6     25888
# [2026.02.01 15:58:31.477] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.477] INFO      1      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.478] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.478] INFO             SHFQC_DEV12256_sg     4         87            7           6     28832
# [2026.02.01 15:58:31.478] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.478] INFO      2      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.479] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.479] INFO             SHFQC_DEV12256_sg     4         87            7           6     31648
# [2026.02.01 15:58:31.479] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.479] INFO      3      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.480] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.480] INFO             SHFQC_DEV12256_sg     4         87            7           6     34592
# [2026.02.01 15:58:31.480] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.480] INFO      4      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.481] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.481] INFO             SHFQC_DEV12256_sg     4         87            7           6     37408
# [2026.02.01 15:58:31.481] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.481] INFO      5      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.481] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.482] INFO             SHFQC_DEV12256_sg     4         87            7           6     40352
# [2026.02.01 15:58:31.482] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.482] INFO      6      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.482] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.482] INFO             SHFQC_DEV12256_sg     4         87            7           6     43168
# [2026.02.01 15:58:31.482] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.483] INFO      7      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.483] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.483] INFO             SHFQC_DEV12256_sg     4         87            7           6     46112
# [2026.02.01 15:58:31.483] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.483] INFO      8      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.483] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.484] INFO             SHFQC_DEV12256_sg     4         87            7           6     48928
# [2026.02.01 15:58:31.484] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.484] INFO      9      SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.484] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.484] INFO             SHFQC_DEV12256_sg     4         87            7           6     51872
# [2026.02.01 15:58:31.484] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.484] INFO      10     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.485] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.485] INFO             SHFQC_DEV12256_sg     4         87            7           6     54688
# [2026.02.01 15:58:31.485] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.485] INFO      11     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.485] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.486] INFO             SHFQC_DEV12256_sg     4         87            7           6     57632
# [2026.02.01 15:58:31.486] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.486] INFO      12     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.486] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.486] INFO             SHFQC_DEV12256_sg     4         87            7           6     60448
# [2026.02.01 15:58:31.486] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.486] INFO      13     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.487] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.487] INFO             SHFQC_DEV12256_sg     4         87            7           6     63392
# [2026.02.01 15:58:31.487] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.487] INFO      14     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.487] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.487] INFO             SHFQC_DEV12256_sg     4         87            7           6     66208
# [2026.02.01 15:58:31.488] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.488] INFO      15     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.488] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.488] INFO             SHFQC_DEV12256_sg     4         87            7           6     69152
# [2026.02.01 15:58:31.488] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.488] INFO      16     SHFQC_DEV12256        0         95            0           1      4000
# [2026.02.01 15:58:31.489] INFO             SHFQC_DEV12256_sg     0        126            6           1       256
# [2026.02.01 15:58:31.489] INFO             SHFQC_DEV12256_sg     4         87            7           6     71968
# [2026.02.01 15:58:31.489] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.489] INFO             TOTAL                         5226          221                904640
# [2026.02.01 15:58:31.489] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.510] INFO    Auto-chunked sweep divided into 17 chunks
# [2026.02.01 15:58:31.511] INFO    Finished LabOne Q Compiler run.
# [2026.02.01 15:58:31.512] INFO    Task 'compile_experiment': ended at 2026-02-01 06:58:31.512207Z
# [2026.02.01 15:58:31.512] INFO    Task 'run_experiment': started at 2026-02-01 06:58:31.512575Z
# [2026.02.01 15:58:31.516] INFO    Starting near-time execution...
# [2026.02.01 15:58:31.540] INFO    Estimated RT execution time: 344.85 s.
# [2026.02.01 15:58:31.552] INFO    Finished near-time execution.
# [2026.02.01 15:58:31.570] INFO    Task 'run_experiment': ended at 2026-02-01 06:58:31.569884Z
# [2026.02.01 15:58:31.571] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.571] INFO      Workflow 'analysis_workflow': execution started at 2026-02-01
# [2026.02.01 15:58:31.572] INFO      06:58:31.571345Z
# [2026.02.01 15:58:31.572] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:31.573] INFO    Task 'calculate_qubit_population_2d': started at 2026-02-01 06:58:31.573261Z
# [2026.02.01 15:58:31.576] INFO    Task 'calculate_qubit_population_2d': ended at 2026-02-01 06:58:31.576682Z
# [2026.02.01 15:58:31.577] INFO    Task 'fit_data': started at 2026-02-01 06:58:31.577075Z
# [2026.02.01 15:58:32.852] INFO    Task 'fit_data': ended at 2026-02-01 06:58:32.852256Z
# [2026.02.01 15:58:32.852] INFO    Task 'extract_qubit_parameters': started at 2026-02-01 06:58:32.852842Z
# [2026.02.01 15:58:32.854] INFO    Task 'extract_qubit_parameters': ended at 2026-02-01 06:58:32.854534Z
# [2026.02.01 15:58:32.855] INFO    Task 'fit_mid_rate_data': started at 2026-02-01 06:58:32.854971Z
# [2026.02.01 15:58:32.859] INFO    Task 'fit_mid_rate_data': ended at 2026-02-01 06:58:32.859751Z
# [2026.02.01 15:58:32.860] INFO    Task 'plot_raw_iq_heatmap_2d': started at 2026-02-01 06:58:32.860208Z
# [2026.02.01 15:58:32.873] INFO    Task 'plot_raw_iq_heatmap_2d': ended at 2026-02-01 06:58:32.873713Z
# [2026.02.01 15:58:32.874] INFO    Task 'plot_population_heatmap_2d': started at 2026-02-01 06:58:32.874229Z
# [2026.02.01 15:58:32.880] INFO    Task 'plot_population_heatmap_2d': ended at 2026-02-01 06:58:32.880467Z
# [2026.02.01 15:58:32.881] INFO    Task 'plot_population': started at 2026-02-01 06:58:32.880908Z
# [2026.02.01 15:58:32.888] INFO    Artifact: 'Ramsey_q1' of type 'Figure' logged at 2026-02-01 06:58:32.888450Z
# [2026.02.01 15:58:32.889] INFO    Task 'plot_population': ended at 2026-02-01 06:58:32.889044Z
# [2026.02.01 15:58:32.889] INFO    Task 'plot_t2_star_vs_frequency': started at 2026-02-01 06:58:32.889472Z
# [2026.02.01 15:58:32.895] INFO    Task 'plot_t2_star_vs_frequency': ended at 2026-02-01 06:58:32.895311Z
# [2026.02.01 15:58:32.895] INFO    Task 'plot_MID_rate_vs_frequency': started at 2026-02-01 06:58:32.895725Z
# [2026.02.01 15:58:32.902] INFO    Task 'plot_MID_rate_vs_frequency': ended at 2026-02-01 06:58:32.902066Z
# [2026.02.01 15:58:32.902] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:32.902] INFO      Workflow 'analysis_workflow': execution ended at 2026-02-01 06:58:32.902562Z
# [2026.02.01 15:58:32.903] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:32.903] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2026.02.01 15:58:32.903] INFO      Workflow 'coherence_spectroscopy': execution ended at 2026-02-01
# [2026.02.01 15:58:32.904] INFO      06:58:32.903421Z
# [2026.02.01 15:58:32.904] INFO     ──────────────────────────────────────────────────────────────────────────────

# %%
# custom coherent spec analysis (offline from saved JSON)
from __future__ import annotations

import json
from pathlib import Path

import numpy as np
from analysis import coherence_spectroscopy as coh_analysis

# Work whether the notebook cwd is repo root or this folder.
base = Path("examples/selectiveRIP")
if not base.exists():
    base = Path(".")

data_path = base / "fit-data.input.processed-data-dict.json"
if not data_path.exists():
    raise FileNotFoundError(f"Could not find {data_path} (cwd={Path.cwd()})")

with open(data_path, "r") as f:
    processed_raw = json.load(f)


def _pairs_to_complex(data_pairs: np.ndarray) -> np.ndarray:
    """Convert [..., real, imag, real, imag, ...] to complex array."""
    real = data_pairs[..., 0::2]
    imag = data_pairs[..., 1::2]
    return real + 1j * imag


processed_data_dict: dict[str, dict] = {}
for uid, entry in processed_raw.items():
    converted: dict = {}
    for key, value in entry.items():
        if key == "data_raw" and isinstance(value, dict) and "data" in value:
            data_pairs = np.asarray(value["data"], dtype=float)
            converted[key] = _pairs_to_complex(data_pairs)
        elif isinstance(value, list):
            converted[key] = np.asarray(value)
        else:
            converted[key] = value
    processed_data_dict[uid] = converted

# Use the qubit objects already defined earlier in the notebook.
q = qubits[0]

# IMPORTANT: set this to the detuning you used in the experiment.
detuning_used = 0.4e6

fit_results = coh_analysis.fit_data([q], processed_data_dict)
qubit_parameters = coh_analysis.extract_qubit_parameters([q], fit_results, detuning_used)
mid_fit_results = coh_analysis.fit_mid_rate_data([q], qubit_parameters)

print(qubit_parameters["per_frequency"][q.uid]["best_index"])
print(qubit_parameters["new_parameter_values"][q.uid])

# Plot both T2* and the MID rate fit.
fig_t2 = coh_analysis.plot_t2_star_vs_frequency([q], qubit_parameters)[q.uid]
fig_mid = coh_analysis.plot_MID_rate_vs_frequency([q], qubit_parameters, mid_fit_results)[q.uid]
fig_t2, fig_mid

# %% [markdown]
# # Amplitude calibration

# %%
from experiments import amplitude_fine
q = qubits[0]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temporary_parameters[q.uid] = temp_pars
#temp_pars.ge_drive_amplitude_pi =0.64
#######################################################################
repetitions =np.arange(1,12) # Due to short T1, 20   
#######################################################################
options = amplitude_fine.experiment_workflow_x180.options()
options.update(False)
options.use_cal_traces(True)
#options.do_pca(False)

#print(workflow.show_fields(options))

###################################################################
error_amp = amplitude_fine.experiment_workflow_x180(
    session=session,
    qpu=qpu,
    qubits=q,
    repetitions=repetitions,
    temporary_parameters=temporary_parameters,
    options=options
)

error_amp_result = error_amp.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(error_amp_result.tasks['analysis_workflow'].output)

# %%
from experiments import amplitude_fine
q = qubits[0]
temporary_parameters = {}
temp_pars =deepcopy(q.parameters)
temporary_parameters[q.uid] = temp_pars
#######################################################################
repetitions =np.arange(1,10)
#######################################################################
options = amplitude_fine.experiment_workflow_x90.options()
options.update(False)
options.use_cal_traces(True)
options.count(1024)

#print(workflow.show_fields(options))

###################################################################
error_amp_half = amplitude_fine.experiment_workflow_x90(
    session=session,
    qpu=qpu,
    qubits=q,
    repetitions=repetitions,
    temporary_parameters=temporary_parameters,
    options=options
)

error_amp_half_result = error_amp_half.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(error_amp_half_result.tasks['analysis_workflow'].output)

# %%
# from helper import save_qubit_parameters
# save_qubit_parameters(qubits={ qubit.uid : qubit for qubit in qubits}, save_folder="./qubit_parameters/", filename="COSPEC2")
