# %% [markdown]
# # Initialization

# %%
import numpy as np
from pprint import pprint


from laboneq.contrib.example_helpers.generate_descriptor import generate_descriptor
#from laboneq.contrib.example_helpers.generate_device_setup import generate_device_setup
from laboneq.dsl.device import DeviceSetup




descriptor = generate_descriptor(
    #pqsc=[""], # 장비 여러개 사용시
    shfqc_6=["DEV12576"],
    number_data_qubits=5,
    multiplex=True,
    number_multiplex=5,
    include_cr_lines=True,
    include_ef_lines=True,
    get_zsync=False,  # Only set to True when using real device
    save = True,
    filename="BF7_KRISS",
    ip_address="10.172.11.217"
)


#descriptor
setup = DeviceSetup.from_descriptor(yaml_text=descriptor, server_host="10.172.11.217")
#setup
setup.instruments[0].device_options = 'SHFQC/PLUS/QC6CH'
#setup.instruments

# %%
from laboneq.simple import Session
session = Session(setup)
session.connect(ignore_version_mismatch=True, do_emulation=False)
#session.disconnect()
# Out:
# [2025.09.04 20:48:35.788] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /home/kriss/JSAHN/qubit-experiment/laboneq_output/log
# [2025.09.04 20:48:35.789] INFO    VERSION: laboneq 2.57.0
# [2025.09.04 20:48:35.790] INFO    Connecting to data server at 10.172.11.217:8004
# [2025.09.04 20:48:35.795] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 10.172.11.217:8004
# [2025.09.04 20:48:35.802] INFO    Configuring the device setup
# [2025.09.04 20:48:35.809] INFO    The device setup is configured

# %%
from qpu_types.transmon import TransmonQubit, TransmonQubitParameters
from helper import load_qubit_parameters, save_qubit_parameters
from operations import TransmonOperations
from laboneq.dsl.quantum.qpu import QPU, QuantumPlatform



_loaded_qubits = load_qubit_parameters(filename="latest") 
#qubits = TransmonQubit.from_device_setup(setup) # Also can be done with load_qubit_parameters 
qubits = list(_loaded_qubits.values())

qubits = []
for i in range(5):
    q = TransmonQubit.from_logical_signal_group(
        f"q{i}",
        setup.logical_signal_groups[f"q{i}"],
        parameters=TransmonQubitParameters()
    )
    qubits.append(q)



qpu = QPU(quantum_elements=qubits, quantum_operations=TransmonOperations())
#quantum_platform = QuantumPlatform(setup=setup, qpu=qpu)

# qpu.topology.add_edge("bus", "q16", "q17")
# qpu.topology.add_edge("bus", "q17", "q18")
# qpu.topology.add_edge("bus", "q18", "q19")
# qpu.topology.plot()




from laboneq.simple import workflow
folder_store = workflow.logbook.FolderStore("./experiment_store") 
folder_store.activate()
#folder_store.deactivate()
workflow.logbook.LoggingStore().activate()
#workflow.logbook.LogbookStore().deactivate()

# %% [markdown]
# BF 7

# %%
qubits
# Out:
# [TransmonQubit(
# │   uid='q0',
# │   signals={
# │   │   'drive': 'q0/drive',
# │   │   'drive_ef': 'q0/drive_ef',
# │   │   'drive_cr': 'q0/drive_cr',
# │   │   'measure': 'q0/measure',
# │   │   'acquire': 'q0/acquire'
# │   },
# │   parameters=TransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=None,
# │   │   readout_lo_frequency=None,
# │   │   resonance_frequency_ge=None,
# │   │   resonance_frequency_ef=None,
# │   │   readout_resonator_frequency=None,
# │   │   resonance_targ_frequency=None,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   cr_drive_amplitude=None,
# │   │   cr_drive_length=None,
# │   │   cr_drive_phase=None,
# │   │   cr_drive_pulse={
# │   │   │   'function': 'GaussianSquareDRAG',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0,
# │   │   │   'beta0': 0.0,
# │   │   │   'beta1': 0.0
# │   │   },
# │   │   cr_drive_cancel_amplitude=None,
# │   │   cr_drive_cancel_length=None,
# │   │   cr_drive_cancel_phase=None,
# │   │   cr_drive_cancel_pulse={
# │   │   │   'function': 'GaussianSquareDRAG',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0,
# │   │   │   'beta0': 0.0,
# │   │   │   'beta1': 0.0
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=1.0,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'GaussianSquare',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=2e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=1e-06,
# │   │   drive_range=10,
# │   │   readout_range_out=5,
# │   │   readout_range_in=10,
# │   │   spectroscopy_length=5e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'GaussianSquare',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0
# │   │   },
# │   │   user_defined={}
# │   )
# )
# ,
#  TransmonQubit(
# │   uid='q1',
# │   signals={
# │   │   'drive': 'q1/drive',
# │   │   'drive_ef': 'q1/drive_ef',
# │   │   'drive_cr': 'q1/drive_cr',
# │   │   'measure': 'q1/measure',
# │   │   'acquire': 'q1/acquire'
# │   },
# │   parameters=TransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=None,
# │   │   readout_lo_frequency=None,
# │   │   resonance_frequency_ge=None,
# │   │   resonance_frequency_ef=None,
# │   │   readout_resonator_frequency=None,
# │   │   resonance_targ_frequency=None,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   cr_drive_amplitude=None,
# │   │   cr_drive_length=None,
# │   │   cr_drive_phase=None,
# │   │   cr_drive_pulse={
# │   │   │   'function': 'GaussianSquareDRAG',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0,
# │   │   │   'beta0': 0.0,
# │   │   │   'beta1': 0.0
# │   │   },
# │   │   cr_drive_cancel_amplitude=None,
# │   │   cr_drive_cancel_length=None,
# │   │   cr_drive_cancel_phase=None,
# │   │   cr_drive_cancel_pulse={
# │   │   │   'function': 'GaussianSquareDRAG',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0,
# │   │   │   'beta0': 0.0,
# │   │   │   'beta1': 0.0
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=1.0,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'GaussianSquare',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=2e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=1e-06,
# │   │   drive_range=10,
# │   │   readout_range_out=5,
# │   │   readout_range_in=10,
# │   │   spectroscopy_length=5e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'GaussianSquare',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0
# │   │   },
# │   │   user_defined={}
# │   )
# )
# ,
#  TransmonQubit(
# │   uid='q2',
# │   signals={
# │   │   'drive': 'q2/drive',
# │   │   'drive_ef': 'q2/drive_ef',
# │   │   'drive_cr': 'q2/drive_cr',
# │   │   'measure': 'q2/measure',
# │   │   'acquire': 'q2/acquire'
# │   },
# │   parameters=TransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=None,
# │   │   readout_lo_frequency=None,
# │   │   resonance_frequency_ge=None,
# │   │   resonance_frequency_ef=None,
# │   │   readout_resonator_frequency=None,
# │   │   resonance_targ_frequency=None,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   cr_drive_amplitude=None,
# │   │   cr_drive_length=None,
# │   │   cr_drive_phase=None,
# │   │   cr_drive_pulse={
# │   │   │   'function': 'GaussianSquareDRAG',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0,
# │   │   │   'beta0': 0.0,
# │   │   │   'beta1': 0.0
# │   │   },
# │   │   cr_drive_cancel_amplitude=None,
# │   │   cr_drive_cancel_length=None,
# │   │   cr_drive_cancel_phase=None,
# │   │   cr_drive_cancel_pulse={
# │   │   │   'function': 'GaussianSquareDRAG',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0,
# │   │   │   'beta0': 0.0,
# │   │   │   'beta1': 0.0
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=1.0,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'GaussianSquare',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=2e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=1e-06,
# │   │   drive_range=10,
# │   │   readout_range_out=5,
# │   │   readout_range_in=10,
# │   │   spectroscopy_length=5e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'GaussianSquare',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0
# │   │   },
# │   │   user_defined={}
# │   )
# )
# ,
#  TransmonQubit(
# │   uid='q3',
# │   signals={
# │   │   'drive': 'q3/drive',
# │   │   'drive_ef': 'q3/drive_ef',
# │   │   'drive_cr': 'q3/drive_cr',
# │   │   'measure': 'q3/measure',
# │   │   'acquire': 'q3/acquire'
# │   },
# │   parameters=TransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=None,
# │   │   readout_lo_frequency=None,
# │   │   resonance_frequency_ge=None,
# │   │   resonance_frequency_ef=None,
# │   │   readout_resonator_frequency=None,
# │   │   resonance_targ_frequency=None,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   cr_drive_amplitude=None,
# │   │   cr_drive_length=None,
# │   │   cr_drive_phase=None,
# │   │   cr_drive_pulse={
# │   │   │   'function': 'GaussianSquareDRAG',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0,
# │   │   │   'beta0': 0.0,
# │   │   │   'beta1': 0.0
# │   │   },
# │   │   cr_drive_cancel_amplitude=None,
# │   │   cr_drive_cancel_length=None,
# │   │   cr_drive_cancel_phase=None,
# │   │   cr_drive_cancel_pulse={
# │   │   │   'function': 'GaussianSquareDRAG',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0,
# │   │   │   'beta0': 0.0,
# │   │   │   'beta1': 0.0
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=1.0,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'GaussianSquare',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=2e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=1e-06,
# │   │   drive_range=10,
# │   │   readout_range_out=5,
# │   │   readout_range_in=10,
# │   │   spectroscopy_length=5e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'GaussianSquare',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0
# │   │   },
# │   │   user_defined={}
# │   )
# )
# ,
#  TransmonQubit(
# │   uid='q4',
# │   signals={
# │   │   'drive': 'q4/drive',
# │   │   'drive_ef': 'q4/drive_ef',
# │   │   'drive_cr': 'q4/drive_cr',
# │   │   'measure': 'q4/measure',
# │   │   'acquire': 'q4/acquire'
# │   },
# │   parameters=TransmonQubitParameters(
# │   │   custom={},
# │   │   ge_T1=0,
# │   │   ge_T2=0,
# │   │   ge_T2_star=0,
# │   │   ef_T1=0,
# │   │   ef_T2=0,
# │   │   ef_T2_star=0,
# │   │   drive_lo_frequency=None,
# │   │   readout_lo_frequency=None,
# │   │   resonance_frequency_ge=None,
# │   │   resonance_frequency_ef=None,
# │   │   readout_resonator_frequency=None,
# │   │   resonance_targ_frequency=None,
# │   │   ge_drive_amplitude_pi=0.2,
# │   │   ge_drive_amplitude_pi2=0.1,
# │   │   ge_drive_length=5e-08,
# │   │   ge_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   ef_drive_amplitude_pi=0.2,
# │   │   ef_drive_amplitude_pi2=0.1,
# │   │   ef_drive_length=5e-08,
# │   │   ef_drive_pulse={
# │   │   │   'function': 'drag',
# │   │   │   'beta': 0,
# │   │   │   'sigma': 0.25
# │   │   },
# │   │   cr_drive_amplitude=None,
# │   │   cr_drive_length=None,
# │   │   cr_drive_phase=None,
# │   │   cr_drive_pulse={
# │   │   │   'function': 'GaussianSquareDRAG',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0,
# │   │   │   'beta0': 0.0,
# │   │   │   'beta1': 0.0
# │   │   },
# │   │   cr_drive_cancel_amplitude=None,
# │   │   cr_drive_cancel_length=None,
# │   │   cr_drive_cancel_phase=None,
# │   │   cr_drive_cancel_pulse={
# │   │   │   'function': 'GaussianSquareDRAG',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0,
# │   │   │   'beta0': 0.0,
# │   │   │   'beta1': 0.0
# │   │   },
# │   │   qubit_resonator_coupling_strength_g=0,
# │   │   ge_chi_shift=0,
# │   │   readout_amplitude=1.0,
# │   │   readout_length=2e-06,
# │   │   readout_pulse={
# │   │   │   'function': 'GaussianSquare',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0
# │   │   },
# │   │   readout_integration_length=2e-06,
# │   │   readout_integration_delay=2e-08,
# │   │   readout_integration_kernels_type='default',
# │   │   readout_integration_kernels=None,
# │   │   readout_integration_discrimination_thresholds=None,
# │   │   reset_delay_length=1e-06,
# │   │   drive_range=10,
# │   │   readout_range_out=5,
# │   │   readout_range_in=10,
# │   │   spectroscopy_length=5e-06,
# │   │   spectroscopy_amplitude=1,
# │   │   spectroscopy_pulse={
# │   │   │   'function': 'GaussianSquare',
# │   │   │   'sigma': 0.2,
# │   │   │   'risefall_sigma_ratio': 3.0
# │   │   },
# │   │   user_defined={}
# │   )
# )
# ]

# %%
# 0 : 15 , 1 : 16 , 2 : 17, 3 : 18, 4 : 19
for q in qubits:
    #q.parameters.ge_drive_pulse["sigma"] = 0.25
    q.parameters.readout_amplitude = 1.0
    q.parameters.reset_delay_length = 20e-6

    q.parameters.readout_range_out = -25
    q.parameters.readout_range_in = 0
    q.parameters.drive_range = -10

    q.parameters.readout_lo_frequency = 7.0e9
    q.parameters.drive_lo_frequency = 4.8e9

    q.parameters.spectroscopy_length = 10e-6

    q.parameters.ge_drive_length =64e-9
    

 

qubits[2].parameters.resonance_frequency_ge = 4.716e9
qubits[3].parameters.resonance_frequency_ge = 4.664e9
qubits[4].parameters.resonance_frequency_ge = 4.779e9

qubits[2].parameters.readout_resonator_frequency = 6.9226e9
qubits[3].parameters.readout_resonator_frequency = 6.8433e9
qubits[4].parameters.readout_resonator_frequency = 6.7739e9

# %% [markdown]
# # 1. Spectroscopy

# %%
from helper import adjust_amplitude_for_output_range, calculate_power
adjust_amplitude_for_output_range(initial_output_dbm=0, initial_amplitude= 0.002, new_output_dbm=-5)
calculate_power(output_dbm=0, amplitude=0.001,attenuation=[])
# Out:
# 0.006324555320336759

# %% [markdown]
# ### 1.1 Resonator spectroscopy with amplitude sweep
#
# STRATEGY
# 1. CW spectroscpy for wide range scan
#     * CW spectroscopy can be done for wide range scan
#     * amplitude, frequency 2D sweep 을 통해  power에 따른 broadening 및 SNR 경향 관찰
#     * $\Delta F$ : frequency span,  $\Delta f_r$
#     * Pick $\Delta F / \Delta f_r$ 1~2

# %%
from experiments import resonator_spectroscopy_amplitude

####################################################################################
q=qubits[4]
pprint(q.readout_parameters())
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
frequencies = q.parameters.readout_resonator_frequency + np.linspace(-10e6,10e6,501)
amplitudes = np.linspace(0.0, 1.0, 21)
#####################################################################################
options = resonator_spectroscopy_amplitude.experiment_workflow.options()
#workflow.show_fields(options)
options.update(True)
options.use_cw(False)
options.do_analysis(True)
######################################################################################
# Build and run resonator_spectroscopy_amplitude wormflow
res_spec_amp = resonator_spectroscopy_amplitude.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=q,
    frequencies=frequencies,
    amplitudes=amplitudes,
    options=options
)
res_spec_amp_result=res_spec_amp.run()

# %% [markdown]
# ### 1.2 Resonator Spectroscopy
# * CW not recommended

# %%
from experiments import resonator_spectroscopy

####################################################################################
q=qubits[4]
q.parameters.readout_amplitude = 0.5
print(q.readout_parameters())
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#frequencies = q.parameters.readout_resonator_frequency + np.linspace(-10e6,10e6,501)
frequencies = q.parameters.readout_resonator_frequency + np.linspace(-0.5e6,0.5e6,1001)
#####################################################################################
options = resonator_spectroscopy.experiment_workflow.options()
#workflow.show_fields(options)
options.count(1024*2)
options.update(False)
options.use_cw(False) #qop.measure 
options.fit_complex_resonator(False)
options.fit_lorentzian(True)
######################################################################################
# Build and run resonator_spectroscopy_amplitude wormflow
res_spec = resonator_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubit=q,
    frequencies=frequencies,
    options=options
)
res_spec_result = res_spec.run()
res_spec_analysis_result = res_spec_result.tasks["analysis_workflow"]
pprint(res_spec_analysis_result.output)

# %%
res_spec_result.tasks["analysis_workflow"].tasks["fit_data"].output

# %%
# res_spec_result.tasks["analysis_workflow"].tasks["plot_real_imaginary"].output

# %%
from laboneq.simple import show_pulse_sheet
from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

#show_pulse_sheet(compiled_experiment=res_spec_result.tasks["compile_experiment"].output,name='test', interactive=True)
#plot_simulation(compiled_experiment=res_spec_result.tasks["compile_experiment"].output)

# %% [markdown]
# ### 2.1 Qubit Spectroscopy with Amplitude Sweep
# * Current qubit spectroscopy modules do not support CW
# * Recommended to use long enough spectroscopy drive (pulsed) to see steady state signals

# %%
qubits[2].parameters.drive_range = -5
qubits[2].parameters.drive

# %%
from experiments import qubit_spectroscopy_amplitude

###############################################################
q = qubits[4]
frequencies = q.parameters.resonance_frequency_ge + np.linspace(-2e6, 2e6, 101)
amplitudes = np.linspace(0.01, 0.002, 11)
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")

pprint(q.readout_parameters())
pprint(q.spectroscopy_parameters())
################################################################
options = qubit_spectroscopy_amplitude.experiment_workflow.options()
options.update(False)
# workflow.show_fields(options)
###################################################################
qubit_spec_amp = qubit_spectroscopy_amplitude.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    frequencies=frequencies,
    amplitudes=amplitudes,
    options=options
)

qubit_spec_amp_result = qubit_spec_amp.run()
qubit_spec_amp_result
# Out:
# DRIVE range (dBm) : 0, READOUT range (dBm) : -25
# ('measure',
#  {'amplitude': 0.6,
#   'length': 2e-06,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# ('drive',
#  {'amplitude': 0.002,
#   'length': 1e-05,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# [2025.09.04 21:02:58.832] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:02:58.833] INFO      Workflow 'qubit_spectroscopy_amplitude': execution started at 2025-09-04
# [2025.09.04 21:02:58.833] INFO      12:02:58.832495Z
# [2025.09.04 21:02:58.833] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:02:58.846] INFO    Task 'temporary_qpu': started at 2025-09-04 12:02:58.845817Z
# [2025.09.04 21:02:58.847] INFO    Task 'temporary_qpu': ended at 2025-09-04 12:02:58.847133Z
# [2025.09.04 21:02:58.849] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2025-09-04
# [2025.09.04 21:02:58.850] INFO    12:02:58.849611Z
# [2025.09.04 21:02:58.850] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2025-09-04 12:02:58.850467Z
# [2025.09.04 21:02:58.851] INFO    Task 'create_experiment': started at 2025-09-04 12:02:58.851510Z
# [2025.09.04 21:02:58.858] INFO    Task 'create_experiment': ended at 2025-09-04 12:02:58.857910Z
# [2025.09.04 21:02:58.859] INFO    Task 'compile_experiment': started at 2025-09-04 12:02:58.859314Z
# [2025.09.04 21:02:58.861] INFO    Resolved modulation type of oscillator 'q4_readout_acquire_osc' on signal 'q4/acquire' to SOFTWARE
# [2025.09.04 21:02:58.861] INFO    Resolved modulation type of oscillator 'q4_drive_ge_osc' on signal 'q4/drive' to HARDWARE
# [2025.09.04 21:02:58.861] INFO    Starting LabOne Q Compiler run...
# [2025.09.04 21:02:59.197] INFO    Schedule completed. [0.335 s]
# [2025.09.04 21:02:59.459] INFO    Code generation completed for all AWGs. [0.262 s]
# [2025.09.04 21:02:59.460] INFO    Completed compilation step 1 of 1. [0.597 s]
# [2025.09.04 21:02:59.462] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:02:59.462] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2025.09.04 21:02:59.462] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:02:59.463] INFO      SHFQC_DEV12576        0         10            0           1      8000
# [2025.09.04 21:02:59.463] INFO      SHFQC_DEV12576_sg     4        133           12           1     40000
# [2025.09.04 21:02:59.463] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:02:59.463] INFO      TOTAL                          143           12                 48000
# [2025.09.04 21:02:59.463] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:02:59.468] INFO    Finished LabOne Q Compiler run.
# [2025.09.04 21:02:59.469] INFO    Task 'compile_experiment': ended at 2025-09-04 12:02:59.468838Z
# [2025.09.04 21:02:59.476] INFO    Task 'run_experiment': started at 2025-09-04 12:02:59.476438Z
# [2025.09.04 21:02:59.477] INFO    Connecting to data server at 10.172.11.217:8004
# [2025.09.04 21:02:59.484] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 10.172.11.217:8004
# [2025.09.04 21:02:59.488] INFO    Configuring the device setup
# [2025.09.04 21:02:59.497] INFO    The device setup is configured
# [2025.09.04 21:02:59.754] INFO    Starting near-time execution...
# [2025.09.04 21:02:59.797] INFO    Estimated RT execution time: 241.28 s.
# [2025.09.04 21:07:01.127] INFO    Finished near-time execution.
# [2025.09.04 21:07:01.291] INFO    Task 'run_experiment': ended at 2025-09-04 12:07:01.290891Z
# [2025.09.04 21:07:01.293] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:07:01.293] INFO      Workflow 'analysis_workflow': execution started at 2025-09-04
# [2025.09.04 21:07:01.293] INFO      12:07:01.292905Z
# [2025.09.04 21:07:01.293] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:07:01.295] INFO    Task 'plot_raw_complex_data_2d': started at 2025-09-04 12:07:01.295056Z
# [2025.09.04 21:07:01.323] INFO    Artifact: 'Raw_data_q4' of type 'Figure' logged at 2025-09-04 12:07:01.323431Z
# [2025.09.04 21:07:01.474] INFO    Task 'plot_raw_complex_data_2d': ended at 2025-09-04 12:07:01.474309Z
# [2025.09.04 21:07:01.475] INFO    Task 'plot_signal_magnitude_and_phase_2d': started at 2025-09-04
# [2025.09.04 21:07:01.475] INFO    12:07:01.475306Z
# [2025.09.04 21:07:01.494] INFO    Artifact: 'Magnitude_Phase_q4' of type 'Figure' logged at 2025-09-04
# [2025.09.04 21:07:01.495] INFO    12:07:01.494687Z
# [2025.09.04 21:07:01.654] INFO    Task 'plot_signal_magnitude_and_phase_2d': ended at 2025-09-04 12:07:01.653954Z
# [2025.09.04 21:07:01.654] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:07:01.655] INFO      Workflow 'analysis_workflow': execution ended at 2025-09-04 12:07:01.654706Z
# [2025.09.04 21:07:01.655] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:07:01.655] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:07:01.655] INFO      Workflow 'qubit_spectroscopy_amplitude': execution ended at 2025-09-04
# [2025.09.04 21:07:01.656] INFO      12:07:01.655601Z
# [2025.09.04 21:07:01.656] INFO     ──────────────────────────────────────────────────────────────────────────────
# WorkflowResult(name=qubit_spectroscopy_amplitude, index=())

# %% [markdown]
# ### 2.2 Qubit Spectroscopy

# %%
from experiments import qubit_spectroscopy

q
###############################################################
q = qubits[4]
q.parameters.spectroscopy_amplitude = 0.002
q.parameters.readout_amplitude = 0.6
frequencies = q.parameters.resonance_frequency_ge + np.linspace(-3e6, 3e6, 501)
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
pprint(q.readout_parameters())
pprint(q.spectroscopy_parameters())
################################################################
options = qubit_spectroscopy.experiment_workflow.options()
options.update(False)
# workflow.show_fields(options)
###################################################################
qubit_spec = qubit_spectroscopy.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    frequencies=frequencies,
    options=options
)

qubit_spec_result = qubit_spec.run()
qubit_spec_result
# Out:
# DRIVE range (dBm) : -10, READOUT range (dBm) : -25
# ('measure',
#  {'amplitude': 0.6,
#   'length': 2e-06,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# ('drive',
#  {'amplitude': 0.006,
#   'length': 1e-05,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# [2025.09.04 21:22:09.772] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:22:09.772] INFO      Workflow 'qubit_spectroscopy': execution started at 2025-09-04
# [2025.09.04 21:22:09.772] INFO      12:22:09.772033Z
# [2025.09.04 21:22:09.773] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:22:09.782] INFO    Task 'temporary_qpu': started at 2025-09-04 12:22:09.782505Z
# [2025.09.04 21:22:09.784] INFO    Task 'temporary_qpu': ended at 2025-09-04 12:22:09.783930Z
# [2025.09.04 21:22:09.786] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2025-09-04
# [2025.09.04 21:22:09.786] INFO    12:22:09.786269Z
# [2025.09.04 21:22:09.787] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2025-09-04 12:22:09.787217Z
# [2025.09.04 21:22:09.788] INFO    Task 'create_experiment': started at 2025-09-04 12:22:09.788167Z
# [2025.09.04 21:22:09.793] INFO    Task 'create_experiment': ended at 2025-09-04 12:22:09.793628Z
# [2025.09.04 21:22:09.794] INFO    Task 'compile_experiment': started at 2025-09-04 12:22:09.794774Z
# [2025.09.04 21:22:09.796] INFO    Resolved modulation type of oscillator 'q4_readout_acquire_osc' on signal 'q4/acquire' to SOFTWARE
# [2025.09.04 21:22:09.797] INFO    Resolved modulation type of oscillator 'q4_drive_ge_osc' on signal 'q4/drive' to HARDWARE
# [2025.09.04 21:22:09.797] INFO    Starting LabOne Q Compiler run...
# [2025.09.04 21:22:09.909] INFO    Schedule completed. [0.111 s]
# [2025.09.04 21:22:09.991] INFO    Code generation completed for all AWGs. [0.082 s]
# [2025.09.04 21:22:09.991] INFO    Completed compilation step 1 of 1. [0.193 s]
# [2025.09.04 21:22:09.993] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:22:09.994] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2025.09.04 21:22:09.994] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:22:09.994] INFO      SHFQC_DEV12576        0         10            0           1      8000
# [2025.09.04 21:22:09.994] INFO      SHFQC_DEV12576_sg     4         28            3           2     40256
# [2025.09.04 21:22:09.995] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:22:09.995] INFO      TOTAL                           38            3                 48256
# [2025.09.04 21:22:09.995] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:22:10.000] INFO    Finished LabOne Q Compiler run.
# [2025.09.04 21:22:10.001] INFO    Task 'compile_experiment': ended at 2025-09-04 12:22:10.001275Z
# [2025.09.04 21:22:10.007] INFO    Task 'run_experiment': started at 2025-09-04 12:22:10.007354Z
# [2025.09.04 21:22:10.008] INFO    Connecting to data server at 10.172.11.217:8004
# [2025.09.04 21:22:10.014] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 10.172.11.217:8004
# [2025.09.04 21:22:10.018] INFO    Configuring the device setup
# [2025.09.04 21:22:10.026] INFO    The device setup is configured
# [2025.09.04 21:22:10.272] INFO    Starting near-time execution...
# [2025.09.04 21:22:10.311] INFO    Estimated RT execution time: 108.84 s.
# [2025.09.04 21:23:59.203] INFO    Finished near-time execution.
# [2025.09.04 21:23:59.311] INFO    Task 'run_experiment': ended at 2025-09-04 12:23:59.310777Z
# [2025.09.04 21:23:59.312] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:23:59.312] INFO      Workflow 'analysis_workflow': execution started at 2025-09-04
# [2025.09.04 21:23:59.312] INFO      12:23:59.312180Z
# [2025.09.04 21:23:59.313] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:23:59.314] INFO    Task 'calculate_signal_magnitude_and_phase': started at 2025-09-04
# [2025.09.04 21:23:59.315] INFO    12:23:59.314644Z
# [2025.09.04 21:23:59.315] INFO    Task 'calculate_signal_magnitude_and_phase': ended at 2025-09-04
# [2025.09.04 21:23:59.315] INFO    12:23:59.315374Z
# [2025.09.04 21:23:59.315] WARNING Type <class 'dict'> not supported by the serializer [name: calculate_signal_magnitude_and_phase.output.q4].
# [2025.09.04 21:23:59.316] INFO    Task 'fit_data': started at 2025-09-04 12:23:59.316194Z
# [2025.09.04 21:23:59.316] WARNING Type <class 'dict'> not supported by the serializer [name: fit_data.input.processed_data_dict].
# [2025.09.04 21:23:59.322] INFO    Task 'fit_data': ended at 2025-09-04 12:23:59.321894Z
# [2025.09.04 21:23:59.322] WARNING Type <class 'lmfit.model.ModelResult'> not supported by the serializer [name: fit_data.output.q4].
# [2025.09.04 21:23:59.322] INFO    Task 'extract_qubit_parameters': started at 2025-09-04 12:23:59.322799Z
# [2025.09.04 21:23:59.323] WARNING Type <class 'dict'> not supported by the serializer [name: extract_qubit_parameters.input.fit_results].
# [2025.09.04 21:23:59.324] INFO    Task 'extract_qubit_parameters': ended at 2025-09-04 12:23:59.324139Z
# [2025.09.04 21:23:59.324] WARNING Type <class 'dict'> not supported by the serializer [name: extract_qubit_parameters.output.new_parameter_values].
# [2025.09.04 21:23:59.325] INFO    Task 'plot_raw_complex_data_1d': started at 2025-09-04 12:23:59.324861Z
# [2025.09.04 21:23:59.335] INFO    Artifact: 'Raw_data_q4' of type 'Figure' logged at 2025-09-04 12:23:59.335019Z
# [2025.09.04 21:23:59.419] INFO    Task 'plot_raw_complex_data_1d': ended at 2025-09-04 12:23:59.419620Z
# [2025.09.04 21:23:59.420] INFO    Task 'plot_qubit_spectroscopy': started at 2025-09-04 12:23:59.420348Z
# [2025.09.04 21:23:59.420] WARNING Type <class 'dict'> not supported by the serializer [name: plot_qubit_spectroscopy.input.processed_data_dict].
# [2025.09.04 21:23:59.421] WARNING Type <class 'dict'> not supported by the serializer [name: plot_qubit_spectroscopy.input.fit_results].
# [2025.09.04 21:23:59.421] WARNING Type <class 'dict'> not supported by the serializer [name: plot_qubit_spectroscopy.input.qubit_parameters].
# [2025.09.04 21:23:59.427] INFO    Artifact: 'Qubit_Spectroscopy_q4' of type 'Figure' logged at 2025-09-04
# [2025.09.04 21:23:59.428] INFO    12:23:59.427497Z
# [2025.09.04 21:23:59.689] INFO    Task 'plot_qubit_spectroscopy': ended at 2025-09-04 12:23:59.688921Z
# [2025.09.04 21:23:59.690] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:23:59.690] INFO      Workflow 'analysis_workflow': execution ended at 2025-09-04 12:23:59.689819Z
# [2025.09.04 21:23:59.690] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:23:59.690] WARNING Type <class 'dict'> not supported by the serializer [name: analysis_workflow.output.new_parameter_values].
# [2025.09.04 21:23:59.691] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:23:59.691] INFO      Workflow 'qubit_spectroscopy': execution ended at 2025-09-04
# [2025.09.04 21:23:59.691] INFO      12:23:59.691006Z
# [2025.09.04 21:23:59.691] INFO     ──────────────────────────────────────────────────────────────────────────────
# WorkflowResult(name=qubit_spectroscopy, index=())

# %% [markdown]
# # 2. Rabi

# %% [markdown]
# ## 2.1 Rabi Amplitude

# %%
qubits[4].parameters.ge_drive_amplitude_pi = 0.2571
qubits[4].parameters.ge_drive_amplitude_pi2 = 0.1222

# %%
from laboneq_applications.experiments import amplitude_rabi
q = qubits[4]

#######################################################################
amplitudes = np.linspace(0.02, 1.0,501)
print(q.parameters.ge_drive_amplitude_pi)
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = amplitude_rabi.experiment_workflow.options()
options.update(False)
options.use_cal_traces(False)
#print(workflow.show_fields(options))

###################################################################
rabi_amp = amplitude_rabi.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    amplitudes=amplitudes,
    options=options
)

rabi_amp_result = rabi_amp.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(rabi_amp_result.tasks['analysis_workflow'].output)
# Out:
# 0.2
# DRIVE range (dBm) : -10, READOUT range (dBm) : -25
# [2025.09.04 21:18:51.420] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:18:51.420] INFO      Workflow 'amplitude_rabi': execution started at 2025-09-04 12:18:51.419811Z
# [2025.09.04 21:18:51.421] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:18:51.431] INFO    Task 'temporary_qpu': started at 2025-09-04 12:18:51.431297Z
# [2025.09.04 21:18:51.432] INFO    Task 'temporary_qpu': ended at 2025-09-04 12:18:51.432282Z
# [2025.09.04 21:18:51.434] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2025-09-04
# [2025.09.04 21:18:51.435] INFO    12:18:51.434582Z
# [2025.09.04 21:18:51.435] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2025-09-04 12:18:51.435721Z
# [2025.09.04 21:18:51.437] INFO    Task 'create_experiment': started at 2025-09-04 12:18:51.436907Z
# [2025.09.04 21:18:51.443] INFO    Task 'create_experiment': ended at 2025-09-04 12:18:51.442851Z
# [2025.09.04 21:18:51.444] INFO    Task 'compile_experiment': started at 2025-09-04 12:18:51.444594Z
# [2025.09.04 21:18:51.446] INFO    Resolved modulation type of oscillator 'q4_readout_acquire_osc' on signal 'q4/acquire' to SOFTWARE
# [2025.09.04 21:18:51.446] INFO    Resolved modulation type of oscillator 'q4_drive_ge_osc' on signal 'q4/drive' to HARDWARE
# [2025.09.04 21:18:51.447] INFO    Starting LabOne Q Compiler run...
# [2025.09.04 21:18:51.531] INFO    Schedule completed. [0.083 s]
# [2025.09.04 21:18:51.753] INFO    Code generation completed for all AWGs. [0.222 s]
# [2025.09.04 21:18:51.754] INFO    Completed compilation step 1 of 1. [0.306 s]
# [2025.09.04 21:18:51.756] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:18:51.756] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2025.09.04 21:18:51.756] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:18:51.757] INFO      SHFQC_DEV12576        0         10            0           1      8000
# [2025.09.04 21:18:51.757] INFO      SHFQC_DEV12576_sg     4       1011          502           1       256
# [2025.09.04 21:18:51.757] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:18:51.757] INFO      TOTAL                         1021          502                  8256
# [2025.09.04 21:18:51.757] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:18:51.771] INFO    Finished LabOne Q Compiler run.
# [2025.09.04 21:18:51.771] INFO    Task 'compile_experiment': ended at 2025-09-04 12:18:51.771658Z
# [2025.09.04 21:18:51.785] INFO    Task 'run_experiment': started at 2025-09-04 12:18:51.785221Z
# [2025.09.04 21:18:51.786] INFO    Connecting to data server at 10.172.11.217:8004
# [2025.09.04 21:18:51.792] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 10.172.11.217:8004
# [2025.09.04 21:18:51.795] INFO    Configuring the device setup
# [2025.09.04 21:18:51.802] INFO    The device setup is configured
# [2025.09.04 21:18:52.033] INFO    Starting near-time execution...
# [2025.09.04 21:18:52.090] INFO    Estimated RT execution time: 11.32 s.
# [2025.09.04 21:19:03.431] WARNING SHFQC/QA:dev12576: Channel 0 Output overrange count: 1115
# [2025.09.04 21:19:03.471] INFO    Finished near-time execution.
# [2025.09.04 21:19:03.527] INFO    Task 'run_experiment': ended at 2025-09-04 12:19:03.527493Z
# [2025.09.04 21:19:03.529] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:19:03.529] INFO      Workflow 'analysis_workflow': execution started at 2025-09-04
# [2025.09.04 21:19:03.529] INFO      12:19:03.528997Z
# [2025.09.04 21:19:03.530] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:19:03.532] INFO    Task 'calculate_qubit_population': started at 2025-09-04 12:19:03.532294Z
# [2025.09.04 21:19:03.533] INFO    Task 'calculate_qubit_population': ended at 2025-09-04 12:19:03.533511Z
# [2025.09.04 21:19:03.534] WARNING Type <class 'dict'> not supported by the serializer [name: calculate_qubit_population.output.q4].
# [2025.09.04 21:19:03.534] INFO    Task 'fit_data': started at 2025-09-04 12:19:03.534556Z
# [2025.09.04 21:19:03.534] WARNING Type <class 'dict'> not supported by the serializer [name: fit_data.input.processed_data_dict].
# [2025.09.04 21:19:03.537] INFO    Task 'fit_data': ended at 2025-09-04 12:19:03.537793Z
# [2025.09.04 21:19:03.538] WARNING Type <class 'lmfit.model.ModelResult'> not supported by the serializer [name: fit_data.output.q4].
# [2025.09.04 21:19:03.538] INFO    Task 'extract_qubit_parameters': started at 2025-09-04 12:19:03.538464Z
# [2025.09.04 21:19:03.538] WARNING Type <class 'dict'> not supported by the serializer [name: extract_qubit_parameters.input.processed_data_dict].
# [2025.09.04 21:19:03.538] WARNING Type <class 'dict'> not supported by the serializer [name: extract_qubit_parameters.input.fit_results].
# [2025.09.04 21:19:03.540] INFO    Task 'extract_qubit_parameters': ended at 2025-09-04 12:19:03.540244Z
# [2025.09.04 21:19:03.540] WARNING Type <class 'dict'> not supported by the serializer [name: extract_qubit_parameters.output.new_parameter_values].
# [2025.09.04 21:19:03.541] INFO    Task 'plot_raw_complex_data_1d': started at 2025-09-04 12:19:03.541488Z
# [2025.09.04 21:19:03.551] INFO    Artifact: 'Raw_data_q4' of type 'Figure' logged at 2025-09-04 12:19:03.551560Z
# [2025.09.04 21:19:03.634] INFO    Task 'plot_raw_complex_data_1d': ended at 2025-09-04 12:19:03.634646Z
# [2025.09.04 21:19:03.635] INFO    Task 'plot_population': started at 2025-09-04 12:19:03.635675Z
# [2025.09.04 21:19:03.636] WARNING Type <class 'dict'> not supported by the serializer [name: plot_population.input.processed_data_dict].
# [2025.09.04 21:19:03.636] WARNING Type <class 'dict'> not supported by the serializer [name: plot_population.input.fit_results].
# [2025.09.04 21:19:03.636] WARNING Type <class 'dict'> not supported by the serializer [name: plot_population.input.qubit_parameters].
# [2025.09.04 21:19:03.643] INFO    Artifact: 'Rabi_q4' of type 'Figure' logged at 2025-09-04 12:19:03.643360Z
# [2025.09.04 21:19:03.709] INFO    Task 'plot_population': ended at 2025-09-04 12:19:03.709094Z
# [2025.09.04 21:19:03.710] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:19:03.710] INFO      Workflow 'analysis_workflow': execution ended at 2025-09-04 12:19:03.710073Z
# [2025.09.04 21:19:03.710] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:19:03.711] WARNING Type <class 'dict'> not supported by the serializer [name: analysis_workflow.output.new_parameter_values].
# [2025.09.04 21:19:03.711] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:19:03.712] INFO      Workflow 'amplitude_rabi': execution ended at 2025-09-04 12:19:03.711696Z
# [2025.09.04 21:19:03.712] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'old_parameter_values': {'q4': {'ge_drive_amplitude_pi': 0.2, 'ge_drive_amplitude_pi2': 0.1}}, 'new_parameter_values': {'q4': {'ge_drive_amplitude_pi': 0.25706810163274224+/-0.0026901872506446822, 'ge_drive_amplitude_pi2': 0.12224549703314205+/-0.002518954188039887}}}

# %% [markdown]
# ## 2.2 (optional) Rabi Amplitude Chevron

# %%
from experiments import amplitude_rabi_chevron

#######################################################################
q = qubits[4]
amplitudes = np.linspace(0,0.5,11)
frequencies = q.parameters.resonance_frequency_ge + np.linspace(-3e6, 3e6, 51)
print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
#######################################################################
options = amplitude_rabi_chevron.experiment_workflow.options()

#print(workflow.show_fields(options))

###################################################################
rabi_amp_chev = amplitude_rabi_chevron.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    frequencies=frequencies,
    amplitudes=amplitudes,
    options=options
)

rabi_amp_chev_result = rabi_amp_chev.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(rabi_amp_chev_result.tasks['analysis_workflow'].output)
# Out:
# DRIVE range (dBm) : 0, READOUT range (dBm) : -25
# [2025.09.04 21:11:27.995] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:11:27.995] INFO      Workflow 'amplitude_rabi_chevron': execution started at 2025-09-04
# [2025.09.04 21:11:27.996] INFO      12:11:27.994975Z
# [2025.09.04 21:11:27.996] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:11:28.007] INFO    Task 'create_experiment': started at 2025-09-04 12:11:28.007238Z
# [2025.09.04 21:11:28.014] INFO    Task 'create_experiment': ended at 2025-09-04 12:11:28.013843Z
# [2025.09.04 21:11:28.015] INFO    Task 'compile_experiment': started at 2025-09-04 12:11:28.015275Z
# [2025.09.04 21:11:28.017] INFO    Resolved modulation type of oscillator 'q4_readout_acquire_osc' on signal 'q4/acquire' to SOFTWARE
# [2025.09.04 21:11:28.017] INFO    Resolved modulation type of oscillator 'q4_drive_ge_osc' on signal 'q4/drive' to HARDWARE
# [2025.09.04 21:11:28.017] INFO    Starting LabOne Q Compiler run...
# [2025.09.04 21:11:28.387] INFO    Schedule completed. [0.368 s]
# [2025.09.04 21:11:28.538] INFO    Code generation completed for all AWGs. [0.150 s]
# [2025.09.04 21:11:28.539] INFO    Completed compilation step 1 of 1. [0.520 s]
# [2025.09.04 21:11:28.540] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:11:28.541] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2025.09.04 21:11:28.541] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:11:28.541] INFO      SHFQC_DEV12576        0         14            0           1      8000
# [2025.09.04 21:11:28.542] INFO      SHFQC_DEV12576_sg     4        180           12           2       448
# [2025.09.04 21:11:28.542] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:11:28.542] INFO      TOTAL                          194           12                  8448
# [2025.09.04 21:11:28.542] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:11:28.548] INFO    Finished LabOne Q Compiler run.
# [2025.09.04 21:11:28.548] INFO    Task 'compile_experiment': ended at 2025-09-04 12:11:28.548518Z
# [2025.09.04 21:11:28.555] INFO    Task 'run_experiment': started at 2025-09-04 12:11:28.555014Z
# [2025.09.04 21:11:28.556] INFO    Connecting to data server at 10.172.11.217:8004
# [2025.09.04 21:11:28.563] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 10.172.11.217:8004
# [2025.09.04 21:11:28.567] INFO    Configuring the device setup
# [2025.09.04 21:11:28.575] INFO    The device setup is configured
# [2025.09.04 21:11:28.844] INFO    Starting near-time execution...
# [2025.09.04 21:11:28.887] INFO    Estimated RT execution time: 38.03 s.
# [2025.09.04 21:12:06.977] INFO    Finished near-time execution.
# [2025.09.04 21:12:07.048] INFO    Task 'run_experiment': ended at 2025-09-04 12:12:07.048265Z
# [2025.09.04 21:12:07.050] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:12:07.050] INFO      Workflow 'analysis_workflow': execution started at 2025-09-04
# [2025.09.04 21:12:07.050] INFO      12:12:07.049765Z
# [2025.09.04 21:12:07.050] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:12:07.052] INFO    Task 'calculate_qubit_population_2d': started at 2025-09-04 12:12:07.051978Z
# [2025.09.04 21:12:07.053] INFO    Task 'calculate_qubit_population_2d': ended at 2025-09-04 12:12:07.053034Z
# [2025.09.04 21:12:07.053] WARNING Type <class 'dict'> not supported by the serializer [name: calculate_qubit_population_2d.output.q4].
# [2025.09.04 21:12:07.053] INFO    Task 'plot_population': started at 2025-09-04 12:12:07.053713Z
# [2025.09.04 21:12:07.054] WARNING Type <class 'dict'> not supported by the serializer [name: plot_population.input.processed_data_dict].
# [2025.09.04 21:12:07.064] INFO    Artifact: 'Amplitude_Rabi_Chevron_q4' of type 'Figure' logged at 2025-09-04
# [2025.09.04 21:12:07.064] INFO    12:12:07.064127Z
# [2025.09.04 21:12:07.123] INFO    Task 'plot_population': ended at 2025-09-04 12:12:07.123312Z
# [2025.09.04 21:12:07.124] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:12:07.124] INFO      Workflow 'analysis_workflow': execution ended at 2025-09-04 12:12:07.124251Z
# [2025.09.04 21:12:07.124] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:12:07.125] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:12:07.126] INFO      Workflow 'amplitude_rabi_chevron': execution ended at 2025-09-04
# [2025.09.04 21:12:07.126] INFO      12:12:07.125625Z
# [2025.09.04 21:12:07.126] INFO     ──────────────────────────────────────────────────────────────────────────────
# None

# %% [markdown]
# ## 2.3 (optional) Rabi Length
# - Not working yet

# %%
# from experiments import time_rabi
# #######################################################################
# q = qubits[2]
# q.parameters.ge_drive_amplitude_pi = 0.3
# lengths = np.linspace(0.0, 240e-9, 21 ),
# print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
# #######################################################################
# options = time_rabi.experiment_workflow.options()

# #print(workflow.show_fields(options))

# ###################################################################
# rabi_length = time_rabi.experiment_workflow(
#     session=session,
#     qpu=qpu,
#     qubits=q,
#     lengths=lengths,
#     options=options
# )

# rabi_length_result = rabi_length.run()
# #qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
# print(rabi_length_result.tasks['analysis_workflow'].output)

# %% [markdown]
# ## 2.2 (optional) Rabi Length Chevron

# %%
# from experiments import time_rabi_chevron
# #######################################################################
# q = qubits[4]

# frequencies = q.parameters.resonance_frequency_ge + np.linspace(-5e6, 5e6, 21)
# lengths = np.linspace(0.0, 240e-9, 21 ),
# print(f"DRIVE range (dBm) : {q.parameters.drive_range}, READOUT range (dBm) : {q.parameters.readout_range_out}")
# #######################################################################
# options = time_rabi_chevron.experiment_workflow.options()

# #print(workflow.show_fields(options))

# ###################################################################
# rabi_length_chev = time_rabi_chevron.experiment_workflow(
#     session=session,
#     qpu=qpu,
#     qubits=q,
#     frequencies=frequencies,
#     lengths=lengths,
#     options=options
# )

# rabi_length_chev_result = rabi_length_chev.run()
# #qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
# print(rabi_length_chev_result.tasks['analysis_workflow'].output)
# Out:
# DRIVE range (dBm) : 0, READOUT range (dBm) : -25
# [2025.09.04 21:11:10.036] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:11:10.036] INFO      Workflow 'time_rabi_chevron': execution started at 2025-09-04
# [2025.09.04 21:11:10.037] INFO      12:11:10.035846Z
# [2025.09.04 21:11:10.037] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:11:10.041] WARNING Type <class 'tuple'> not supported by the serializer [name: time_rabi_chevron.input.lengths].
# [2025.09.04 21:11:10.047] INFO    Task 'create_experiment': started at 2025-09-04 12:11:10.047649Z
# [2025.09.04 21:11:10.048] WARNING Type <class 'tuple'> not supported by the serializer [name: create_experiment.input.lengths].
# [2025.09.04 21:11:10.053] ERROR   Task 'create_experiment': failed at 2025-09-04 12:11:10.052956Z with:
# [2025.09.04 21:11:10.053] ERROR   Task 'create_experiment': failed at 2025-09-04 12:11:10.052956Z with:
# [2025.09.04 21:11:10.053] ERROR   TypeError("'tuple' object does not support item assignment")
# [2025.09.04 21:11:10.053] ERROR   TypeError("'tuple' object does not support item assignment")
# [2025.09.04 21:11:10.054] INFO    Task 'create_experiment': ended at 2025-09-04 12:11:10.054008Z
# [2025.09.04 21:11:10.055] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:11:10.055] INFO      Workflow 'time_rabi_chevron': execution ended at 2025-09-04 12:11:10.054957Z
# [2025.09.04 21:11:10.055] INFO     ──────────────────────────────────────────────────────────────────────────────
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 23
#      11 #print(workflow.show_fields(options))
#      12
#      13 ###################################################################
#      14 rabi_length_chev = time_rabi_chevron.experiment_workflow(
#      15     session=session,
#      16     qpu=qpu,
#    (...)     20     options=options
#      21 )
# ---> 23 rabi_length_chev_result = rabi_length_chev.run()
#      24 #qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
#      25 print(rabi_length_chev_result.tasks['analysis_workflow'].output)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/core.py:218, in Workflow.run(self, until)
#     214 for logstore in self._logstores():
#     215     state.add_recorder(
#     216         logstore.create_logbook(self, start_time=state.start_time)
#     217     )
# --> 218 return self._execute(state)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/core.py:128, in Workflow._execute(self, state)
#     126 try:
#     127     with executor.ExecutorStateContext.scoped(state):
# --> 128         self._root.execute(state)
#     129 except Exception:
#     130     if self._recovery is not None:
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/blocks/workflow_block.py:159, in WorkflowBlock.execute(self, executor)
#     154     if executor.get_block_status(block) in (
#     155         ExecutionStatus.FINISHED,
#     156         ExecutionStatus.SKIPPED,
#     157     ):
#     158         continue
# --> 159     block.execute(executor)
#     160 body_loop_finished = True
#     161 executor.set_block_status(self, ExecutionStatus.FINISHED)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/blocks/task_block.py:61, in TaskBlock.execute(self, executor)
#      59     self._exucute_hidden(executor)
#      60 else:
# ---> 61     self._execute_visible(executor)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/blocks/task_block.py:91, in TaskBlock._execute_visible(self, executor)
#      89 executor.set_block_status(self, ExecutionStatus.IN_PROGRESS)
#      90 try:
# ---> 91     task._output = self.task.func(**params)
#      92 except Exception as error:
#      93     task._end_time = utc_now()
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/dsl/experiment/build_experiment.py:201, in qubit_experiment.<locals>.build_qubit_experiment(*args, **kw)
#     199 @functools.wraps(exp_func)
#     200 def build_qubit_experiment(*args, **kw) -> Experiment:
# --> 201     return builder(*args, **kw)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/dsl/experiment/build_experiment.py:126, in ExperimentBuilder.__call__(self, *args, **kw)
#     124     exp_calibration.calibration_items.update(calibration)
#     125     if self.context:
# --> 126         self.exp_func(*args, **kw)
#     128 if not self.context:
#     129     self.exp_func(exp, *args, **kw)
#
# File ~/JSAHN/qubit-experiment/experiments/time_rabi_chevron.py:195, in create_experiment(qpu, qubits, frequencies, lengths, options)
#     192 opts = TuneupExperimentOptions() if options is None else options
#     194 _, frequencies = validate_and_convert_qubits_sweeps(qubits, frequencies)
# --> 195 qubits, lengths = validate_and_convert_qubits_sweeps(qubits, lengths)
#     197 qop = qpu.quantum_operations
#     198 with dsl.acquire_loop_rt(
#     199     count=opts.count,
#     200     averaging_mode=opts.averaging_mode,
#    (...)    204     reset_oscillator_phase=opts.reset_oscillator_phase,
#     205 ):
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/variable_tracker.py:77, in track.<locals>.inner(*args, **kwargs)
#      75         for k, v in frame.f_back.f_locals.items():
#      76             ctx.add_variable(k, v)
# ---> 77 return func(*args, **kwargs)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq/workflow/task_wrapper.py:85, in task_.__call__(self, *args, **kwargs)
#      83     root.extend(block)
#      84     return cast(B, block.ref)
# ---> 85 return self._func(*args, **kwargs)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq_applications/core/validation.py:226, in validate_and_convert_qubits_sweeps(qubits, sweep_points)
#     224 # Make sure the sweep points are arrays or lists of arrays
#     225 if sweep_points is not None:
# --> 226     sweep_points = validate_and_convert_sweeps_to_arrays(sweep_points)
#     228 # Make sure the length of qubits and sweep points is the same
#     229 qubits_sweep_points = validate_length_qubits_sweeps(qubits, sweep_points)
#
# File ~/JSAHN/qubit-experiment/.venv/lib/python3.12/site-packages/laboneq_applications/core/validation.py:79, in validate_and_convert_sweeps_to_arrays(sweep_points)
#      76     # we do not do list comprehension here in order to keep the original type of
#      77     # sweep_points, which might be an array
#      78     for i in range(len(sweep_points)):
# ---> 79         sweep_points[i] = np.array(sweep_points[i])
#      81 return sweep_points
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # 3. Ramsey

# %%
from experiments import ramsey

q = qubits[4]
#######################################################################
delays = np.linspace(0,20e-6,301)
detunings = 0.4e6
pprint(q.readout_parameters())
#######################################################################
options = ramsey.experiment_workflow.options()
options.update(True)
options.count(1024)
options.use_cal_traces(True)
# Build and run Ramsey workflow (no explicit command table options required)
ramsey_wf = ramsey.experiment_workflow(
    session=session,
    qpu=qpu,
    qubits=q,
    delays=delays,
    detunings=detunings,
    options=options
)
ramsey_result = ramsey_wf.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(ramsey_result.tasks['analysis_workflow'].output)
# Out:
# ('measure',
#  {'amplitude': 0.6,
#   'length': 2e-06,
#   'pulse': {'function': 'GaussianSquare',
#             'risefall_sigma_ratio': 3.0,
#             'sigma': 0.2}})
# [2025.09.04 21:32:57.789] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:32:57.790] INFO      Workflow 'ramsey': execution started at 2025-09-04 12:32:57.789681Z
# [2025.09.04 21:32:57.790] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:32:57.800] INFO    Task 'temporary_qpu': started at 2025-09-04 12:32:57.800013Z
# [2025.09.04 21:32:57.801] INFO    Task 'temporary_qpu': ended at 2025-09-04 12:32:57.801033Z
# [2025.09.04 21:32:57.803] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2025-09-04
# [2025.09.04 21:32:57.803] INFO    12:32:57.803162Z
# [2025.09.04 21:32:57.804] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2025-09-04 12:32:57.804118Z
# [2025.09.04 21:32:57.805] INFO    Task 'create_experiment': started at 2025-09-04 12:32:57.805145Z
# [2025.09.04 21:32:57.811] INFO    Task 'create_experiment': ended at 2025-09-04 12:32:57.811070Z
# [2025.09.04 21:32:57.813] INFO    Task 'compile_experiment': started at 2025-09-04 12:32:57.812874Z
# [2025.09.04 21:32:57.815] INFO    Resolved modulation type of oscillator 'q4_readout_acquire_osc' on signal 'q4/acquire' to SOFTWARE
# [2025.09.04 21:32:57.815] INFO    Resolved modulation type of oscillator 'q4_drive_ge_osc' on signal 'q4/drive' to HARDWARE
# [2025.09.04 21:32:57.816] INFO    Starting LabOne Q Compiler run...
# [2025.09.04 21:32:58.078] INFO    Schedule completed. [0.261 s]
# [2025.09.04 21:32:58.133] INFO    Code generation completed for all AWGs. [0.055 s]
# [2025.09.04 21:32:58.134] INFO    Completed compilation step 1 of 1. [0.316 s]
# [2025.09.04 21:32:58.136] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:32:58.136] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2025.09.04 21:32:58.136] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:32:58.137] INFO      SHFQC_DEV12576        0        912            0           1      8000
# [2025.09.04 21:32:58.137] INFO      SHFQC_DEV12576_sg     4       1443           79          77     19776
# [2025.09.04 21:32:58.137] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:32:58.138] INFO      TOTAL                         2355           79                 27776
# [2025.09.04 21:32:58.138] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:32:58.161] INFO    Finished LabOne Q Compiler run.
# [2025.09.04 21:32:58.162] INFO    Task 'compile_experiment': ended at 2025-09-04 12:32:58.162260Z
# [2025.09.04 21:32:58.173] INFO    Task 'run_experiment': started at 2025-09-04 12:32:58.173155Z
# [2025.09.04 21:32:58.174] INFO    Connecting to data server at 10.172.11.217:8004
# [2025.09.04 21:32:58.181] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 10.172.11.217:8004
# [2025.09.04 21:32:58.184] INFO    Configuring the device setup
# [2025.09.04 21:32:58.193] INFO    The device setup is configured
# [2025.09.04 21:32:58.440] INFO    Starting near-time execution...
# [2025.09.04 21:32:58.491] INFO    Estimated RT execution time: 9.95 s.
# [2025.09.04 21:33:08.490] INFO    Finished near-time execution.
# [2025.09.04 21:33:08.544] INFO    Task 'run_experiment': ended at 2025-09-04 12:33:08.544658Z
# [2025.09.04 21:33:08.546] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:33:08.546] INFO      Workflow 'analysis_workflow': execution started at 2025-09-04
# [2025.09.04 21:33:08.546] INFO      12:33:08.545947Z
# [2025.09.04 21:33:08.546] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:33:08.549] INFO    Task 'calculate_qubit_population': started at 2025-09-04 12:33:08.548871Z
# [2025.09.04 21:33:08.550] INFO    Task 'calculate_qubit_population': ended at 2025-09-04 12:33:08.549875Z
# [2025.09.04 21:33:08.550] WARNING Type <class 'dict'> not supported by the serializer [name: calculate_qubit_population.output.q4].
# [2025.09.04 21:33:08.550] INFO    Task 'fit_data': started at 2025-09-04 12:33:08.550557Z
# [2025.09.04 21:33:08.550] WARNING Type <class 'dict'> not supported by the serializer [name: fit_data.input.processed_data_dict].
# [2025.09.04 21:33:08.555] INFO    Task 'fit_data': ended at 2025-09-04 12:33:08.554861Z
# [2025.09.04 21:33:08.555] WARNING Type <class 'lmfit.model.ModelResult'> not supported by the serializer [name: fit_data.output.q4].
# [2025.09.04 21:33:08.555] INFO    Task 'extract_qubit_parameters': started at 2025-09-04 12:33:08.555507Z
# [2025.09.04 21:33:08.555] WARNING Type <class 'dict'> not supported by the serializer [name: extract_qubit_parameters.input.fit_results].
# [2025.09.04 21:33:08.556] INFO    Task 'extract_qubit_parameters': ended at 2025-09-04 12:33:08.556425Z
# [2025.09.04 21:33:08.556] WARNING Type <class 'dict'> not supported by the serializer [name: extract_qubit_parameters.output.new_parameter_values].
# [2025.09.04 21:33:08.557] INFO    Task 'plot_raw_complex_data_1d': started at 2025-09-04 12:33:08.557072Z
# [2025.09.04 21:33:08.570] INFO    Artifact: 'Raw_data_q4' of type 'Figure' logged at 2025-09-04 12:33:08.570035Z
# [2025.09.04 21:33:08.654] INFO    Task 'plot_raw_complex_data_1d': ended at 2025-09-04 12:33:08.654329Z
# [2025.09.04 21:33:08.655] INFO    Task 'plot_population': started at 2025-09-04 12:33:08.655119Z
# [2025.09.04 21:33:08.655] WARNING Type <class 'dict'> not supported by the serializer [name: plot_population.input.processed_data_dict].
# [2025.09.04 21:33:08.655] WARNING Type <class 'dict'> not supported by the serializer [name: plot_population.input.fit_results].
# [2025.09.04 21:33:08.656] WARNING Type <class 'dict'> not supported by the serializer [name: plot_population.input.qubit_parameters].
# [2025.09.04 21:33:08.662] INFO    Artifact: 'Ramsey_q4' of type 'Figure' logged at 2025-09-04 12:33:08.662590Z
# [2025.09.04 21:33:08.739] INFO    Task 'plot_population': ended at 2025-09-04 12:33:08.739705Z
# [2025.09.04 21:33:08.740] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:33:08.741] INFO      Workflow 'analysis_workflow': execution ended at 2025-09-04 12:33:08.740567Z
# [2025.09.04 21:33:08.741] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:33:08.741] WARNING Type <class 'dict'> not supported by the serializer [name: analysis_workflow.output.new_parameter_values].
# [2025.09.04 21:33:08.742] INFO    Task 'update_qubits': started at 2025-09-04 12:33:08.742165Z
# [2025.09.04 21:33:08.742] WARNING Type <class 'dict'> not supported by the serializer [name: update_qubits.input.qubit_parameters].
# [2025.09.04 21:33:08.743] INFO    Task 'update_qubits': ended at 2025-09-04 12:33:08.742950Z
# [2025.09.04 21:33:08.743] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:33:08.743] INFO      Workflow 'ramsey': execution ended at 2025-09-04 12:33:08.743375Z
# [2025.09.04 21:33:08.743] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'old_parameter_values': {'q4': {'resonance_frequency_ge': 4779000000.0, 'ge_T2_star': 0}}, 'new_parameter_values': {'q4': {'resonance_frequency_ge': 4779020371.683766+/-547.9576654963022, 'ge_T2_star': 1.7807723843299428e-05+/-6.597211757679217e-07}}}

# %%
from laboneq_applications.experiments import amplitude_fine
q = qubits[4]
temporary_parameters = q.parameters.copy()

#######################################################################
repetitions =np.arange(1,50)
#######################################################################
options = amplitude_fine.experiment_workflow_x180.options()
workflow.show_fields(options)
# Out:
# Option Fields
# =============
# acquisition_type:
# 	Description: Acquisition type to use for the experiment.
# 	Classes and Defaults: [('TuneupExperimentOptions', AcquisitionType.INTEGRATION)],
#
# active_reset:
# 	Description: Whether to use active reset.
# 	Classes and Defaults: [('TuneupExperimentOptions', False)],
#
# active_reset_repetitions:
# 	Description: The number of times to repeat the active resets.
# 	Classes and Defaults: [('TuneupExperimentOptions', 1)],
#
# active_reset_states:
# 	Description: The qubit states to actively reset.
# 	Classes and Defaults: [('TuneupExperimentOptions', 'ge')],
#
# averaging_mode:
# 	Description: Averaging mode to use for the experiment.
# 	Classes and Defaults: [('TuneupExperimentOptions', AveragingMode.CYCLIC)],
#
# cal_states:
# 	Description: The states to prepare in the calibration traces.
# 	Classes and Defaults: [('TuneupExperimentOptions', 'ge'), ('CalculateQubitPopulationOptions', 'ge'), ('PlotPopulationOptions', 'ge')],
#
# 	Description: The states to prepare in the calibration traces.Can be any string or tuple made from combining the characters 'g', 'e', 'f'.
# 	Classes and Defaults: [('PlotRawDataOptions', 'ge')],
#
# close_figures:
# 	Description: Whether to close the figures.
# 	Classes and Defaults: [('PlotRawDataOptions', True), ('PlotPopulationOptions', True)],
#
# compiler_settings:
# 	Description: Optional settings to pass to the compiler.
# 	Classes and Defaults: [('CompileExperimentOptions', None)],
#
# count:
# 	Description: The number of repetitions.
# 	Classes and Defaults: [('TuneupExperimentOptions', 1024)],
#
# do_analysis:
# 	Description: Whether to run the analysis workflow.
# 	Classes and Defaults: [('TuneUpWorkflowOptions', True)],
#
# do_fitting:
# 	Description: Whether to perform the fit.
# 	Classes and Defaults: [('TuneUpAnalysisWorkflowOptions', True), ('FitDataOptions', True), ('DoFittingOption', True), ('ExtractQubitParametersTransitionOptions', True), ('PlotPopulationOptions', True)],
#
# do_pca:
# 	Description: Whether to perform principal component analysis on the raw data independent of whether there were calibration traces in the experiment.
# 	Classes and Defaults: [('CalculateQubitPopulationOptions', False), ('PlotPopulationOptions', False)],
#
# do_plotting:
# 	Description: Whether to make plots.
# 	Classes and Defaults: [('TuneUpAnalysisWorkflowOptions', True)],
#
# do_qubit_population_plotting:
# 	Description: Whether to plot the qubit population.
# 	Classes and Defaults: [('TuneUpAnalysisWorkflowOptions', True)],
#
# do_raw_data_plotting:
# 	Description: Whether to plot the raw data.
# 	Classes and Defaults: [('TuneUpAnalysisWorkflowOptions', True)],
#
# do_rotation:
# 	Description: Whether to rotate the raw data based on calibration traces or principal component analysis.
# 	Classes and Defaults: [('CalculateQubitPopulationOptions', True), ('FitDataOptions', True), ('PlotPopulationOptions', True)],
#
# figure_size_raw_data:
# 	Description: The size of the figure.
# 	Classes and Defaults: [('PlotRawDataOptions', None)],
#
# fit_parameters_hints:
# 	Description: Parameters hints accepted by lmfit.
# 	Classes and Defaults: [('FitDataOptions', None)],
#
# include_results_metadata:
# 	Description: Passed to `Session.run` to specify whether the `.device_setup`, `.experiment` and `.compiled_experiment` attributes of the result should be populated.
# 	Classes and Defaults: [('RunExperimentOptions', False)],
#
# logstore:
# 	Description: The logstores to use.
# 	Classes and Defaults: [('TuneUpWorkflowOptions', None), ('TuneUpAnalysisWorkflowOptions', None)],
#
# repetition_mode:
# 	Description: The repetition mode to use for the experiment.
# 	Classes and Defaults: [('TuneupExperimentOptions', RepetitionMode.FASTEST)],
#
# repetition_time:
# 	Description: The repetition time.
# 	Classes and Defaults: [('TuneupExperimentOptions', None)],
#
# reset_oscillator_phase:
# 	Description: Whether to reset the oscillator phase.
# 	Classes and Defaults: [('TuneupExperimentOptions', False)],
#
# return_legacy_results:
# 	Description: Alias for `include_results_metadata`. Deprecated.
# 	Classes and Defaults: [('RunExperimentOptions', False)],
#
# save_figures:
# 	Description: Whether to save the figures.
# 	Classes and Defaults: [('PlotRawDataOptions', True), ('PlotPopulationOptions', True)],
#
# transition:
# 	Description: Transition to perform the experiment on. May be any transition supported by the quantum operations.
# 	Classes and Defaults: [('TuneupExperimentOptions', 'ge'), ('ExtractQubitParametersTransitionOptions', 'ge'), ('PlotPopulationOptions', 'ge')],
#
# update:
# 	Description: Whether to update the setup based on the results from the analysis.
# 	Classes and Defaults: [('TuneUpWorkflowOptions', False)],
#
# use_cal_traces:
# 	Description: Whether to include calibration traces in the experiment.
# 	Classes and Defaults: [('TuneupExperimentOptions', True), ('CalculateQubitPopulationOptions', True), ('PlotRawDataOptions', True)],

# %%
from laboneq_applications.experiments import amplitude_fine
q = qubits[4]
temporary_parameters = q.parameters.copy()

#######################################################################
repetitions =np.arange(1,50)
#######################################################################
options = amplitude_fine.experiment_workflow_x180.options()
options.update(True)
options.use_cal_traces(False)
options.do_pca(False)

#print(workflow.show_fields(options))

###################################################################
error_amp = amplitude_fine.experiment_workflow_x180(
    session=session,
    qpu=qpu,
    qubits=q,
    repetitions=repetitions,
    temporary_parameters={q.uid : temporary_parameters},
    options=options
)

error_amp_result = error_amp.run()
#qubit_spec_compiled = session.compile(amplitude_rabi.create_experiment(qpu=qpu,qubit=q,amplitudes=amplitudes, options=options))
print(error_amp_result.tasks['analysis_workflow'].output)
# Out:
# [2025.09.04 21:35:59.979] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:35:59.980] INFO      Workflow 'experiment_workflow_x180': execution started at 2025-09-04
# [2025.09.04 21:35:59.980] INFO      12:35:59.979321Z
# [2025.09.04 21:35:59.980] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:35:59.982] WARNING Type <class 'dict'> not supported by the serializer [name: experiment_workflow_x180.input.temporary_parameters].
# [2025.09.04 21:35:59.990] INFO    Task 'temporary_qpu': started at 2025-09-04 12:35:59.990541Z
# [2025.09.04 21:35:59.991] WARNING Type <class 'dict'> not supported by the serializer [name: temporary_qpu.input.temporary_parameters].
# [2025.09.04 21:35:59.992] INFO    Task 'temporary_qpu': ended at 2025-09-04 12:35:59.991927Z
# [2025.09.04 21:35:59.994] INFO    Task 'temporary_quantum_elements_from_qpu': started at 2025-09-04
# [2025.09.04 21:35:59.994] INFO    12:35:59.994049Z
# [2025.09.04 21:35:59.995] INFO    Task 'temporary_quantum_elements_from_qpu': ended at 2025-09-04 12:35:59.995014Z
# [2025.09.04 21:35:59.996] INFO    Task 'create_experiment': started at 2025-09-04 12:35:59.996347Z
# [2025.09.04 21:36:00.012] INFO    Task 'create_experiment': ended at 2025-09-04 12:36:00.012214Z
# [2025.09.04 21:36:00.019] INFO    Task 'compile_experiment': started at 2025-09-04 12:36:00.019480Z
# [2025.09.04 21:36:00.027] INFO    Resolved modulation type of oscillator 'q4_readout_acquire_osc' on signal 'q4/acquire' to SOFTWARE
# [2025.09.04 21:36:00.027] INFO    Resolved modulation type of oscillator 'q4_drive_ge_osc' on signal 'q4/drive' to HARDWARE
# [2025.09.04 21:36:00.028] INFO    Starting LabOne Q Compiler run...
# [2025.09.04 21:36:00.048] INFO    Schedule completed. [0.016 s]
# [2025.09.04 21:36:00.077] INFO    Code generation completed for all AWGs. [0.029 s]
# [2025.09.04 21:36:00.078] INFO    Completed compilation step 1 of 1. [0.046 s]
# [2025.09.04 21:36:00.080] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:36:00.080] INFO      Device              AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2025.09.04 21:36:00.081] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:36:00.081] INFO      SHFQC_DEV12576        0        152            0           1      8000
# [2025.09.04 21:36:00.081] INFO      SHFQC_DEV12576_sg     4        251            3           1       256
# [2025.09.04 21:36:00.081] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:36:00.081] INFO      TOTAL                          403            3                  8256
# [2025.09.04 21:36:00.082] INFO     ───────────────────────────────────────────────────────────────────────
# [2025.09.04 21:36:00.087] INFO    Finished LabOne Q Compiler run.
# [2025.09.04 21:36:00.088] INFO    Task 'compile_experiment': ended at 2025-09-04 12:36:00.088080Z
# [2025.09.04 21:36:00.107] INFO    Task 'run_experiment': started at 2025-09-04 12:36:00.106862Z
# [2025.09.04 21:36:00.108] INFO    Connecting to data server at 10.172.11.217:8004
# [2025.09.04 21:36:00.113] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 10.172.11.217:8004
# [2025.09.04 21:36:00.116] INFO    Configuring the device setup
# [2025.09.04 21:36:00.122] INFO    The device setup is configured
# [2025.09.04 21:36:00.365] INFO    Starting near-time execution...
# [2025.09.04 21:36:01.629] INFO    Finished near-time execution.
# [2025.09.04 21:36:01.676] INFO    Task 'run_experiment': ended at 2025-09-04 12:36:01.675772Z
# [2025.09.04 21:36:01.677] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:36:01.678] INFO      Workflow 'analysis_workflow': execution started at 2025-09-04
# [2025.09.04 21:36:01.678] INFO      12:36:01.677619Z
# [2025.09.04 21:36:01.679] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:36:01.681] INFO    Task 'calculate_qubit_population': started at 2025-09-04 12:36:01.681576Z
# [2025.09.04 21:36:01.682] INFO    Task 'calculate_qubit_population': ended at 2025-09-04 12:36:01.682772Z
# [2025.09.04 21:36:01.683] WARNING Type <class 'dict'> not supported by the serializer [name: calculate_qubit_population.output.q4].
# [2025.09.04 21:36:01.683] INFO    Task 'fit_data': started at 2025-09-04 12:36:01.683602Z
# [2025.09.04 21:36:01.683] WARNING Type <class 'dict'> not supported by the serializer [name: fit_data.input.processed_data_dict].
# [2025.09.04 21:36:01.686] INFO    Task 'fit_data': ended at 2025-09-04 12:36:01.686397Z
# [2025.09.04 21:36:01.686] WARNING Type <class 'lmfit.model.ModelResult'> not supported by the serializer [name: fit_data.output.q4].
# [2025.09.04 21:36:01.687] INFO    Task 'process_fit_results': started at 2025-09-04 12:36:01.687166Z
# [2025.09.04 21:36:01.687] WARNING Type <class 'dict'> not supported by the serializer [name: process_fit_results.input.fit_results].
# [2025.09.04 21:36:01.688] INFO    Task 'process_fit_results': ended at 2025-09-04 12:36:01.688223Z
# [2025.09.04 21:36:01.688] WARNING Type <class 'dict'> not supported by the serializer [name: process_fit_results.output.q4].
# [2025.09.04 21:36:01.689] INFO    Task 'extract_qubit_parameters': started at 2025-09-04 12:36:01.688854Z
# [2025.09.04 21:36:01.689] WARNING Type <class 'dict'> not supported by the serializer [name: extract_qubit_parameters.input.fit_results].
# [2025.09.04 21:36:01.689] WARNING Type <class 'dict'> not supported by the serializer [name: extract_qubit_parameters.input.processed_fit_results].
# [2025.09.04 21:36:01.690] INFO    Task 'extract_qubit_parameters': ended at 2025-09-04 12:36:01.690504Z
# [2025.09.04 21:36:01.690] WARNING Type <class 'dict'> not supported by the serializer [name: extract_qubit_parameters.output.new_parameter_values].
# [2025.09.04 21:36:01.691] INFO    Task 'xaxis_label': started at 2025-09-04 12:36:01.691154Z
# [2025.09.04 21:36:01.691] INFO    Task 'xaxis_label': ended at 2025-09-04 12:36:01.691546Z
# [2025.09.04 21:36:01.692] INFO    Task 'plot_raw_complex_data_1d': started at 2025-09-04 12:36:01.691912Z
# [2025.09.04 21:36:01.701] INFO    Artifact: 'Raw_data_q4' of type 'Figure' logged at 2025-09-04 12:36:01.701541Z
# [2025.09.04 21:36:01.783] INFO    Task 'plot_raw_complex_data_1d': ended at 2025-09-04 12:36:01.782824Z
# [2025.09.04 21:36:01.783] INFO    Task 'plot_population': started at 2025-09-04 12:36:01.783694Z
# [2025.09.04 21:36:01.784] WARNING Type <class 'dict'> not supported by the serializer [name: plot_population.input.processed_data_dict].
# [2025.09.04 21:36:01.784] WARNING Type <class 'dict'> not supported by the serializer [name: plot_population.input.fit_results].
# [2025.09.04 21:36:01.784] WARNING Type <class 'dict'> not supported by the serializer [name: plot_population.input.processed_fit_results].
# [2025.09.04 21:36:01.784] WARNING Type <class 'dict'> not supported by the serializer [name: plot_population.input.qubit_parameters].
# [2025.09.04 21:36:01.790] INFO    Artifact: 'Amplitude_Fine_q4' of type 'Figure' logged at 2025-09-04
# [2025.09.04 21:36:01.790] INFO    12:36:01.790319Z
# [2025.09.04 21:36:01.848] INFO    Task 'plot_population': ended at 2025-09-04 12:36:01.848658Z
# [2025.09.04 21:36:01.849] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:36:01.849] INFO      Workflow 'analysis_workflow': execution ended at 2025-09-04 12:36:01.849467Z
# [2025.09.04 21:36:01.850] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:36:01.850] WARNING Type <class 'dict'> not supported by the serializer [name: analysis_workflow.output.new_parameter_values].
# [2025.09.04 21:36:01.850] INFO    Task 'update_qubits': started at 2025-09-04 12:36:01.850839Z
# [2025.09.04 21:36:01.851] WARNING Type <class 'dict'> not supported by the serializer [name: update_qubits.input.qubit_parameters].
# [2025.09.04 21:36:01.851] INFO    Task 'update_qubits': ended at 2025-09-04 12:36:01.851675Z
# [2025.09.04 21:36:01.852] INFO     ──────────────────────────────────────────────────────────────────────────────
# [2025.09.04 21:36:01.852] INFO      Workflow 'experiment_workflow_x180': execution ended at 2025-09-04
# [2025.09.04 21:36:01.853] INFO      12:36:01.852164Z
# [2025.09.04 21:36:01.853] INFO     ──────────────────────────────────────────────────────────────────────────────
# {'old_parameter_values': {'q4': {'ge_drive_amplitude_pi': 0.2618613242958965}}, 'new_parameter_values': {'q4': {'ge_drive_amplitude_pi': 0.26119502690647023+/-0.0008981541839604016}}}

# %% [markdown]
# # Basic Readout optimization
# Here we optimize SNR via
#
# * `readout_length`
# * `readout-amplitude`
#
# * `readout_integration_length`
# * `readout_integration_delay`
# * `readout_integration_weight`

# %%
from experiments import dispersive_shift

# %%
from experiments import time_traces

# %%
from experiments import signal_propagation_delay

# %% [markdown]
# # Save Qubit Parameters

# %%
from helper import load_qubit_parameters, save_qubit_parameters
save_qubit_parameters(qubits={ qubit.uid : qubit for qubit in qubits}, save_folder="./qubit_parameters", filename="KRISS")
